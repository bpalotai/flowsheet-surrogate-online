# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_excel('../02_Base_Surrogate_Training/Adaptive_train_data.xlsx', index_col=0)
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'surrogate', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/AdaptivedatFNN/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 21:27:13 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 21:27:13 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/AdaptivedatFNN/sklearnann.joblib
# [INFO] 21:27:13 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 21:27:16 - CalibrationWorkflow:
# ============================================================
# [INFO] 21:27:16 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 21:27:16 - CalibrationWorkflow: ============================================================
#
# [INFO] 21:27:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 21:27:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:16 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.01146311158719026, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:27:16 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.445887 > threshold: 0.1
# [INFO] 21:27:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:16 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:27:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:22 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.01349766682404266, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0003988716953401774, 'E2FOULING': 0.0005293447900512528}
# [INFO] 21:27:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.013498 < threshold 0.100000
# [INFO] 21:27:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 21:27:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:23 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.012807674933113678, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:27:23 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.321249 > threshold: 0.1
# [INFO] 21:27:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:23 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:27:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:30 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.06548641590295982, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0003425211390128326, 'E2FOULING': 0.0005938693712867844}
# [INFO] 21:27:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.065486 < threshold 0.100000
# [INFO] 21:27:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:30 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 21:27:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:31 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.02859908495961344, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:27:31 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.299507 > threshold: 0.1
# [INFO] 21:27:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:31 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:27:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:37 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.023020934642913493, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00036558098844951615, 'E2FOULING': 0.0004893555702069037}
# [INFO] 21:27:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.023021 < threshold 0.100000
# [INFO] 21:27:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 21:27:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:37 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.011260551073231683, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0003245001675423048, 'E2FOULING': 0.00025}
# [INFO] 21:27:37 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.197039 > threshold: 0.1
# [INFO] 21:27:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:37 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:27:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:49 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.04890724890414724, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0004791972845689796, 'E2FOULING': 0.0004941388739122298}
# [INFO] 21:27:49 - CalibrationWorkflow: Working point is accurate enough with cost: 0.048907 < threshold 0.100000
# [INFO] 21:27:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:49 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 21:27:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:49 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.010175259890126161, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:27:49 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.289587 > threshold: 0.1
# [INFO] 21:27:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:49 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:27:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:59 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.04671004322429988, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00033956520073513376, 'E2FOULING': 0.0005946902555838064}
# [INFO] 21:27:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.046710 < threshold 0.100000
# [INFO] 21:27:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:27:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 21:27:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:00 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.015635463286460018, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:28:00 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.323109 > threshold: 0.1
# [INFO] 21:28:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:00 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:28:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:06 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.02576368056781994, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00035396538653051726, 'E2FOULING': 0.0005027512988475233}
# [INFO] 21:28:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.025764 < threshold 0.100000
# [INFO] 21:28:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 21:28:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:06 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.010921814026340055, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:28:06 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.258464 > threshold: 0.1
# [INFO] 21:28:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:06 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:28:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:14 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.07020733112245636, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00038302031104017314, 'E2FOULING': 0.0005602656408019461}
# [INFO] 21:28:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.070207 < threshold 0.100000
# [INFO] 21:28:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 21:28:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:14 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.1125635173806012e-05, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.00036167488099838474, 'E2FOULING': 0.00025}
# [INFO] 21:28:14 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.131847 > threshold: 0.1
# [INFO] 21:28:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:14 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:28:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:21 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.07799507103512679, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.00040661323579121176, 'E2FOULING': 0.0006133774759519894}
# [INFO] 21:28:21 - CalibrationWorkflow: Working point is accurate enough with cost: 0.077995 < threshold 0.100000
# [INFO] 21:28:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 21:28:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:22 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.029741282272107802, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:28:22 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.311560 > threshold: 0.1
# [INFO] 21:28:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:22 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:28:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:37 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 0.05589321205049437, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00042752827875793724, 'E2FOULING': 0.0004709490452171542}
# [INFO] 21:28:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.055893 < threshold 0.100000
# [INFO] 21:28:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 21:28:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:37 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.012574019932464861, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:28:37 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.471263 > threshold: 0.1
# [INFO] 21:28:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:37 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:28:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:48 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.04830267212083268, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00039283799231451587, 'E2FOULING': 0.0005812042225455911}
# [INFO] 21:28:48 - CalibrationWorkflow: Working point is accurate enough with cost: 0.048303 < threshold 0.100000
# [INFO] 21:28:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 21:28:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:48 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.006984946398998073, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00030845867830485424, 'E2FOULING': 0.0002753516243315644}
# [INFO] 21:28:48 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.168794 > threshold: 0.1
# [INFO] 21:28:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:48 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:28:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:57 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.08138030066782297, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00035986845423789085, 'E2FOULING': 0.0006310838370673843}
# [INFO] 21:28:57 - CalibrationWorkflow: Working point is accurate enough with cost: 0.081380 < threshold 0.100000
# [INFO] 21:28:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 21:28:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:57 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 8.503630883277373e-06, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0003403885015046182, 'E2FOULING': 0.00025}
# [INFO] 21:28:57 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.134872 > threshold: 0.1
# [INFO] 21:28:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:28:57 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:28:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:09 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.07745297332501054, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0003221891025389351, 'E2FOULING': 0.0005693035523170561}
# [INFO] 21:29:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.077453 < threshold 0.100000
# [INFO] 21:29:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 21:29:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:09 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 6.234004992709742e-06, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0003552836357945835, 'E2FOULING': 0.00025}
# [INFO] 21:29:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.091905 < threshold 0.100000
# [INFO] 21:29:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 21:29:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:09 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.00815917528062695, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:29:09 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.296656 > threshold: 0.1
# [INFO] 21:29:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:09 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:29:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:17 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.01523223229431914, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00036586953060625853, 'E2FOULING': 0.0005266297364603684}
# [INFO] 21:29:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.015232 < threshold 0.100000
# [INFO] 21:29:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 21:29:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:17 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.8141985344047814e-05, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.000467103239751717, 'E2FOULING': 0.00027486292182123063}
# [INFO] 21:29:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.047698 < threshold 0.100000
# [INFO] 21:29:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 21:29:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:18 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.008382616822459747, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0002695521806548855, 'E2FOULING': 0.00025}
# [INFO] 21:29:18 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.221685 > threshold: 0.1
# [INFO] 21:29:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:18 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:29:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:27 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.007592319068445928, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0003736809548787476, 'E2FOULING': 0.00045817070944411515}
# [INFO] 21:29:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.007592 < threshold 0.100000
# [INFO] 21:29:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 21:29:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:28 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.007516804964170348, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:29:28 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.292389 > threshold: 0.1
# [INFO] 21:29:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:28 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:29:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:36 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.0794595945568284, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0003507446273570889, 'E2FOULING': 0.0006044340622734835}
# [INFO] 21:29:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.079460 < threshold 0.100000
# [INFO] 21:29:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 21:29:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:36 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 5.933759108949057e-06, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.00030473522133411953, 'E2FOULING': 0.0002836178102965438}
# [INFO] 21:29:36 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.114060 > threshold: 0.1
# [INFO] 21:29:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:36 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:29:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:42 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.0567860144468648, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.000399442973870967, 'E2FOULING': 0.0005975669142791924}
# [INFO] 21:29:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.056786 < threshold 0.100000
# [INFO] 21:29:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 21:29:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:42 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 6.020435958247963e-06, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.0003216758719649064, 'E2FOULING': 0.000310541528171502}
# [INFO] 21:29:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.062310 < threshold 0.100000
# [INFO] 21:29:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 21:29:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:42 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 8.4470841059695e-06, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:29:42 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.228349 > threshold: 0.1
# [INFO] 21:29:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:42 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:29:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:53 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.07041055498891337, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00030635408753911143, 'E2FOULING': 0.0005772113937044662}
# [INFO] 21:29:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.070411 < threshold 0.100000
# [INFO] 21:29:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 21:29:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:53 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.007460487130198543, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0003622620815981586, 'E2FOULING': 0.00034336770775003877}
# [INFO] 21:29:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.014357 < threshold 0.100000
# [INFO] 21:29:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 21:29:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:53 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.0581099470174569e-05, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.00033922335185051974, 'E2FOULING': 0.00025}
# [INFO] 21:29:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.091613 < threshold 0.100000
# [INFO] 21:29:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 21:29:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:53 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.2247510015354549e-05, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.000375182397851648, 'E2FOULING': 0.00025}
# [INFO] 21:29:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.078195 < threshold 0.100000
# [INFO] 21:29:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 21:29:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:53 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 5.551600165627911e-06, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.0003929304169434879, 'E2FOULING': 0.00027301571224138885}
# [INFO] 21:29:54 - CalibrationWorkflow: Working point is accurate enough with cost: 0.065692 < threshold 0.100000
# [INFO] 21:29:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:54 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 21:29:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:54 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 1.0557631404173987e-05, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0003798467253276125, 'E2FOULING': 0.00025}
# [INFO] 21:29:54 - CalibrationWorkflow: Working point is accurate enough with cost: 0.082713 < threshold 0.100000
# [INFO] 21:29:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:54 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 21:29:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:54 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.3936269866747008e-05, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:29:54 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.217606 > threshold: 0.1
# [INFO] 21:29:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:29:54 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:29:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:05 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.04578893272282564, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.00033330820141281344, 'E2FOULING': 0.00058141501400258}
# [INFO] 21:30:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.045789 < threshold 0.100000
# [INFO] 21:30:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 21:30:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:05 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 7.572655413871304e-06, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.00039507521240464015, 'E2FOULING': 0.00025}
# [INFO] 21:30:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.067955 < threshold 0.100000
# [INFO] 21:30:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 21:30:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:05 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.4034362453690405e-05, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.00031393851521435695, 'E2FOULING': 0.0002958884943388551}
# [INFO] 21:30:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.065699 < threshold 0.100000
# [INFO] 21:30:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 21:30:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:05 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.0974013718066488e-05, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.00041756983188670797, 'E2FOULING': 0.0002769543485215161}
# [INFO] 21:30:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.043087 < threshold 0.100000
# [INFO] 21:30:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 29 of 529.
# [INFO] 21:30:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:06 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.4249446323948632e-05, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:06 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.207062 > threshold: 0.1
# [INFO] 21:30:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:06 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:30:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:11 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.0589147119845554, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.00029934988882473275, 'E2FOULING': 0.0005958573510976015}
# [INFO] 21:30:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.058915 < threshold 0.100000
# [INFO] 21:30:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 30 of 529.
# [INFO] 21:30:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:11 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.30968216543006233, values: {'FEED1MASSFLOW': 18170.33282487203, 'FEED1TEMP': 24.88142490999688, 'PROD1MASSFLOW': 45110.96621847873, 'PROD1TEMP': 115.0679318499356, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 21:30:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 31 of 529.
# [INFO] 21:30:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:11 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.38139483485806086, values: {'FEED1MASSFLOW': 18607.84387976851, 'FEED1TEMP': 25.14488217461214, 'PROD1MASSFLOW': 43738.61199857389, 'PROD1TEMP': 115.3747174316839, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 21:30:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 32 of 529.
# [INFO] 21:30:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:12 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.4240891905045856, values: {'FEED1MASSFLOW': 19115.08117402765, 'FEED1TEMP': 24.77391698651811, 'PROD1MASSFLOW': 42751.55908633373, 'PROD1TEMP': 115.3524481338415, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 21:30:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 33 of 529.
# [INFO] 21:30:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:12 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.33677281093421096, values: {'FEED1MASSFLOW': 19418.03437168451, 'FEED1TEMP': 25.0300579250388, 'PROD1MASSFLOW': 43087.88928120025, 'PROD1TEMP': 114.4650169900805, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 21:30:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 34 of 529.
# [INFO] 21:30:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:12 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.3580465048071831, values: {'FEED1MASSFLOW': 19996.37302723919, 'FEED1TEMP': 25.05396733167793, 'PROD1MASSFLOW': 39075.45922402187, 'PROD1TEMP': 115.4384103153362, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 21:30:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 35 of 529.
# [INFO] 21:30:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:13 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.33538120758082146, values: {'FEED1MASSFLOW': 20114.96473047106, 'FEED1TEMP': 24.8676559665023, 'PROD1MASSFLOW': 40171.91798417241, 'PROD1TEMP': 115.7924017721878, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 21:30:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 36 of 529.
# [INFO] 21:30:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:13 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.29930394401404387, values: {'FEED1MASSFLOW': 20464.74060999631, 'FEED1TEMP': 25.14479618506942, 'PROD1MASSFLOW': 39328.05034260821, 'PROD1TEMP': 115.7990352506138, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 21:30:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 37 of 529.
# [INFO] 21:30:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:13 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.3156213009963035, values: {'FEED1MASSFLOW': 20969.69452156387, 'FEED1TEMP': 25.25139017769914, 'PROD1MASSFLOW': 39239.44675475179, 'PROD1TEMP': 115.2266590735738, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 21:30:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 38 of 529.
# [INFO] 21:30:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:13 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.347377676238234, values: {'FEED1MASSFLOW': 21516.56747134487, 'FEED1TEMP': 25.01599682709554, 'PROD1MASSFLOW': 37569.24954175691, 'PROD1TEMP': 115.7682074791824, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 21:30:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 39 of 529.
# [INFO] 21:30:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:14 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.3916275857641144, values: {'FEED1MASSFLOW': 21885.72678255862, 'FEED1TEMP': 24.92770160919124, 'PROD1MASSFLOW': 36155.43092699922, 'PROD1TEMP': 115.2474249227753, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 21:30:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 40 of 529.
# [INFO] 21:30:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:14 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.3875011887334938, values: {'FEED1MASSFLOW': 22629.3343245605, 'FEED1TEMP': 24.93546075225073, 'PROD1MASSFLOW': 35951.0272805308, 'PROD1TEMP': 114.5619751637425, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 21:30:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 41 of 529.
# [INFO] 21:30:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:14 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.33264185685266723, values: {'FEED1MASSFLOW': 23052.81408141617, 'FEED1TEMP': 24.96979552398567, 'PROD1MASSFLOW': 35366.6433778873, 'PROD1TEMP': 114.8085323228307, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 21:30:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 42 of 529.
# [INFO] 21:30:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:15 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.3470083392106853, values: {'FEED1MASSFLOW': 23873.98895120752, 'FEED1TEMP': 24.64705546402934, 'PROD1MASSFLOW': 33606.38987270086, 'PROD1TEMP': 115.3910956750255, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 21:30:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 43 of 529.
# [INFO] 21:30:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:15 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.24465272136811905, values: {'FEED1MASSFLOW': 24085.05631312843, 'FEED1TEMP': 25.02029345511958, 'PROD1MASSFLOW': 32971.19764637543, 'PROD1TEMP': 114.4096466605709, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 21:30:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 44 of 529.
# [INFO] 21:30:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:15 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.2297759258425115, values: {'FEED1MASSFLOW': 24511.37433920987, 'FEED1TEMP': 25.15025757714137, 'PROD1MASSFLOW': 31438.14255483319, 'PROD1TEMP': 115.5269277385362, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 21:30:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 45 of 529.
# [INFO] 21:30:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:15 - CalibrationWorkflow: Treshold reached with 8 iteration, best cost: 0.04874946117648582, values: {'FEED1MASSFLOW': 24226.00532269698, 'FEED1TEMP': 24.88169880079636, 'PROD1MASSFLOW': 32240.80420031684, 'PROD1TEMP': 117.4063795109899, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:16 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.168981 > threshold: 0.1
# [INFO] 21:30:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:16 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:30:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:22 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.008472458370606461, values: {'FEED1MASSFLOW': 24226.00532269698, 'FEED1TEMP': 24.88169880079636, 'PROD1MASSFLOW': 32240.80420031684, 'PROD1TEMP': 117.4063795109899, 'E1FOULING': 0.0003463679591605542, 'E2FOULING': 0.0004896406702532364}
# [INFO] 21:30:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.008472 < threshold 0.100000
# [INFO] 21:30:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 46 of 529.
# [INFO] 21:30:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:23 - CalibrationWorkflow: Treshold reached with 28 iteration, best cost: 0.027847042329323453, values: {'FEED1MASSFLOW': 24185.81175407174, 'FEED1TEMP': 25.15256677443595, 'PROD1MASSFLOW': 33087.53564862187, 'PROD1TEMP': 114.7991019852639, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002663188160646086}
# [INFO] 21:30:23 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.201644 > threshold: 0.1
# [INFO] 21:30:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:23 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:30:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:35 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.0781627034077093, values: {'FEED1MASSFLOW': 24185.81175407174, 'FEED1TEMP': 25.15256677443595, 'PROD1MASSFLOW': 33087.53564862187, 'PROD1TEMP': 114.7991019852639, 'E1FOULING': 0.0006139506110299613, 'E2FOULING': 0.00027975450472151155}
# [INFO] 21:30:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.078163 < threshold 0.100000
# [INFO] 21:30:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 47 of 529.
# [INFO] 21:30:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:35 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.027993886629309468, values: {'FEED1MASSFLOW': 24367.98927160785, 'FEED1TEMP': 24.84838832565562, 'PROD1MASSFLOW': 31903.84913114287, 'PROD1TEMP': 116.9796772662115, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:30:35 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.227639 > threshold: 0.1
# [INFO] 21:30:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:30:35 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:30:35 - CalibrationWorkflow: ----------------------------------------
# ...
# [INFO] 21:54:35 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:54:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:54:44 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.05188329913514472, values: {'FEED1MASSFLOW': 13389.10627836312, 'FEED1TEMP': 20.00940520749543, 'PROD1MASSFLOW': 35184.59183121471, 'PROD1TEMP': 128.043630919933, 'E1FOULING': 0.000489062811667936, 'E2FOULING': 0.0006225944439455544}
# [INFO] 21:54:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.051883 < threshold 0.100000
# [INFO] 21:54:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:54:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 519 of 529.
# [INFO] 21:54:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:54:45 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 4.046491059171403e-06, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:54:45 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.337174 > threshold: 0.1
# [INFO] 21:54:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:54:45 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:54:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:54:51 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.0511691263543856, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.0005000750719709157, 'E2FOULING': 0.0006650312896405814}
# [INFO] 21:54:51 - CalibrationWorkflow: Working point is accurate enough with cost: 0.051169 < threshold 0.100000
# [INFO] 21:54:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:54:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 21:54:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:54:51 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.017121309831953088, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:54:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.065046 > threshold: 0.1
# [INFO] 21:54:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:54:51 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:54:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:00 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 7.0386219615797206e-06, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.0004810865080409341, 'E2FOULING': 0.000517265501423048}
# [INFO] 21:55:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000007 < threshold 0.100000
# [INFO] 21:55:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 21:55:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:00 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.04147791411164695, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:55:00 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.188020 > threshold: 0.1
# [INFO] 21:55:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:00 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:55:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:07 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.00977808421388216, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0005676764296099347, 'E2FOULING': 0.00045784601495370796}
# [INFO] 21:55:07 - CalibrationWorkflow: Working point is accurate enough with cost: 0.009778 < threshold 0.100000
# [INFO] 21:55:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:07 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 21:55:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:07 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 8.114602621170566e-06, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:55:08 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.132474 > threshold: 0.1
# [INFO] 21:55:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:08 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:55:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:14 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.07707870603847777, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005145909296798219, 'E2FOULING': 0.0006554626365757715}
# [INFO] 21:55:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.077079 < threshold 0.100000
# [INFO] 21:55:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 21:55:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:14 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.027262819325568278, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:55:14 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.271031 > threshold: 0.1
# [INFO] 21:55:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:14 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:55:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:20 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 7.733294899278254e-06, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0005460246549225668, 'E2FOULING': 0.00040183747185007745}
# [INFO] 21:55:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 21:55:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:20 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 21:55:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:21 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.020557871882001463, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:55:21 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.079417 > threshold: 0.1
# [INFO] 21:55:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:21 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:55:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:28 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.019108051447374885, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0004805286744532656, 'E2FOULING': 0.0005095662116832362}
# [INFO] 21:55:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.019108 < threshold 0.100000
# [INFO] 21:55:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 21:55:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:28 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.09528215584225334, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:55:28 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.757946 > threshold: 0.1
# [INFO] 21:55:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:28 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:55:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:37 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.050441246036707826, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00048578168453251294, 'E2FOULING': 0.000542091556447534}
# [INFO] 21:55:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.050441 < threshold 0.100000
# [INFO] 21:55:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 21:55:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:37 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.0514516507434789, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:55:37 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.917745 > threshold: 0.1
# [INFO] 21:55:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:37 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:55:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:43 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.07515448204762717, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.00048624097829399874, 'E2FOULING': 0.0006162348482316986}
# [INFO] 21:55:43 - CalibrationWorkflow: Working point is accurate enough with cost: 0.075154 < threshold 0.100000
# [INFO] 21:55:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 21:55:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:43 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.02660325272064238, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:55:43 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.845409 > threshold: 0.1
# [INFO] 21:55:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:43 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:55:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:51 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.07427957757507136, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0004924022372966116, 'E2FOULING': 0.0005966289633923514}
# [INFO] 21:55:51 - CalibrationWorkflow: Working point is accurate enough with cost: 0.074280 < threshold 0.100000
# [INFO] 21:55:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 21:55:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:51 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.008995697721568644, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:55:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.080815 > threshold: 0.1
# [INFO] 21:55:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:51 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:55:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:59 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.06357918469212037, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0004883699511924055, 'E2FOULING': 0.000638905901808976}
# [INFO] 21:55:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.063579 < threshold 0.100000
# [INFO] 21:55:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 21:55:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:59 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.01847344930464504, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:55:59 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.978513 > threshold: 0.1
# [INFO] 21:55:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:55:59 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 21:55:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:56:07 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.01257869487762658, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0004950376595534703, 'E2FOULING': 0.0005186169438311699}
# [INFO] 21:56:07 - CalibrationWorkflow: Working point is accurate enough with cost: 0.012579 < threshold 0.100000
# [INFO] 21:56:07 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/Surrogate_base/02_Calibration_static_FNN-BNN-low.xlsx')
# Out:
# [INFO] 21:56:07 - CalibrationWorkflow: Calibration results saved to ./Results/Surrogate_base/Calibration_result_FNN_BNN_with_direct.xlsx

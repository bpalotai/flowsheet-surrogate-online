# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_200.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodel/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 23:43:48 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 23:43:48 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodel/sklearnann.joblib
# [INFO] 23:43:48 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 23:43:48 - CalibrationWorkflow:
# ============================================================
# [INFO] 23:43:48 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 23:43:48 - CalibrationWorkflow: ============================================================
#
# [INFO] 23:43:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:43:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 23:43:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:43:49 - CalibrationWorkflow: Treshold reached with 29 iteration, best cost: 0.10627340257517832, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002695464195836319}
# [INFO] 23:43:49 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.448510 > threshold: 0.1
# [INFO] 23:43:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:43:49 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:43:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:44:26 - CalibrationWorkflow: Treshold reached with 23 iteration, best cost: 0.27124529514175605, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005599517388647488}
# [INFO] 23:44:26 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.271245 > threshold: 0.1
# [INFO] 23:44:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:44:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:44:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:44:26 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:44:26 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:44:26 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 23:44:26 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:44:26 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:44:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:44:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 23:44:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:44:27 - CalibrationWorkflow: Treshold reached with 32 iteration, best cost: 0.10176959637069673, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0003350875018243639, 'E2FOULING': 0.000260992980476035}
# [INFO] 23:44:27 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.103205 > threshold: 0.1
# [INFO] 23:44:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:44:27 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:44:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:44:49 - CalibrationWorkflow: Treshold reached with 12 iteration, best cost: 0.20500789899402627, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004559980728725837}
# [INFO] 23:44:49 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.205008 > threshold: 0.1
# [INFO] 23:44:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:44:49 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:44:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:44:49 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:44:49 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:44:49 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 23:44:49 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:44:49 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:44:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:44:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 23:44:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:44:50 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.08555733836423648, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 23:44:50 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.321750 > threshold: 0.1
# [INFO] 23:44:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:44:50 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:44:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:45:34 - CalibrationWorkflow: Treshold reached with 25 iteration, best cost: 0.19569897661450925, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025313700387219967, 'E2FOULING': 0.0004249108031608483}
# [INFO] 23:45:34 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.195699 > threshold: 0.1
# [INFO] 23:45:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:45:34 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:45:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:45:34 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:45:34 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:45:34 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 23:45:34 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:45:34 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:45:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:45:34 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 23:45:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:45:35 - CalibrationWorkflow: Treshold reached with 27 iteration, best cost: 0.04952679098202937, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00045880136943692414, 'E2FOULING': 0.00026159649436451927}
# [INFO] 23:45:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.056606 < threshold 0.100000
# [INFO] 23:45:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:45:35 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:45:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:45:35 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:45:35 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:45:35 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 23:45:35 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:45:35 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:45:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:45:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 23:45:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:45:36 - CalibrationWorkflow: Treshold reached with 22 iteration, best cost: 0.045796697980388774, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003881918572609381}
# [INFO] 23:45:36 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.179397 > threshold: 0.1
# [INFO] 23:45:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:45:36 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:45:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:46:09 - CalibrationWorkflow: Treshold reached with 19 iteration, best cost: 0.15289931875381899, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004895101065915332}
# [INFO] 23:46:10 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.152899 > threshold: 0.1
# [INFO] 23:46:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:46:10 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:46:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:46:10 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:46:10 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:46:10 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 23:46:10 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:46:10 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:46:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:46:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 23:46:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:46:11 - CalibrationWorkflow: Treshold reached with 28 iteration, best cost: 0.031019172148425977, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.0005055325477362993, 'E2FOULING': 0.00025907300540492403}
# [INFO] 23:46:11 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.123015 > threshold: 0.1
# [INFO] 23:46:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:46:11 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:46:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:46:59 - CalibrationWorkflow: Treshold reached with 29 iteration, best cost: 0.2240985059598279, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00025, 'E2FOULING': 0.00048403927557404716}
# [INFO] 23:46:59 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.224099 > threshold: 0.1
# [INFO] 23:46:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:46:59 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:46:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:46:59 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:46:59 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:46:59 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 23:46:59 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:46:59 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:47:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 23:47:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:00 - CalibrationWorkflow: Treshold reached with 28 iteration, best cost: 0.021778851547609255, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00038546242542177213, 'E2FOULING': 0.00033820750660079683}
# [INFO] 23:47:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 23:47:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:47:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:01 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:47:01 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:47:01 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 23:47:01 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:47:01 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:47:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 23:47:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:02 - CalibrationWorkflow: Obj Treshold reached with 16 iteration, best cost: 0.009715820959361963, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0007137626761538523, 'E2FOULING': 0.000274176392921444}
# [INFO] 23:47:02 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.328539 > threshold: 0.1
# [INFO] 23:47:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:02 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:47:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:10 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.016362981999819313, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.00045142717504823026, 'E2FOULING': 0.0004781536563683407}
# [INFO] 23:47:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.016363 < threshold 0.100000
# [INFO] 23:47:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:10 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:47:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:10 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:47:10 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:47:10 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 23:47:10 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:47:10 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:47:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 23:47:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:11 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 7.5315356668544184e-06, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.0005779594080004533, 'E2FOULING': 0.00025}
# [INFO] 23:47:11 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.170156 > threshold: 0.1
# [INFO] 23:47:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:11 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:47:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:38 - CalibrationWorkflow: Treshold reached with 16 iteration, best cost: 0.258968443426179, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00025, 'E2FOULING': 0.00037496594370563344}
# [INFO] 23:47:38 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.258968 > threshold: 0.1
# [INFO] 23:47:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:47:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:38 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:47:38 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:47:38 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 23:47:38 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:47:38 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:47:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 23:47:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:39 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 8.542734267007978e-06, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0005340399483169851, 'E2FOULING': 0.0005576338691274786}
# [INFO] 23:47:39 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.183630 > threshold: 0.1
# [INFO] 23:47:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:47:39 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:47:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:48:51 - CalibrationWorkflow: Treshold reached with 42 iteration, best cost: 0.17383740797627445, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0002912355015148152, 'E2FOULING': 0.0005163725921948785}
# [INFO] 23:48:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.173837 > threshold: 0.1
# [INFO] 23:48:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:48:51 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:48:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:48:51 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:48:51 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:48:51 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 23:48:51 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:48:51 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:48:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:48:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 23:48:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:48:51 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.1867356170647173e-05, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.0007419689621930919, 'E2FOULING': 0.00036807534906485026}
# [INFO] 23:48:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.468596 > threshold: 0.1
# [INFO] 23:48:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:48:51 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:48:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:49:25 - CalibrationWorkflow: Treshold reached with 19 iteration, best cost: 0.2579380174953871, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00025, 'E2FOULING': 0.00048147075457515167}
# [INFO] 23:49:25 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.257938 > threshold: 0.1
# [INFO] 23:49:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:49:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:49:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:49:25 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:49:25 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:49:25 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 23:49:25 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:49:25 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:49:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:49:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 23:49:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:49:25 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 3.4228858023369175e-07, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0007150863144434027, 'E2FOULING': 0.00046061624918352945}
# [INFO] 23:49:25 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.497614 > threshold: 0.1
# [INFO] 23:49:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:49:25 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:49:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:50:00 - CalibrationWorkflow: Obj Treshold reached with 20 iteration, best cost: 0.09704773652260729, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.00029702232731116827, 'E2FOULING': 0.0004634570455630658}
# [INFO] 23:50:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.097048 < threshold 0.100000
# [INFO] 23:50:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:50:00 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:50:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:50:00 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:50:00 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:50:00 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 23:50:00 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:50:00 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:50:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:50:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 23:50:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:50:01 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 1.4520896126039591e-05, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0007857406378792114, 'E2FOULING': 0.00034334181814153894}
# [INFO] 23:50:01 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.605073 > threshold: 0.1
# [INFO] 23:50:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:50:01 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:50:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:50:29 - CalibrationWorkflow: Treshold reached with 15 iteration, best cost: 0.21521780138237143, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004157767237914331}
# [INFO] 23:50:29 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.215218 > threshold: 0.1
# [INFO] 23:50:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:50:29 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:50:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:50:29 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:50:29 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:50:29 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 23:50:29 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:50:29 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:50:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:50:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 23:50:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:50:29 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 3.1821377682770782e-06, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.0006034300642040701, 'E2FOULING': 0.00048742358660621424}
# [INFO] 23:50:29 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.378269 > threshold: 0.1
# [INFO] 23:50:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:50:29 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:50:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:03 - CalibrationWorkflow: Treshold reached with 18 iteration, best cost: 0.1847194915758931, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00025, 'E2FOULING': 0.00046241406350049}
# [INFO] 23:51:03 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.184719 > threshold: 0.1
# [INFO] 23:51:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:03 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:51:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:03 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:51:03 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:51:03 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 23:51:03 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:51:03 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:51:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 23:51:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:03 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.009267222139582811, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.000886911934581126, 'E2FOULING': 0.00044574820272860706}
# [INFO] 23:51:03 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.551217 > threshold: 0.1
# [INFO] 23:51:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:03 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:51:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:13 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.05793667290155177, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0005233746756595431, 'E2FOULING': 0.00025}
# [INFO] 23:51:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.057937 < threshold 0.100000
# [INFO] 23:51:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:51:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:13 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:51:13 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:51:13 - CalibrationWorkflow: Self.model updated to online_v14
# [INFO] 23:51:13 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:51:13 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:51:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 23:51:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:13 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 1.1248555435335793e-05, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0006695057278609943, 'E2FOULING': 0.0004242506747542309}
# [INFO] 23:51:13 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.458789 > threshold: 0.1
# [INFO] 23:51:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:13 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:51:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:51 - CalibrationWorkflow: Treshold reached with 22 iteration, best cost: 0.20173952193953087, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004317596739054294}
# [INFO] 23:51:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.201740 > threshold: 0.1
# [INFO] 23:51:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:51 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:51:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:51 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:51:51 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:51:51 - CalibrationWorkflow: Self.model updated to online_v15
# [INFO] 23:51:51 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:51:51 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:51:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:52 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 23:51:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:52 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 0.0075134527634994185, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0007078677149178732, 'E2FOULING': 0.0004034763911695085}
# [INFO] 23:51:52 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.536900 > threshold: 0.1
# [INFO] 23:51:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:51:52 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:51:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:52:26 - CalibrationWorkflow: Treshold reached with 20 iteration, best cost: 0.2064021919457105, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004925418481476199}
# [INFO] 23:52:26 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.206402 > threshold: 0.1
# [INFO] 23:52:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:52:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:52:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:52:26 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:52:26 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:52:26 - CalibrationWorkflow: Self.model updated to online_v16
# [INFO] 23:52:26 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:52:26 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:52:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:52:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 23:52:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:52:27 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.399236324134536e-05, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.0006697341234528115, 'E2FOULING': 0.0005256349261270005}
# [INFO] 23:52:27 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.499279 > threshold: 0.1
# [INFO] 23:52:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:52:27 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:52:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:53:08 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.15581477046400646, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005059519191268947}
# [INFO] 23:53:08 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.155815 > threshold: 0.1
# [INFO] 23:53:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:53:08 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:53:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:53:08 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:53:08 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:53:08 - CalibrationWorkflow: Self.model updated to online_v17
# [INFO] 23:53:08 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:53:08 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:53:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:53:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 23:53:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:53:09 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.009020294531462943, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.0006082936156394305, 'E2FOULING': 0.0005071108341199841}
# [INFO] 23:53:09 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.361616 > threshold: 0.1
# [INFO] 23:53:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:53:09 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:53:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:54:00 - CalibrationWorkflow: Treshold reached with 30 iteration, best cost: 0.15844271796216683, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.00025003986734763953, 'E2FOULING': 0.000513113130190019}
# [INFO] 23:54:00 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.158443 > threshold: 0.1
# [INFO] 23:54:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:54:00 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:54:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:54:00 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:54:00 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:54:00 - CalibrationWorkflow: Self.model updated to online_v18
# [INFO] 23:54:00 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:54:00 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:54:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:54:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 23:54:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:54:01 - CalibrationWorkflow: Obj Treshold reached with 23 iteration, best cost: 0.009822793215441097, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.0006612251617870917, 'E2FOULING': 0.00041395988061281936}
# [INFO] 23:54:01 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.469312 > threshold: 0.1
# [INFO] 23:54:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:54:01 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:54:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:54:34 - CalibrationWorkflow: Treshold reached with 19 iteration, best cost: 0.13320054863464534, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.0002520420528197779, 'E2FOULING': 0.000456835050267767}
# [INFO] 23:54:34 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.133201 > threshold: 0.1
# [INFO] 23:54:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:54:34 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:54:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:54:34 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:54:34 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:54:34 - CalibrationWorkflow: Self.model updated to online_v19
# [INFO] 23:54:34 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:54:34 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:54:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:54:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 23:54:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:54:35 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.5949828791699593e-05, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0007294555352611587, 'E2FOULING': 0.00042853766380324045}
# [INFO] 23:54:35 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.523227 > threshold: 0.1
# [INFO] 23:54:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:54:35 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:54:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:55:22 - CalibrationWorkflow: Treshold reached with 28 iteration, best cost: 0.1756386398440914, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0002500224000357345, 'E2FOULING': 0.0004747211586256882}
# [INFO] 23:55:22 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.175639 > threshold: 0.1
# [INFO] 23:55:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:55:22 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:55:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:55:22 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:55:22 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:55:22 - CalibrationWorkflow: Self.model updated to online_v20
# [INFO] 23:55:22 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:55:22 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:55:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:55:23 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 23:55:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:55:23 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 0.0096960173431277, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0007831348777276359, 'E2FOULING': 0.0003458304800302732}
# [INFO] 23:55:23 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.464991 > threshold: 0.1
# [INFO] 23:55:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:55:23 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:55:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:55:47 - CalibrationWorkflow: Obj Treshold reached with 12 iteration, best cost: 0.08513271298449235, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0003389159976032489, 'E2FOULING': 0.000574917744785001}
# [INFO] 23:55:47 - CalibrationWorkflow: Working point is accurate enough with cost: 0.085133 < threshold 0.100000
# [INFO] 23:55:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:55:47 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:55:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:55:47 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:55:47 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:55:47 - CalibrationWorkflow: Self.model updated to online_v21
# [INFO] 23:55:47 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:55:47 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:55:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:55:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 23:55:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:55:48 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.8908869350964686e-05, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.0007158382128705964, 'E2FOULING': 0.00034007577294553463}
# [INFO] 23:55:48 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.398439 > threshold: 0.1
# [INFO] 23:55:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:55:48 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:55:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:56:25 - CalibrationWorkflow: Treshold reached with 20 iteration, best cost: 0.18021629781071363, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004603061979534281}
# [INFO] 23:56:25 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.180216 > threshold: 0.1
# [INFO] 23:56:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:56:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:56:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:56:25 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:56:25 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:56:25 - CalibrationWorkflow: Self.model updated to online_v22
# [INFO] 23:56:25 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:56:25 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:56:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:56:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 23:56:25 - CalibrationWorkflow: ----------------------------------------
# ...
# [INFO] 00:13:25 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 00:13:25 - CalibrationWorkflow: Self.model updated to online_v519
# [INFO] 00:13:25 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 00:13:25 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 00:13:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 00:13:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:26 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.1756128706561766e-06, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.00045424825505974446, 'E2FOULING': 0.00045517556281025705}
# [INFO] 00:13:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000017 < threshold 0.100000
# [INFO] 00:13:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 00:13:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:26 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 00:13:26 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 00:13:26 - CalibrationWorkflow: Self.model updated to online_v520
# [INFO] 00:13:26 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 00:13:26 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 00:13:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 00:13:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:26 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 2.2279617602455524e-05, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0005922670848796559, 'E2FOULING': 0.00025}
# [INFO] 00:13:26 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.177746 > threshold: 0.1
# [INFO] 00:13:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:26 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 00:13:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:34 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.007097147147996892, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0005518786468246158, 'E2FOULING': 0.00036257493728352315}
# [INFO] 00:13:34 - CalibrationWorkflow: Working point is accurate enough with cost: 0.007097 < threshold 0.100000
# [INFO] 00:13:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:34 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 00:13:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:34 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 00:13:34 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 00:13:34 - CalibrationWorkflow: Self.model updated to online_v521
# [INFO] 00:13:34 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 00:13:34 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 00:13:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 00:13:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:35 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 4.566444569590603e-06, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005720385109746708, 'E2FOULING': 0.0005713080621076871}
# [INFO] 00:13:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.055627 < threshold 0.100000
# [INFO] 00:13:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:35 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 00:13:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:35 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 00:13:35 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 00:13:35 - CalibrationWorkflow: Self.model updated to online_v522
# [INFO] 00:13:35 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 00:13:35 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 00:13:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 00:13:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:36 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 2.9111908019652217e-06, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.00056286669464951, 'E2FOULING': 0.0004474714611718938}
# [INFO] 00:13:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 00:13:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:36 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 00:13:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:36 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 00:13:36 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 00:13:36 - CalibrationWorkflow: Self.model updated to online_v523
# [INFO] 00:13:36 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 00:13:36 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 00:13:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 00:13:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:36 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.00786183738058251, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0006714513119684868, 'E2FOULING': 0.00048350587431968795}
# [INFO] 00:13:36 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.180650 > threshold: 0.1
# [INFO] 00:13:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:36 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 00:13:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:44 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.1951179628870605e-05, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.00048802485073085603, 'E2FOULING': 0.000466973741249832}
# [INFO] 00:13:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 00:13:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 00:13:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:44 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 00:13:44 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 00:13:44 - CalibrationWorkflow: Self.model updated to online_v524
# [INFO] 00:13:44 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 00:13:44 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 00:13:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 00:13:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:45 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 3.933538200440194e-06, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.0003901676750357782, 'E2FOULING': 0.0003701605112351815}
# [INFO] 00:13:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.065718 < threshold 0.100000
# [INFO] 00:13:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:45 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 00:13:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:45 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 00:13:45 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 00:13:45 - CalibrationWorkflow: Self.model updated to online_v525
# [INFO] 00:13:45 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 00:13:45 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 00:13:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 00:13:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:45 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.6341802057308015e-05, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0005252720772169536, 'E2FOULING': 0.0004918860152928963}
# [INFO] 00:13:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.018553 < threshold 0.100000
# [INFO] 00:13:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:45 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 00:13:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:45 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 00:13:45 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 00:13:45 - CalibrationWorkflow: Self.model updated to online_v526
# [INFO] 00:13:46 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 00:13:46 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 00:13:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 00:13:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:47 - CalibrationWorkflow: Obj Treshold reached with 28 iteration, best cost: 0.009842993047589637, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0005584897758446069, 'E2FOULING': 0.00033310393337683607}
# [INFO] 00:13:47 - CalibrationWorkflow: Working point is accurate enough with cost: 0.075591 < threshold 0.100000
# [INFO] 00:13:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:47 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 00:13:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:47 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 00:13:47 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 00:13:47 - CalibrationWorkflow: Self.model updated to online_v527
# [INFO] 00:13:47 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 00:13:47 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 00:13:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 00:13:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:48 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 3.4802546147579207e-06, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.000581147122827479, 'E2FOULING': 0.000523040790563515}
# [INFO] 00:13:48 - CalibrationWorkflow: Working point is accurate enough with cost: 0.071492 < threshold 0.100000
# [INFO] 00:13:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:48 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 00:13:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:48 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 00:13:48 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 00:13:48 - CalibrationWorkflow: Self.model updated to online_v528
# [INFO] 00:13:48 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 00:13:48 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 00:13:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 00:13:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:49 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 9.136210011779553e-06, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0005897170395620805, 'E2FOULING': 0.00044547831029351345}
# [INFO] 00:13:49 - CalibrationWorkflow: Working point is accurate enough with cost: 0.059714 < threshold 0.100000
# [INFO] 00:13:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:49 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 00:13:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 00:13:49 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 00:13:49 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 00:13:49 - CalibrationWorkflow: Self.model updated to online_v529
# [INFO] 00:13:49 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 00:13:49 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 00:13:49 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/06_Calibration_Online_FNN-low_always-one-noreplay.xlsx')
# Out:
# [INFO] 00:14:04 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_always-one-noreplay.xlsx

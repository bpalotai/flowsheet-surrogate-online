# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_200.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodel/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.25, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 15:58:48 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 15:58:48 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodel/sklearnann.joblib
# [INFO] 15:58:48 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.25, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 15:58:48 - CalibrationWorkflow:
# ============================================================
# [INFO] 15:58:48 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 15:58:48 - CalibrationWorkflow: ============================================================
#
# [INFO] 15:58:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:58:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 15:58:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:58:49 - CalibrationWorkflow: Treshold reached with 25 iteration, best cost: 0.1130845900004153, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002690628289903498}
# [INFO] 15:58:49 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.450323 > threshold: 0.1
# [INFO] 15:58:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:58:49 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:58:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:00:14 - CalibrationWorkflow: Treshold reached with 43 iteration, best cost: 1.0043181451473533, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0003329565891214803, 'E2FOULING': 0.002053128345800697}
# [INFO] 16:00:14 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.004318 > threshold: 0.1
# [INFO] 16:00:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:00:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:00:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:00:14 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:00:14 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:00:14 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 16:00:14 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:00:14 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:00:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:00:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 16:00:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:00:16 - CalibrationWorkflow: Treshold reached with 29 iteration, best cost: 0.11531021720009574, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0003213731972567762, 'E2FOULING': 0.00025}
# [INFO] 16:00:16 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.149569 > threshold: 0.1
# [INFO] 16:00:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:00:16 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:00:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:01:38 - CalibrationWorkflow: Treshold reached with 41 iteration, best cost: 1.1022313396819712, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00030488407555125953, 'E2FOULING': 0.0022691013414648862}
# [INFO] 16:01:38 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.102231 > threshold: 0.1
# [INFO] 16:01:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:01:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:01:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:01:38 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:01:38 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:01:38 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 16:01:38 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:01:38 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:01:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:01:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 16:01:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:01:39 - CalibrationWorkflow: Treshold reached with 9 iteration, best cost: 0.11026356842428128, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 16:01:39 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.324633 > threshold: 0.1
# [INFO] 16:01:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:01:39 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:01:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:02:47 - CalibrationWorkflow: Treshold reached with 33 iteration, best cost: 1.4140802250624782, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00029684359896533, 'E2FOULING': 0.002544796741673957}
# [INFO] 16:02:47 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.414080 > threshold: 0.1
# [INFO] 16:02:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:02:47 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:02:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:02:47 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:02:47 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:02:47 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 16:02:47 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:02:47 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:02:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:02:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 16:02:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:02:48 - CalibrationWorkflow: Treshold reached with 19 iteration, best cost: 0.08984806398534297, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002769966593740988}
# [INFO] 16:02:48 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.467959 > threshold: 0.1
# [INFO] 16:02:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:02:48 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:02:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:04:20 - CalibrationWorkflow: Treshold reached with 45 iteration, best cost: 1.0818774730245766, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0003466280919485591, 'E2FOULING': 0.0019501119675229813}
# [INFO] 16:04:20 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.081877 > threshold: 0.1
# [INFO] 16:04:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:04:20 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:04:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:04:20 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:04:20 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:04:20 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 16:04:20 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:04:20 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:04:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:04:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 16:04:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:04:22 - CalibrationWorkflow: Treshold reached with 18 iteration, best cost: 0.09290098905618721, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002837837584876166}
# [INFO] 16:04:22 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.265543 > threshold: 0.1
# [INFO] 16:04:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:04:22 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:04:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:05:44 - CalibrationWorkflow: Treshold reached with 41 iteration, best cost: 1.0914841610754569, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00026785833032477637, 'E2FOULING': 0.0024832087271433284}
# [INFO] 16:05:44 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.091484 > threshold: 0.1
# [INFO] 16:05:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:05:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:05:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:05:44 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:05:44 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:05:44 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 16:05:44 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:05:44 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:05:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:05:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 16:05:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:05:45 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.0957143796028106, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 16:05:45 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.347325 > threshold: 0.1
# [INFO] 16:05:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:05:45 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:05:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:07:12 - CalibrationWorkflow: Treshold reached with 43 iteration, best cost: 1.2047372637747014, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.0003027547753837899, 'E2FOULING': 0.0023269274045713277}
# [INFO] 16:07:12 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.204737 > threshold: 0.1
# [INFO] 16:07:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:07:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:07:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:07:12 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:07:12 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:07:12 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 16:07:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:07:12 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:07:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:07:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 16:07:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:07:13 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.09199577205606606, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 16:07:13 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.285975 > threshold: 0.1
# [INFO] 16:07:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:07:13 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:07:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:08:34 - CalibrationWorkflow: Treshold reached with 41 iteration, best cost: 1.1884517569673565, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.0002955247351165897, 'E2FOULING': 0.0022618891154240813}
# [INFO] 16:08:34 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.188452 > threshold: 0.1
# [INFO] 16:08:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:08:34 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:08:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:08:34 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:08:34 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:08:34 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 16:08:34 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:08:34 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:08:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:08:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 16:08:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:08:36 - CalibrationWorkflow: Treshold reached with 22 iteration, best cost: 0.08115773558160898, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0003312601375435308, 'E2FOULING': 0.0003301295788766307}
# [INFO] 16:08:36 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.116380 > threshold: 0.1
# [INFO] 16:08:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:08:36 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:08:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:09:59 - CalibrationWorkflow: Treshold reached with 41 iteration, best cost: 0.8820308364880862, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.00032899493634588027, 'E2FOULING': 0.001760650781504898}
# [INFO] 16:09:59 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.882031 > threshold: 0.1
# [INFO] 16:09:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:09:59 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:09:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:09:59 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:09:59 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:09:59 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 16:09:59 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:09:59 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:10:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:10:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 16:10:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:10:00 - CalibrationWorkflow: Treshold reached with 9 iteration, best cost: 0.07848127050494383, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 16:10:00 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.345498 > threshold: 0.1
# [INFO] 16:10:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:10:00 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:10:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:11:41 - CalibrationWorkflow: Treshold reached with 50 iteration, best cost: 1.0709143865363415, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.0003557016400239505, 'E2FOULING': 0.0016503158004739535}
# [INFO] 16:11:41 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.070914 > threshold: 0.1
# [INFO] 16:11:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:11:41 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:11:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:11:41 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:11:41 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:11:41 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 16:11:41 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:11:41 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:11:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:11:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 16:11:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:11:43 - CalibrationWorkflow: Treshold reached with 15 iteration, best cost: 0.04946198832696819, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00025351181599789213, 'E2FOULING': 0.000304760817704472}
# [INFO] 16:11:43 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.427929 > threshold: 0.1
# [INFO] 16:11:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:11:43 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:11:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:13:17 - CalibrationWorkflow: Treshold reached with 46 iteration, best cost: 1.2034995055151367, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0003171005275332527, 'E2FOULING': 0.0023214615865927283}
# [INFO] 16:13:17 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.203500 > threshold: 0.1
# [INFO] 16:13:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:13:17 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:13:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:13:17 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:13:17 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:13:17 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 16:13:17 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:13:17 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:13:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:13:18 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 16:13:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:13:18 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.07042702345258785, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.0003228340393069678, 'E2FOULING': 0.00032205969364587606}
# [INFO] 16:13:18 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.110933 > threshold: 0.1
# [INFO] 16:13:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:13:18 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:13:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:13:38 - CalibrationWorkflow: Treshold reached with 8 iteration, best cost: 1.1446514296921801, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00030026769632297785, 'E2FOULING': 0.00241501390572368}
# [INFO] 16:13:38 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.144651 > threshold: 0.1
# [INFO] 16:13:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:13:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:13:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:13:38 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:13:38 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:13:38 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 16:13:38 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:13:38 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:13:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:13:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 16:13:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:13:40 - CalibrationWorkflow: Treshold reached with 26 iteration, best cost: 0.11212523266564182, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0002622433915191004, 'E2FOULING': 0.0005853555427653581}
# [INFO] 16:13:40 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.227083 > threshold: 0.1
# [INFO] 16:13:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:13:40 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:13:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:14:04 - CalibrationWorkflow: Treshold reached with 10 iteration, best cost: 1.1037619586639578, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.000273380752828325, 'E2FOULING': 0.002411984792757146}
# [INFO] 16:14:04 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.103762 > threshold: 0.1
# [INFO] 16:14:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:14:04 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:14:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:14:04 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:14:04 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:14:04 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 16:14:04 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:14:04 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:14:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:14:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 16:14:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:14:05 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.06430804654110268, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.00030863224031747494, 'E2FOULING': 0.0003442172562439087}
# [INFO] 16:14:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.083991 < threshold 0.100000
# [INFO] 16:14:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:14:06 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:14:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:14:06 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 16:14:06 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:14:06 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 16:14:06 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:14:06 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 16:14:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:14:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 16:14:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:14:07 - CalibrationWorkflow: Treshold reached with 29 iteration, best cost: 0.060017040335295924, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.000290094515603885, 'E2FOULING': 0.00030477318827994853}
# [INFO] 16:14:08 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.133720 > threshold: 0.1
# [INFO] 16:14:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:14:08 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:14:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:15:32 - CalibrationWorkflow: Treshold reached with 41 iteration, best cost: 1.0954369051759874, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.0002981800023443269, 'E2FOULING': 0.0023061669523286566}
# [INFO] 16:15:32 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.095437 > threshold: 0.1
# [INFO] 16:15:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:15:32 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:15:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:15:32 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:15:32 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:15:32 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 16:15:32 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:15:32 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:15:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:15:33 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 16:15:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:15:33 - CalibrationWorkflow: Treshold reached with 18 iteration, best cost: 0.034063583509415414, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0006301807850213386, 'E2FOULING': 0.00025}
# [INFO] 16:15:33 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.108118 > threshold: 0.1
# [INFO] 16:15:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:15:33 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:15:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:15:42 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.09561777203293573, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0006152739976582468, 'E2FOULING': 0.00025}
# [INFO] 16:15:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.095618 < threshold 0.100000
# [INFO] 16:15:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:15:42 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:15:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:15:42 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:15:42 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:15:42 - CalibrationWorkflow: Self.model updated to online_v14
# [INFO] 16:15:42 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:15:42 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:15:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:15:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 16:15:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:15:43 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.04672273707462803, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.00029195732335765665, 'E2FOULING': 0.0002628246524573792}
# [INFO] 16:15:43 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.165778 > threshold: 0.1
# [INFO] 16:15:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:15:43 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:15:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:16:59 - CalibrationWorkflow: Treshold reached with 46 iteration, best cost: 1.1842689043488734, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0003562469077515035, 'E2FOULING': 0.002086549042917421}
# [INFO] 16:16:59 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.184269 > threshold: 0.1
# [INFO] 16:16:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:16:59 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:16:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:16:59 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:16:59 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:16:59 - CalibrationWorkflow: Self.model updated to online_v15
# [INFO] 16:16:59 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:16:59 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:17:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:17:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 16:17:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:17:00 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.04071431043028511, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002961486894939882}
# [INFO] 16:17:00 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.274278 > threshold: 0.1
# [INFO] 16:17:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:17:00 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:17:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:18:11 - CalibrationWorkflow: Treshold reached with 44 iteration, best cost: 1.0403546772806056, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0003102037119969265, 'E2FOULING': 0.002026268761309703}
# [INFO] 16:18:11 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.040355 > threshold: 0.1
# [INFO] 16:18:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:18:11 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:18:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:18:11 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:18:11 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:18:11 - CalibrationWorkflow: Self.model updated to online_v16
# [INFO] 16:18:11 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:18:11 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:18:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:18:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 16:18:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:18:12 - CalibrationWorkflow: Treshold reached with 27 iteration, best cost: 0.039415065678072986, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.00029913826777229664, 'E2FOULING': 0.00038087816715882505}
# [INFO] 16:18:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.066943 < threshold 0.100000
# [INFO] 16:18:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:18:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:18:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:18:12 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 16:18:12 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:18:12 - CalibrationWorkflow: Self.model updated to online_v17
# [INFO] 16:18:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:18:12 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 16:18:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:18:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 16:18:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:18:13 - CalibrationWorkflow: Treshold reached with 11 iteration, best cost: 0.033329063384544125, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004045896277088528}
# [INFO] 16:18:13 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.172139 > threshold: 0.1
# [INFO] 16:18:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:18:13 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:18:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:19:25 - CalibrationWorkflow: Treshold reached with 43 iteration, best cost: 0.8539484518728111, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.0002819097416892525, 'E2FOULING': 0.0020728162874017286}
# [INFO] 16:19:25 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.853948 > threshold: 0.1
# [INFO] 16:19:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:19:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:19:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:19:25 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:19:25 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:19:25 - CalibrationWorkflow: Self.model updated to online_v18
# [INFO] 16:19:25 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:19:25 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:19:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:19:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 16:19:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:19:26 - CalibrationWorkflow: Treshold reached with 31 iteration, best cost: 0.02913672661613821, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00025002296394508074, 'E2FOULING': 0.000303988791171948}
# [INFO] 16:19:27 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.198813 > threshold: 0.1
# [INFO] 16:19:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:19:27 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:19:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:20:38 - CalibrationWorkflow: Treshold reached with 44 iteration, best cost: 1.029983384186889, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.0002898168165481544, 'E2FOULING': 0.0021422175799593207}
# [INFO] 16:20:38 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.029983 > threshold: 0.1
# [INFO] 16:20:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:20:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:20:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:20:38 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:20:38 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:20:38 - CalibrationWorkflow: Self.model updated to online_v19
# [INFO] 16:20:38 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:20:38 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:20:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:20:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 16:20:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:20:39 - CalibrationWorkflow: Treshold reached with 14 iteration, best cost: 0.035853934383681445, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0004839252710031178, 'E2FOULING': 0.0002855619999310067}
# [INFO] 16:20:40 - CalibrationWorkflow: Working point is accurate enough with cost: 0.072245 < threshold 0.100000
# [INFO] 16:20:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:20:40 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:20:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:20:40 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 16:20:40 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:20:40 - CalibrationWorkflow: Self.model updated to online_v20
# [INFO] 16:20:40 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:20:40 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 16:20:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:20:40 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 16:20:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:20:41 - CalibrationWorkflow: Treshold reached with 26 iteration, best cost: 0.024581289999888487, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0006069768184934489, 'E2FOULING': 0.0002519744051071836}
# [INFO] 16:20:41 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.172388 > threshold: 0.1
# [INFO] 16:20:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:20:41 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 16:20:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:21:58 - CalibrationWorkflow: Treshold reached with 47 iteration, best cost: 0.7782480330922323, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0002981137244670146, 'E2FOULING': 0.0016443889901019805}
# [INFO] 16:21:58 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.778248 > threshold: 0.1
# [INFO] 16:21:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:21:58 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:21:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:21:58 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 16:21:58 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:21:58 - CalibrationWorkflow: Self.model updated to online_v21
# [INFO] 16:21:58 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:21:58 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 16:21:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:21:58 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 16:21:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:21:59 - CalibrationWorkflow: Treshold reached with 27 iteration, best cost: 0.025980630030820826, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.000498049296924188, 'E2FOULING': 0.0002525248149981732}
# [INFO] 16:21:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.098013 < threshold 0.100000
# [INFO] 16:21:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:21:59 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:21:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:21:59 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 16:21:59 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:21:59 - CalibrationWorkflow: Self.model updated to online_v22
# [INFO] 16:21:59 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:21:59 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 16:22:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:22:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 16:22:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:22:01 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.022882316379698227, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.0004914106598678647, 'E2FOULING': 0.0002813806153705024}
# [INFO] 16:22:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.060793 < threshold 0.100000
# [INFO] 16:22:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:22:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 16:22:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:22:01 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 16:22:01 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 16:22:01 - CalibrationWorkflow: Self.model updated to online_v23
# [INFO] 16:22:01 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 16:22:01 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 16:22:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 16:22:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 16:22:02 - CalibrationWorkflow: ----------------------------------------
# ...
# [INFO] 17:18:43 - CalibrationWorkflow: Self.model updated to online_v521
# [INFO] 17:18:43 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 17:18:43 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 17:18:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:18:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 17:18:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:18:44 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.5039698286147066e-05, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.00036298495743756327, 'E2FOULING': 0.0004707269708070949}
# [INFO] 17:18:44 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.252472 > threshold: 0.1
# [INFO] 17:18:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:18:44 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 17:18:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:19:09 - CalibrationWorkflow: Obj Treshold reached with 13 iteration, best cost: 0.06428411238814985, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005169026901271269, 'E2FOULING': 0.000627318161676615}
# [INFO] 17:19:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.064284 < threshold 0.100000
# [INFO] 17:19:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:19:09 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 17:19:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:19:09 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 17:19:09 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 17:19:09 - CalibrationWorkflow: Self.model updated to online_v522
# [INFO] 17:19:09 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 17:19:09 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 17:19:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:19:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 17:19:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:19:10 - CalibrationWorkflow: Treshold reached with 36 iteration, best cost: 0.012382262816536866, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.000414472010173325, 'E2FOULING': 0.00037440393077253515}
# [INFO] 17:19:10 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.185079 > threshold: 0.1
# [INFO] 17:19:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:19:10 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 17:19:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:19:26 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 0.08625905932578186, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.000536267518239563, 'E2FOULING': 0.0006190654415164554}
# [INFO] 17:19:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.086259 < threshold 0.100000
# [INFO] 17:19:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:19:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 17:19:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:19:26 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 17:19:26 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 17:19:26 - CalibrationWorkflow: Self.model updated to online_v523
# [INFO] 17:19:26 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 17:19:26 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 17:19:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:19:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 17:19:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:19:27 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 0.00733019220509466, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.00041843652251691613, 'E2FOULING': 0.00041534810339939306}
# [INFO] 17:19:27 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.105505 > threshold: 0.1
# [INFO] 17:19:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:19:27 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 17:19:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:20:54 - CalibrationWorkflow: Treshold reached with 54 iteration, best cost: 0.44285251604984766, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.00047635366343036885, 'E2FOULING': 0.0009252146966933362}
# [INFO] 17:20:54 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.442853 > threshold: 0.1
# [INFO] 17:20:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:20:54 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 17:20:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:20:54 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 17:20:54 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 17:20:54 - CalibrationWorkflow: Self.model updated to online_v524
# [INFO] 17:20:54 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 17:20:54 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 17:20:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:20:55 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 17:20:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:20:56 - CalibrationWorkflow: Treshold reached with 29 iteration, best cost: 0.01823743889266537, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.0003253727763425569, 'E2FOULING': 0.00025}
# [INFO] 17:20:56 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.417676 > threshold: 0.1
# [INFO] 17:20:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:20:56 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 17:20:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:22:21 - CalibrationWorkflow: Treshold reached with 51 iteration, best cost: 0.5853424528011373, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00040308735898719403, 'E2FOULING': 0.0010400847636063007}
# [INFO] 17:22:21 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.585342 > threshold: 0.1
# [INFO] 17:22:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:22:21 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 17:22:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:22:21 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 17:22:21 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 17:22:21 - CalibrationWorkflow: Self.model updated to online_v525
# [INFO] 17:22:21 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 17:22:21 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 17:22:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:22:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 17:22:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:22:22 - CalibrationWorkflow: Treshold reached with 15 iteration, best cost: 0.013738886548885046, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.00029546830031053383, 'E2FOULING': 0.0004129450642745252}
# [INFO] 17:22:22 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.467619 > threshold: 0.1
# [INFO] 17:22:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:22:22 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 17:22:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:22:42 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 0.030703418910715527, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0005362633217306606, 'E2FOULING': 0.0004718095170339572}
# [INFO] 17:22:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.030703 < threshold 0.100000
# [INFO] 17:22:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:22:42 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 17:22:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:22:42 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 17:22:42 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 17:22:42 - CalibrationWorkflow: Self.model updated to online_v526
# [INFO] 17:22:42 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 17:22:42 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 17:22:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:22:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 17:22:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:22:43 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.00952384363811202, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0002972514610907969, 'E2FOULING': 0.00037617657558838597}
# [INFO] 17:22:43 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.435707 > threshold: 0.1
# [INFO] 17:22:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:22:43 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 17:22:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:23:17 - CalibrationWorkflow: Obj Treshold reached with 19 iteration, best cost: 0.09325132651264147, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0004529219540898529, 'E2FOULING': 0.0006309586631625252}
# [INFO] 17:23:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.093251 < threshold 0.100000
# [INFO] 17:23:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:23:17 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 17:23:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:23:17 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 17:23:17 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 17:23:17 - CalibrationWorkflow: Self.model updated to online_v527
# [INFO] 17:23:17 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 17:23:17 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 17:23:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:23:18 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 17:23:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:23:18 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.864355752193901e-05, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0004457857957731418, 'E2FOULING': 0.000391373710254381}
# [INFO] 17:23:18 - CalibrationWorkflow: Working point is accurate enough with cost: 0.055376 < threshold 0.100000
# [INFO] 17:23:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:23:18 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 17:23:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:23:18 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 17:23:18 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 17:23:18 - CalibrationWorkflow: Self.model updated to online_v528
# [INFO] 17:23:18 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 17:23:18 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 17:23:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:23:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 17:23:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:23:19 - CalibrationWorkflow: Obj Treshold reached with 13 iteration, best cost: 0.00860808922031385, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.00041901477808653416, 'E2FOULING': 0.0004133818892566557}
# [INFO] 17:23:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.071218 < threshold 0.100000
# [INFO] 17:23:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:23:19 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 17:23:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 17:23:19 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 17:23:19 - CalibrationWorkflow: Retraining model with 51 samples (replay + outliers)
# [INFO] 17:23:19 - CalibrationWorkflow: Self.model updated to online_v529
# [INFO] 17:23:19 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 17:23:19 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 17:23:20 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/Calibration_result_online_always-one-replay-0.25.xlsx')
# Out:
# [INFO] 17:23:20 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_always-one-replay-0.25.xlsx

# %%
res = workflow.get_results()

# %%
resdf = pd.DataFrame(res)

# %%
resdf.columns
# Out:
# Index(['SampleID', 'Total_workflow_EllapsedTime', 'Calibration_type',
#        'OriginalFactors', 'Target', 'Calibration_Base_Type',
#        'Calibration_Base_EllapsedTime', 'Calibration_Base_IterationNum',
#        'Calibration_Base_Final_obj', 'Calibration_Base_FinalIO',
#        'Calibration_Base_SurrogatePred', 'Validation_Base_SimulationRes',
#        'Validation_Base_SimCost', 'Validation_Base_Accurate',
#        'Validation_Base_Decision', 'Calibration_Direct_EllapsedTime',
#        'Calibration_Direct_IterationNum', 'Calibration_Direct_Final_obj',
#        'Calibration_Direct_FinalIO', 'Calibration_Direct_SimCost',
#        'Calibration_Direct_Accuracy', 'Calibration_Direct_Decision',
#        'OnlineLearning_New_Data', 'OnlineLearning_New_SelectionType',
#        'OnlineLearning_New_DataType', 'OnlineLearning_EllapsedTime',
#        'OnlineLearning_SelectedReplayids', 'OnlineLearning_SelectedReplayIOs',
#        'LocalImprovement', 'GlobalRetention', 'Used_Surrogate_version',
#        'New_Surrogate_version', 'Final_Calibration_Result_IOs',
#        'Final_Calibration_SimCost', 'Final_Calibration_Accurate',
#        'Final_Calibration_Type'],
#       dtype='object')

# %%
resdf['Validation_Base_Accurate'].value_counts()
# Out:
# Validation_Base_Accurate
# True     418
# False    112
# Name: count, dtype: int64

# %%
resdf['Final_Calibration_Accurate'].value_counts()
# Out:
# Final_Calibration_Accurate
# True     495
# False     35
# Name: count, dtype: int64

# %%
workflow_settings['sim_validation_treshold']
# Out:
# 0.1

# %%
import seaborn as sns

#sns.kdeplot(resdf['Calibration_Base_Final_obj'], label='Surrogate obj',  fill=True, linewidth=2, clip=(0, None))
sns.kdeplot(resdf['Validation_Base_SimCost'], label='Validation obj',  fill=True, linewidth=2, clip=(0, None))
sns.kdeplot(resdf['Final_Calibration_SimCost'], label='Final Calib obj',  fill=True, linewidth=2, clip=(0, None))
plt.axvline(x=workflow_settings['sim_validation_treshold'], color='red', linestyle='--', label='Threshold')
plt.legend()

# %%
resdf['Calibration_Direct_EllapsedTime'].plot()
# Out:
# <Axes: >

# %%
resdf['LocalImprovement'].mean()
# Out:
# 2.264860149739256

# %%
resdf['GlobalRetention'].plot()
# Out:
# <Axes: >

# %%
resdf
# Out:
#      SampleID  Total_workflow_EllapsedTime Calibration_type  \
# 0           0                    87.192581           online
# 1           1                    83.741481           online
# 2           2                    68.683143           online
# 3           3                    93.539983           online
# 4           4                    83.471364           online
# ..        ...                          ...              ...
# 525       525                    86.812029           online
# 526       526                    21.408472           online
# 527       527                    34.601534           online
# 528       528                     0.916220           online
# 529       529                     1.085203           online
#
#                                        OriginalFactors  \
# 0    {'E1FOULING': 0.0003966064602180043, 'E2FOULIN...
# 1    {'E1FOULING': 0.0003858453451426925, 'E2FOULIN...
# 2    {'E1FOULING': 0.0003847697530392205, 'E2FOULIN...
# 3    {'E1FOULING': 0.0004268043194975153, 'E2FOULIN...
# 4    {'E1FOULING': 0.0003682943731335989, 'E2FOULIN...
# ..                                                 ...
# 525  {'E1FOULING': 0.0004548607687919593, 'E2FOULIN...
# 526  {'E1FOULING': 0.0004822419516333996, 'E2FOULIN...
# 527  {'E1FOULING': 0.0004733674673527922, 'E2FOULIN...
# 528  {'E1FOULING': 0.0004984942750080559, 'E2FOULIN...
# 529  {'E1FOULING': 0.0005021358045441324, 'E2FOULIN...
#
#                                                 Target  \
# 0    {'PROD1E1IN': 108.2722567668642, 'PROD1OUT': 9...
# 1    {'PROD1E1IN': 104.3535050140472, 'PROD1OUT': 9...
# 2    {'PROD1E1IN': 105.9350937121914, 'PROD1OUT': 9...
# 3    {'PROD1E1IN': 106.0854462410004, 'PROD1OUT': 9...
# 4    {'PROD1E1IN': 105.0075133590793, 'PROD1OUT': 9...
# ..                                                 ...
# 525  {'PROD1E1IN': 116.9302158164906, 'PROD1OUT': 1...
# 526  {'PROD1E1IN': 116.2112946019632, 'PROD1OUT': 1...
# 527  {'PROD1E1IN': 116.4229042179647, 'PROD1OUT': 1...
# 528  {'PROD1E1IN': 116.8454717819132, 'PROD1OUT': 1...
# 529  {'PROD1E1IN': 116.0362633732756, 'PROD1OUT': 1...
#
#          Calibration_Base_Type  Calibration_Base_EllapsedTime  \
# 0    CalibrationType.SURROGATE                       0.937255
# 1    CalibrationType.SURROGATE                       1.024001
# 2    CalibrationType.SURROGATE                       0.362120
# 3    CalibrationType.SURROGATE                       0.637222
# 4    CalibrationType.SURROGATE                       0.641023
# ..                         ...                            ...
# 525  CalibrationType.SURROGATE                       0.783219
# 526  CalibrationType.SURROGATE                       0.425798
# 527  CalibrationType.SURROGATE                       0.217915
# 528  CalibrationType.SURROGATE                       0.197631
# 529  CalibrationType.SURROGATE                       0.364928
#
#      Calibration_Base_IterationNum  Calibration_Base_Final_obj  \
# 0                               27                    0.113085
# 1                               31                    0.115310
# 2                               11                    0.110264
# 3                               21                    0.089848
# 4                               20                    0.092901
# ..                             ...                         ...
# 525                             31                    0.018237
# 526                             17                    0.013739
# 527                              9                    0.009524
# 528                              8                    0.000019
# 529                             15                    0.008608
#
#                               Calibration_Base_FinalIO  ...  \
# 0    {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEM...  ...
# 1    {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEM...  ...
# 2    {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEM...  ...
# 3    {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEM...  ...
# 4    {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEM...  ...
# ..                                                 ...  ...
# 525  {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP...  ...
# 526  {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEM...  ...
# 527  {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEM...  ...
# 528  {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEM...  ...
# 529  {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEM...  ...
#
#                       OnlineLearning_SelectedReplayids  \
# 0    [11, 23, 113, 78, 134, 169, 32, 191, 110, 186,...
# 1    [187, 109, 127, 154, 8, 66, 146, 0, 162, 135, ...
# 2    [45, 195, 68, 156, 4, 5, 186, 151, 2, 94, 87, ...
# 3    [131, 99, 126, 132, 180, 117, 125, 35, 179, 19...
# 4    [42, 13, 159, 147, 172, 92, 114, 68, 53, 123, ...
# ..                                                 ...
# 525  [60, 158, 56, 185, 187, 136, 47, 76, 62, 6, 10...
# 526  [103, 91, 86, 158, 152, 22, 104, 175, 132, 37,...
# 527  [93, 64, 106, 173, 135, 4, 53, 82, 89, 102, 71...
# 528  [194, 75, 149, 61, 127, 29, 150, 55, 43, 2, 18...
# 529  [181, 82, 150, 145, 29, 138, 127, 197, 171, 8,...
#
#     OnlineLearning_SelectedReplayIOs  LocalImprovement  GlobalRetention  \
# 0                               None          1.014087         1.007277
# 1                               None          1.023900         1.015001
# 2                               None          1.027217         1.022190
# 3                               None          1.028974         1.031125
# 4                               None          1.031011         1.038838
# ..                               ...               ...              ...
# 525                             None          1.036858         5.152981
# 526                             None          1.046533         5.125443
# 527                             None          1.039893         5.144821
# 528                             None          1.064556         5.143578
# 529                             None               NaN         5.167930
#
#     Used_Surrogate_version  New_Surrogate_version  \
# 0                     base              online_v0
# 1                online_v0              online_v1
# 2                online_v1              online_v2
# 3                online_v2              online_v3
# 4                online_v3              online_v4
# ..                     ...                    ...
# 525            online_v524            online_v525
# 526            online_v525            online_v526
# 527            online_v526            online_v527
# 528            online_v527            online_v528
# 529            online_v528            online_v529
#
#                           Final_Calibration_Result_IOs  \
# 0    {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEM...
# 1    {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEM...
# 2    {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEM...
# 3    {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEM...
# 4    {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEM...
# ..                                                 ...
# 525  {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP...
# 526  {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEM...
# 527  {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEM...
# 528  {'PROD1E1IN': 116.40049228150605, 'PROD1OUT': ...
# 529  {'PROD1E1IN': 116.1495928390068, 'PROD1OUT': 1...
#
#      Final_Calibration_SimCost Final_Calibration_Accurate  \
# 0                     1.004318                      False
# 1                     1.102231                      False
# 2                     1.414080                      False
# 3                     1.081877                      False
# 4                     1.091484                      False
# ..                         ...                        ...
# 525                   0.585342                      False
# 526                   0.030703                       True
# 527                   0.093251                       True
# 528                   0.055376                       True
# 529                   0.071218                       True
#
#      Final_Calibration_Type
# 0                    direct
# 1                    direct
# 2                    direct
# 3                    direct
# 4                    direct
# ..                      ...
# 525                  direct
# 526                  direct
# 527                  direct
# 528              validation
# 529              validation
#
# [530 rows x 36 columns]

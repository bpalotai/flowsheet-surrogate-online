# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
from sklearn.neural_network import MLPRegressor
from Scaler_driver import DataScaler as DS
# Import drivers
import Surrogate_driver_sklearn as SD
import PSO_driver_withscaler as PSO
import Simulation_driver as SM


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras import layers, models
from keras.saving import register_keras_serializable

# --- Custom Monte Carlo Dropout Layer ---
@register_keras_serializable()
class MCDropout(layers.Dropout):
    def call(self, inputs, training=None):
        return super().call(inputs, training=True)

# --- Build BNN ---
def build_bnn_model(input_dim, output_dim, dropout_rate=0.1):
    model = models.Sequential([
        layers.Input(shape=(input_dim,)),
        layers.Dense(50, activation='relu'),
        MCDropout(dropout_rate),
        layers.Dense(output_dim)
    ])
    model.compile(optimizer='adam', loss='mse')
    return model

# --- Predict with Uncertainty ---
def predict_with_uncertainty(f_model, x_tensor, n_iter=50):
    preds = np.stack([f_model(x_tensor, training=True).numpy() for _ in range(n_iter)], axis=0)
    mean_preds = preds.mean(axis=0)
    std_preds = preds.std(axis=0)
    return mean_preds, std_preds

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_200.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'surrogate', # direct, surrogate, online
                     'run_direct_for_not_accurate': False,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/AdaptiveModel/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 20:56:21 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 20:56:21 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/AdaptiveModel/sklearnann.joblib
# [INFO] 20:56:21 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 20:56:22 - CalibrationWorkflow:
# ============================================================
# [INFO] 20:56:22 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 20:56:22 - CalibrationWorkflow: ============================================================
#
# [INFO] 20:56:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:56:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 20:56:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:56:30 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 1.780912014010695e-06, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004939975142064824}
# [INFO] 20:56:31 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.263091 > threshold: 0.1
# [INFO] 20:56:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:56:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 20:56:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:56:37 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 4.8451208841267605e-06, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0002834452222321771, 'E2FOULING': 0.0003484922507997281}
# [INFO] 20:56:37 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.140907 > threshold: 0.1
# [INFO] 20:56:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:56:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 20:56:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:56:45 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 8.64656012324512e-06, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00026923877550084896}
# [INFO] 20:56:45 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.296067 > threshold: 0.1
# [INFO] 20:56:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:56:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 20:56:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:56:57 - CalibrationWorkflow: Obj Treshold reached with 13 iteration, best cost: 1.5179447827846822e-05, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005808039710889024}
# [INFO] 20:56:57 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.370501 > threshold: 0.1
# [INFO] 20:56:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:56:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 20:56:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:07 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 0.009460260383364005, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.000635234721820567}
# [INFO] 20:57:07 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.199619 > threshold: 0.1
# [INFO] 20:57:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:07 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 20:57:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:13 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.009760015392411796, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00025, 'E2FOULING': 0.00047133897083474595}
# [INFO] 20:57:13 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.224339 > threshold: 0.1
# [INFO] 20:57:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 20:57:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:20 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.5657561874691057e-05, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00025, 'E2FOULING': 0.00042819249106586916}
# [INFO] 20:57:21 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.175535 > threshold: 0.1
# [INFO] 20:57:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 20:57:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:30 - CalibrationWorkflow: Treshold reached with 10 iteration, best cost: 0.03170336387878746, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005873355005175799}
# [INFO] 20:57:30 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.330511 > threshold: 0.1
# [INFO] 20:57:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:30 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 20:57:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:37 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 2.2267523106788215e-05, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00025, 'E2FOULING': 0.00041408889580959286}
# [INFO] 20:57:37 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.257384 > threshold: 0.1
# [INFO] 20:57:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 20:57:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:46 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 0.008113709673838667, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0002522623844716866, 'E2FOULING': 0.000622502183468409}
# [INFO] 20:57:47 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.348312 > threshold: 0.1
# [INFO] 20:57:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:47 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 20:57:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:55 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 6.790444684403942e-06, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00026568526978866844, 'E2FOULING': 0.0005362273914623747}
# [INFO] 20:57:55 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.214144 > threshold: 0.1
# [INFO] 20:57:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:57:55 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 20:57:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:02 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.009377357269234339, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.00025, 'E2FOULING': 0.000757851272562704}
# [INFO] 20:58:02 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.334172 > threshold: 0.1
# [INFO] 20:58:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 20:58:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:18 - CalibrationWorkflow: Obj Treshold reached with 20 iteration, best cost: 1.8954559097507984e-05, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0002501900701750765, 'E2FOULING': 0.0006928084694204422}
# [INFO] 20:58:18 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.279046 > threshold: 0.1
# [INFO] 20:58:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:18 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 20:58:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:25 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 5.872799854677701e-06, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005890149043583536}
# [INFO] 20:58:25 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.207679 > threshold: 0.1
# [INFO] 20:58:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 20:58:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:36 - CalibrationWorkflow: Obj Treshold reached with 12 iteration, best cost: 1.138656852912771e-05, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0002521348103961679, 'E2FOULING': 0.00035761198233233497}
# [INFO] 20:58:36 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.582673 > threshold: 0.1
# [INFO] 20:58:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 20:58:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:44 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 0.007497481062315198, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005348602285707252}
# [INFO] 20:58:44 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.227770 > threshold: 0.1
# [INFO] 20:58:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 20:58:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:51 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 8.571923770641365e-06, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003906878976573649}
# [INFO] 20:58:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.214146 > threshold: 0.1
# [INFO] 20:58:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 20:58:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:58 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.9345123378782864e-06, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005685349297747408}
# [INFO] 20:58:58 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.179623 > threshold: 0.1
# [INFO] 20:58:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:58:58 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 20:58:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:05 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 8.12604377485806e-06, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.0002501751203168179, 'E2FOULING': 0.0006359543728073943}
# [INFO] 20:59:05 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.181334 > threshold: 0.1
# [INFO] 20:59:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 20:59:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:15 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 0.009224588473795727, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004124591199775108}
# [INFO] 20:59:15 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.144773 > threshold: 0.1
# [INFO] 20:59:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 20:59:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:21 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.007472633151313727, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.00025, 'E2FOULING': 0.0007262974534213775}
# [INFO] 20:59:21 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.246949 > threshold: 0.1
# [INFO] 20:59:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 20:59:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:29 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 1.9016713535531596e-05, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005648335220933258}
# [INFO] 20:59:29 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.238716 > threshold: 0.1
# [INFO] 20:59:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 20:59:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:36 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 5.126513878582405e-06, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.00025, 'E2FOULING': 0.0006269900682126075}
# [INFO] 20:59:36 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.227778 > threshold: 0.1
# [INFO] 20:59:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 20:59:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:46 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 1.0889796320873701e-05, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005521235647769074}
# [INFO] 20:59:46 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.284661 > threshold: 0.1
# [INFO] 20:59:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 20:59:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:56 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 7.551518117445755e-06, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005025678396654779}
# [INFO] 20:59:56 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.158076 > threshold: 0.1
# [INFO] 20:59:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 20:59:56 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 20:59:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:00:09 - CalibrationWorkflow: Obj Treshold reached with 15 iteration, best cost: 1.1464875298254713e-05, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.0002637028094362465, 'E2FOULING': 0.0006218881229948941}
# [INFO] 21:00:09 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.135258 > threshold: 0.1
# [INFO] 21:00:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:00:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 21:00:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:00:20 - CalibrationWorkflow: Obj Treshold reached with 13 iteration, best cost: 1.7430669207852772e-05, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.00025, 'E2FOULING': 0.000668296575908054}
# [INFO] 21:00:20 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.277105 > threshold: 0.1
# [INFO] 21:00:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:00:20 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 21:00:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:00:26 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 7.476211962347245e-06, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.00025, 'E2FOULING': 0.0006323507238538484}
# [INFO] 21:00:26 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.211734 > threshold: 0.1
# [INFO] 21:00:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:00:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 21:00:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:00:31 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 6.835776206886258e-06, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.00025, 'E2FOULING': 0.0006181582771128511}
# [INFO] 21:00:32 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.265512 > threshold: 0.1
# [INFO] 21:00:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:00:32 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 29 of 529.
# [INFO] 21:00:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:00:36 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.008622019955364999, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.00025, 'E2FOULING': 0.0006582782501262335}
# [INFO] 21:00:36 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.152303 > threshold: 0.1
# [INFO] 21:00:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:00:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 30 of 529.
# [INFO] 21:00:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:01:19 - CalibrationWorkflow: Treshold reached with 55 iteration, best cost: 0.13025285494159292, values: {'FEED1MASSFLOW': 18170.33282487203, 'FEED1TEMP': 24.88142490999688, 'PROD1MASSFLOW': 45110.96621847873, 'PROD1TEMP': 115.0679318499356, 'E1FOULING': 0.00025, 'E2FOULING': 0.00042490101488407215}
# [INFO] 21:01:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.064103 < threshold 0.100000
# [INFO] 21:01:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:01:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 31 of 529.
# [INFO] 21:01:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:01:27 - CalibrationWorkflow: Treshold reached with 9 iteration, best cost: 0.12465305160670045, values: {'FEED1MASSFLOW': 18607.84387976851, 'FEED1TEMP': 25.14488217461214, 'PROD1MASSFLOW': 43738.61199857389, 'PROD1TEMP': 115.3747174316839, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:01:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 21:01:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:01:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 32 of 529.
# [INFO] 21:01:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:01:51 - CalibrationWorkflow: Treshold reached with 29 iteration, best cost: 0.14138863074616542, values: {'FEED1MASSFLOW': 19115.08117402765, 'FEED1TEMP': 24.77391698651811, 'PROD1MASSFLOW': 42751.55908633373, 'PROD1TEMP': 115.3524481338415, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:01:51 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 21:01:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:01:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 33 of 529.
# [INFO] 21:01:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:02:01 - CalibrationWorkflow: Treshold reached with 12 iteration, best cost: 0.11841450698388506, values: {'FEED1MASSFLOW': 19418.03437168451, 'FEED1TEMP': 25.0300579250388, 'PROD1MASSFLOW': 43087.88928120025, 'PROD1TEMP': 114.4650169900805, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:02:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 21:02:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:02:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 34 of 529.
# [INFO] 21:02:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:03:18 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.381843 > threshold: 0.1
# [INFO] 21:03:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:03:18 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 35 of 529.
# [INFO] 21:03:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:03:35 - CalibrationWorkflow: Treshold reached with 21 iteration, best cost: 0.07815251751007671, values: {'FEED1MASSFLOW': 20114.96473047106, 'FEED1TEMP': 24.8676559665023, 'PROD1MASSFLOW': 40171.91798417241, 'PROD1TEMP': 115.7924017721878, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 21:03:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 21:03:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:03:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 36 of 529.
# [INFO] 21:03:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:04:00 - CalibrationWorkflow: Treshold reached with 31 iteration, best cost: 0.08663017290098829, values: {'FEED1MASSFLOW': 20464.74060999631, 'FEED1TEMP': 25.14479618506942, 'PROD1MASSFLOW': 39328.05034260821, 'PROD1TEMP': 115.7990352506138, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025162970942315153}
# [INFO] 21:04:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 21:04:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:04:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 37 of 529.
# [INFO] 21:04:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:04:28 - CalibrationWorkflow: Treshold reached with 35 iteration, best cost: 0.07256313780050017, values: {'FEED1MASSFLOW': 20969.69452156387, 'FEED1TEMP': 25.25139017769914, 'PROD1MASSFLOW': 39239.44675475179, 'PROD1TEMP': 115.2266590735738, 'E1FOULING': 0.00025237061678195843, 'E2FOULING': 0.0002516897354077821}
# [INFO] 21:04:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 21:04:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:04:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 38 of 529.
# [INFO] 21:04:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:05:15 - CalibrationWorkflow: Treshold reached with 64 iteration, best cost: 0.11924112341161748, values: {'FEED1MASSFLOW': 21516.56747134487, 'FEED1TEMP': 25.01599682709554, 'PROD1MASSFLOW': 37569.24954175691, 'PROD1TEMP': 115.7682074791824, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002604915044822593}
# [INFO] 21:05:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 21:05:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:05:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 39 of 529.
# [INFO] 21:05:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:06:05 - CalibrationWorkflow: Treshold reached with 69 iteration, best cost: 0.08849980206954944, values: {'FEED1MASSFLOW': 21885.72678255862, 'FEED1TEMP': 24.92770160919124, 'PROD1MASSFLOW': 36155.43092699922, 'PROD1TEMP': 115.2474249227753, 'E1FOULING': 0.00025185971740326375, 'E2FOULING': 0.0002513842164860632}
# [INFO] 21:06:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 21:06:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:06:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 40 of 529.
# [INFO] 21:06:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:06:37 - CalibrationWorkflow: Treshold reached with 42 iteration, best cost: 0.10390598201671064, values: {'FEED1MASSFLOW': 22629.3343245605, 'FEED1TEMP': 24.93546075225073, 'PROD1MASSFLOW': 35951.0272805308, 'PROD1TEMP': 114.5619751637425, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002502029589748676}
# [INFO] 21:06:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 21:06:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:06:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 41 of 529.
# [INFO] 21:06:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:07:26 - CalibrationWorkflow: Treshold reached with 68 iteration, best cost: 0.18817205128529885, values: {'FEED1MASSFLOW': 23052.81408141617, 'FEED1TEMP': 24.96979552398567, 'PROD1MASSFLOW': 35366.6433778873, 'PROD1TEMP': 114.8085323228307, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005128643027826874}
# [INFO] 21:07:26 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.172312 > threshold: 0.1
# [INFO] 21:07:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:07:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 42 of 529.
# [INFO] 21:07:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:08:10 - CalibrationWorkflow: Treshold reached with 59 iteration, best cost: 0.18281680055776442, values: {'FEED1MASSFLOW': 23873.98895120752, 'FEED1TEMP': 24.64705546402934, 'PROD1MASSFLOW': 33606.38987270086, 'PROD1TEMP': 115.3910956750255, 'E1FOULING': 0.00025, 'E2FOULING': 0.000595792594885402}
# [INFO] 21:08:10 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.234223 > threshold: 0.1
# [INFO] 21:08:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:08:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 43 of 529.
# [INFO] 21:08:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:09:03 - CalibrationWorkflow: Obj Treshold reached with 73 iteration, best cost: 2.0112502789745405e-05, values: {'FEED1MASSFLOW': 24085.05631312843, 'FEED1TEMP': 25.02029345511958, 'PROD1MASSFLOW': 32971.19764637543, 'PROD1TEMP': 114.4096466605709, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025255621323198206}
# [INFO] 21:09:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 21:09:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:09:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 44 of 529.
# [INFO] 21:09:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:09:42 - CalibrationWorkflow: Treshold reached with 52 iteration, best cost: 0.1745795866635187, values: {'FEED1MASSFLOW': 24511.37433920987, 'FEED1TEMP': 25.15025757714137, 'PROD1MASSFLOW': 31438.14255483319, 'PROD1TEMP': 115.5269277385362, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005279030078110275}
# [INFO] 21:09:42 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.215791 > threshold: 0.1
# [INFO] 21:09:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:09:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 45 of 529.
# [INFO] 21:09:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:10:33 - CalibrationWorkflow: Treshold reached with 70 iteration, best cost: 0.1715579977180136, values: {'FEED1MASSFLOW': 24226.00532269698, 'FEED1TEMP': 24.88169880079636, 'PROD1MASSFLOW': 32240.80420031684, 'PROD1TEMP': 117.4063795109899, 'E1FOULING': 0.0002531549509952774, 'E2FOULING': 0.0009149064441842774}
# [INFO] 21:10:33 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.354713 > threshold: 0.1
# [INFO] 21:10:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:10:33 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 46 of 529.
# [INFO] 21:10:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:10:42 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 2.2526092497870875e-05, values: {'FEED1MASSFLOW': 24185.81175407174, 'FEED1TEMP': 25.15256677443595, 'PROD1MASSFLOW': 33087.53564862187, 'PROD1TEMP': 114.7991019852639, 'E1FOULING': 0.00025, 'E2FOULING': 0.00045179290220994994}
# [INFO] 21:10:42 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.159066 > threshold: 0.1
# [INFO] 21:10:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:10:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 47 of 529.
# [INFO] 21:10:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:10:50 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 1.6859492340827083e-05, values: {'FEED1MASSFLOW': 24367.98927160785, 'FEED1TEMP': 24.84838832565562, 'PROD1MASSFLOW': 31903.84913114287, 'PROD1TEMP': 116.9796772662115, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005979449332360084}
# [INFO] 21:10:50 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.142275 > threshold: 0.1
# [INFO] 21:10:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:10:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 48 of 529.
# [INFO] 21:10:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:10:59 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 0.009740679488904187, values: {'FEED1MASSFLOW': 24554.35227057168, 'FEED1TEMP': 25.02471861497049, 'PROD1MASSFLOW': 32022.1791526673, 'PROD1TEMP': 116.3501387404943, 'E1FOULING': 0.00025, 'E2FOULING': 0.00035990905768902944}
# [INFO] 21:10:59 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.154854 > threshold: 0.1
# [INFO] 21:10:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:10:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 49 of 529.
# [INFO] 21:10:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:05 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 3.928142784417499e-06, values: {'FEED1MASSFLOW': 23510.03829878515, 'FEED1TEMP': 24.79841939343487, 'PROD1MASSFLOW': 31039.17958137653, 'PROD1TEMP': 117.2529818070609, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005847536920762587}
# [INFO] 21:11:05 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.141152 > threshold: 0.1
# [INFO] 21:11:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 50 of 529.
# [INFO] 21:11:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:16 - CalibrationWorkflow: Obj Treshold reached with 13 iteration, best cost: 1.1679780091062728e-05, values: {'FEED1MASSFLOW': 23728.09554496014, 'FEED1TEMP': 24.52961152685626, 'PROD1MASSFLOW': 31552.0289471732, 'PROD1TEMP': 116.7924665286068, 'E1FOULING': 0.0002501895720836554, 'E2FOULING': 0.0006767091593527116}
# [INFO] 21:11:16 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.138154 > threshold: 0.1
# [INFO] 21:11:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 51 of 529.
# [INFO] 21:11:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:24 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 3.707418991757323e-07, values: {'FEED1MASSFLOW': 24084.31166513767, 'FEED1TEMP': 24.60578099779845, 'PROD1MASSFLOW': 33418.07416342494, 'PROD1TEMP': 114.474852883691, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005809126139613859}
# [INFO] 21:11:24 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.126489 > threshold: 0.1
# [INFO] 21:11:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 52 of 529.
# [INFO] 21:11:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:30 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.009103318598921968, values: {'FEED1MASSFLOW': 24783.50089742459, 'FEED1TEMP': 24.56950754491758, 'PROD1MASSFLOW': 32049.26725524412, 'PROD1TEMP': 116.8620378533065, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005321050209199297}
# [INFO] 21:11:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.094844 < threshold 0.100000
# [INFO] 21:11:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:30 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 53 of 529.
# [INFO] 21:11:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:37 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 6.464976100496488e-06, values: {'FEED1MASSFLOW': 23450.84449491451, 'FEED1TEMP': 25.12667649559109, 'PROD1MASSFLOW': 31927.98360760983, 'PROD1TEMP': 118.234668493345, 'E1FOULING': 0.00025, 'E2FOULING': 0.0006457876714307892}
# [INFO] 21:11:37 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.173180 > threshold: 0.1
# [INFO] 21:11:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 54 of 529.
# [INFO] 21:11:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:45 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 7.49765289316575e-06, values: {'FEED1MASSFLOW': 23463.14122141384, 'FEED1TEMP': 24.3124994479043, 'PROD1MASSFLOW': 32759.6560159508, 'PROD1TEMP': 116.776228112195, 'E1FOULING': 0.00025, 'E2FOULING': 0.000636751474620252}
# [INFO] 21:11:45 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.182301 > threshold: 0.1
# [INFO] 21:11:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 55 of 529.
# [INFO] 21:11:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:57 - CalibrationWorkflow: Obj Treshold reached with 15 iteration, best cost: 1.0424529537344836e-05, values: {'FEED1MASSFLOW': 23723.10791088088, 'FEED1TEMP': 24.92019063719255, 'PROD1MASSFLOW': 32909.33550971355, 'PROD1TEMP': 120.8778018556371, 'E1FOULING': 0.00025288457347607434, 'E2FOULING': 0.0004740854905052716}
# [INFO] 21:11:57 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.139233 > threshold: 0.1
# [INFO] 21:11:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:11:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 56 of 529.
# [INFO] 21:11:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:12:14 - CalibrationWorkflow: Obj Treshold reached with 21 iteration, best cost: 0.009545390055380625, values: {'FEED1MASSFLOW': 24185.49452260674, 'FEED1TEMP': 24.22785984645597, 'PROD1MASSFLOW': 31711.29158196089, 'PROD1TEMP': 114.4005859726987, 'E1FOULING': 0.00025947999242161815, 'E2FOULING': 0.0007718209707717937}
# [INFO] 21:12:14 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.199854 > threshold: 0.1
# [INFO] 21:12:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:12:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 57 of 529.
# [INFO] 21:12:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:12:23 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 9.761997045429395e-06, values: {'FEED1MASSFLOW': 23877.02178156325, 'FEED1TEMP': 24.41885939347203, 'PROD1MASSFLOW': 32846.28776418294, 'PROD1TEMP': 119.0428362815956, 'E1FOULING': 0.00025, 'E2FOULING': 0.00046840708796206526}
# [INFO] 21:12:23 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.103877 > threshold: 0.1
# [INFO] 21:12:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:12:23 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 58 of 529.
# [INFO] 21:12:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:12:31 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 5.050615909921765e-06, values: {'FEED1MASSFLOW': 23669.7143349172, 'FEED1TEMP': 24.42891257209249, 'PROD1MASSFLOW': 32627.35553558619, 'PROD1TEMP': 118.0090775053084, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005958877636981737}
# [INFO] 21:12:31 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.149449 > threshold: 0.1
# [INFO] 21:12:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:12:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 59 of 529.
# [INFO] 21:12:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:12:38 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 0.007367406584252791, values: {'FEED1MASSFLOW': 23943.17532133758, 'FEED1TEMP': 23.87248769817969, 'PROD1MASSFLOW': 33415.53745911072, 'PROD1TEMP': 118.0054844767737, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004759338251697332}
# [INFO] 21:12:38 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.200371 > threshold: 0.1
# [INFO] 21:12:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:12:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 60 of 529.
# [INFO] 21:12:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:12:47 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 9.225783554065373e-06, values: {'FEED1MASSFLOW': 23681.05874285964, 'FEED1TEMP': 24.00742839463467, 'PROD1MASSFLOW': 33631.37968161814, 'PROD1TEMP': 118.6958749740123, 'E1FOULING': 0.00025, 'E2FOULING': 0.00045648406905013096}
# [INFO] 21:12:47 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.163681 > threshold: 0.1
# [INFO] 21:12:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:12:47 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 61 of 529.
# [INFO] 21:12:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:12:56 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 1.133444145677793e-05, values: {'FEED1MASSFLOW': 23417.17253443502, 'FEED1TEMP': 24.53872067236895, 'PROD1MASSFLOW': 32788.00132901206, 'PROD1TEMP': 117.2260057789928, 'E1FOULING': 0.00025, 'E2FOULING': 0.0007232206414679572}
# [INFO] 21:12:57 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.180564 > threshold: 0.1
# [INFO] 21:12:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:12:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 62 of 529.
# [INFO] 21:12:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:13:02 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.008687140999558272, values: {'FEED1MASSFLOW': 23139.13451713724, 'FEED1TEMP': 23.76246366509142, 'PROD1MASSFLOW': 32779.01315824939, 'PROD1TEMP': 118.0289461874185, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005645213704351356}
# [INFO] 21:13:02 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.137718 > threshold: 0.1
# [INFO] 21:13:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:13:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 63 of 529.
# [INFO] 21:13:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:13:45 - CalibrationWorkflow: Treshold reached with 58 iteration, best cost: 0.05590702896303157, values: {'FEED1MASSFLOW': 23421.12496342705, 'FEED1TEMP': 23.96721982578627, 'PROD1MASSFLOW': 33350.16985299164, 'PROD1TEMP': 119.6066953787307, 'E1FOULING': 0.00025, 'E2FOULING': 0.000835374385037803}
# [INFO] 21:13:45 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.411635 > threshold: 0.1
# [INFO] 21:13:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:13:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 64 of 529.
# [INFO] 21:13:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:13:50 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 4.135044640844386e-06, values: {'FEED1MASSFLOW': 23003.70730422672, 'FEED1TEMP': 23.77230595316833, 'PROD1MASSFLOW': 34591.10434454396, 'PROD1TEMP': 119.1611092782815, 'E1FOULING': 0.00025, 'E2FOULING': 0.0006315440300501083}
# [INFO] 21:13:50 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.218201 > threshold: 0.1
# [INFO] 21:13:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:13:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 65 of 529.
# [INFO] 21:13:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:13:57 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.3720828484846349e-05, values: {'FEED1MASSFLOW': 23038.53630719265, 'FEED1TEMP': 23.4865162218132, 'PROD1MASSFLOW': 33850.30114277963, 'PROD1TEMP': 121.3515211100006, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005210858698710198}
# [INFO] 21:13:57 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.143010 > threshold: 0.1
# [INFO] 21:13:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:13:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 66 of 529.
# [INFO] 21:13:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:14:03 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.007388148952828791, values: {'FEED1MASSFLOW': 22976.1235898672, 'FEED1TEMP': 23.57484259976275, 'PROD1MASSFLOW': 32964.68268668753, 'PROD1TEMP': 119.2259547318991, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005362092834434371}
# [INFO] 21:14:03 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.180367 > threshold: 0.1
# [INFO] 21:14:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:14:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 67 of 529.
# [INFO] 21:14:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:14:11 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 1.2268083651857858e-05, values: {'FEED1MASSFLOW': 23076.74146743403, 'FEED1TEMP': 24.23779169977461, 'PROD1MASSFLOW': 32582.15388854899, 'PROD1TEMP': 121.4257216200965, 'E1FOULING': 0.00025, 'E2FOULING': 0.0006129973378240327}
# [INFO] 21:14:12 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.244619 > threshold: 0.1
# [INFO] 21:14:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:14:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 68 of 529.
# [INFO] 21:14:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:14:17 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.007248753946303122, values: {'FEED1MASSFLOW': 23176.18586424605, 'FEED1TEMP': 23.74100477212071, 'PROD1MASSFLOW': 34449.6459579803, 'PROD1TEMP': 121.1329743864569, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004384578791052499}
# [INFO] 21:14:17 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.124719 > threshold: 0.1
# [INFO] 21:14:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:14:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 69 of 529.
# [INFO] 21:14:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:14:24 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 3.5604824567100948e-06, values: {'FEED1MASSFLOW': 22055.11683670486, 'FEED1TEMP': 24.15476678783768, 'PROD1MASSFLOW': 33475.57200927992, 'PROD1TEMP': 121.2253049012832, 'E1FOULING': 0.00025, 'E2FOULING': 0.0006140922669212199}
# [INFO] 21:14:24 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.196396 > threshold: 0.1
# [INFO] 21:14:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 21:14:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 70 of 529.
# [INFO] 21:14:24 - CalibrationWorkflow: ----------------------------------------
# ...
# [INFO] 22:45:47 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 506 of 529.
# [INFO] 22:45:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:45:58 - CalibrationWorkflow: Obj Treshold reached with 12 iteration, best cost: 4.2241794622032595e-06, values: {'FEED1MASSFLOW': 13945.38991416783, 'FEED1TEMP': 19.32837612879744, 'PROD1MASSFLOW': 35173.10285350482, 'PROD1TEMP': 126.7491635684822, 'E1FOULING': 0.00026572706105795166, 'E2FOULING': 0.0002604330678742126}
# [INFO] 22:45:58 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.777167 > threshold: 0.1
# [INFO] 22:45:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:45:58 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 507 of 529.
# [INFO] 22:45:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:46:46 - CalibrationWorkflow: Obj Treshold reached with 63 iteration, best cost: 0.007045924493192826, values: {'FEED1MASSFLOW': 13620.27436689572, 'FEED1TEMP': 19.63704469656584, 'PROD1MASSFLOW': 34654.51038701771, 'PROD1TEMP': 128.805281875239, 'E1FOULING': 0.00025000792392334756, 'E2FOULING': 0.00025142912124708204}
# [INFO] 22:46:46 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.346226 > threshold: 0.1
# [INFO] 22:46:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:46:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 508 of 529.
# [INFO] 22:46:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:46:55 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 1.5330153424318132e-05, values: {'FEED1MASSFLOW': 13644.67830461279, 'FEED1TEMP': 20.07020317139242, 'PROD1MASSFLOW': 34775.11099994354, 'PROD1TEMP': 126.3504462702761, 'E1FOULING': 0.00038576554640283426, 'E2FOULING': 0.0004571001937927427}
# [INFO] 22:46:56 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.267542 > threshold: 0.1
# [INFO] 22:46:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:46:56 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 509 of 529.
# [INFO] 22:46:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:47:10 - CalibrationWorkflow: Obj Treshold reached with 17 iteration, best cost: 8.877806331110246e-06, values: {'FEED1MASSFLOW': 13346.49373614571, 'FEED1TEMP': 19.60188993342847, 'PROD1MASSFLOW': 34916.85085696288, 'PROD1TEMP': 127.0623981190557, 'E1FOULING': 0.00025, 'E2FOULING': 0.000507160880838429}
# [INFO] 22:47:10 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.859080 > threshold: 0.1
# [INFO] 22:47:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:47:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 510 of 529.
# [INFO] 22:47:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:48:24 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.767562 > threshold: 0.1
# [INFO] 22:48:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:48:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 511 of 529.
# [INFO] 22:48:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:48:47 - CalibrationWorkflow: Obj Treshold reached with 29 iteration, best cost: 0.009500144705818139, values: {'FEED1MASSFLOW': 13726.95788671875, 'FEED1TEMP': 19.86310415215531, 'PROD1MASSFLOW': 34639.18833004832, 'PROD1TEMP': 129.0635052473672, 'E1FOULING': 0.00025, 'E2FOULING': 0.0007039354267385864}
# [INFO] 22:48:47 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.045187 > threshold: 0.1
# [INFO] 22:48:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:48:47 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 512 of 529.
# [INFO] 22:48:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:48:55 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 0.009436156625857554, values: {'FEED1MASSFLOW': 13766.80636447861, 'FEED1TEMP': 19.82999074920533, 'PROD1MASSFLOW': 36087.67058309269, 'PROD1TEMP': 127.4517716655803, 'E1FOULING': 0.000577879849802913, 'E2FOULING': 0.0003152488403031367}
# [INFO] 22:48:56 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.140753 > threshold: 0.1
# [INFO] 22:48:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:48:56 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 513 of 529.
# [INFO] 22:48:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:49:04 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 1.0784206087271997e-05, values: {'FEED1MASSFLOW': 13892.86282542806, 'FEED1TEMP': 19.74733446761203, 'PROD1MASSFLOW': 34547.00334725757, 'PROD1TEMP': 125.9578022370135, 'E1FOULING': 0.0003635445101309451, 'E2FOULING': 0.0005791443237268036}
# [INFO] 22:49:04 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.166622 > threshold: 0.1
# [INFO] 22:49:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:49:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 514 of 529.
# [INFO] 22:49:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:49:15 - CalibrationWorkflow: Obj Treshold reached with 13 iteration, best cost: 0.008045962499909217, values: {'FEED1MASSFLOW': 13659.14182919502, 'FEED1TEMP': 19.67169907645779, 'PROD1MASSFLOW': 34075.05785309214, 'PROD1TEMP': 127.742943778597, 'E1FOULING': 0.0002550611846575402, 'E2FOULING': 0.0005272860660584043}
# [INFO] 22:49:15 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.562726 > threshold: 0.1
# [INFO] 22:49:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:49:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 515 of 529.
# [INFO] 22:49:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:49:27 - CalibrationWorkflow: Obj Treshold reached with 15 iteration, best cost: 0.00829593716722305, values: {'FEED1MASSFLOW': 13446.23225120787, 'FEED1TEMP': 20.06623393859448, 'PROD1MASSFLOW': 34322.13868500174, 'PROD1TEMP': 125.2841647247034, 'E1FOULING': 0.0002515192569123067, 'E2FOULING': 0.00028293586089477593}
# [INFO] 22:49:27 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.199736 > threshold: 0.1
# [INFO] 22:49:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:49:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 516 of 529.
# [INFO] 22:49:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:49:36 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 0.007148341128664255, values: {'FEED1MASSFLOW': 13153.73470081068, 'FEED1TEMP': 19.631740839806, 'PROD1MASSFLOW': 34459.58525000857, 'PROD1TEMP': 127.1071217371806, 'E1FOULING': 0.00032816519433034506, 'E2FOULING': 0.0006169147145937215}
# [INFO] 22:49:36 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.395730 > threshold: 0.1
# [INFO] 22:49:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:49:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 517 of 529.
# [INFO] 22:49:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:49:54 - CalibrationWorkflow: Obj Treshold reached with 23 iteration, best cost: 1.0029308606713208e-05, values: {'FEED1MASSFLOW': 13432.96831314839, 'FEED1TEMP': 20.03079581838237, 'PROD1MASSFLOW': 34778.16427305674, 'PROD1TEMP': 129.410996339145, 'E1FOULING': 0.00028812772252619843, 'E2FOULING': 0.0005756327486566486}
# [INFO] 22:49:54 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.785857 > threshold: 0.1
# [INFO] 22:49:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:49:54 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 518 of 529.
# [INFO] 22:49:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:50:34 - CalibrationWorkflow: Obj Treshold reached with 52 iteration, best cost: 1.2294725571098994e-05, values: {'FEED1MASSFLOW': 13389.10627836312, 'FEED1TEMP': 20.00940520749543, 'PROD1MASSFLOW': 35184.59183121471, 'PROD1TEMP': 128.043630919933, 'E1FOULING': 0.0002607296248821023, 'E2FOULING': 0.00025551447177344153}
# [INFO] 22:50:34 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.241353 > threshold: 0.1
# [INFO] 22:50:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:50:34 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 519 of 529.
# [INFO] 22:50:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:50:52 - CalibrationWorkflow: Obj Treshold reached with 22 iteration, best cost: 4.1785108878283085e-06, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.0003783992079321191, 'E2FOULING': 0.0005326872739175392}
# [INFO] 22:50:52 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.220331 > threshold: 0.1
# [INFO] 22:50:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:50:52 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 22:50:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:51:15 - CalibrationWorkflow: Obj Treshold reached with 29 iteration, best cost: 0.009246626793950517, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.0002502382352779203, 'E2FOULING': 0.0005759447922327491}
# [INFO] 22:51:15 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.803498 > threshold: 0.1
# [INFO] 22:51:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:51:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 22:51:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:51:28 - CalibrationWorkflow: Obj Treshold reached with 16 iteration, best cost: 8.238418003723587e-06, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.000262627547408005, 'E2FOULING': 0.000434644722762549}
# [INFO] 22:51:28 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.944406 > threshold: 0.1
# [INFO] 22:51:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:51:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 22:51:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:51:41 - CalibrationWorkflow: Obj Treshold reached with 15 iteration, best cost: 1.0811006232313899e-05, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.00040474711343102825, 'E2FOULING': 0.0005740490901294393}
# [INFO] 22:51:41 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.130729 > threshold: 0.1
# [INFO] 22:51:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:51:41 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 22:51:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:51:49 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 9.313825981268803e-06, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.00025901680236996977, 'E2FOULING': 0.0003453807888074345}
# [INFO] 22:51:49 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.128950 > threshold: 0.1
# [INFO] 22:51:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:51:49 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 22:51:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:51:56 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 7.147854358065425e-06, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0003719361320165647, 'E2FOULING': 0.0004948911453819566}
# [INFO] 22:51:56 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.227752 > threshold: 0.1
# [INFO] 22:51:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:51:56 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 22:51:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:53:07 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.736366 > threshold: 0.1
# [INFO] 22:53:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:53:07 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 22:53:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:53:23 - CalibrationWorkflow: Obj Treshold reached with 19 iteration, best cost: 1.1821999938987424e-05, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0003626217853586074, 'E2FOULING': 0.0005552773665817924}
# [INFO] 22:53:23 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.174204 > threshold: 0.1
# [INFO] 22:53:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:53:23 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 22:53:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:53:32 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 2.0642936986899524e-05, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00027531312904391364, 'E2FOULING': 0.00034841354040580355}
# [INFO] 22:53:32 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.588810 > threshold: 0.1
# [INFO] 22:53:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:53:32 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 22:53:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:54:14 - CalibrationWorkflow: Treshold reached with 53 iteration, best cost: 0.2502501064263671, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.00031601973242272925, 'E2FOULING': 0.0010594702814665077}
# [INFO] 22:54:14 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.731569 > threshold: 0.1
# [INFO] 22:54:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:54:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 22:54:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:54:24 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 7.462107490092473e-06, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003779255691984607}
# [INFO] 22:54:25 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.878810 > threshold: 0.1
# [INFO] 22:54:25 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/Surrogate_base/02_Calibration_static_BNN.xlsx')
# Out:
# [INFO] 22:54:31 - CalibrationWorkflow: Calibration results saved to ./Results/Surrogate_base/Calibration_adaptive_surrogate_no_direct.xlsx

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_excel('../02_Base_Surrogate_Training/Adaptive_train_data.xlsx', index_col=0)
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-both',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/AdaptivedatFNN/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 22:16:50 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 22:16:50 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/AdaptivedatFNN/sklearnann.joblib
# [INFO] 22:16:50 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 22:16:50 - CalibrationWorkflow:
# ============================================================
# [INFO] 22:16:50 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 22:16:50 - CalibrationWorkflow: ============================================================
#
# [INFO] 22:16:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:16:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 22:16:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:16:50 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.01146311158719026, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 22:16:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.450269 > threshold: 0.1
# [INFO] 22:16:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:16:51 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:16:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:16:59 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.024866896990211558, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.000454642400927646, 'E2FOULING': 0.0003778589187391116}
# [INFO] 22:16:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.024867 < threshold 0.100000
# [INFO] 22:16:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:16:59 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:16:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:16:59 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 22:16:59 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 22:16:59 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 22:16:59 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:16:59 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 22:16:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:16:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 22:16:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:00 - CalibrationWorkflow: Treshold reached with 11 iteration, best cost: 0.01107026802943791, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00025100475568216765, 'E2FOULING': 0.00025}
# [INFO] 22:17:00 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.317017 > threshold: 0.1
# [INFO] 22:17:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:00 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:17:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:12 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.2926316129089626e-05, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00034767156274939106, 'E2FOULING': 0.0003860093662246201}
# [INFO] 22:17:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000013 < threshold 0.100000
# [INFO] 22:17:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:17:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:12 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 22:17:12 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 22:17:12 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 22:17:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:17:12 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 22:17:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 22:17:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:13 - CalibrationWorkflow: Treshold reached with 18 iteration, best cost: 0.013647177812043854, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 22:17:13 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.292664 > threshold: 0.1
# [INFO] 22:17:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:13 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:17:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:24 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.2132722978851659e-05, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.0004279798727397173, 'E2FOULING': 0.0003596268526809493}
# [INFO] 22:17:24 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 22:17:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:24 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:17:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:24 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 22:17:24 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 22:17:24 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 22:17:24 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:17:24 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 22:17:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 22:17:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:25 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 8.138347476447708e-06, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00044441910579463324, 'E2FOULING': 0.00025}
# [INFO] 22:17:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.060850 < threshold 0.100000
# [INFO] 22:17:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:17:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:25 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:17:25 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:17:25 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 22:17:25 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:17:25 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:17:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 22:17:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:25 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 6.4047862118744905e-06, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00035042761214066373, 'E2FOULING': 0.00025}
# [INFO] 22:17:25 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.101780 > threshold: 0.1
# [INFO] 22:17:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:25 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:17:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:34 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.039833751649738784, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0003247142820745395, 'E2FOULING': 0.0005636063119299768}
# [INFO] 22:17:34 - CalibrationWorkflow: Working point is accurate enough with cost: 0.039834 < threshold 0.100000
# [INFO] 22:17:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:34 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:17:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:34 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 22:17:34 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 22:17:34 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 22:17:34 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:17:34 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 22:17:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:34 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 22:17:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:34 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 0.009853470003306405, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.0004378786561936545, 'E2FOULING': 0.00036784323016318167}
# [INFO] 22:17:34 - CalibrationWorkflow: Working point is accurate enough with cost: 0.016232 < threshold 0.100000
# [INFO] 22:17:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:34 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:17:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:34 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:17:34 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:17:34 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 22:17:34 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:17:34 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:17:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 22:17:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:35 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 7.852938339383008e-06, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00043845211752964095, 'E2FOULING': 0.0003704077877506104}
# [INFO] 22:17:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.018099 < threshold 0.100000
# [INFO] 22:17:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:35 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:17:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:35 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:17:35 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:17:35 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 22:17:35 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:17:35 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:17:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 22:17:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:36 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 2.047547160069255e-05, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0005659946047450893, 'E2FOULING': 0.00025}
# [INFO] 22:17:36 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.118419 > threshold: 0.1
# [INFO] 22:17:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:36 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:17:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:43 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.03163321597361267, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0003932417518613894, 'E2FOULING': 0.00052380059625826}
# [INFO] 22:17:43 - CalibrationWorkflow: Working point is accurate enough with cost: 0.031633 < threshold 0.100000
# [INFO] 22:17:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:43 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:17:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:43 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 22:17:43 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 22:17:43 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 22:17:43 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:17:43 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 22:17:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 22:17:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:44 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.963759328021098e-06, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00042881992298283647, 'E2FOULING': 0.00033209447667432014}
# [INFO] 22:17:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 22:17:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:17:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:44 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:17:44 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:17:44 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 22:17:44 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:17:44 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:17:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 22:17:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:44 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.476778370596332e-05, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00034442700885671816, 'E2FOULING': 0.0004831442300375985}
# [INFO] 22:17:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.045816 < threshold 0.100000
# [INFO] 22:17:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:17:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:44 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:17:44 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:17:44 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 22:17:44 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:17:44 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:17:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 22:17:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:45 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.0448419113329075e-05, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00041429148741035926, 'E2FOULING': 0.0005094676144394156}
# [INFO] 22:17:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.017599 < threshold 0.100000
# [INFO] 22:17:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:45 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:17:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:45 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:17:45 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:17:45 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 22:17:45 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:17:45 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:17:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 22:17:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:46 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 5.140918451252106e-06, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0005043184330977765, 'E2FOULING': 0.0005424721617661435}
# [INFO] 22:17:46 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.120417 > threshold: 0.1
# [INFO] 22:17:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:46 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:17:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:55 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 4.739523548941974e-06, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0004287102638023952, 'E2FOULING': 0.0003637213075327468}
# [INFO] 22:17:55 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 22:17:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:55 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:17:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:55 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 22:17:55 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 22:17:55 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 22:17:55 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:17:55 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 22:17:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:55 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 22:17:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:55 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 5.547611972074093e-06, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.00048126625533494497, 'E2FOULING': 0.0005454314054762453}
# [INFO] 22:17:55 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.113197 > threshold: 0.1
# [INFO] 22:17:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:17:55 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:17:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:04 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.0275230816619638e-05, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.00035790615506030147, 'E2FOULING': 0.00039343922059703726}
# [INFO] 22:18:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 22:18:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:04 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:04 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 22:18:04 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 22:18:04 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 22:18:04 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:04 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 22:18:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 22:18:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:05 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.2374017624079652e-05, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00034759200239305285, 'E2FOULING': 0.00047632628340366437}
# [INFO] 22:18:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.011062 < threshold 0.100000
# [INFO] 22:18:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:05 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:05 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:05 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:05 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 22:18:05 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:05 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 22:18:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:05 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 6.58997354188901e-06, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0006599748810537792, 'E2FOULING': 0.0005132502942032208}
# [INFO] 22:18:05 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.185491 > threshold: 0.1
# [INFO] 22:18:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:05 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:18:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:11 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.07489054488610242, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.000593973169310648, 'E2FOULING': 0.0004680087591730389}
# [INFO] 22:18:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.074891 < threshold 0.100000
# [INFO] 22:18:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:11 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:11 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 22:18:11 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 22:18:11 - CalibrationWorkflow: Self.model updated to online_v14
# [INFO] 22:18:11 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:11 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 22:18:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 22:18:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:11 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.9132890543407985e-06, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.000376472366264714, 'E2FOULING': 0.0004931146096090609}
# [INFO] 22:18:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.018585 < threshold 0.100000
# [INFO] 22:18:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:11 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:11 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:11 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:11 - CalibrationWorkflow: Self.model updated to online_v15
# [INFO] 22:18:11 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:11 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 22:18:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:12 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 4.082556101885402e-06, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0003583296161347853, 'E2FOULING': 0.0005451625842264724}
# [INFO] 22:18:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.042212 < threshold 0.100000
# [INFO] 22:18:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:12 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:12 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:12 - CalibrationWorkflow: Self.model updated to online_v16
# [INFO] 22:18:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:12 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 22:18:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:12 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 9.213281964949356e-06, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.000384613220341313, 'E2FOULING': 0.0005868005731329229}
# [INFO] 22:18:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.038345 < threshold 0.100000
# [INFO] 22:18:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:12 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:12 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:12 - CalibrationWorkflow: Self.model updated to online_v17
# [INFO] 22:18:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:12 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 22:18:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:13 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 4.930690039047944e-06, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.00036283476051525193, 'E2FOULING': 0.0004883927870351102}
# [INFO] 22:18:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 22:18:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:13 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:13 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:13 - CalibrationWorkflow: Self.model updated to online_v18
# [INFO] 22:18:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:13 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 22:18:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:14 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 4.423655002526389e-06, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00029578372380377693, 'E2FOULING': 0.0004463316302744936}
# [INFO] 22:18:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.040326 < threshold 0.100000
# [INFO] 22:18:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:14 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:14 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:14 - CalibrationWorkflow: Self.model updated to online_v19
# [INFO] 22:18:14 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:14 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 22:18:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:14 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 1.0150871889831756e-06, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0003991093780786421, 'E2FOULING': 0.0004543969620738763}
# [INFO] 22:18:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 22:18:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:14 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:14 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:14 - CalibrationWorkflow: Self.model updated to online_v20
# [INFO] 22:18:14 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:14 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 22:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:15 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 5.100972788792466e-06, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0004561806281289764, 'E2FOULING': 0.0003377434055927579}
# [INFO] 22:18:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 22:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:15 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:15 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:15 - CalibrationWorkflow: Self.model updated to online_v21
# [INFO] 22:18:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:15 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 22:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:16 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 8.323359719074257e-06, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.00037955968255185495, 'E2FOULING': 0.000517920089243984}
# [INFO] 22:18:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.013231 < threshold 0.100000
# [INFO] 22:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:16 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:16 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:16 - CalibrationWorkflow: Self.model updated to online_v22
# [INFO] 22:18:16 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:16 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 22:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:16 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.2371592018146993e-05, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.00040242658786998967, 'E2FOULING': 0.0004976610415979265}
# [INFO] 22:18:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.007958 < threshold 0.100000
# [INFO] 22:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:16 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:16 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:16 - CalibrationWorkflow: Self.model updated to online_v23
# [INFO] 22:18:16 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:16 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 22:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:17 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.008109718328661907, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0004319914088550561, 'E2FOULING': 0.00025}
# [INFO] 22:18:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.086942 < threshold 0.100000
# [INFO] 22:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:17 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:17 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:17 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:17 - CalibrationWorkflow: Self.model updated to online_v24
# [INFO] 22:18:17 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:17 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 22:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:17 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 5.612423301305065e-07, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.0004072864451112483, 'E2FOULING': 0.0003486970597760924}
# [INFO] 22:18:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 22:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:17 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:17 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:17 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:17 - CalibrationWorkflow: Self.model updated to online_v25
# [INFO] 22:18:17 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:17 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:18 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 22:18:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:18 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.0039445095585946e-05, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.0004939034831433866, 'E2FOULING': 0.00025}
# [INFO] 22:18:18 - CalibrationWorkflow: Working point is accurate enough with cost: 0.068774 < threshold 0.100000
# [INFO] 22:18:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:18 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:18 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:18 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:18 - CalibrationWorkflow: Self.model updated to online_v26
# [INFO] 22:18:18 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:18 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 22:18:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:19 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 2.4217788490652945e-06, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.0003728591473337506, 'E2FOULING': 0.0002924433876334571}
# [INFO] 22:18:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.017009 < threshold 0.100000
# [INFO] 22:18:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:19 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:19 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:19 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:19 - CalibrationWorkflow: Self.model updated to online_v27
# [INFO] 22:18:19 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:19 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 22:18:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:19 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.7776367750439073e-06, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.0004921779498988707, 'E2FOULING': 0.00038198747294784655}
# [INFO] 22:18:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.022522 < threshold 0.100000
# [INFO] 22:18:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:19 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:18:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:19 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:18:19 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:18:19 - CalibrationWorkflow: Self.model updated to online_v28
# [INFO] 22:18:19 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:18:19 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:18:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:20 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 29 of 529.
# [INFO] 22:18:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:18:20 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 4.896892482448472e-07, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.0003812483335315609, 'E2FOULING': 0.00040378297018586187}
# [INFO] 22:18:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 22:18:20 - CalibrationWorkflow: ----------------------------------------
# ...
# [INFO] 22:26:51 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:26:51 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:26:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:26:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 22:26:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:26:51 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 5.358236653067666e-06, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.0005019808190744923, 'E2FOULING': 0.0004117572870479058}
# [INFO] 22:26:51 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 22:26:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:26:51 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:26:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:26:51 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:26:51 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:26:51 - CalibrationWorkflow: Self.model updated to online_v520
# [INFO] 22:26:51 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:26:51 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:26:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:26:52 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 22:26:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:26:52 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.3347296628302241e-05, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.00042964597049337613, 'E2FOULING': 0.0003325623954559705}
# [INFO] 22:26:52 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.142666 > threshold: 0.1
# [INFO] 22:26:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:26:52 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:26:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:01 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.07566082737105843, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.00044050202025034996, 'E2FOULING': 0.0005240145104251149}
# [INFO] 22:27:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.075661 < threshold 0.100000
# [INFO] 22:27:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:27:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:01 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 22:27:01 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 22:27:01 - CalibrationWorkflow: Self.model updated to online_v521
# [INFO] 22:27:01 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:27:01 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 22:27:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 22:27:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:02 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 5.129904445558857e-06, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005762944914406139, 'E2FOULING': 0.00045806726104116627}
# [INFO] 22:27:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.019188 < threshold 0.100000
# [INFO] 22:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:02 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:27:02 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:27:02 - CalibrationWorkflow: Self.model updated to online_v522
# [INFO] 22:27:02 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:27:02 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 22:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:02 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 3.807018596926716e-06, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.00047830724102204236, 'E2FOULING': 0.00039609751914002793}
# [INFO] 22:27:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.038367 < threshold 0.100000
# [INFO] 22:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:02 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:27:02 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:27:02 - CalibrationWorkflow: Self.model updated to online_v523
# [INFO] 22:27:02 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:27:02 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:27:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 22:27:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:03 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 8.527097873826199e-06, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.00048371100745533084, 'E2FOULING': 0.00037192984153765066}
# [INFO] 22:27:03 - CalibrationWorkflow: Working point is accurate enough with cost: 0.020466 < threshold 0.100000
# [INFO] 22:27:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:03 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:27:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:03 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:27:03 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:27:03 - CalibrationWorkflow: Self.model updated to online_v524
# [INFO] 22:27:03 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:27:03 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:27:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 22:27:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:04 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 7.675349566574526e-07, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.0003789615337098051, 'E2FOULING': 0.00039642955008150455}
# [INFO] 22:27:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.069412 < threshold 0.100000
# [INFO] 22:27:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:04 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:27:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:04 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:27:04 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:27:04 - CalibrationWorkflow: Self.model updated to online_v525
# [INFO] 22:27:04 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:27:04 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:27:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 22:27:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:04 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.009014537296487683, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.00033555131593248716, 'E2FOULING': 0.0003776566455357792}
# [INFO] 22:27:04 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.273098 > threshold: 0.1
# [INFO] 22:27:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:04 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:27:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:13 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.017829323673611962, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0004915383694164025, 'E2FOULING': 0.0005240988659781433}
# [INFO] 22:27:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.017829 < threshold 0.100000
# [INFO] 22:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:13 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 22:27:13 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 22:27:13 - CalibrationWorkflow: Self.model updated to online_v526
# [INFO] 22:27:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:27:13 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 22:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 22:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:13 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.0797824089297408e-06, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0004809139291097321, 'E2FOULING': 0.000446647952609937}
# [INFO] 22:27:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 22:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:13 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:27:13 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:27:13 - CalibrationWorkflow: Self.model updated to online_v527
# [INFO] 22:27:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:27:13 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 22:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:14 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 3.758880440149044e-06, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0005604865146655814, 'E2FOULING': 0.00044636494995273766}
# [INFO] 22:27:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.023344 < threshold 0.100000
# [INFO] 22:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:14 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:27:14 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:27:14 - CalibrationWorkflow: Self.model updated to online_v528
# [INFO] 22:27:14 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:27:14 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 22:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:14 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.4393887799137946e-06, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0005414287544915446, 'E2FOULING': 0.0004828498549803008}
# [INFO] 22:27:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.014713 < threshold 0.100000
# [INFO] 22:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 22:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:27:14 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 22:27:14 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:27:14 - CalibrationWorkflow: Self.model updated to online_v529
# [INFO] 22:27:14 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:27:14 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 22:27:15 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/04_Calibration_Online_FNN-BNN-low_always-both.xlsx')
# Out:
# [INFO] 22:28:01 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_FNN-BNN_always-both.xlsx

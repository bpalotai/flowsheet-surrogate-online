# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_200.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodel/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.05, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 14:54:48 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 14:54:48 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodel/sklearnann.joblib
# [INFO] 14:54:48 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.05, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 14:54:48 - CalibrationWorkflow:
# ============================================================
# [INFO] 14:54:48 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 14:54:48 - CalibrationWorkflow: ============================================================
#
# [INFO] 14:54:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:54:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 14:54:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:54:48 - CalibrationWorkflow: Treshold reached with 8 iteration, best cost: 0.11373207515391552, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 14:54:49 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.493398 > threshold: 0.1
# [INFO] 14:54:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:54:49 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:54:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:55:40 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.26167998222491934, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004976088928818681}
# [INFO] 14:55:40 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.261680 > threshold: 0.1
# [INFO] 14:55:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:55:40 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:55:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:55:40 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:55:40 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:55:40 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 14:55:40 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:55:40 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:55:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:55:41 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 14:55:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:55:41 - CalibrationWorkflow: Treshold reached with 22 iteration, best cost: 0.10799906282896267, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00030330065733801567, 'E2FOULING': 0.0002575543410675781}
# [INFO] 14:55:41 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.169949 > threshold: 0.1
# [INFO] 14:55:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:55:41 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:55:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:55:53 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.07605178173732724, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0004289150264630291, 'E2FOULING': 0.00025}
# [INFO] 14:55:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.076052 < threshold 0.100000
# [INFO] 14:55:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:55:53 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:55:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:55:53 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:55:53 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:55:53 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 14:55:53 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:55:53 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:55:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:55:54 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 14:55:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:55:55 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.10640498300288576, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 14:55:55 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.321865 > threshold: 0.1
# [INFO] 14:55:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:55:55 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:55:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:56:04 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.053901576782307475, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.0004205528042120482, 'E2FOULING': 0.00025}
# [INFO] 14:56:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.053902 < threshold 0.100000
# [INFO] 14:56:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:56:04 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:56:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:56:04 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:56:04 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:56:04 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 14:56:04 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:56:04 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:56:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:56:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 14:56:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:56:06 - CalibrationWorkflow: Treshold reached with 26 iteration, best cost: 0.07276106749329986, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0003679371014381783, 'E2FOULING': 0.00025054868798226964}
# [INFO] 14:56:06 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.119950 > threshold: 0.1
# [INFO] 14:56:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:56:06 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:56:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:56:23 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.0753359136767321, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0004770760835622548, 'E2FOULING': 0.00025}
# [INFO] 14:56:23 - CalibrationWorkflow: Working point is accurate enough with cost: 0.075336 < threshold 0.100000
# [INFO] 14:56:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:56:23 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:56:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:56:23 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:56:23 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:56:23 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 14:56:23 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:56:23 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:56:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:56:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 14:56:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:56:25 - CalibrationWorkflow: Treshold reached with 29 iteration, best cost: 0.07853333430202454, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025051643267726977, 'E2FOULING': 0.00029890163898866197}
# [INFO] 14:56:25 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.242425 > threshold: 0.1
# [INFO] 14:56:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:56:25 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:56:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:08 - CalibrationWorkflow: Treshold reached with 20 iteration, best cost: 0.15580571347101918, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.000512626355170879}
# [INFO] 14:57:08 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.155806 > threshold: 0.1
# [INFO] 14:57:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:08 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:57:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:08 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:57:08 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:57:08 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 14:57:08 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:57:08 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:57:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 14:57:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:09 - CalibrationWorkflow: Treshold reached with 10 iteration, best cost: 0.08187552518649767, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025048240659011255}
# [INFO] 14:57:09 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.352425 > threshold: 0.1
# [INFO] 14:57:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:09 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:57:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:23 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.0712615495211534, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00043804336720644065, 'E2FOULING': 0.00025}
# [INFO] 14:57:23 - CalibrationWorkflow: Working point is accurate enough with cost: 0.071262 < threshold 0.100000
# [INFO] 14:57:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:23 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:57:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:23 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:57:23 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:57:23 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 14:57:23 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:57:23 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:57:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 14:57:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:24 - CalibrationWorkflow: Treshold reached with 10 iteration, best cost: 0.07254782666615639, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 14:57:24 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.284353 > threshold: 0.1
# [INFO] 14:57:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:24 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:57:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:36 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.05084533014882505, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00040534478871922494, 'E2FOULING': 0.00025}
# [INFO] 14:57:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.050845 < threshold 0.100000
# [INFO] 14:57:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:36 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:57:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:36 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:57:36 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:57:36 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 14:57:36 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:57:36 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:57:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 14:57:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:38 - CalibrationWorkflow: Treshold reached with 33 iteration, best cost: 0.05975612511708253, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0005146708567442236, 'E2FOULING': 0.0002629166586297604}
# [INFO] 14:57:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.080393 < threshold 0.100000
# [INFO] 14:57:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:57:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:38 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:57:38 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:57:38 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 14:57:38 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:57:38 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:57:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 14:57:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:40 - CalibrationWorkflow: Treshold reached with 21 iteration, best cost: 0.046325570546507086, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.0002976688715250735, 'E2FOULING': 0.00025}
# [INFO] 14:57:40 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.178023 > threshold: 0.1
# [INFO] 14:57:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:40 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:57:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:55 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.09514249681578854, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.0005213984915530519, 'E2FOULING': 0.00025}
# [INFO] 14:57:55 - CalibrationWorkflow: Working point is accurate enough with cost: 0.095142 < threshold 0.100000
# [INFO] 14:57:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:55 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:57:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:55 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:57:55 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:57:55 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 14:57:55 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:57:55 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:57:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:55 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 14:57:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:57 - CalibrationWorkflow: Treshold reached with 32 iteration, best cost: 0.033498106990676596, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00025, 'E2FOULING': 0.000364125601190562}
# [INFO] 14:57:57 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.382745 > threshold: 0.1
# [INFO] 14:57:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:57:57 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:57:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:11 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.050219653927857565, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00045877857762604396, 'E2FOULING': 0.0002971162770174544}
# [INFO] 14:58:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.050220 < threshold 0.100000
# [INFO] 14:58:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:11 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:58:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:11 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:58:11 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:58:11 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 14:58:11 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:58:11 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:58:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 14:58:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:13 - CalibrationWorkflow: Treshold reached with 38 iteration, best cost: 0.04006632444837825, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.0004871092201101889, 'E2FOULING': 0.00029943074053231255}
# [INFO] 14:58:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.048087 < threshold 0.100000
# [INFO] 14:58:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:58:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:13 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:58:13 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:58:13 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 14:58:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:58:13 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:58:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 14:58:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:14 - CalibrationWorkflow: Treshold reached with 12 iteration, best cost: 0.040568678180407935, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0004945041470134492, 'E2FOULING': 0.00033472781260767505}
# [INFO] 14:58:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.046075 < threshold 0.100000
# [INFO] 14:58:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:58:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:14 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:58:14 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:58:14 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 14:58:14 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:58:14 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:58:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 14:58:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:16 - CalibrationWorkflow: Treshold reached with 26 iteration, best cost: 0.03559593519742223, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.00045667795533433156, 'E2FOULING': 0.00033914848131103026}
# [INFO] 14:58:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.023472 < threshold 0.100000
# [INFO] 14:58:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:58:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:16 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:58:16 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:58:16 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 14:58:16 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:58:16 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:58:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 14:58:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:18 - CalibrationWorkflow: Treshold reached with 27 iteration, best cost: 0.038725483715262805, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.0003331919013645249, 'E2FOULING': 0.000350507417905568}
# [INFO] 14:58:18 - CalibrationWorkflow: Working point is accurate enough with cost: 0.032208 < threshold 0.100000
# [INFO] 14:58:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:18 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:58:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:18 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:58:18 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:58:18 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 14:58:18 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:58:18 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:58:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 14:58:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:20 - CalibrationWorkflow: Treshold reached with 14 iteration, best cost: 0.013281833309175784, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0006880358905601043, 'E2FOULING': 0.00029348331110186517}
# [INFO] 14:58:20 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.140094 > threshold: 0.1
# [INFO] 14:58:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:20 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:58:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:34 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.05933942746588783, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0005305753944025771, 'E2FOULING': 0.00025}
# [INFO] 14:58:34 - CalibrationWorkflow: Working point is accurate enough with cost: 0.059339 < threshold 0.100000
# [INFO] 14:58:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:34 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:58:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:34 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:58:34 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:58:34 - CalibrationWorkflow: Self.model updated to online_v14
# [INFO] 14:58:34 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:58:34 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:58:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 14:58:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:36 - CalibrationWorkflow: Treshold reached with 22 iteration, best cost: 0.027437842907664486, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0004510142677732479, 'E2FOULING': 0.00025}
# [INFO] 14:58:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.062066 < threshold 0.100000
# [INFO] 14:58:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:36 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:58:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:36 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:58:36 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:58:36 - CalibrationWorkflow: Self.model updated to online_v15
# [INFO] 14:58:36 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:58:36 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:58:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 14:58:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:38 - CalibrationWorkflow: Treshold reached with 41 iteration, best cost: 0.032384317551163104, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.00041782047538866887, 'E2FOULING': 0.0002740017156249834}
# [INFO] 14:58:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.042927 < threshold 0.100000
# [INFO] 14:58:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:58:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:38 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:58:38 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:58:38 - CalibrationWorkflow: Self.model updated to online_v16
# [INFO] 14:58:38 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:58:38 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:58:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 14:58:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:40 - CalibrationWorkflow: Treshold reached with 25 iteration, best cost: 0.02446299306642444, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.0005079279746813198, 'E2FOULING': 0.00033392373024278255}
# [INFO] 14:58:40 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.100271 > threshold: 0.1
# [INFO] 14:58:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:40 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:58:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:56 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.08934587342133699, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.00038151659213132833, 'E2FOULING': 0.00025}
# [INFO] 14:58:56 - CalibrationWorkflow: Working point is accurate enough with cost: 0.089346 < threshold 0.100000
# [INFO] 14:58:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:56 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:58:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:56 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:58:56 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:58:56 - CalibrationWorkflow: Self.model updated to online_v17
# [INFO] 14:58:56 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:58:56 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:58:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 14:58:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:58 - CalibrationWorkflow: Treshold reached with 25 iteration, best cost: 0.0183238020488657, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.0003252458050449385, 'E2FOULING': 0.00043658565897894836}
# [INFO] 14:58:58 - CalibrationWorkflow: Working point is accurate enough with cost: 0.018330 < threshold 0.100000
# [INFO] 14:58:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:58 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:58:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:58 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:58:58 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:58:58 - CalibrationWorkflow: Self.model updated to online_v18
# [INFO] 14:58:58 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:58:58 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:58:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:58:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 14:58:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:00 - CalibrationWorkflow: Treshold reached with 23 iteration, best cost: 0.019041210648410557, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.0002731066976626215, 'E2FOULING': 0.00043941842026244666}
# [INFO] 14:59:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.076873 < threshold 0.100000
# [INFO] 14:59:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:00 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:59:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:00 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:59:00 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:59:00 - CalibrationWorkflow: Self.model updated to online_v19
# [INFO] 14:59:00 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:59:00 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:59:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 14:59:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:02 - CalibrationWorkflow: Treshold reached with 32 iteration, best cost: 0.02417647612159673, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0004678625940667492, 'E2FOULING': 0.0004140896421796926}
# [INFO] 14:59:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.038119 < threshold 0.100000
# [INFO] 14:59:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:59:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:02 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:59:02 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:59:02 - CalibrationWorkflow: Self.model updated to online_v20
# [INFO] 14:59:02 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:59:02 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:59:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 14:59:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:04 - CalibrationWorkflow: Treshold reached with 14 iteration, best cost: 0.012348737898891047, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0005227077064795449, 'E2FOULING': 0.0003910127453189327}
# [INFO] 14:59:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.062593 < threshold 0.100000
# [INFO] 14:59:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:04 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:59:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:04 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:59:04 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:59:04 - CalibrationWorkflow: Self.model updated to online_v21
# [INFO] 14:59:04 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:59:04 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:59:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 14:59:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:06 - CalibrationWorkflow: Treshold reached with 45 iteration, best cost: 0.0199425992052309, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.0005363231610861036, 'E2FOULING': 0.00038543609707913104}
# [INFO] 14:59:06 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.105268 > threshold: 0.1
# [INFO] 14:59:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:06 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:59:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:16 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.05490107222300311, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.00047979529855222443, 'E2FOULING': 0.00029484878512992544}
# [INFO] 14:59:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.054901 < threshold 0.100000
# [INFO] 14:59:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:59:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:16 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:59:16 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:59:16 - CalibrationWorkflow: Self.model updated to online_v22
# [INFO] 14:59:16 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:59:16 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:59:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 14:59:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:18 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.008982500204160386, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.00048015204356258574, 'E2FOULING': 0.0004655253304012851}
# [INFO] 14:59:18 - CalibrationWorkflow: Working point is accurate enough with cost: 0.034425 < threshold 0.100000
# [INFO] 14:59:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:18 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:59:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:18 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:59:18 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:59:18 - CalibrationWorkflow: Self.model updated to online_v23
# [INFO] 14:59:18 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:59:18 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:59:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 14:59:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:20 - CalibrationWorkflow: Treshold reached with 33 iteration, best cost: 0.01637475734151592, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.00033672406909270535, 'E2FOULING': 0.0004689476542131307}
# [INFO] 14:59:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.013957 < threshold 0.100000
# [INFO] 14:59:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:20 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:59:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:20 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:59:20 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:59:20 - CalibrationWorkflow: Self.model updated to online_v24
# [INFO] 14:59:20 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:59:20 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:59:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 14:59:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:22 - CalibrationWorkflow: Treshold reached with 22 iteration, best cost: 0.012635324303283672, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.0005051453356218252, 'E2FOULING': 0.0004491370103716651}
# [INFO] 14:59:22 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.128495 > threshold: 0.1
# [INFO] 14:59:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:22 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:59:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:38 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.07270595982299961, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.00042833102796246356, 'E2FOULING': 0.00025}
# [INFO] 14:59:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.072706 < threshold 0.100000
# [INFO] 14:59:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:59:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:38 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:59:38 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:59:38 - CalibrationWorkflow: Self.model updated to online_v25
# [INFO] 14:59:38 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:59:38 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:59:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 14:59:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:39 - CalibrationWorkflow: Treshold reached with 14 iteration, best cost: 0.011366239698278453, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.0005638138088590169, 'E2FOULING': 0.00035866239865074717}
# [INFO] 14:59:39 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.104007 > threshold: 0.1
# [INFO] 14:59:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:39 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:59:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:53 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.08227992570193525, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.0005006191486930972, 'E2FOULING': 0.00025}
# [INFO] 14:59:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.082280 < threshold 0.100000
# [INFO] 14:59:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:53 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:59:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:59:53 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:59:53 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 14:59:53 - CalibrationWorkflow: Self.model updated to online_v26
# [INFO] 14:59:53 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# ...
# [INFO] 15:22:48 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 15:22:48 - CalibrationWorkflow: Self.model updated to online_v520
# [INFO] 15:22:48 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:22:48 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:22:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:22:49 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 15:22:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:22:49 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.606256252994103e-05, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.00046946979513534524, 'E2FOULING': 0.0003753250143911104}
# [INFO] 15:22:49 - CalibrationWorkflow: Working point is accurate enough with cost: 0.046034 < threshold 0.100000
# [INFO] 15:22:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:22:49 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:22:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:22:49 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:22:49 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 15:22:49 - CalibrationWorkflow: Self.model updated to online_v521
# [INFO] 15:22:49 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:22:49 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:22:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:22:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 15:22:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:22:50 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 0.007572867446130251, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005377331559726419, 'E2FOULING': 0.0005530073703776503}
# [INFO] 15:22:50 - CalibrationWorkflow: Working point is accurate enough with cost: 0.022618 < threshold 0.100000
# [INFO] 15:22:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:22:50 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:22:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:22:50 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:22:50 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 15:22:50 - CalibrationWorkflow: Self.model updated to online_v522
# [INFO] 15:22:50 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:22:50 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:22:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:22:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 15:22:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:22:52 - CalibrationWorkflow: Obj Treshold reached with 18 iteration, best cost: 0.007124150821256614, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.00045042874009916767, 'E2FOULING': 0.0003604677198144999}
# [INFO] 15:22:52 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.111313 > threshold: 0.1
# [INFO] 15:22:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:22:52 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:22:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:07 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.036875441460885665, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0005085530672104293, 'E2FOULING': 0.00035459191878994486}
# [INFO] 15:23:07 - CalibrationWorkflow: Working point is accurate enough with cost: 0.036875 < threshold 0.100000
# [INFO] 15:23:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:07 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:23:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:07 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:23:07 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 15:23:07 - CalibrationWorkflow: Self.model updated to online_v523
# [INFO] 15:23:07 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:23:07 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:23:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:08 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 15:23:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:08 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 1.0992932648942482e-05, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0005337809649365306, 'E2FOULING': 0.0004289532521946326}
# [INFO] 15:23:08 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 15:23:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:08 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:23:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:08 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:23:08 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 15:23:08 - CalibrationWorkflow: Self.model updated to online_v524
# [INFO] 15:23:08 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:23:08 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:23:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 15:23:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:09 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 0.00993087435947834, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00035325446246318217, 'E2FOULING': 0.0002940200286622668}
# [INFO] 15:23:09 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.229622 > threshold: 0.1
# [INFO] 15:23:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:09 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:23:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:21 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.07217319679069936, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.0005081176626786984, 'E2FOULING': 0.00030455941861219285}
# [INFO] 15:23:21 - CalibrationWorkflow: Working point is accurate enough with cost: 0.072173 < threshold 0.100000
# [INFO] 15:23:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:21 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:23:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:21 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:23:21 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 15:23:21 - CalibrationWorkflow: Self.model updated to online_v525
# [INFO] 15:23:21 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:23:21 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:23:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 15:23:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:22 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.0566555083331173e-05, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.00030904876890284084, 'E2FOULING': 0.0004676316809402205}
# [INFO] 15:23:22 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.369901 > threshold: 0.1
# [INFO] 15:23:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:22 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:23:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:44 - CalibrationWorkflow: Treshold reached with 9 iteration, best cost: 0.1674927170839635, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0005027528430121599, 'E2FOULING': 0.00025}
# [INFO] 15:23:44 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.167493 > threshold: 0.1
# [INFO] 15:23:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:23:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:44 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:23:44 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 15:23:44 - CalibrationWorkflow: Self.model updated to online_v526
# [INFO] 15:23:44 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:23:44 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:23:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 15:23:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:45 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.007191539779274225, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00044506234667248534, 'E2FOULING': 0.00034801910558245237}
# [INFO] 15:23:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.034889 < threshold 0.100000
# [INFO] 15:23:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:45 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:23:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:45 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:23:45 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 15:23:45 - CalibrationWorkflow: Self.model updated to online_v527
# [INFO] 15:23:45 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:23:45 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:23:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 15:23:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:46 - CalibrationWorkflow: Obj Treshold reached with 16 iteration, best cost: 0.007104827894242944, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.000416061816945619, 'E2FOULING': 0.0004453515270110678}
# [INFO] 15:23:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.069049 < threshold 0.100000
# [INFO] 15:23:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:46 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:23:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:46 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:23:46 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 15:23:46 - CalibrationWorkflow: Self.model updated to online_v528
# [INFO] 15:23:46 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:23:46 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:23:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:47 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 15:23:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:48 - CalibrationWorkflow: Treshold reached with 29 iteration, best cost: 0.03609507867781056, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0004818106068332395, 'E2FOULING': 0.00025}
# [INFO] 15:23:48 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.177162 > threshold: 0.1
# [INFO] 15:23:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:23:48 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:23:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:25:05 - CalibrationWorkflow: Treshold reached with 36 iteration, best cost: 0.13793765789232335, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0005264878150806093, 'E2FOULING': 0.0002630950406126153}
# [INFO] 15:25:05 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.137938 > threshold: 0.1
# [INFO] 15:25:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:25:05 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:25:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:25:05 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:25:05 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 15:25:05 - CalibrationWorkflow: Self.model updated to online_v529
# [INFO] 15:25:05 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:25:05 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:25:06 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/Calibration_result_online_always-one-replay-0.05.xlsx')
# Out:
# [INFO] 15:25:06 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_always-one-replay-0.05.xlsx

# %%
res = workflow.get_results()

# %%
resdf = pd.DataFrame(res)

# %%
resdf.columns
# Out:
# Index(['SampleID', 'Total_workflow_EllapsedTime', 'Calibration_type',
#        'OriginalFactors', 'Target', 'Calibration_Base_Type',
#        'Calibration_Base_EllapsedTime', 'Calibration_Base_IterationNum',
#        'Calibration_Base_Final_obj', 'Calibration_Base_FinalIO',
#        'Calibration_Base_SurrogatePred', 'Validation_Base_SimulationRes',
#        'Validation_Base_SimCost', 'Validation_Base_Accurate',
#        'Validation_Base_Decision', 'Calibration_Direct_EllapsedTime',
#        'Calibration_Direct_IterationNum', 'Calibration_Direct_Final_obj',
#        'Calibration_Direct_FinalIO', 'Calibration_Direct_SimCost',
#        'Calibration_Direct_Accuracy', 'Calibration_Direct_Decision',
#        'OnlineLearning_New_Data', 'OnlineLearning_New_SelectionType',
#        'OnlineLearning_New_DataType', 'OnlineLearning_EllapsedTime',
#        'OnlineLearning_SelectedReplayids', 'OnlineLearning_SelectedReplayIOs',
#        'LocalImprovement', 'GlobalRetention', 'Used_Surrogate_version',
#        'New_Surrogate_version', 'Final_Calibration_Result_IOs',
#        'Final_Calibration_SimCost', 'Final_Calibration_Accurate',
#        'Final_Calibration_Type'],
#       dtype='object')

# %%
resdf['Validation_Base_Accurate'].value_counts()
# Out:
# Validation_Base_Accurate
# True     473
# False     57
# Name: count, dtype: int64

# %%
resdf['Final_Calibration_Accurate'].value_counts()
# Out:
# Final_Calibration_Accurate
# True     522
# False      8
# Name: count, dtype: int64

# %%
workflow_settings['sim_validation_treshold']
# Out:
# 0.1

# %%
import seaborn as sns

#sns.kdeplot(resdf['Calibration_Base_Final_obj'], label='Surrogate obj',  fill=True, linewidth=2, clip=(0, None))
sns.kdeplot(resdf['Validation_Base_SimCost'], label='Validation obj',  fill=True, linewidth=2, clip=(0, None))
sns.kdeplot(resdf['Final_Calibration_SimCost'], label='Final Calib obj',  fill=True, linewidth=2, clip=(0, None))
plt.axvline(x=workflow_settings['sim_validation_treshold'], color='red', linestyle='--', label='Threshold')
plt.legend()

# %%
resdf['Calibration_Direct_EllapsedTime'].plot()
# Out:
# <Axes: >

# %%
resdf['LocalImprovement'].mean()
# Out:
# 14.724197904035801

# %%
resdf['GlobalRetention'].plot()
# Out:
# <Axes: >

# %%
resdf
# Out:
#      SampleID  Total_workflow_EllapsedTime Calibration_type  \
# 0           0                    52.879399           online
# 1           1                    13.743777           online
# 2           2                    10.367253           online
# 3           3                    19.491568           online
# 4           4                    44.761856           online
# ..        ...                          ...              ...
# 525       525                    12.545106           online
# 526       526                    23.006889           online
# 527       527                     1.114627           online
# 528       528                     1.478426           online
# 529       529                    78.613117           online
#
#                                        OriginalFactors  \
# 0    {'E1FOULING': 0.0003966064602180043, 'E2FOULIN...
# 1    {'E1FOULING': 0.0003858453451426925, 'E2FOULIN...
# 2    {'E1FOULING': 0.0003847697530392205, 'E2FOULIN...
# 3    {'E1FOULING': 0.0004268043194975153, 'E2FOULIN...
# 4    {'E1FOULING': 0.0003682943731335989, 'E2FOULIN...
# ..                                                 ...
# 525  {'E1FOULING': 0.0004548607687919593, 'E2FOULIN...
# 526  {'E1FOULING': 0.0004822419516333996, 'E2FOULIN...
# 527  {'E1FOULING': 0.0004733674673527922, 'E2FOULIN...
# 528  {'E1FOULING': 0.0004984942750080559, 'E2FOULIN...
# 529  {'E1FOULING': 0.0005021358045441324, 'E2FOULIN...
#
#                                                 Target  \
# 0    {'PROD1E1IN': 108.2722567668642, 'PROD1OUT': 9...
# 1    {'PROD1E1IN': 104.3535050140472, 'PROD1OUT': 9...
# 2    {'PROD1E1IN': 105.9350937121914, 'PROD1OUT': 9...
# 3    {'PROD1E1IN': 106.0854462410004, 'PROD1OUT': 9...
# 4    {'PROD1E1IN': 105.0075133590793, 'PROD1OUT': 9...
# ..                                                 ...
# 525  {'PROD1E1IN': 116.9302158164906, 'PROD1OUT': 1...
# 526  {'PROD1E1IN': 116.2112946019632, 'PROD1OUT': 1...
# 527  {'PROD1E1IN': 116.4229042179647, 'PROD1OUT': 1...
# 528  {'PROD1E1IN': 116.8454717819132, 'PROD1OUT': 1...
# 529  {'PROD1E1IN': 116.0362633732756, 'PROD1OUT': 1...
#
#          Calibration_Base_Type  Calibration_Base_EllapsedTime  \
# 0    CalibrationType.SURROGATE                       0.363589
# 1    CalibrationType.SURROGATE                       0.818091
# 2    CalibrationType.SURROGATE                       0.282180
# 3    CalibrationType.SURROGATE                       0.947271
# 4    CalibrationType.SURROGATE                       1.013661
# ..                         ...                            ...
# 525  CalibrationType.SURROGATE                       0.382880
# 526  CalibrationType.SURROGATE                       0.226095
# 527  CalibrationType.SURROGATE                       0.226408
# 528  CalibrationType.SURROGATE                       0.580853
# 529  CalibrationType.SURROGATE                       0.941617
#
#      Calibration_Base_IterationNum  Calibration_Base_Final_obj  \
# 0                               10                    0.113732
# 1                               24                    0.107999
# 2                                8                    0.106405
# 3                               28                    0.072761
# 4                               31                    0.078533
# ..                             ...                         ...
# 525                             11                    0.009931
# 526                              8                    0.000011
# 527                              7                    0.007192
# 528                             18                    0.007105
# 529                             31                    0.036095
#
#                               Calibration_Base_FinalIO  ...  \
# 0    {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEM...  ...
# 1    {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEM...  ...
# 2    {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEM...  ...
# 3    {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEM...  ...
# 4    {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEM...  ...
# ..                                                 ...  ...
# 525  {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP...  ...
# 526  {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEM...  ...
# 527  {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEM...  ...
# 528  {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEM...  ...
# 529  {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEM...  ...
#
#                    OnlineLearning_SelectedReplayids  \
# 0     [49, 115, 108, 60, 161, 134, 23, 47, 173, 68]
# 1     [121, 84, 12, 109, 13, 138, 40, 145, 77, 170]
# 2     [33, 76, 155, 183, 46, 41, 148, 177, 99, 136]
# 3    [184, 23, 159, 49, 122, 142, 37, 126, 48, 107]
# 4       [199, 103, 34, 78, 82, 13, 63, 59, 146, 47]
# ..                                              ...
# 525      [178, 73, 93, 54, 179, 39, 3, 25, 161, 21]
# 526      [3, 172, 4, 74, 182, 180, 43, 60, 91, 151]
# 527   [114, 135, 64, 19, 185, 160, 144, 68, 109, 0]
# 528   [120, 140, 186, 143, 95, 14, 33, 98, 89, 115]
# 529   [27, 75, 198, 101, 188, 138, 21, 30, 56, 105]
#
#     OnlineLearning_SelectedReplayIOs  LocalImprovement  GlobalRetention  \
# 0                               None          1.023108         1.008547
# 1                               None          1.052561         1.017453
# 2                               None          1.149527         1.028421
# 3                               None          1.086202         1.036226
# 4                               None          1.102665         1.044667
# ..                               ...               ...              ...
# 525                             None          1.054997         3.765214
# 526                             None          1.137592         3.752840
# 527                             None          1.221721         3.719615
# 528                             None          1.202890         3.686086
# 529                             None               NaN         3.651474
#
#     Used_Surrogate_version  New_Surrogate_version  \
# 0                     base              online_v0
# 1                online_v0              online_v1
# 2                online_v1              online_v2
# 3                online_v2              online_v3
# 4                online_v3              online_v4
# ..                     ...                    ...
# 525            online_v524            online_v525
# 526            online_v525            online_v526
# 527            online_v526            online_v527
# 528            online_v527            online_v528
# 529            online_v528            online_v529
#
#                           Final_Calibration_Result_IOs  \
# 0    {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEM...
# 1    {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEM...
# 2    {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEM...
# 3    {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEM...
# 4    {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEM...
# ..                                                 ...
# 525  {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP...
# 526  {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEM...
# 527  {'PROD1E1IN': 115.66645741441016, 'PROD1OUT': ...
# 528  {'PROD1E1IN': 116.98522435889168, 'PROD1OUT': ...
# 529  {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEM...
#
#      Final_Calibration_SimCost Final_Calibration_Accurate  \
# 0                     0.261680                      False
# 1                     0.076052                       True
# 2                     0.053902                       True
# 3                     0.075336                       True
# 4                     0.155806                      False
# ..                         ...                        ...
# 525                   0.072173                       True
# 526                   0.167493                      False
# 527                   0.034889                       True
# 528                   0.069049                       True
# 529                   0.137938                      False
#
#      Final_Calibration_Type
# 0                    direct
# 1                    direct
# 2                    direct
# 3                    direct
# 4                    direct
# ..                      ...
# 525                  direct
# 526                  direct
# 527              validation
# 528              validation
# 529                  direct
#
# [530 rows x 36 columns]

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_1000.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodelbig/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 09:59:38 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 09:59:38 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodelbig/sklearnann.joblib
# [INFO] 09:59:38 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 09:59:38 - CalibrationWorkflow:
# ============================================================
# [INFO] 09:59:38 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 09:59:38 - CalibrationWorkflow: ============================================================
#
# [INFO] 09:59:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 09:59:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:38 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.008337749654028486, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00028915387420906934, 'E2FOULING': 0.00032834489517422457}
# [INFO] 09:59:39 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.231281 > threshold: 0.1
# [INFO] 09:59:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:39 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:59:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:42 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.2853189651337188e-06, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 09:59:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 09:59:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:42 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 09:59:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:42 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 09:59:42 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 09:59:42 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 09:59:42 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 09:59:42 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 09:59:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 09:59:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:44 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.8948484646819654e-05, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0003496468704125709, 'E2FOULING': 0.0003787557253438092}
# [INFO] 09:59:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000017 < threshold 0.100000
# [INFO] 09:59:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 09:59:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:44 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 09:59:44 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 09:59:44 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 09:59:44 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 09:59:44 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 09:59:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:47 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 09:59:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:47 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 6.141454259108185e-06, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.0002675, 'E2FOULING': 0.0003103000000000001}
# [INFO] 09:59:47 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.206150 > threshold: 0.1
# [INFO] 09:59:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:47 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:59:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:51 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.008922461226396852, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.0003700000000000003, 'E2FOULING': 0.00039000000000000037}
# [INFO] 09:59:51 - CalibrationWorkflow: Working point is accurate enough with cost: 0.008922 < threshold 0.100000
# [INFO] 09:59:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:51 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 09:59:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:51 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 09:59:51 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 09:59:51 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 09:59:51 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 09:59:51 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 09:59:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 09:59:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:53 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 9.045210897342263e-06, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0003700000000000003, 'E2FOULING': 0.00039000000000000037}
# [INFO] 09:59:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.022713 < threshold 0.100000
# [INFO] 09:59:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:53 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 09:59:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:53 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 09:59:53 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 09:59:53 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 09:59:53 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 09:59:53 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 09:59:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:56 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 09:59:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:56 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 8.798885138042667e-06, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0003002510061855781, 'E2FOULING': 0.0004835840484538754}
# [INFO] 09:59:56 - CalibrationWorkflow: Working point is accurate enough with cost: 0.046654 < threshold 0.100000
# [INFO] 09:59:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:56 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 09:59:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:56 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 09:59:56 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 09:59:56 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 09:59:56 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 09:59:56 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 09:59:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 09:59:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:59 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 3.928749215530241e-06, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.0002975171399625686, 'E2FOULING': 0.0003353142833021406}
# [INFO] 09:59:59 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.112506 > threshold: 0.1
# [INFO] 09:59:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:59:59 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:59:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:02 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 5.348538256282878e-06, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.0003700000000000003, 'E2FOULING': 0.00039000000000000037}
# [INFO] 10:00:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 10:00:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:02 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 10:00:02 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:02 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 10:00:02 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:02 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 10:00:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 10:00:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:04 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 5.271047206741691e-06, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.0003062632217131756, 'E2FOULING': 0.00034260268476097975}
# [INFO] 10:00:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.066811 < threshold 0.100000
# [INFO] 10:00:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:05 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:05 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:05 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:05 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 10:00:05 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:05 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:07 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 10:00:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:07 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 4.441000395612043e-06, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:00:07 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 10:00:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:07 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:07 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:07 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:07 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 10:00:07 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:07 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 10:00:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:10 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 9.293763646945421e-06, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00030626371206656335, 'E2FOULING': 0.0003426030933888029}
# [INFO] 10:00:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.094940 < threshold 0.100000
# [INFO] 10:00:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:10 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:10 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:10 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:10 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 10:00:10 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:10 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 10:00:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:13 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 9.909491374217618e-07, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0003700000000000003, 'E2FOULING': 0.00039000000000000037}
# [INFO] 10:00:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.028837 < threshold 0.100000
# [INFO] 10:00:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:13 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:13 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:13 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 10:00:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:13 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 10:00:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:16 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 2.6404457908703285e-06, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:00:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 10:00:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:16 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:16 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:16 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 10:00:16 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:16 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:18 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 10:00:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:19 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 3.1920580454940943e-06, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:00:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 10:00:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:19 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:19 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:19 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:19 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 10:00:19 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:19 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 10:00:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:21 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 3.701087979519941e-06, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:00:21 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 10:00:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:21 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:21 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:21 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:21 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 10:00:21 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:21 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 10:00:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:24 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 5.79647000063771e-06, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.0003700000000000003, 'E2FOULING': 0.00039000000000000037}
# [INFO] 10:00:24 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 10:00:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:24 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:24 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:24 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:24 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 10:00:24 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:24 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 10:00:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:27 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 3.788920797066973e-06, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0005778000000000008, 'E2FOULING': 0.00042800000000000043}
# [INFO] 10:00:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.045685 < threshold 0.100000
# [INFO] 10:00:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:27 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:27 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:27 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:27 - CalibrationWorkflow: Self.model updated to online_v14
# [INFO] 10:00:27 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:27 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:30 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 10:00:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:30 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 4.052281139312384e-06, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0003700000000000003, 'E2FOULING': 0.00039000000000000037}
# [INFO] 10:00:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 10:00:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:30 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:30 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:30 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:30 - CalibrationWorkflow: Self.model updated to online_v15
# [INFO] 10:00:30 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:30 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:32 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 10:00:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:33 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.817788097817364e-06, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0003700000000000003, 'E2FOULING': 0.00039000000000000037}
# [INFO] 10:00:33 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 10:00:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:33 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:33 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:33 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:33 - CalibrationWorkflow: Self.model updated to online_v16
# [INFO] 10:00:33 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:33 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 10:00:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:35 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 7.758787550753794e-06, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:00:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 10:00:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:35 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:35 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:35 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:35 - CalibrationWorkflow: Self.model updated to online_v17
# [INFO] 10:00:35 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:35 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 10:00:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:38 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 6.751983874492539e-06, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:00:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 10:00:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:38 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:38 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:38 - CalibrationWorkflow: Self.model updated to online_v18
# [INFO] 10:00:38 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:38 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:41 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 10:00:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:41 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 7.427995333235577e-06, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.0003700000000000003, 'E2FOULING': 0.00039000000000000037}
# [INFO] 10:00:41 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 10:00:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:41 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:41 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:41 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:41 - CalibrationWorkflow: Self.model updated to online_v19
# [INFO] 10:00:41 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:41 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 10:00:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:44 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 5.706013533420784e-06, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:00:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 10:00:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:44 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:44 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:44 - CalibrationWorkflow: Self.model updated to online_v20
# [INFO] 10:00:44 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:44 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:47 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 10:00:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:47 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 9.710424958705732e-06, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:00:47 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 10:00:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:47 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:47 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:47 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:47 - CalibrationWorkflow: Self.model updated to online_v21
# [INFO] 10:00:47 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:47 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:49 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 10:00:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:49 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 2.778334397776813e-06, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:00:49 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 10:00:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:49 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:49 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:49 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:49 - CalibrationWorkflow: Self.model updated to online_v22
# [INFO] 10:00:49 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:49 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:52 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 10:00:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:52 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 5.129603896072612e-06, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:00:52 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 10:00:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:52 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:52 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:52 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:52 - CalibrationWorkflow: Self.model updated to online_v23
# [INFO] 10:00:52 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:52 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:55 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 10:00:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:55 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 7.631368120947166e-06, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:00:55 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 10:00:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:55 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:55 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:55 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:55 - CalibrationWorkflow: Self.model updated to online_v24
# [INFO] 10:00:55 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:55 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:00:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:58 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 10:00:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:58 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 9.059933042871802e-06, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:00:58 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000007 < threshold 0.100000
# [INFO] 10:00:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:58 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:00:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:00:58 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:00:58 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:00:58 - CalibrationWorkflow: Self.model updated to online_v25
# [INFO] 10:00:58 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:00:58 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:01:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 10:01:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:01 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 6.77706747634416e-06, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:01:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 10:01:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:01:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:01 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:01:01 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:01:01 - CalibrationWorkflow: Self.model updated to online_v26
# [INFO] 10:01:01 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:01:01 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:01:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 10:01:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:03 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 3.981317511020988e-06, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.0003700000000000003, 'E2FOULING': 0.00039000000000000037}
# [INFO] 10:01:03 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 10:01:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:03 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:01:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:03 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:01:03 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:01:03 - CalibrationWorkflow: Self.model updated to online_v27
# [INFO] 10:01:03 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:01:03 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:01:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 10:01:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:06 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.0463772903437372e-05, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.00044370964143465336, 'E2FOULING': 0.0004201123318490976}
# [INFO] 10:01:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 10:01:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:06 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:01:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:06 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:01:06 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:01:06 - CalibrationWorkflow: Self.model updated to online_v28
# [INFO] 10:01:06 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:01:06 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:01:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 29 of 529.
# [INFO] 10:01:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:09 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 9.561645365650039e-06, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:01:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 10:01:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:09 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:01:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:09 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:01:09 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:01:09 - CalibrationWorkflow: Self.model updated to online_v29
# [INFO] 10:01:09 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:01:09 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:01:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 30 of 529.
# [INFO] 10:01:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:12 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.09012931979181923, values: {'FEED1MASSFLOW': 18170.33282487203, 'FEED1TEMP': 24.88142490999688, 'PROD1MASSFLOW': 45110.96621847873, 'PROD1TEMP': 115.0679318499356, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 10:01:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 10:01:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:01:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:12 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:01:12 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:01:12 - CalibrationWorkflow: Self.model updated to online_v30
# [INFO] 10:01:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:01:12 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:01:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 31 of 529.
# [INFO] 10:01:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:15 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.13130111131164754, values: {'FEED1MASSFLOW': 18607.84387976851, 'FEED1TEMP': 25.14488217461214, 'PROD1MASSFLOW': 43738.61199857389, 'PROD1TEMP': 115.3747174316839, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 10:01:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 10:01:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:01:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:15 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:01:15 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:01:15 - CalibrationWorkflow: Self.model updated to online_v31
# [INFO] 10:01:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:01:15 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:01:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 32 of 529.
# [INFO] 10:01:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:01:18 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.14347684075528533, values: {'FEED1MASSFLOW': 19115.08117402765, 'FEED1TEMP': 24.77391698651811, 'PROD1MASSFLOW': 42751.55908633373, 'PROD1TEMP': 115.3524481338415, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 10:01:18 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# ...
# [INFO] 10:24:56 - CalibrationWorkflow: Working point is accurate enough with cost: 0.022523 < threshold 0.100000
# [INFO] 10:24:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:24:56 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:24:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:24:56 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:24:56 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:24:56 - CalibrationWorkflow: Self.model updated to online_v519
# [INFO] 10:24:56 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:24:56 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:24:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:24:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 10:24:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:24:59 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 6.09321629448683e-06, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.0004517428805301743, 'E2FOULING': 0.00042058487532530475}
# [INFO] 10:24:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.020167 < threshold 0.100000
# [INFO] 10:24:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:24:59 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:24:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:24:59 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:24:59 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:24:59 - CalibrationWorkflow: Self.model updated to online_v520
# [INFO] 10:24:59 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:24:59 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:25:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 10:25:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:02 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 5.910408371390454e-06, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0004341909096195064, 'E2FOULING': 0.00041955240644820665}
# [INFO] 10:25:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.084563 < threshold 0.100000
# [INFO] 10:25:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:25:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:02 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:25:02 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:25:02 - CalibrationWorkflow: Self.model updated to online_v521
# [INFO] 10:25:02 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:25:02 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:25:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 10:25:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:05 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.1010371639772263e-05, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005400000000000008, 'E2FOULING': 0.0004000000000000004}
# [INFO] 10:25:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000019 < threshold 0.100000
# [INFO] 10:25:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:05 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:25:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:05 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:25:05 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:25:05 - CalibrationWorkflow: Self.model updated to online_v522
# [INFO] 10:25:05 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:25:05 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:25:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:08 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 10:25:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:08 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.3483029186817581e-05, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0004326485786943253, 'E2FOULING': 0.00041946168109966656}
# [INFO] 10:25:08 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.114476 > threshold: 0.1
# [INFO] 10:25:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:08 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 10:25:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:10 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.013809412905207704, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0005400000000000008, 'E2FOULING': 0.0004000000000000004}
# [INFO] 10:25:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.013809 < threshold 0.100000
# [INFO] 10:25:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:10 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:25:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:10 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 10:25:10 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:25:10 - CalibrationWorkflow: Self.model updated to online_v523
# [INFO] 10:25:10 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:25:10 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 10:25:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 10:25:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:13 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 8.92735366815635e-06, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0005400000000000008, 'E2FOULING': 0.0004000000000000004}
# [INFO] 10:25:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 10:25:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:25:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:13 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:25:13 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:25:13 - CalibrationWorkflow: Self.model updated to online_v524
# [INFO] 10:25:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:25:13 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:25:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 10:25:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:16 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 8.746274864881754e-07, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:25:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.040066 < threshold 0.100000
# [INFO] 10:25:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:25:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:16 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:25:16 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:25:16 - CalibrationWorkflow: Self.model updated to online_v525
# [INFO] 10:25:16 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:25:16 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:25:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 10:25:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:19 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.2183584623200408e-05, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.00039590000000000035, 'E2FOULING': 0.0004173000000000004}
# [INFO] 10:25:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.092329 < threshold 0.100000
# [INFO] 10:25:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:19 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:25:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:19 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:25:19 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:25:19 - CalibrationWorkflow: Self.model updated to online_v526
# [INFO] 10:25:19 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:25:19 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:25:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 10:25:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:22 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 2.4962088907966995e-06, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00046329244715627264, 'E2FOULING': 0.0004212642615974282}
# [INFO] 10:25:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 10:25:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:22 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:25:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:22 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:25:22 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:25:22 - CalibrationWorkflow: Self.model updated to online_v527
# [INFO] 10:25:22 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:25:22 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:25:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 10:25:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:25 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.2547947715678142e-05, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0005778000000000008, 'E2FOULING': 0.00042800000000000043}
# [INFO] 10:25:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.044461 < threshold 0.100000
# [INFO] 10:25:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:25:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:25 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:25:25 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:25:25 - CalibrationWorkflow: Self.model updated to online_v528
# [INFO] 10:25:25 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:25:25 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:25:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 10:25:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:28 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.0648978668099979e-05, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0005400000000000008, 'E2FOULING': 0.0004000000000000004}
# [INFO] 10:25:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.012449 < threshold 0.100000
# [INFO] 10:25:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:28 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:25:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:25:28 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:25:28 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 10:25:28 - CalibrationWorkflow: Self.model updated to online_v529
# [INFO] 10:25:28 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:25:28 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:25:30 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/03_Calibration_Online_FNN-high_always-one.xlsx')
# Out:
# [INFO] 10:28:42 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_always-one.xlsx

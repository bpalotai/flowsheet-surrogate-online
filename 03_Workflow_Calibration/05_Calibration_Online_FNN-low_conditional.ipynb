# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_200.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'conditional',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodel/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 23:00:58 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 23:00:58 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodel/sklearnann.joblib
# [INFO] 23:00:58 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 23:00:58 - CalibrationWorkflow:
# ============================================================
# [INFO] 23:00:58 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 23:00:58 - CalibrationWorkflow: ============================================================
#
# [INFO] 23:00:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:00:58 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 23:00:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:00:58 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.11373207515391552, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 23:00:58 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.493398 > threshold: 0.1
# [INFO] 23:00:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:00:58 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:00:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:01 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.07173923232209825, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:01:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.071739 < threshold 0.100000
# [INFO] 23:01:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:01 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:01:01 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 23:01:01 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:01:01 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:01:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 23:01:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:02 - CalibrationWorkflow: Treshold reached with 20 iteration, best cost: 0.10473728855939834, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0002671223759771538, 'E2FOULING': 0.0002843348290230022}
# [INFO] 23:01:03 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.243136 > threshold: 0.1
# [INFO] 23:01:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:03 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:01:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:05 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.03767383042377727, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:01:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.037674 < threshold 0.100000
# [INFO] 23:01:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:05 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:05 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:01:05 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 23:01:05 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:01:05 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:01:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 23:01:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:06 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.09261166944182177, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 23:01:06 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.320089 > threshold: 0.1
# [INFO] 23:01:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:06 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:01:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:10 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.03278151959217313, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:01:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.032782 < threshold 0.100000
# [INFO] 23:01:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:10 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:10 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:01:10 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 23:01:10 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:01:10 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:01:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 23:01:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:11 - CalibrationWorkflow: Treshold reached with 32 iteration, best cost: 0.06154153347299608, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0002685176053775098, 'E2FOULING': 0.00031056596892648663}
# [INFO] 23:01:11 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.338129 > threshold: 0.1
# [INFO] 23:01:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:11 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:01:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:16 - CalibrationWorkflow: Obj Treshold reached with 1 iteration, best cost: 0.06640508515362965, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00034689000000000014, 'E2FOULING': 0.00038046000000000027}
# [INFO] 23:01:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.066405 < threshold 0.100000
# [INFO] 23:01:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:16 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:01:16 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 23:01:16 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:01:16 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:01:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 23:01:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:17 - CalibrationWorkflow: Treshold reached with 27 iteration, best cost: 0.06093053639326324, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0002696681880709799, 'E2FOULING': 0.0003189673309252645}
# [INFO] 23:01:17 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.165581 > threshold: 0.1
# [INFO] 23:01:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:17 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:01:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:20 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.01685755453141396, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:01:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.016858 < threshold 0.100000
# [INFO] 23:01:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:20 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:20 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:01:20 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 23:01:20 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:01:20 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:01:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 23:01:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:22 - CalibrationWorkflow: Treshold reached with 15 iteration, best cost: 0.052049326767967065, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00025009829169342075, 'E2FOULING': 0.00032078775488712726}
# [INFO] 23:01:22 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.265386 > threshold: 0.1
# [INFO] 23:01:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:22 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:01:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:25 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.036845217462521514, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:01:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.036845 < threshold 0.100000
# [INFO] 23:01:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:25 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:01:25 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 23:01:25 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:01:25 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:01:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 23:01:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:26 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.0385396150291876, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003908851671523675}
# [INFO] 23:01:26 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.185147 > threshold: 0.1
# [INFO] 23:01:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:26 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:01:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:30 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.017398854859677942, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:01:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.017399 < threshold 0.100000
# [INFO] 23:01:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:30 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:30 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:01:30 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 23:01:30 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:01:30 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:01:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:30 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 23:01:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:31 - CalibrationWorkflow: Treshold reached with 28 iteration, best cost: 0.023353462764185266, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0004100198453946078, 'E2FOULING': 0.0003980411974467065}
# [INFO] 23:01:31 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 23:01:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:31 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:31 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:31 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:31 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:32 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 23:01:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:32 - CalibrationWorkflow: Treshold reached with 17 iteration, best cost: 0.018151646378922685, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.0002996784942353232, 'E2FOULING': 0.0002986673714887659}
# [INFO] 23:01:32 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.128621 > threshold: 0.1
# [INFO] 23:01:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:32 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:01:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:36 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.047505672431962395, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:01:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.047506 < threshold 0.100000
# [INFO] 23:01:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:36 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:36 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:01:36 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 23:01:36 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:01:36 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:01:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 23:01:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:37 - CalibrationWorkflow: Obj Treshold reached with 1 iteration, best cost: 0.009888929676471498, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00034689000000000014, 'E2FOULING': 0.00038046000000000027}
# [INFO] 23:01:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.058948 < threshold 0.100000
# [INFO] 23:01:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:37 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:37 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:37 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:37 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 23:01:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:38 - CalibrationWorkflow: Treshold reached with 17 iteration, best cost: 0.013340944956331754, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.0003804964970985065, 'E2FOULING': 0.0004157258499464015}
# [INFO] 23:01:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 23:01:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:38 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:38 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:38 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 23:01:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:40 - CalibrationWorkflow: Treshold reached with 33 iteration, best cost: 0.01690705691903423, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.00042265678580878543, 'E2FOULING': 0.00040015055768107775}
# [INFO] 23:01:40 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 23:01:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:40 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:40 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:40 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:40 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:40 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 23:01:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:41 - CalibrationWorkflow: Treshold reached with 32 iteration, best cost: 0.014705549690495276, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.00039914741579092684, 'E2FOULING': 0.00039856003627099164}
# [INFO] 23:01:41 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 23:01:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:41 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:41 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:41 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:41 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 23:01:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:43 - CalibrationWorkflow: Treshold reached with 35 iteration, best cost: 0.012893671358087461, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.0002853615313281015, 'E2FOULING': 0.00041864385590221424}
# [INFO] 23:01:43 - CalibrationWorkflow: Working point is accurate enough with cost: 0.090989 < threshold 0.100000
# [INFO] 23:01:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:43 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:43 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:43 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:43 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 23:01:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:44 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 0.009858367456789465, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0006488323051429068, 'E2FOULING': 0.00038116900223244106}
# [INFO] 23:01:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.093987 < threshold 0.100000
# [INFO] 23:01:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:44 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:44 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:44 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 23:01:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:45 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 0.008860120859005534, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0003120406781332068, 'E2FOULING': 0.0003499130260216281}
# [INFO] 23:01:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.063006 < threshold 0.100000
# [INFO] 23:01:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:45 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:45 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:45 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:45 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 23:01:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:46 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.008869994453273168, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0002925484700929024, 'E2FOULING': 0.0004188486038059816}
# [INFO] 23:01:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.081606 < threshold 0.100000
# [INFO] 23:01:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:46 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:46 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:46 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:46 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 23:01:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:47 - CalibrationWorkflow: Treshold reached with 23 iteration, best cost: 0.010134180107992575, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.0004036320518859246, 'E2FOULING': 0.0004329979356693219}
# [INFO] 23:01:47 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 23:01:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:47 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:47 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:47 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:47 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 23:01:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:48 - CalibrationWorkflow: Treshold reached with 25 iteration, best cost: 0.011869538741389015, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.00032176078054765053, 'E2FOULING': 0.0005265398547996226}
# [INFO] 23:01:48 - CalibrationWorkflow: Working point is accurate enough with cost: 0.029037 < threshold 0.100000
# [INFO] 23:01:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:48 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:48 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:48 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:48 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:49 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 23:01:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:49 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.009884238658414457, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00025, 'E2FOULING': 0.00041490119813093827}
# [INFO] 23:01:49 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.140944 > threshold: 0.1
# [INFO] 23:01:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:49 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:01:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:52 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.008014451978992917, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:01:52 - CalibrationWorkflow: Working point is accurate enough with cost: 0.008014 < threshold 0.100000
# [INFO] 23:01:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:52 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:52 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:01:52 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 23:01:52 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:01:52 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:01:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 23:01:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:53 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.009933282776574704, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0004629789902990776, 'E2FOULING': 0.0004576250335849507}
# [INFO] 23:01:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.042050 < threshold 0.100000
# [INFO] 23:01:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:53 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:53 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:53 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:53 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:54 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 23:01:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:54 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 2.259528006160065e-05, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.000526965489263541, 'E2FOULING': 0.00041378065642246883}
# [INFO] 23:01:54 - CalibrationWorkflow: Working point is accurate enough with cost: 0.084061 < threshold 0.100000
# [INFO] 23:01:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:54 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:54 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:54 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:54 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:55 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 23:01:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:55 - CalibrationWorkflow: Treshold reached with 8 iteration, best cost: 0.018204529864817163, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.00041023552063426704, 'E2FOULING': 0.0004161805051896188}
# [INFO] 23:01:55 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 23:01:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:55 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:55 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:55 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:55 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:56 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 23:01:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:56 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.545875338843867e-05, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.0004532188862915594, 'E2FOULING': 0.0004582858717391302}
# [INFO] 23:01:56 - CalibrationWorkflow: Working point is accurate enough with cost: 0.012298 < threshold 0.100000
# [INFO] 23:01:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:56 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:01:56 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:01:56 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:01:56 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:01:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 23:01:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:57 - CalibrationWorkflow: Treshold reached with 19 iteration, best cost: 0.013858167262535782, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0004990561839459274, 'E2FOULING': 0.0004886911044298311}
# [INFO] 23:01:57 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.124517 > threshold: 0.1
# [INFO] 23:01:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:01:57 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:01:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:00 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.01932565990428197, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:02:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.019326 < threshold 0.100000
# [INFO] 23:02:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:00 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:02:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:00 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:02:00 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 23:02:00 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:02:00 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:02:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 23:02:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:01 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.007949221298741878, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.0005241071226073147, 'E2FOULING': 0.0004996955805289504}
# [INFO] 23:02:01 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.190909 > threshold: 0.1
# [INFO] 23:02:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:01 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:02:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:04 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.009224063844670482, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:02:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.009224 < threshold 0.100000
# [INFO] 23:02:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:04 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:02:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:04 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:02:04 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 23:02:04 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:02:04 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:02:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 23:02:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:05 - CalibrationWorkflow: Obj Treshold reached with 15 iteration, best cost: 2.004838333004294e-05, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.0005113140848111841, 'E2FOULING': 0.0005190850470607358}
# [INFO] 23:02:05 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.117338 > threshold: 0.1
# [INFO] 23:02:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:05 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:02:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:08 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.05756898797722987, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:02:08 - CalibrationWorkflow: Working point is accurate enough with cost: 0.057569 < threshold 0.100000
# [INFO] 23:02:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:08 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:02:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:08 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:02:08 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 23:02:08 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:02:08 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:02:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 23:02:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:09 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 1.611483498017553e-05, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.0005990238867645849, 'E2FOULING': 0.00043756571525140064}
# [INFO] 23:02:09 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.281208 > threshold: 0.1
# [INFO] 23:02:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:09 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:02:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:12 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.023846490688850405, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:02:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.023846 < threshold 0.100000
# [INFO] 23:02:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:02:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:12 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:02:12 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 23:02:12 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:02:12 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:02:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 23:02:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:13 - CalibrationWorkflow: Obj Treshold reached with 19 iteration, best cost: 2.0116231900672068e-05, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.0006077869640198358, 'E2FOULING': 0.0005293158578772641}
# [INFO] 23:02:13 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.246339 > threshold: 0.1
# [INFO] 23:02:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:13 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:02:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:16 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.0630191827497924, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:02:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.063019 < threshold 0.100000
# [INFO] 23:02:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:02:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:16 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:02:16 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 23:02:16 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:02:16 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:02:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 29 of 529.
# [INFO] 23:02:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:17 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.2695110048978613e-05, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.0005626155588279838, 'E2FOULING': 0.0005247313555583604}
# [INFO] 23:02:17 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.291033 > threshold: 0.1
# [INFO] 23:02:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:02:17 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:02:17 - CalibrationWorkflow: ----------------------------------------
# ...
# [INFO] 23:20:50 - CalibrationWorkflow: Self.model updated to online_v104
# [INFO] 23:20:50 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:20:50 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:20:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:20:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 23:20:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:20:51 - CalibrationWorkflow: Obj Treshold reached with 1 iteration, best cost: 0.009667845692011172, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005791437922912695, 'E2FOULING': 0.0005266938692204292}
# [INFO] 23:20:51 - CalibrationWorkflow: Working point is accurate enough with cost: 0.045788 < threshold 0.100000
# [INFO] 23:20:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:20:51 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:20:51 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 23:20:51 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 23:20:51 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 23:20:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:20:52 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 23:20:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:20:52 - CalibrationWorkflow: Obj Treshold reached with 1 iteration, best cost: 1.5772213950720554e-05, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.00034689000000000014, 'E2FOULING': 0.00038046000000000027}
# [INFO] 23:20:52 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.455334 > threshold: 0.1
# [INFO] 23:20:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:20:52 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:20:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:20:58 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.07314670391507778, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0005930400115544438, 'E2FOULING': 0.0005403825448312578}
# [INFO] 23:20:58 - CalibrationWorkflow: Working point is accurate enough with cost: 0.073147 < threshold 0.100000
# [INFO] 23:20:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:20:58 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:20:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:20:58 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:20:58 - CalibrationWorkflow: Self.model updated to online_v105
# [INFO] 23:20:58 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:20:58 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:20:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:20:58 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 23:20:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:20:58 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.1311922983857387e-05, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0004099145300223147, 'E2FOULING': 0.00044276607307991325}
# [INFO] 23:20:58 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.117803 > threshold: 0.1
# [INFO] 23:20:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:20:58 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:20:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:05 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.04700404868118485, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0004422897345354678, 'E2FOULING': 0.0004454936476704799}
# [INFO] 23:21:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.047004 < threshold 0.100000
# [INFO] 23:21:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:05 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:21:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:05 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:21:05 - CalibrationWorkflow: Self.model updated to online_v106
# [INFO] 23:21:05 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:21:05 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:21:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 23:21:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:05 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 7.398004098528448e-06, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00031000000000000016, 'E2FOULING': 0.00034000000000000024}
# [INFO] 23:21:06 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.337671 > threshold: 0.1
# [INFO] 23:21:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:06 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:21:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:15 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.09106333143724307, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00037017627000000017, 'E2FOULING': 0.0004059997800000003}
# [INFO] 23:21:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.091063 < threshold 0.100000
# [INFO] 23:21:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:21:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:15 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:21:15 - CalibrationWorkflow: Self.model updated to online_v107
# [INFO] 23:21:15 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:21:15 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:21:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 23:21:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:16 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 6.5960616591195835e-06, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:21:16 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.331770 > threshold: 0.1
# [INFO] 23:21:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:16 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:21:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:24 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 3.465161615653389e-06, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0004631390706147704, 'E2FOULING': 0.00046209801112781864}
# [INFO] 23:21:24 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 23:21:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:24 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:21:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:24 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:21:24 - CalibrationWorkflow: Self.model updated to online_v108
# [INFO] 23:21:24 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:21:24 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:21:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 23:21:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:25 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 7.719400130721832e-06, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:21:25 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.286494 > threshold: 0.1
# [INFO] 23:21:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:25 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:21:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:34 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.015145708959750656, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00042875569521546924, 'E2FOULING': 0.0004430067528621124}
# [INFO] 23:21:34 - CalibrationWorkflow: Working point is accurate enough with cost: 0.015146 < threshold 0.100000
# [INFO] 23:21:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:34 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:21:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:34 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:21:34 - CalibrationWorkflow: Self.model updated to online_v109
# [INFO] 23:21:34 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:21:34 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:21:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 23:21:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:35 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.007896509061102047, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0003649661000000002, 'E2FOULING': 0.0004002854000000003}
# [INFO] 23:21:35 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.237155 > threshold: 0.1
# [INFO] 23:21:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:35 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:21:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:45 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 3.2979688326786593e-06, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.00047956194894471945, 'E2FOULING': 0.00047460532455219763}
# [INFO] 23:21:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 23:21:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:45 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:21:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:45 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:21:45 - CalibrationWorkflow: Self.model updated to online_v110
# [INFO] 23:21:45 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:21:45 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:21:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 23:21:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:46 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.006942303178893465, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.00033170000000000015, 'E2FOULING': 0.0003638000000000003}
# [INFO] 23:21:46 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.384697 > threshold: 0.1
# [INFO] 23:21:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:46 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:21:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:53 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.045991687174861594, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0004271239179965854, 'E2FOULING': 0.00045790169112618464}
# [INFO] 23:21:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.045992 < threshold 0.100000
# [INFO] 23:21:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:53 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 23:21:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:21:53 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:21:53 - CalibrationWorkflow: Self.model updated to online_v111
# [INFO] 23:21:53 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:21:53 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:21:53 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/05_Calibration_Online_FNN-low_conditional.xlsx')
# Out:
# [INFO] 23:22:32 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_conditional.xlsx

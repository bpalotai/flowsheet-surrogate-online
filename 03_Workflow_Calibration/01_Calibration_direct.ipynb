# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_200.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'direct', # direct, surrogate, online
                     'run_direct_for_not_accurate': False,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # This is the error inflexpoint of current y_fitt setting
                     'base_calibration_error_factor': 1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodel/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 18:40:19 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 18:40:19 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodel/sklearnann.joblib
# [INFO] 18:40:19 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 18:40:19 - CalibrationWorkflow:
# ============================================================
# [INFO] 18:40:19 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 18:40:19 - CalibrationWorkflow: ============================================================
#
# [INFO] 18:40:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:40:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 18:40:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:40:31 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 8.930300471644116e-06, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0004146986403340647, 'E2FOULING': 0.0003840533632513979}
# [INFO] 18:40:31 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 18:40:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:40:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 18:40:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:40:42 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.008061018321411654, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0004228876108994768, 'E2FOULING': 0.0004239976268357519}
# [INFO] 18:40:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.008061 < threshold 0.100000
# [INFO] 18:40:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:40:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 18:40:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:40:52 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 9.232088289239662e-06, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00041002245937125405, 'E2FOULING': 0.0003931977245459551}
# [INFO] 18:40:52 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 18:40:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:40:52 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 18:40:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:40:59 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 7.5342443336898e-06, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0004519305254226655, 'E2FOULING': 0.0004119619007930458}
# [INFO] 18:40:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 18:40:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:40:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 18:40:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:41:07 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.011432911380652727, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0003256888419699925, 'E2FOULING': 0.0003824577764527608}
# [INFO] 18:41:07 - CalibrationWorkflow: Working point is accurate enough with cost: 0.011433 < threshold 0.100000
# [INFO] 18:41:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:41:07 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 18:41:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:41:19 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.018999754915268636, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00039689073307282586, 'E2FOULING': 0.00029011658496404133}
# [INFO] 18:41:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.019000 < threshold 0.100000
# [INFO] 18:41:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:41:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 18:41:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:41:28 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.105784827216199e-05, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00034380670615121063, 'E2FOULING': 0.00040438412754410444}
# [INFO] 18:41:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000011 < threshold 0.100000
# [INFO] 18:41:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:41:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 18:41:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:41:34 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.013586511389097685, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.00045834105292492217, 'E2FOULING': 0.00045872490699855654}
# [INFO] 18:41:34 - CalibrationWorkflow: Working point is accurate enough with cost: 0.013587 < threshold 0.100000
# [INFO] 18:41:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:41:34 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 18:41:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:41:44 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.022354179588000782, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00043428206879828654, 'E2FOULING': 0.00041740621445545784}
# [INFO] 18:41:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.022354 < threshold 0.100000
# [INFO] 18:41:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:41:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 18:41:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:41:52 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.939914113440936e-06, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00043776382595109666, 'E2FOULING': 0.0004098647167142289}
# [INFO] 18:41:52 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 18:41:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:41:52 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 18:41:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:00 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.0258118380639065e-06, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00041369690531354263, 'E2FOULING': 0.0003815030257815066}
# [INFO] 18:42:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 18:42:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 18:42:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:11 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 7.895296480043407e-06, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0004423536691875173, 'E2FOULING': 0.0003741624503936119}
# [INFO] 18:42:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 18:42:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 18:42:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:22 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.713260553818782e-06, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0004125912825864477, 'E2FOULING': 0.00038763316558418397}
# [INFO] 18:42:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 18:42:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 18:42:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:29 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.117259003488627e-05, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00041908147531255165, 'E2FOULING': 0.0003744862647596361}
# [INFO] 18:42:29 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000011 < threshold 0.100000
# [INFO] 18:42:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 18:42:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:38 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 9.530553944451577e-06, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0004645031614137437, 'E2FOULING': 0.00041725770518836433}
# [INFO] 18:42:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 18:42:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 18:42:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:45 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.03243398289194636, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0003810092531174303, 'E2FOULING': 0.0005059645396466727}
# [INFO] 18:42:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.032434 < threshold 0.100000
# [INFO] 18:42:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 18:42:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:53 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.2197248937723493e-05, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0004260012377721141, 'E2FOULING': 0.0003429490059884228}
# [INFO] 18:42:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 18:42:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:42:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 18:42:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:00 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.4884025223185824e-05, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.0003990824895459047, 'E2FOULING': 0.0003460597118397791}
# [INFO] 18:43:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000015 < threshold 0.100000
# [INFO] 18:43:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 18:43:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:11 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 5.937518532605872e-06, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.000391933212127566, 'E2FOULING': 0.0004634769540057712}
# [INFO] 18:43:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 18:43:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 18:43:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:22 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.007802033534262802, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.0003750260018735213, 'E2FOULING': 0.00032179231513293754}
# [INFO] 18:43:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.007802 < threshold 0.100000
# [INFO] 18:43:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 18:43:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:32 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.345050598183077e-05, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.00042793399272921196, 'E2FOULING': 0.00035211178180117654}
# [INFO] 18:43:32 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000013 < threshold 0.100000
# [INFO] 18:43:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:32 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 18:43:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:43 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.013021964234033699, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0004055225072519563, 'E2FOULING': 0.0002947198627714395}
# [INFO] 18:43:43 - CalibrationWorkflow: Working point is accurate enough with cost: 0.013022 < threshold 0.100000
# [INFO] 18:43:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 18:43:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:49 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 2.0574526095053968e-05, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.000363084303421107, 'E2FOULING': 0.00048807580104825413}
# [INFO] 18:43:49 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000021 < threshold 0.100000
# [INFO] 18:43:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:49 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 18:43:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:55 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.05862258615368671, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.00043765604776645315, 'E2FOULING': 0.0005615605634360336}
# [INFO] 18:43:55 - CalibrationWorkflow: Working point is accurate enough with cost: 0.058623 < threshold 0.100000
# [INFO] 18:43:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:43:55 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 18:43:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:04 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 5.837166277747266e-06, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.00035076314086421767, 'E2FOULING': 0.00041276616468436224}
# [INFO] 18:44:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 18:44:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 18:44:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:10 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.3592432261478708e-05, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.00033952826092653783, 'E2FOULING': 0.0004721565151848797}
# [INFO] 18:44:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000014 < threshold 0.100000
# [INFO] 18:44:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 18:44:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:18 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.025316028428253586, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.000397648444258679, 'E2FOULING': 0.000521197378544503}
# [INFO] 18:44:18 - CalibrationWorkflow: Working point is accurate enough with cost: 0.025316 < threshold 0.100000
# [INFO] 18:44:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:18 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 18:44:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:27 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.3302923311313631e-05, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.0004245448772557488, 'E2FOULING': 0.00038827047604308594}
# [INFO] 18:44:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000013 < threshold 0.100000
# [INFO] 18:44:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 18:44:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:37 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 6.347550709111365e-06, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.0004488025797949774, 'E2FOULING': 0.0004065941380203868}
# [INFO] 18:44:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 18:44:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 29 of 529.
# [INFO] 18:44:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:44 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.015010460676901545, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.00032041834044879534, 'E2FOULING': 0.0005174369088223958}
# [INFO] 18:44:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.015010 < threshold 0.100000
# [INFO] 18:44:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 30 of 529.
# [INFO] 18:44:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:57 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 6.545093801276485e-06, values: {'FEED1MASSFLOW': 18170.33282487203, 'FEED1TEMP': 24.88142490999688, 'PROD1MASSFLOW': 45110.96621847873, 'PROD1TEMP': 115.0679318499356, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002816159552308672}
# [INFO] 18:44:57 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000007 < threshold 0.100000
# [INFO] 18:44:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:44:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 31 of 529.
# [INFO] 18:44:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:45:09 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.02071333765667145, values: {'FEED1MASSFLOW': 18607.84387976851, 'FEED1TEMP': 25.14488217461214, 'PROD1MASSFLOW': 43738.61199857389, 'PROD1TEMP': 115.3747174316839, 'E1FOULING': 0.00025, 'E2FOULING': 0.00034396625943768983}
# [INFO] 18:45:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.020713 < threshold 0.100000
# [INFO] 18:45:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:45:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 32 of 529.
# [INFO] 18:45:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:45:17 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.0895231395355104e-06, values: {'FEED1MASSFLOW': 19115.08117402765, 'FEED1TEMP': 24.77391698651811, 'PROD1MASSFLOW': 42751.55908633373, 'PROD1TEMP': 115.3524481338415, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 18:45:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 18:45:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:45:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 33 of 529.
# [INFO] 18:45:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:45:26 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.5144128540430578e-06, values: {'FEED1MASSFLOW': 19418.03437168451, 'FEED1TEMP': 25.0300579250388, 'PROD1MASSFLOW': 43087.88928120025, 'PROD1TEMP': 114.4650169900805, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 18:45:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 18:45:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:45:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 34 of 529.
# [INFO] 18:45:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:45:35 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.029639981486724025, values: {'FEED1MASSFLOW': 19996.37302723919, 'FEED1TEMP': 25.05396733167793, 'PROD1MASSFLOW': 39075.45922402187, 'PROD1TEMP': 115.4384103153362, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003527993075150122}
# [INFO] 18:45:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.029640 < threshold 0.100000
# [INFO] 18:45:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:45:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 35 of 529.
# [INFO] 18:45:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:45:44 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.5444579417375893e-06, values: {'FEED1MASSFLOW': 20114.96473047106, 'FEED1TEMP': 24.8676559665023, 'PROD1MASSFLOW': 40171.91798417241, 'PROD1TEMP': 115.7924017721878, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 18:45:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 18:45:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:45:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 36 of 529.
# [INFO] 18:45:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:45:57 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.00777450730649538, values: {'FEED1MASSFLOW': 20464.74060999631, 'FEED1TEMP': 25.14479618506942, 'PROD1MASSFLOW': 39328.05034260821, 'PROD1TEMP': 115.7990352506138, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003389359969997107}
# [INFO] 18:45:57 - CalibrationWorkflow: Working point is accurate enough with cost: 0.007775 < threshold 0.100000
# [INFO] 18:45:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:45:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 37 of 529.
# [INFO] 18:45:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:09 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.9204343975666867e-05, values: {'FEED1MASSFLOW': 20969.69452156387, 'FEED1TEMP': 25.25139017769914, 'PROD1MASSFLOW': 39239.44675475179, 'PROD1TEMP': 115.2266590735738, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003008230516834805}
# [INFO] 18:46:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000019 < threshold 0.100000
# [INFO] 18:46:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 38 of 529.
# [INFO] 18:46:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:15 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.183362628750202e-07, values: {'FEED1MASSFLOW': 21516.56747134487, 'FEED1TEMP': 25.01599682709554, 'PROD1MASSFLOW': 37569.24954175691, 'PROD1TEMP': 115.7682074791824, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 18:46:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 18:46:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 39 of 529.
# [INFO] 18:46:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:25 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 4.462847632117735e-06, values: {'FEED1MASSFLOW': 21885.72678255862, 'FEED1TEMP': 24.92770160919124, 'PROD1MASSFLOW': 36155.43092699922, 'PROD1TEMP': 115.2474249227753, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 18:46:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 18:46:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 40 of 529.
# [INFO] 18:46:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:34 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 9.21713184118801e-06, values: {'FEED1MASSFLOW': 22629.3343245605, 'FEED1TEMP': 24.93546075225073, 'PROD1MASSFLOW': 35951.0272805308, 'PROD1TEMP': 114.5619751637425, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 18:46:34 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 18:46:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:34 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 41 of 529.
# [INFO] 18:46:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:41 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 6.178735950498544e-07, values: {'FEED1MASSFLOW': 23052.81408141617, 'FEED1TEMP': 24.96979552398567, 'PROD1MASSFLOW': 35366.6433778873, 'PROD1TEMP': 114.8085323228307, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 18:46:41 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 18:46:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:41 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 42 of 529.
# [INFO] 18:46:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:48 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 2.569868118046034e-06, values: {'FEED1MASSFLOW': 23873.98895120752, 'FEED1TEMP': 24.64705546402934, 'PROD1MASSFLOW': 33606.38987270086, 'PROD1TEMP': 115.3910956750255, 'E1FOULING': 0.00025, 'E2FOULING': 0.00027705857387533663}
# [INFO] 18:46:48 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 18:46:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 43 of 529.
# [INFO] 18:46:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:55 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.0394794909509448, values: {'FEED1MASSFLOW': 24085.05631312843, 'FEED1TEMP': 25.02029345511958, 'PROD1MASSFLOW': 32971.19764637543, 'PROD1TEMP': 114.4096466605709, 'E1FOULING': 0.00035740829014796016, 'E2FOULING': 0.00025}
# [INFO] 18:46:55 - CalibrationWorkflow: Working point is accurate enough with cost: 0.039479 < threshold 0.100000
# [INFO] 18:46:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:46:55 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 44 of 529.
# [INFO] 18:46:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:03 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 9.977152773852895e-07, values: {'FEED1MASSFLOW': 24511.37433920987, 'FEED1TEMP': 25.15025757714137, 'PROD1MASSFLOW': 31438.14255483319, 'PROD1TEMP': 115.5269277385362, 'E1FOULING': 0.00027146630042447365, 'E2FOULING': 0.00025}
# [INFO] 18:47:03 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 18:47:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 45 of 529.
# [INFO] 18:47:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:11 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.03966860719588795, values: {'FEED1MASSFLOW': 24226.00532269698, 'FEED1TEMP': 24.88169880079636, 'PROD1MASSFLOW': 32240.80420031684, 'PROD1TEMP': 117.4063795109899, 'E1FOULING': 0.0003785112658221884, 'E2FOULING': 0.0005147727195109888}
# [INFO] 18:47:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.039669 < threshold 0.100000
# [INFO] 18:47:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 46 of 529.
# [INFO] 18:47:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:16 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 1.535719024453061e-05, values: {'FEED1MASSFLOW': 24185.81175407174, 'FEED1TEMP': 25.15256677443595, 'PROD1MASSFLOW': 33087.53564862187, 'PROD1TEMP': 114.7991019852639, 'E1FOULING': 0.00048088576325079364, 'E2FOULING': 0.00030168109514789807}
# [INFO] 18:47:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000015 < threshold 0.100000
# [INFO] 18:47:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 47 of 529.
# [INFO] 18:47:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:24 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.007429323705920183, values: {'FEED1MASSFLOW': 24367.98927160785, 'FEED1TEMP': 24.84838832565562, 'PROD1MASSFLOW': 31903.84913114287, 'PROD1TEMP': 116.9796772662115, 'E1FOULING': 0.00037603211393059217, 'E2FOULING': 0.0005097107602500939}
# [INFO] 18:47:24 - CalibrationWorkflow: Working point is accurate enough with cost: 0.007429 < threshold 0.100000
# [INFO] 18:47:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 48 of 529.
# [INFO] 18:47:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:34 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.044953155104256e-05, values: {'FEED1MASSFLOW': 24554.35227057168, 'FEED1TEMP': 25.02471861497049, 'PROD1MASSFLOW': 32022.1791526673, 'PROD1TEMP': 116.3501387404943, 'E1FOULING': 0.00036470453801882343, 'E2FOULING': 0.0003909420333834037}
# [INFO] 18:47:34 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 18:47:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:34 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 49 of 529.
# [INFO] 18:47:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:39 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 1.1027570436035528e-05, values: {'FEED1MASSFLOW': 23510.03829878515, 'FEED1TEMP': 24.79841939343487, 'PROD1MASSFLOW': 31039.17958137653, 'PROD1TEMP': 117.2529818070609, 'E1FOULING': 0.00042644429566100734, 'E2FOULING': 0.0003438610447181387}
# [INFO] 18:47:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000011 < threshold 0.100000
# [INFO] 18:47:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 50 of 529.
# [INFO] 18:47:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:46 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.6850827789161822e-05, values: {'FEED1MASSFLOW': 23728.09554496014, 'FEED1TEMP': 24.52961152685626, 'PROD1MASSFLOW': 31552.0289471732, 'PROD1TEMP': 116.7924665286068, 'E1FOULING': 0.00036140429875720665, 'E2FOULING': 0.000491419479718209}
# [INFO] 18:47:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000017 < threshold 0.100000
# [INFO] 18:47:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 51 of 529.
# [INFO] 18:47:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:54 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.0532435926300891, values: {'FEED1MASSFLOW': 24084.31166513767, 'FEED1TEMP': 24.60578099779845, 'PROD1MASSFLOW': 33418.07416342494, 'PROD1TEMP': 114.474852883691, 'E1FOULING': 0.00039969543222849083, 'E2FOULING': 0.0005281584669985401}
# [INFO] 18:47:54 - CalibrationWorkflow: Working point is accurate enough with cost: 0.053244 < threshold 0.100000
# [INFO] 18:47:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:47:54 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 52 of 529.
# [INFO] 18:47:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:00 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 8.585373660591643e-06, values: {'FEED1MASSFLOW': 24783.50089742459, 'FEED1TEMP': 24.56950754491758, 'PROD1MASSFLOW': 32049.26725524412, 'PROD1TEMP': 116.8620378533065, 'E1FOULING': 0.0004269547829156567, 'E2FOULING': 0.00039939872615094246}
# [INFO] 18:48:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 18:48:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 53 of 529.
# [INFO] 18:48:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:05 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 3.45039701312124e-06, values: {'FEED1MASSFLOW': 23450.84449491451, 'FEED1TEMP': 25.12667649559109, 'PROD1MASSFLOW': 31927.98360760983, 'PROD1TEMP': 118.234668493345, 'E1FOULING': 0.00038112451317800177, 'E2FOULING': 0.0004498618354537579}
# [INFO] 18:48:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 18:48:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 54 of 529.
# [INFO] 18:48:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:15 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 3.5533689760818927e-06, values: {'FEED1MASSFLOW': 23463.14122141384, 'FEED1TEMP': 24.3124994479043, 'PROD1MASSFLOW': 32759.6560159508, 'PROD1TEMP': 116.776228112195, 'E1FOULING': 0.00038602903211049306, 'E2FOULING': 0.00045587962764079027}
# [INFO] 18:48:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 18:48:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 55 of 529.
# [INFO] 18:48:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:23 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.021810878592858903, values: {'FEED1MASSFLOW': 23723.10791088088, 'FEED1TEMP': 24.92019063719255, 'PROD1MASSFLOW': 32909.33550971355, 'PROD1TEMP': 120.8778018556371, 'E1FOULING': 0.000442765740305982, 'E2FOULING': 0.00028217526529488595}
# [INFO] 18:48:23 - CalibrationWorkflow: Working point is accurate enough with cost: 0.021811 < threshold 0.100000
# [INFO] 18:48:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:23 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 56 of 529.
# [INFO] 18:48:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:29 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.2611700447700874e-05, values: {'FEED1MASSFLOW': 24185.49452260674, 'FEED1TEMP': 24.22785984645597, 'PROD1MASSFLOW': 31711.29158196089, 'PROD1TEMP': 114.4005859726987, 'E1FOULING': 0.0003906853459816606, 'E2FOULING': 0.0004975836814415954}
# [INFO] 18:48:29 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000013 < threshold 0.100000
# [INFO] 18:48:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 57 of 529.
# [INFO] 18:48:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:38 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 3.480738718132685e-06, values: {'FEED1MASSFLOW': 23877.02178156325, 'FEED1TEMP': 24.41885939347203, 'PROD1MASSFLOW': 32846.28776418294, 'PROD1TEMP': 119.0428362815956, 'E1FOULING': 0.000388971291796286, 'E2FOULING': 0.0003372055186915859}
# [INFO] 18:48:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 18:48:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 58 of 529.
# [INFO] 18:48:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:46 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.04898212221786158, values: {'FEED1MASSFLOW': 23669.7143349172, 'FEED1TEMP': 24.42891257209249, 'PROD1MASSFLOW': 32627.35553558619, 'PROD1TEMP': 118.0090775053084, 'E1FOULING': 0.00041916827591518516, 'E2FOULING': 0.000546808471226141}
# [INFO] 18:48:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.048982 < threshold 0.100000
# [INFO] 18:48:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 59 of 529.
# [INFO] 18:48:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:54 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.0175810048440439, values: {'FEED1MASSFLOW': 23943.17532133758, 'FEED1TEMP': 23.87248769817969, 'PROD1MASSFLOW': 33415.53745911072, 'PROD1TEMP': 118.0054844767737, 'E1FOULING': 0.0004378106255404015, 'E2FOULING': 0.0005028733415938749}
# [INFO] 18:48:54 - CalibrationWorkflow: Working point is accurate enough with cost: 0.017581 < threshold 0.100000
# [INFO] 18:48:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:48:54 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 60 of 529.
# [INFO] 18:48:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:00 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 5.311485259636157e-07, values: {'FEED1MASSFLOW': 23681.05874285964, 'FEED1TEMP': 24.00742839463467, 'PROD1MASSFLOW': 33631.37968161814, 'PROD1TEMP': 118.6958749740123, 'E1FOULING': 0.00041936711372819204, 'E2FOULING': 0.0003769448184002045}
# [INFO] 18:49:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 18:49:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 61 of 529.
# [INFO] 18:49:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:12 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.04683037396618998, values: {'FEED1MASSFLOW': 23417.17253443502, 'FEED1TEMP': 24.53872067236895, 'PROD1MASSFLOW': 32788.00132901206, 'PROD1TEMP': 117.2260057789928, 'E1FOULING': 0.0004236614770514471, 'E2FOULING': 0.0005526789905803142}
# [INFO] 18:49:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.046830 < threshold 0.100000
# [INFO] 18:49:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 62 of 529.
# [INFO] 18:49:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:20 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 8.00872527154491e-06, values: {'FEED1MASSFLOW': 23139.13451713724, 'FEED1TEMP': 23.76246366509142, 'PROD1MASSFLOW': 32779.01315824939, 'PROD1TEMP': 118.0289461874185, 'E1FOULING': 0.0004242706999413588, 'E2FOULING': 0.0003995290230645736}
# [INFO] 18:49:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 18:49:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:20 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 63 of 529.
# [INFO] 18:49:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:25 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.008306566283686605, values: {'FEED1MASSFLOW': 23421.12496342705, 'FEED1TEMP': 23.96721982578627, 'PROD1MASSFLOW': 33350.16985299164, 'PROD1TEMP': 119.6066953787307, 'E1FOULING': 0.00046754234457093455, 'E2FOULING': 0.0003991247285685377}
# [INFO] 18:49:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.008307 < threshold 0.100000
# [INFO] 18:49:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 64 of 529.
# [INFO] 18:49:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:32 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.2880687472865262e-05, values: {'FEED1MASSFLOW': 23003.70730422672, 'FEED1TEMP': 23.77230595316833, 'PROD1MASSFLOW': 34591.10434454396, 'PROD1TEMP': 119.1611092782815, 'E1FOULING': 0.00043282053430034317, 'E2FOULING': 0.00034636473642187394}
# [INFO] 18:49:32 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000013 < threshold 0.100000
# [INFO] 18:49:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:32 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 65 of 529.
# [INFO] 18:49:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:45 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.07015123477998053, values: {'FEED1MASSFLOW': 23038.53630719265, 'FEED1TEMP': 23.4865162218132, 'PROD1MASSFLOW': 33850.30114277963, 'PROD1TEMP': 121.3515211100006, 'E1FOULING': 0.0004185917346513587, 'E2FOULING': 0.0005442688131717665}
# [INFO] 18:49:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.070151 < threshold 0.100000
# [INFO] 18:49:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 66 of 529.
# [INFO] 18:49:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:54 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.08071339429359992, values: {'FEED1MASSFLOW': 22976.1235898672, 'FEED1TEMP': 23.57484259976275, 'PROD1MASSFLOW': 32964.68268668753, 'PROD1TEMP': 119.2259547318991, 'E1FOULING': 0.0005497465527906681, 'E2FOULING': 0.00029648276885149076}
# [INFO] 18:49:54 - CalibrationWorkflow: Working point is accurate enough with cost: 0.080713 < threshold 0.100000
# [INFO] 18:49:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:49:54 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 67 of 529.
# [INFO] 18:49:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:50:04 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.013424146235589143, values: {'FEED1MASSFLOW': 23076.74146743403, 'FEED1TEMP': 24.23779169977461, 'PROD1MASSFLOW': 32582.15388854899, 'PROD1TEMP': 121.4257216200965, 'E1FOULING': 0.00045622668806950215, 'E2FOULING': 0.0004666120073583643}
# [INFO] 18:50:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.013424 < threshold 0.100000
# [INFO] 18:50:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:50:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 68 of 529.
# [INFO] 18:50:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:50:13 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 7.827329053212187e-06, values: {'FEED1MASSFLOW': 23176.18586424605, 'FEED1TEMP': 23.74100477212071, 'PROD1MASSFLOW': 34449.6459579803, 'PROD1TEMP': 121.1329743864569, 'E1FOULING': 0.0003598288241047037, 'E2FOULING': 0.00042414580745148893}
# [INFO] 18:50:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 18:50:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 18:50:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 69 of 529.
# [INFO] 18:50:13 - CalibrationWorkflow: ----------------------------------------
# ...
# [INFO] 19:50:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:50:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 507 of 529.
# [INFO] 19:50:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:50:32 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.04964390485512618, values: {'FEED1MASSFLOW': 13620.27436689572, 'FEED1TEMP': 19.63704469656584, 'PROD1MASSFLOW': 34654.51038701771, 'PROD1TEMP': 128.805281875239, 'E1FOULING': 0.00045467095529078203, 'E2FOULING': 0.00043756252391205356}
# [INFO] 19:50:32 - CalibrationWorkflow: Working point is accurate enough with cost: 0.049644 < threshold 0.100000
# [INFO] 19:50:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:50:32 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 508 of 529.
# [INFO] 19:50:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:50:37 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.09535393103228422, values: {'FEED1MASSFLOW': 13644.67830461279, 'FEED1TEMP': 20.07020317139242, 'PROD1MASSFLOW': 34775.11099994354, 'PROD1TEMP': 126.3504462702761, 'E1FOULING': 0.0005200000000000007, 'E2FOULING': 0.000620000000000001}
# [INFO] 19:50:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.095354 < threshold 0.100000
# [INFO] 19:50:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:50:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 509 of 529.
# [INFO] 19:50:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:50:46 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.07884680161120104, values: {'FEED1MASSFLOW': 13346.49373614571, 'FEED1TEMP': 19.60188993342847, 'PROD1MASSFLOW': 34916.85085696288, 'PROD1TEMP': 127.0623981190557, 'E1FOULING': 0.0005166536025258603, 'E2FOULING': 0.0006295875942633707}
# [INFO] 19:50:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.078847 < threshold 0.100000
# [INFO] 19:50:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:50:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 510 of 529.
# [INFO] 19:50:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:01 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 6.425120153567065e-06, values: {'FEED1MASSFLOW': 13500.88255669364, 'FEED1TEMP': 19.74485655969625, 'PROD1MASSFLOW': 35746.26010616649, 'PROD1TEMP': 122.2582646253043, 'E1FOULING': 0.00048052995413191475, 'E2FOULING': 0.00047432929449681697}
# [INFO] 19:51:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 19:51:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 511 of 529.
# [INFO] 19:51:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:06 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.08501006043851539, values: {'FEED1MASSFLOW': 13726.95788671875, 'FEED1TEMP': 19.86310415215531, 'PROD1MASSFLOW': 34639.18833004832, 'PROD1TEMP': 129.0635052473672, 'E1FOULING': 0.0005200000000000007, 'E2FOULING': 0.000620000000000001}
# [INFO] 19:51:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.085010 < threshold 0.100000
# [INFO] 19:51:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 512 of 529.
# [INFO] 19:51:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:10 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.08953174572953768, values: {'FEED1MASSFLOW': 13766.80636447861, 'FEED1TEMP': 19.82999074920533, 'PROD1MASSFLOW': 36087.67058309269, 'PROD1TEMP': 127.4517716655803, 'E1FOULING': 0.0005200000000000007, 'E2FOULING': 0.000620000000000001}
# [INFO] 19:51:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.089532 < threshold 0.100000
# [INFO] 19:51:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 513 of 529.
# [INFO] 19:51:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:21 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 2.5181332298466203e-06, values: {'FEED1MASSFLOW': 13892.86282542806, 'FEED1TEMP': 19.74733446761203, 'PROD1MASSFLOW': 34547.00334725757, 'PROD1TEMP': 125.9578022370135, 'E1FOULING': 0.00047965048220989574, 'E2FOULING': 0.00046333013120168626}
# [INFO] 19:51:21 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 19:51:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 514 of 529.
# [INFO] 19:51:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:34 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 2.119803160125818e-06, values: {'FEED1MASSFLOW': 13659.14182919502, 'FEED1TEMP': 19.67169907645779, 'PROD1MASSFLOW': 34075.05785309214, 'PROD1TEMP': 127.742943778597, 'E1FOULING': 0.00047026619929661437, 'E2FOULING': 0.00045634669601639426}
# [INFO] 19:51:34 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 19:51:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:34 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 515 of 529.
# [INFO] 19:51:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:39 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.09663979447015864, values: {'FEED1MASSFLOW': 13446.23225120787, 'FEED1TEMP': 20.06623393859448, 'PROD1MASSFLOW': 34322.13868500174, 'PROD1TEMP': 125.2841647247034, 'E1FOULING': 0.0005200000000000007, 'E2FOULING': 0.000620000000000001}
# [INFO] 19:51:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.096640 < threshold 0.100000
# [INFO] 19:51:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 516 of 529.
# [INFO] 19:51:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:51 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.01247540111669049, values: {'FEED1MASSFLOW': 13153.73470081068, 'FEED1TEMP': 19.631740839806, 'PROD1MASSFLOW': 34459.58525000857, 'PROD1TEMP': 127.1071217371806, 'E1FOULING': 0.0004726269530676266, 'E2FOULING': 0.0004735502905165893}
# [INFO] 19:51:51 - CalibrationWorkflow: Working point is accurate enough with cost: 0.012475 < threshold 0.100000
# [INFO] 19:51:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 517 of 529.
# [INFO] 19:51:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:59 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 9.945120126384826e-06, values: {'FEED1MASSFLOW': 13432.96831314839, 'FEED1TEMP': 20.03079581838237, 'PROD1MASSFLOW': 34778.16427305674, 'PROD1TEMP': 129.410996339145, 'E1FOULING': 0.0005715942619837569, 'E2FOULING': 0.00045333092012618146}
# [INFO] 19:51:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 19:51:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:51:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 518 of 529.
# [INFO] 19:51:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:52:11 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 8.214755671033506e-06, values: {'FEED1MASSFLOW': 13389.10627836312, 'FEED1TEMP': 20.00940520749543, 'PROD1MASSFLOW': 35184.59183121471, 'PROD1TEMP': 128.043630919933, 'E1FOULING': 0.0004997192317934083, 'E2FOULING': 0.000516757991027821}
# [INFO] 19:52:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 19:52:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:52:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 519 of 529.
# [INFO] 19:52:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:52:15 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.08249994342266757, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.0005200000000000007, 'E2FOULING': 0.000620000000000001}
# [INFO] 19:52:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.082500 < threshold 0.100000
# [INFO] 19:52:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:52:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 19:52:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:52:27 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.5061261875399796e-06, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.00048248691299757285, 'E2FOULING': 0.0004764769091730283}
# [INFO] 19:52:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 19:52:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:52:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 19:52:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:52:43 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.273855634415206e-06, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0005199552701277353, 'E2FOULING': 0.00044395389050673267}
# [INFO] 19:52:43 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 19:52:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:52:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 19:52:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:52:57 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.16918417657802862, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005758856201825438, 'E2FOULING': 0.0006866328548330331}
# [INFO] 19:52:57 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.169184 > threshold: 0.1
# [INFO] 19:52:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:52:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 19:52:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:53:08 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.018078693047443542, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0004933134005019428, 'E2FOULING': 0.0005061658384613054}
# [INFO] 19:53:08 - CalibrationWorkflow: Working point is accurate enough with cost: 0.018079 < threshold 0.100000
# [INFO] 19:53:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:53:08 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 19:53:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:53:19 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.01824604013381688, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0004833000083432007, 'E2FOULING': 0.0005013982318278979}
# [INFO] 19:53:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.018246 < threshold 0.100000
# [INFO] 19:53:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:53:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 19:53:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:53:33 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.008635336710770944, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.0004610130866129484, 'E2FOULING': 0.0004800366115029419}
# [INFO] 19:53:33 - CalibrationWorkflow: Working point is accurate enough with cost: 0.008635 < threshold 0.100000
# [INFO] 19:53:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:53:33 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 19:53:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:53:42 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 8.452006523238741e-06, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.00047887157570207603, 'E2FOULING': 0.0004933586587518097}
# [INFO] 19:53:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 19:53:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:53:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 19:53:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:53:51 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.09128565204456793, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0004922171577775309, 'E2FOULING': 0.0006087218790526148}
# [INFO] 19:53:51 - CalibrationWorkflow: Working point is accurate enough with cost: 0.091286 < threshold 0.100000
# [INFO] 19:53:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:53:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 19:53:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:54:04 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.4385050735731257e-06, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0004944666501499151, 'E2FOULING': 0.00048498478817592117}
# [INFO] 19:54:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 19:54:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:54:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 19:54:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 19:54:18 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.615069120144342e-06, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0005148118284104922, 'E2FOULING': 0.000428947613662931}
# [INFO] 19:54:18 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 19:54:18 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/Direct/01_Calibration_direct.xlsx')
# Out:
# [INFO] 19:58:11 - CalibrationWorkflow: Calibration results saved to ./Results/Direct/Direct_calibration_results.xlsx

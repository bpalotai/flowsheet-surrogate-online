# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_200.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'surrogate', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodel/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 07:54:38 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 07:54:38 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodel/sklearnann.joblib
# [INFO] 07:54:38 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 07:54:44 - CalibrationWorkflow:
# ============================================================
# [INFO] 07:54:44 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 07:54:44 - CalibrationWorkflow: ============================================================
#
# [INFO] 07:54:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:54:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 07:54:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:54:45 - CalibrationWorkflow: Treshold reached with 25 iteration, best cost: 0.10623492736804709, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.00026922028439002414}
# [INFO] 07:54:45 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.450053 > threshold: 0.1
# [INFO] 07:54:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:54:45 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:54:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:54:54 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.3229025612643411e-05, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0003590790492212539, 'E2FOULING': 0.00043430332531528765}
# [INFO] 07:54:54 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000013 < threshold 0.100000
# [INFO] 07:54:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:54:54 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 07:54:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:54:55 - CalibrationWorkflow: Treshold reached with 22 iteration, best cost: 0.11016719476286214, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002774467994087652}
# [INFO] 07:54:55 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.315658 > threshold: 0.1
# [INFO] 07:54:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:54:55 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:54:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:02 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.0084970513120286, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0003864103034006805, 'E2FOULING': 0.00033368471289935207}
# [INFO] 07:55:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.008497 < threshold 0.100000
# [INFO] 07:55:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 07:55:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:03 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.11420540455702292, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:55:03 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.314325 > threshold: 0.1
# [INFO] 07:55:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:03 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:55:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:15 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.025513733432077582, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.000413564820566842, 'E2FOULING': 0.0004504350214774789}
# [INFO] 07:55:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.025514 < threshold 0.100000
# [INFO] 07:55:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 07:55:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:15 - CalibrationWorkflow: Treshold reached with 21 iteration, best cost: 0.08521809913108554, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0003092879970351573, 'E2FOULING': 0.0002560013829627684}
# [INFO] 07:55:16 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.248895 > threshold: 0.1
# [INFO] 07:55:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:16 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:55:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:22 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 7.079786266816725e-07, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00043024395547782573, 'E2FOULING': 0.0003720702912256482}
# [INFO] 07:55:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 07:55:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 07:55:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:22 - CalibrationWorkflow: Treshold reached with 11 iteration, best cost: 0.10140825685687152, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002820761074180843}
# [INFO] 07:55:22 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.271581 > threshold: 0.1
# [INFO] 07:55:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:22 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:55:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:26 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 4.708425523591214e-06, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00036546719109682723, 'E2FOULING': 0.0004634857785516367}
# [INFO] 07:55:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 07:55:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 07:55:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:27 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.10519695740414477, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:55:27 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.340948 > threshold: 0.1
# [INFO] 07:55:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:27 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:55:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:33 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 6.1258868185745165e-06, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00039303873818788036, 'E2FOULING': 0.00033944348152920294}
# [INFO] 07:55:33 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 07:55:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:33 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 07:55:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:33 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.10308018848698211, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:55:33 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.283837 > threshold: 0.1
# [INFO] 07:55:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:33 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:55:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:40 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.08690680073895844, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.0004854278920812403, 'E2FOULING': 0.00038896596772024266}
# [INFO] 07:55:40 - CalibrationWorkflow: Working point is accurate enough with cost: 0.086907 < threshold 0.100000
# [INFO] 07:55:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:40 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 07:55:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:41 - CalibrationWorkflow: Treshold reached with 30 iteration, best cost: 0.08927431997426873, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0002775018621971368, 'E2FOULING': 0.0003400850761987763}
# [INFO] 07:55:41 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.258997 > threshold: 0.1
# [INFO] 07:55:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:41 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:55:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:48 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 7.645083034547132e-06, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0004147192029268685, 'E2FOULING': 0.0003584825680937221}
# [INFO] 07:55:48 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 07:55:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 07:55:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:48 - CalibrationWorkflow: Treshold reached with 8 iteration, best cost: 0.09744889780029499, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:55:48 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.342942 > threshold: 0.1
# [INFO] 07:55:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:48 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:55:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:56 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.014419962461895482, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.0004608650048958089, 'E2FOULING': 0.0003406621801318691}
# [INFO] 07:55:56 - CalibrationWorkflow: Working point is accurate enough with cost: 0.014420 < threshold 0.100000
# [INFO] 07:55:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:56 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 07:55:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:56 - CalibrationWorkflow: Treshold reached with 29 iteration, best cost: 0.08579402088274304, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00025, 'E2FOULING': 0.00027103813772979326}
# [INFO] 07:55:56 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.491435 > threshold: 0.1
# [INFO] 07:55:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:55:56 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:55:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:02 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.012991661040346854, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0004467866425393354, 'E2FOULING': 0.0004689050742683071}
# [INFO] 07:56:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.012992 < threshold 0.100000
# [INFO] 07:56:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 07:56:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:03 - CalibrationWorkflow: Treshold reached with 31 iteration, best cost: 0.0880935085279508, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00025046431929335607, 'E2FOULING': 0.000331976664656616}
# [INFO] 07:56:03 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.319664 > threshold: 0.1
# [INFO] 07:56:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:03 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:56:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:13 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 7.0037737266316845e-06, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.0003870117612108765, 'E2FOULING': 0.0004452147107920625}
# [INFO] 07:56:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000007 < threshold 0.100000
# [INFO] 07:56:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 07:56:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:13 - CalibrationWorkflow: Treshold reached with 13 iteration, best cost: 0.09850762535430971, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.000416714289696019, 'E2FOULING': 0.00027911769645642254}
# [INFO] 07:56:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.040171 < threshold 0.100000
# [INFO] 07:56:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 07:56:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:14 - CalibrationWorkflow: Treshold reached with 27 iteration, best cost: 0.09368257250896782, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0002500038864507979, 'E2FOULING': 0.00033396560122193143}
# [INFO] 07:56:14 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.255112 > threshold: 0.1
# [INFO] 07:56:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:14 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:56:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:23 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.015335651732506544, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.00041940395758528407, 'E2FOULING': 0.00047032515186757126}
# [INFO] 07:56:23 - CalibrationWorkflow: Working point is accurate enough with cost: 0.015336 < threshold 0.100000
# [INFO] 07:56:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:23 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 07:56:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:24 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.09369430275671543, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00025065533250280114, 'E2FOULING': 0.0002771165405741315}
# [INFO] 07:56:24 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.287220 > threshold: 0.1
# [INFO] 07:56:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:24 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:56:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:30 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.015360643741688466, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00040713836339872423, 'E2FOULING': 0.00046650611060392684}
# [INFO] 07:56:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.015361 < threshold 0.100000
# [INFO] 07:56:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:30 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 07:56:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:30 - CalibrationWorkflow: Treshold reached with 10 iteration, best cost: 0.06721480939762361, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0005743797525859248, 'E2FOULING': 0.00025}
# [INFO] 07:56:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.070697 < threshold 0.100000
# [INFO] 07:56:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:30 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 07:56:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:31 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.08839582285134838, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:56:31 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.308915 > threshold: 0.1
# [INFO] 07:56:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:31 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:56:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:37 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.016232602000132015, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.00036123361735162477, 'E2FOULING': 0.0003116161878761788}
# [INFO] 07:56:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.016233 < threshold 0.100000
# [INFO] 07:56:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 07:56:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:37 - CalibrationWorkflow: Treshold reached with 17 iteration, best cost: 0.0833457485909601, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0002525444632588797, 'E2FOULING': 0.0002521551930556022}
# [INFO] 07:56:37 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.306891 > threshold: 0.1
# [INFO] 07:56:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:37 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:56:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:50 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 4.806203092695704e-06, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0003745550680725288, 'E2FOULING': 0.0003582830854306226}
# [INFO] 07:56:50 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 07:56:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 07:56:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:50 - CalibrationWorkflow: Treshold reached with 33 iteration, best cost: 0.08499030470398601, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.000294060171400356, 'E2FOULING': 0.00035485568035885693}
# [INFO] 07:56:50 - CalibrationWorkflow: Working point is accurate enough with cost: 0.092021 < threshold 0.100000
# [INFO] 07:56:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 07:56:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:51 - CalibrationWorkflow: Treshold reached with 31 iteration, best cost: 0.07703803268788353, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.00025, 'E2FOULING': 0.00036015503865468175}
# [INFO] 07:56:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.195473 > threshold: 0.1
# [INFO] 07:56:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:51 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:56:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:59 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.05786914917196398, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.0004779555711380985, 'E2FOULING': 0.0003814185113868809}
# [INFO] 07:56:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.057869 < threshold 0.100000
# [INFO] 07:56:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 07:56:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:59 - CalibrationWorkflow: Treshold reached with 31 iteration, best cost: 0.0745724166276256, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.0002502628293036643, 'E2FOULING': 0.0002596036935034291}
# [INFO] 07:56:59 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.238733 > threshold: 0.1
# [INFO] 07:56:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:56:59 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:56:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:11 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 1.1050658241178789e-05, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.0003783845604355297, 'E2FOULING': 0.00032673171755283326}
# [INFO] 07:57:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000011 < threshold 0.100000
# [INFO] 07:57:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 07:57:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:11 - CalibrationWorkflow: Treshold reached with 8 iteration, best cost: 0.09496260491559545, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003678697839461089}
# [INFO] 07:57:11 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.214502 > threshold: 0.1
# [INFO] 07:57:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:11 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:57:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:19 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.07154776488585846, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0004991225863877334, 'E2FOULING': 0.0004066874156265003}
# [INFO] 07:57:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.071548 < threshold 0.100000
# [INFO] 07:57:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 07:57:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:19 - CalibrationWorkflow: Treshold reached with 15 iteration, best cost: 0.07138729269516192, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.000532567037745133, 'E2FOULING': 0.0002500020167962402}
# [INFO] 07:57:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.089369 < threshold 0.100000
# [INFO] 07:57:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 07:57:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:20 - CalibrationWorkflow: Treshold reached with 20 iteration, best cost: 0.07384220590227303, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.000422351363577288, 'E2FOULING': 0.00025}
# [INFO] 07:57:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.072020 < threshold 0.100000
# [INFO] 07:57:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:20 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 07:57:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:21 - CalibrationWorkflow: Treshold reached with 27 iteration, best cost: 0.07091666131777744, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.00025, 'E2FOULING': 0.00036393683420509403}
# [INFO] 07:57:21 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.312540 > threshold: 0.1
# [INFO] 07:57:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:21 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:57:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:27 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 2.2648178325464127e-06, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.00043760372986782325, 'E2FOULING': 0.0004094448170596604}
# [INFO] 07:57:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 07:57:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 07:57:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:28 - CalibrationWorkflow: Treshold reached with 34 iteration, best cost: 0.09894351354837523, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0003738693987886394, 'E2FOULING': 0.00031007877252904164}
# [INFO] 07:57:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.025363 < threshold 0.100000
# [INFO] 07:57:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 07:57:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:28 - CalibrationWorkflow: Treshold reached with 25 iteration, best cost: 0.07808795210432423, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.0004273526026691115, 'E2FOULING': 0.00025}
# [INFO] 07:57:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.071278 < threshold 0.100000
# [INFO] 07:57:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 07:57:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:29 - CalibrationWorkflow: Treshold reached with 33 iteration, best cost: 0.08768575214000933, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.00032885887630268267, 'E2FOULING': 0.0003265459156182588}
# [INFO] 07:57:29 - CalibrationWorkflow: Working point is accurate enough with cost: 0.076736 < threshold 0.100000
# [INFO] 07:57:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 07:57:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:30 - CalibrationWorkflow: Treshold reached with 27 iteration, best cost: 0.10104039480984862, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.0003451071642643848, 'E2FOULING': 0.0002615977208866948}
# [INFO] 07:57:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.066349 < threshold 0.100000
# [INFO] 07:57:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:30 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 07:57:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:30 - CalibrationWorkflow: Treshold reached with 17 iteration, best cost: 0.06207593024037785, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.0005487719297688355, 'E2FOULING': 0.00025}
# [INFO] 07:57:30 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.124433 > threshold: 0.1
# [INFO] 07:57:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:30 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:57:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:37 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.009545422654730197, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.0004390659499417779, 'E2FOULING': 0.00045883034375013634}
# [INFO] 07:57:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.009545 < threshold 0.100000
# [INFO] 07:57:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 29 of 529.
# [INFO] 07:57:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:37 - CalibrationWorkflow: Treshold reached with 30 iteration, best cost: 0.06980964437128721, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.0004445585081600724, 'E2FOULING': 0.00025696858811912105}
# [INFO] 07:57:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.083448 < threshold 0.100000
# [INFO] 07:57:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 30 of 529.
# [INFO] 07:57:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:37 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.4999012461322002, values: {'FEED1MASSFLOW': 18170.33282487203, 'FEED1TEMP': 24.88142490999688, 'PROD1MASSFLOW': 45110.96621847873, 'PROD1TEMP': 115.0679318499356, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000011 < threshold 0.100000
# [INFO] 07:57:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 31 of 529.
# [INFO] 07:57:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:38 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.5863386884521302, values: {'FEED1MASSFLOW': 18607.84387976851, 'FEED1TEMP': 25.14488217461214, 'PROD1MASSFLOW': 43738.61199857389, 'PROD1TEMP': 115.3747174316839, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 07:57:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 32 of 529.
# [INFO] 07:57:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:38 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.6110506065499298, values: {'FEED1MASSFLOW': 19115.08117402765, 'FEED1TEMP': 24.77391698651811, 'PROD1MASSFLOW': 42751.55908633373, 'PROD1TEMP': 115.3524481338415, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 07:57:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 33 of 529.
# [INFO] 07:57:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:38 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.5166449518683104, values: {'FEED1MASSFLOW': 19418.03437168451, 'FEED1TEMP': 25.0300579250388, 'PROD1MASSFLOW': 43087.88928120025, 'PROD1TEMP': 114.4650169900805, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 07:57:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 34 of 529.
# [INFO] 07:57:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:38 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.5154193701411248, values: {'FEED1MASSFLOW': 19996.37302723919, 'FEED1TEMP': 25.05396733167793, 'PROD1MASSFLOW': 39075.45922402187, 'PROD1TEMP': 115.4384103153362, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 07:57:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 35 of 529.
# [INFO] 07:57:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:39 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.4792012065822925, values: {'FEED1MASSFLOW': 20114.96473047106, 'FEED1TEMP': 24.8676559665023, 'PROD1MASSFLOW': 40171.91798417241, 'PROD1TEMP': 115.7924017721878, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 07:57:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 36 of 529.
# [INFO] 07:57:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:39 - CalibrationWorkflow: Treshold reached with 8 iteration, best cost: 0.43586562423037944, values: {'FEED1MASSFLOW': 20464.74060999631, 'FEED1TEMP': 25.14479618506942, 'PROD1MASSFLOW': 39328.05034260821, 'PROD1TEMP': 115.7990352506138, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 07:57:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 37 of 529.
# [INFO] 07:57:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:39 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.4221161389513041, values: {'FEED1MASSFLOW': 20969.69452156387, 'FEED1TEMP': 25.25139017769914, 'PROD1MASSFLOW': 39239.44675475179, 'PROD1TEMP': 115.2266590735738, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 07:57:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 38 of 529.
# [INFO] 07:57:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:39 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.4797626493228929, values: {'FEED1MASSFLOW': 21516.56747134487, 'FEED1TEMP': 25.01599682709554, 'PROD1MASSFLOW': 37569.24954175691, 'PROD1TEMP': 115.7682074791824, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 07:57:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 39 of 529.
# [INFO] 07:57:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:40 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.5340159011299603, values: {'FEED1MASSFLOW': 21885.72678255862, 'FEED1TEMP': 24.92770160919124, 'PROD1MASSFLOW': 36155.43092699922, 'PROD1TEMP': 115.2474249227753, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:40 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 07:57:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:40 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 40 of 529.
# [INFO] 07:57:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:40 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.5098399916165394, values: {'FEED1MASSFLOW': 22629.3343245605, 'FEED1TEMP': 24.93546075225073, 'PROD1MASSFLOW': 35951.0272805308, 'PROD1TEMP': 114.5619751637425, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:40 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 07:57:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:40 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 41 of 529.
# [INFO] 07:57:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:40 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.4282056478132378, values: {'FEED1MASSFLOW': 23052.81408141617, 'FEED1TEMP': 24.96979552398567, 'PROD1MASSFLOW': 35366.6433778873, 'PROD1TEMP': 114.8085323228307, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:40 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 07:57:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:40 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 42 of 529.
# [INFO] 07:57:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:40 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.43088938439310676, values: {'FEED1MASSFLOW': 23873.98895120752, 'FEED1TEMP': 24.64705546402934, 'PROD1MASSFLOW': 33606.38987270086, 'PROD1TEMP': 115.3910956750255, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:40 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 07:57:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:40 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 43 of 529.
# [INFO] 07:57:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:41 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.3072007975189366, values: {'FEED1MASSFLOW': 24085.05631312843, 'FEED1TEMP': 25.02029345511958, 'PROD1MASSFLOW': 32971.19764637543, 'PROD1TEMP': 114.4096466605709, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:41 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 07:57:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:41 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 44 of 529.
# [INFO] 07:57:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:41 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.32443963028330286, values: {'FEED1MASSFLOW': 24511.37433920987, 'FEED1TEMP': 25.15025757714137, 'PROD1MASSFLOW': 31438.14255483319, 'PROD1TEMP': 115.5269277385362, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:41 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 07:57:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:41 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 45 of 529.
# [INFO] 07:57:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:42 - CalibrationWorkflow: Treshold reached with 31 iteration, best cost: 0.08177469982722477, values: {'FEED1MASSFLOW': 24226.00532269698, 'FEED1TEMP': 24.88169880079636, 'PROD1MASSFLOW': 32240.80420031684, 'PROD1TEMP': 117.4063795109899, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004303591818758672}
# [INFO] 07:57:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.075068 < threshold 0.100000
# [INFO] 07:57:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 46 of 529.
# [INFO] 07:57:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:42 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.02143903647337018, values: {'FEED1MASSFLOW': 24185.81175407174, 'FEED1TEMP': 25.15256677443595, 'PROD1MASSFLOW': 33087.53564862187, 'PROD1TEMP': 114.7991019852639, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 07:57:42 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.241600 > threshold: 0.1
# [INFO] 07:57:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:42 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 07:57:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:48 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.2164019090630514e-05, values: {'FEED1MASSFLOW': 24185.81175407174, 'FEED1TEMP': 25.15256677443595, 'PROD1MASSFLOW': 33087.53564862187, 'PROD1TEMP': 114.7991019852639, 'E1FOULING': 0.00044691366317611375, 'E2FOULING': 0.000296025413331822}
# [INFO] 07:57:48 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 07:57:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 47 of 529.
# [INFO] 07:57:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:48 - CalibrationWorkflow: Treshold reached with 29 iteration, best cost: 0.040285325401410776, values: {'FEED1MASSFLOW': 24367.98927160785, 'FEED1TEMP': 24.84838832565562, 'PROD1MASSFLOW': 31903.84913114287, 'PROD1TEMP': 116.9796772662115, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005534759060400222}
# [INFO] 07:57:48 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.125301 > threshold: 0.1
# [INFO] 07:57:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 07:57:48 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# ...
# [INFO] 08:21:17 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:21:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:20 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.025140773732629903, values: {'FEED1MASSFLOW': 13389.10627836312, 'FEED1TEMP': 20.00940520749543, 'PROD1MASSFLOW': 35184.59183121471, 'PROD1TEMP': 128.043630919933, 'E1FOULING': 0.0005300000000000007, 'E2FOULING': 0.00046000000000000056}
# [INFO] 08:21:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.025141 < threshold 0.100000
# [INFO] 08:21:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:20 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 519 of 529.
# [INFO] 08:21:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:20 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.2676019987806036, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 08:21:20 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.474948 > threshold: 0.1
# [INFO] 08:21:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:20 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:21:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:22 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.3007068255563608e-05, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.0005300000000000007, 'E2FOULING': 0.00046000000000000056}
# [INFO] 08:21:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000013 < threshold 0.100000
# [INFO] 08:21:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 08:21:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:23 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.46151083484659106, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 08:21:23 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.173824 > threshold: 0.1
# [INFO] 08:21:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:23 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:21:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:25 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.051554136959924626, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.0005300000000000007, 'E2FOULING': 0.00046000000000000056}
# [INFO] 08:21:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.051554 < threshold 0.100000
# [INFO] 08:21:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 08:21:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:26 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.4867964241365921, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 08:21:26 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.333078 > threshold: 0.1
# [INFO] 08:21:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:26 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:21:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:28 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.024766555895430836, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0005300000000000007, 'E2FOULING': 0.00046000000000000056}
# [INFO] 08:21:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.024767 < threshold 0.100000
# [INFO] 08:21:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 08:21:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:29 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.26805843714598665, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 08:21:29 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.253897 > threshold: 0.1
# [INFO] 08:21:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:29 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:21:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:31 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.0237885989216889, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005300000000000007, 'E2FOULING': 0.00046000000000000056}
# [INFO] 08:21:31 - CalibrationWorkflow: Working point is accurate enough with cost: 0.023789 < threshold 0.100000
# [INFO] 08:21:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 08:21:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:31 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.4662762375091226, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 08:21:31 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.416579 > threshold: 0.1
# [INFO] 08:21:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:31 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:21:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:34 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.013119560386968994, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0005300000000000007, 'E2FOULING': 0.00046000000000000056}
# [INFO] 08:21:34 - CalibrationWorkflow: Working point is accurate enough with cost: 0.013120 < threshold 0.100000
# [INFO] 08:21:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:34 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 08:21:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:34 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.3101187196878471, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 08:21:34 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.198052 > threshold: 0.1
# [INFO] 08:21:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:34 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:21:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:37 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.022978013611603947, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0005300000000000007, 'E2FOULING': 0.00046000000000000056}
# [INFO] 08:21:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.022978 < threshold 0.100000
# [INFO] 08:21:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 08:21:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:37 - CalibrationWorkflow: Treshold reached with 12 iteration, best cost: 0.7328664798654518, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 08:21:38 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.839629 > threshold: 0.1
# [INFO] 08:21:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:38 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:21:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:46 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.0070219904885003015, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.0004918733532652427, 'E2FOULING': 0.0004470583422751284}
# [INFO] 08:21:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.007022 < threshold 0.100000
# [INFO] 08:21:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 08:21:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:46 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.6066652427051358, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 08:21:46 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.010840 > threshold: 0.1
# [INFO] 08:21:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:46 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:21:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:49 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.07754901136655377, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0005300000000000007, 'E2FOULING': 0.00046000000000000056}
# [INFO] 08:21:49 - CalibrationWorkflow: Working point is accurate enough with cost: 0.077549 < threshold 0.100000
# [INFO] 08:21:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:49 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 08:21:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:49 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.4989899962434296, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 08:21:49 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.932215 > threshold: 0.1
# [INFO] 08:21:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:49 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:21:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:52 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.09042541310253632, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0005300000000000007, 'E2FOULING': 0.00046000000000000056}
# [INFO] 08:21:52 - CalibrationWorkflow: Working point is accurate enough with cost: 0.090425 < threshold 0.100000
# [INFO] 08:21:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:52 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 08:21:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:52 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.37301979680678876, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 08:21:52 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.169220 > threshold: 0.1
# [INFO] 08:21:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:52 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:21:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:55 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.04205426295714464, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0005300000000000007, 'E2FOULING': 0.00046000000000000056}
# [INFO] 08:21:55 - CalibrationWorkflow: Working point is accurate enough with cost: 0.042054 < threshold 0.100000
# [INFO] 08:21:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:55 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 08:21:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:55 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.43379775746272875, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 08:21:55 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.081247 > threshold: 0.1
# [INFO] 08:21:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:55 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:21:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:21:59 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.05112678974931218, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0005300000000000007, 'E2FOULING': 0.00046000000000000056}
# [INFO] 08:21:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.051127 < threshold 0.100000
# [INFO] 08:21:59 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/Surrogate_base/02_Calibration_static_FNN-low.xlsx')
# Out:
# [INFO] 08:21:59 - CalibrationWorkflow: Calibration results saved to ./Results/Surrogate_base/Calibration_result_base_suorrogate_with_direct.xlsx

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_200.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodel/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.005, 'retrain_scaler': False}

# %%
training_data.shape[0]*0.005
# Out:
# 1.0

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 14:22:36 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 14:22:36 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodel/sklearnann.joblib
# [INFO] 14:22:36 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.005, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 14:22:50 - CalibrationWorkflow:
# ============================================================
# [INFO] 14:22:50 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 14:22:50 - CalibrationWorkflow: ============================================================
#
# [INFO] 14:22:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:22:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 14:22:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:22:51 - CalibrationWorkflow: Treshold reached with 20 iteration, best cost: 0.10626371781160754, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.00026946434487064915}
# [INFO] 14:22:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.449641 > threshold: 0.1
# [INFO] 14:22:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:22:51 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:22:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:22:59 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.1978765308173072e-05, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00042697942467721247, 'E2FOULING': 0.0004473380878011869}
# [INFO] 14:22:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 14:22:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:22:59 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:22:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:22:59 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:22:59 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:22:59 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 14:22:59 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:22:59 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:22:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:22:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 14:22:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:00 - CalibrationWorkflow: Treshold reached with 25 iteration, best cost: 0.10211412946180727, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0003280631138269755, 'E2FOULING': 0.00025}
# [INFO] 14:23:00 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.137323 > threshold: 0.1
# [INFO] 14:23:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:00 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:23:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:07 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.018439556453033003, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0003424008801578239, 'E2FOULING': 0.000422131304681483}
# [INFO] 14:23:07 - CalibrationWorkflow: Working point is accurate enough with cost: 0.018440 < threshold 0.100000
# [INFO] 14:23:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:07 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:23:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:07 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:23:07 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:23:07 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 14:23:07 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:23:07 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:23:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:08 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 14:23:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:08 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.08931158154448317, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 14:23:08 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.321977 > threshold: 0.1
# [INFO] 14:23:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:08 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:23:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:16 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 3.6781990549062405e-06, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00037039273866720454, 'E2FOULING': 0.0003957679347063028}
# [INFO] 14:23:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 14:23:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:23:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:16 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:23:16 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:23:16 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 14:23:16 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:23:16 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:23:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 14:23:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:17 - CalibrationWorkflow: Treshold reached with 27 iteration, best cost: 0.053075917193911165, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0003264704460320809, 'E2FOULING': 0.00026484064285479855}
# [INFO] 14:23:17 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.185280 > threshold: 0.1
# [INFO] 14:23:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:17 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:23:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:28 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.06737376541914206, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0005285252253241547, 'E2FOULING': 0.0003872822912817684}
# [INFO] 14:23:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.067374 < threshold 0.100000
# [INFO] 14:23:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:28 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:23:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:28 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:23:28 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:23:28 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 14:23:28 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:23:28 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:23:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 14:23:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:29 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.04787481389001843, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.00028922324348078725}
# [INFO] 14:23:30 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.264254 > threshold: 0.1
# [INFO] 14:23:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:30 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:23:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:39 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.03516982609486357, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00031415868440133073, 'E2FOULING': 0.00039768735258678185}
# [INFO] 14:23:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.035170 < threshold 0.100000
# [INFO] 14:23:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:39 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:23:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:39 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:23:39 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:23:39 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 14:23:39 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:23:39 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:23:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 14:23:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:40 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.03678970704190993, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00025541992976654934, 'E2FOULING': 0.00027345553771232733}
# [INFO] 14:23:40 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.292604 > threshold: 0.1
# [INFO] 14:23:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:40 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:23:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:51 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.008987419405995269, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.0003685994476033631, 'E2FOULING': 0.0003398044252415614}
# [INFO] 14:23:51 - CalibrationWorkflow: Working point is accurate enough with cost: 0.008987 < threshold 0.100000
# [INFO] 14:23:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:51 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:23:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:51 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:23:51 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:23:51 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 14:23:51 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:23:51 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:23:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 14:23:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:52 - CalibrationWorkflow: Treshold reached with 19 iteration, best cost: 0.02317858568853324, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00025, 'E2FOULING': 0.00029096349150208733}
# [INFO] 14:23:52 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.240347 > threshold: 0.1
# [INFO] 14:23:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:52 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:23:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:57 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.04397926234906411, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.0004426063858113035, 'E2FOULING': 0.00042322275712972524}
# [INFO] 14:23:57 - CalibrationWorkflow: Working point is accurate enough with cost: 0.043979 < threshold 0.100000
# [INFO] 14:23:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:57 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:23:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:57 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:23:57 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:23:57 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 14:23:57 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:23:57 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:23:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 14:23:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:58 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.015573304732639305, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.00038087920055493484, 'E2FOULING': 0.000388033354688471}
# [INFO] 14:23:58 - CalibrationWorkflow: Working point is accurate enough with cost: 0.014646 < threshold 0.100000
# [INFO] 14:23:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:58 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:23:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:58 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:23:58 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:23:58 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 14:23:58 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:23:58 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:23:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:58 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 14:23:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:59 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.008046143556877574, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00028108961326875944, 'E2FOULING': 0.00033343157223240233}
# [INFO] 14:23:59 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.152654 > threshold: 0.1
# [INFO] 14:23:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:23:59 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:23:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:06 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.019450624583963308, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00045980329136074933, 'E2FOULING': 0.00029937071096400455}
# [INFO] 14:24:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.019451 < threshold 0.100000
# [INFO] 14:24:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:06 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:06 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:24:06 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:06 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 14:24:06 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:06 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:24:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 14:24:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:07 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.3737413888950704e-05, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00028572594672708813, 'E2FOULING': 0.0005965881101805033}
# [INFO] 14:24:07 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.216732 > threshold: 0.1
# [INFO] 14:24:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:07 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:24:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:14 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 2.661036164772937e-06, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0004043767768228783, 'E2FOULING': 0.0004105161370468637}
# [INFO] 14:24:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 14:24:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:14 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:24:14 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:14 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 14:24:14 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:14 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:24:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 14:24:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:15 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.401245970250791e-05, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00045371018255868715, 'E2FOULING': 0.0005098979627153975}
# [INFO] 14:24:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.035505 < threshold 0.100000
# [INFO] 14:24:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:15 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:15 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:15 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 14:24:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:15 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 14:24:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:16 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.2053987749142652e-05, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0005337464022318462, 'E2FOULING': 0.0004335021134066392}
# [INFO] 14:24:16 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.103660 > threshold: 0.1
# [INFO] 14:24:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:16 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:24:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:24 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.026455310614482638, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.000388434355530065, 'E2FOULING': 0.0005381088008460575}
# [INFO] 14:24:24 - CalibrationWorkflow: Working point is accurate enough with cost: 0.026455 < threshold 0.100000
# [INFO] 14:24:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:24 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:24 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:24:24 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:24 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 14:24:24 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:24 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:24:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 14:24:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:25 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 9.618101613814524e-06, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0005130451697405963, 'E2FOULING': 0.0004020725035563082}
# [INFO] 14:24:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.084399 < threshold 0.100000
# [INFO] 14:24:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:25 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:25 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:25 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 14:24:25 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:25 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 14:24:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:26 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 7.094604183219695e-06, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00038671862300194, 'E2FOULING': 0.000499800865513719}
# [INFO] 14:24:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.017398 < threshold 0.100000
# [INFO] 14:24:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:26 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:26 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:26 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 14:24:26 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:26 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 14:24:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:27 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 9.489449820948237e-06, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0007169000000000012, 'E2FOULING': 0.0003103000000000001}
# [INFO] 14:24:27 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.176557 > threshold: 0.1
# [INFO] 14:24:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:27 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:24:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:33 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 3.687575373319839e-06, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0005215012030528445, 'E2FOULING': 0.00039037300430058084}
# [INFO] 14:24:33 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 14:24:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:33 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:33 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:24:33 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:33 - CalibrationWorkflow: Self.model updated to online_v14
# [INFO] 14:24:33 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:33 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:24:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:34 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 14:24:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:34 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 8.453718766403104e-06, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0003452720432982864, 'E2FOULING': 0.0004436561250718613}
# [INFO] 14:24:34 - CalibrationWorkflow: Working point is accurate enough with cost: 0.019807 < threshold 0.100000
# [INFO] 14:24:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:34 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:34 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:34 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:34 - CalibrationWorkflow: Self.model updated to online_v15
# [INFO] 14:24:34 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:34 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 14:24:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:35 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 2.606681321083055e-05, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0004565828643282881, 'E2FOULING': 0.00025}
# [INFO] 14:24:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.080370 < threshold 0.100000
# [INFO] 14:24:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:35 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:35 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:35 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:35 - CalibrationWorkflow: Self.model updated to online_v16
# [INFO] 14:24:35 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:35 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 14:24:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:36 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 5.3516626058672835e-06, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.0004751600659707775, 'E2FOULING': 0.0004934413531322364}
# [INFO] 14:24:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.085080 < threshold 0.100000
# [INFO] 14:24:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:36 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:36 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:36 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:36 - CalibrationWorkflow: Self.model updated to online_v17
# [INFO] 14:24:36 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:36 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 14:24:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:37 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 4.91161004156477e-06, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.0004300309825024459, 'E2FOULING': 0.00046271955965235256}
# [INFO] 14:24:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.027538 < threshold 0.100000
# [INFO] 14:24:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:37 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:37 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:37 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:37 - CalibrationWorkflow: Self.model updated to online_v18
# [INFO] 14:24:37 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:37 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 14:24:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:38 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.0254943860453739e-05, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00038424840178500973, 'E2FOULING': 0.0003299100311713082}
# [INFO] 14:24:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 14:24:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:38 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:38 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:38 - CalibrationWorkflow: Self.model updated to online_v19
# [INFO] 14:24:38 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:38 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 14:24:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:38 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 4.675855059006989e-06, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0004894385716384666, 'E2FOULING': 0.00032759411261800635}
# [INFO] 14:24:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.056615 < threshold 0.100000
# [INFO] 14:24:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:38 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:38 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:38 - CalibrationWorkflow: Self.model updated to online_v20
# [INFO] 14:24:38 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:38 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 14:24:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:39 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 4.248801976658973e-06, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0005418228766917019, 'E2FOULING': 0.0003808057366911392}
# [INFO] 14:24:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.081470 < threshold 0.100000
# [INFO] 14:24:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:39 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:39 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:39 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:39 - CalibrationWorkflow: Self.model updated to online_v21
# [INFO] 14:24:39 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:39 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:40 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 14:24:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:40 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.3552554458490925e-06, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.0004028601682840276, 'E2FOULING': 0.00038050517341294286}
# [INFO] 14:24:40 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 14:24:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:40 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:40 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:40 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:40 - CalibrationWorkflow: Self.model updated to online_v22
# [INFO] 14:24:40 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:40 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:41 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 14:24:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:41 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 4.092693957289796e-06, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.0004441375765180742, 'E2FOULING': 0.00036627836951816817}
# [INFO] 14:24:41 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 14:24:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:41 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:41 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:41 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:41 - CalibrationWorkflow: Self.model updated to online_v23
# [INFO] 14:24:41 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:41 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:41 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 14:24:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:41 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 5.999463679417854e-06, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0004097517312460106, 'E2FOULING': 0.00042711578649492403}
# [INFO] 14:24:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 14:24:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:42 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:42 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:42 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:42 - CalibrationWorkflow: Self.model updated to online_v24
# [INFO] 14:24:42 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:42 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 14:24:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:42 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 6.604994776784973e-06, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.00039324572477165574, 'E2FOULING': 0.0002536687698292536}
# [INFO] 14:24:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.064603 < threshold 0.100000
# [INFO] 14:24:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:42 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:42 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:42 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:42 - CalibrationWorkflow: Self.model updated to online_v25
# [INFO] 14:24:42 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:42 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 14:24:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:43 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 5.576467162355661e-07, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.0004166805980536762, 'E2FOULING': 0.00032385458945489624}
# [INFO] 14:24:43 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 14:24:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:43 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:43 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:43 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:43 - CalibrationWorkflow: Self.model updated to online_v26
# [INFO] 14:24:43 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:43 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 14:24:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:44 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 3.379385458417229e-06, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.00036071276139543944, 'E2FOULING': 0.00025}
# [INFO] 14:24:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.068795 < threshold 0.100000
# [INFO] 14:24:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:24:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:44 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:24:44 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:24:44 - CalibrationWorkflow: Self.model updated to online_v27
# [INFO] 14:24:44 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:24:44 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:24:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:24:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 14:24:44 - CalibrationWorkflow: ----------------------------------------
# ...
# [INFO] 14:34:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.075403 < threshold 0.100000
# [INFO] 14:34:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:11 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:34:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:11 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:34:11 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:34:11 - CalibrationWorkflow: Self.model updated to online_v520
# [INFO] 14:34:11 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:34:11 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:34:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 14:34:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:12 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.9122051086289764e-05, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0005117380929388978, 'E2FOULING': 0.00025}
# [INFO] 14:34:12 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.180490 > threshold: 0.1
# [INFO] 14:34:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:12 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:34:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:20 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.02848535186528033, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0005861510547454599, 'E2FOULING': 0.0003815443530406822}
# [INFO] 14:34:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.028485 < threshold 0.100000
# [INFO] 14:34:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:20 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:34:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:20 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:34:20 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:34:20 - CalibrationWorkflow: Self.model updated to online_v521
# [INFO] 14:34:20 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:34:20 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:34:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 14:34:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:21 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 2.1905291229438077e-06, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005422502179994107, 'E2FOULING': 0.0004950949783680023}
# [INFO] 14:34:21 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 14:34:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:21 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:34:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:21 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:34:21 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:34:21 - CalibrationWorkflow: Self.model updated to online_v522
# [INFO] 14:34:21 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:34:21 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:34:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 14:34:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:21 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.748266396559077e-05, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0005498866031747277, 'E2FOULING': 0.00033624838547164493}
# [INFO] 14:34:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.040071 < threshold 0.100000
# [INFO] 14:34:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:22 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:34:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:22 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:34:22 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:34:22 - CalibrationWorkflow: Self.model updated to online_v523
# [INFO] 14:34:22 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:34:22 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:34:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 14:34:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:22 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.2306242654586785e-06, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0005405768304495888, 'E2FOULING': 0.0004229659171539824}
# [INFO] 14:34:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 14:34:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:22 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:34:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:22 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:34:22 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:34:22 - CalibrationWorkflow: Self.model updated to online_v524
# [INFO] 14:34:22 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:34:22 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:34:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:23 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 14:34:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:23 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 9.764891395802236e-06, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00034426969263685794, 'E2FOULING': 0.00043274519587994085}
# [INFO] 14:34:23 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.152209 > threshold: 0.1
# [INFO] 14:34:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:23 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:34:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:28 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 2.107497691090359e-07, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.0004579445590504644, 'E2FOULING': 0.0004256926998528585}
# [INFO] 14:34:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 14:34:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:28 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:34:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:28 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:34:28 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:34:28 - CalibrationWorkflow: Self.model updated to online_v525
# [INFO] 14:34:28 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:34:28 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:34:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 14:34:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:29 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.2127427117950604e-05, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0003829009003811506, 'E2FOULING': 0.0004681401549378502}
# [INFO] 14:34:29 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.102774 > threshold: 0.1
# [INFO] 14:34:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:29 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 14:34:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:35 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.02127758138060199, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0005261457498427303, 'E2FOULING': 0.00036937474764263737}
# [INFO] 14:34:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.021278 < threshold 0.100000
# [INFO] 14:34:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:35 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:34:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:35 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 14:34:35 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:34:35 - CalibrationWorkflow: Self.model updated to online_v526
# [INFO] 14:34:35 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:34:35 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 14:34:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 14:34:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:36 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.2938333598666727e-06, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0004796803805079761, 'E2FOULING': 0.00043511662551415516}
# [INFO] 14:34:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 14:34:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:36 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:34:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:36 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:34:36 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:34:36 - CalibrationWorkflow: Self.model updated to online_v527
# [INFO] 14:34:36 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:34:36 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:34:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 14:34:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:37 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.920487414465502e-06, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0004922411057115322, 'E2FOULING': 0.0005076873429402901}
# [INFO] 14:34:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 14:34:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:37 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:34:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:37 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:34:37 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:34:37 - CalibrationWorkflow: Self.model updated to online_v528
# [INFO] 14:34:37 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:34:37 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:34:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 14:34:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:38 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 3.208524223733115e-06, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.000493857090063386, 'E2FOULING': 0.0004990258628209206}
# [INFO] 14:34:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.007286 < threshold 0.100000
# [INFO] 14:34:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 14:34:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 14:34:38 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 14:34:38 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 14:34:38 - CalibrationWorkflow: Self.model updated to online_v529
# [INFO] 14:34:38 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 14:34:38 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 14:34:38 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/Calibration_result_online_always-one-replay-0.005.xlsx')
# Out:
# [INFO] 14:34:39 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_always-one-replay-0.005.xlsx

# %%
res = workflow.get_results()

# %%
resdf = pd.DataFrame(res)

# %%
resdf.columns
# Out:
# Index(['SampleID', 'Total_workflow_EllapsedTime', 'Calibration_type',
#        'OriginalFactors', 'Target', 'Calibration_Base_Type',
#        'Calibration_Base_EllapsedTime', 'Calibration_Base_IterationNum',
#        'Calibration_Base_Final_obj', 'Calibration_Base_FinalIO',
#        'Calibration_Base_SurrogatePred', 'Validation_Base_SimulationRes',
#        'Validation_Base_SimCost', 'Validation_Base_Accurate',
#        'Validation_Base_Decision', 'Calibration_Direct_EllapsedTime',
#        'Calibration_Direct_IterationNum', 'Calibration_Direct_Final_obj',
#        'Calibration_Direct_FinalIO', 'Calibration_Direct_SimCost',
#        'Calibration_Direct_Accuracy', 'Calibration_Direct_Decision',
#        'OnlineLearning_New_Data', 'OnlineLearning_New_SelectionType',
#        'OnlineLearning_New_DataType', 'OnlineLearning_EllapsedTime',
#        'OnlineLearning_SelectedReplayids', 'OnlineLearning_SelectedReplayIOs',
#        'LocalImprovement', 'GlobalRetention', 'Used_Surrogate_version',
#        'New_Surrogate_version', 'Final_Calibration_Result_IOs',
#        'Final_Calibration_SimCost', 'Final_Calibration_Accurate',
#        'Final_Calibration_Type'],
#       dtype='object')

# %%
resdf['Validation_Base_Accurate'].value_counts()
# Out:
# Validation_Base_Accurate
# True     492
# False     38
# Name: count, dtype: int64

# %%
resdf['Final_Calibration_Accurate'].value_counts()
# Out:
# Final_Calibration_Accurate
# True    530
# Name: count, dtype: int64

# %%
workflow_settings['sim_validation_treshold']
# Out:
# 0.1

# %%
import seaborn as sns

#sns.kdeplot(resdf['Calibration_Base_Final_obj'], label='Surrogate obj',  fill=True, linewidth=2, clip=(0, None))
sns.kdeplot(resdf['Validation_Base_SimCost'], label='Validation obj',  fill=True, linewidth=2, clip=(0, None))
sns.kdeplot(resdf['Final_Calibration_SimCost'], label='Final Calib obj',  fill=True, linewidth=2, clip=(0, None))
plt.axvline(x=workflow_settings['sim_validation_treshold'], color='red', linestyle='--', label='Threshold')
plt.legend()

# %%
resdf['Calibration_Direct_EllapsedTime'].plot()
# Out:
# <Axes: >

# %%
resdf['LocalImprovement'].mean()
# Out:
# 17.015600823402934

# %%
resdf['GlobalRetention'].plot()
# Out:
# <Axes: >

# %%
resdf
# Out:
#      SampleID  Total_workflow_EllapsedTime Calibration_type  \
# 0           0                     9.017154           online
# 1           1                     8.798940           online
# 2           2                     8.705360           online
# 3           3                    12.081853           online
# 4           4                    10.497484           online
# ..        ...                          ...              ...
# 525       525                     5.546304           online
# 526       526                     7.413994           online
# 527       527                     0.814936           online
# 528       528                     0.843105           online
# 529       529                     0.815003           online
#
#                                        OriginalFactors  \
# 0    {'E1FOULING': 0.0003966064602180043, 'E2FOULIN...
# 1    {'E1FOULING': 0.0003858453451426925, 'E2FOULIN...
# 2    {'E1FOULING': 0.0003847697530392205, 'E2FOULIN...
# 3    {'E1FOULING': 0.0004268043194975153, 'E2FOULIN...
# 4    {'E1FOULING': 0.0003682943731335989, 'E2FOULIN...
# ..                                                 ...
# 525  {'E1FOULING': 0.0004548607687919593, 'E2FOULIN...
# 526  {'E1FOULING': 0.0004822419516333996, 'E2FOULIN...
# 527  {'E1FOULING': 0.0004733674673527922, 'E2FOULIN...
# 528  {'E1FOULING': 0.0004984942750080559, 'E2FOULIN...
# 529  {'E1FOULING': 0.0005021358045441324, 'E2FOULIN...
#
#                                                 Target  \
# 0    {'PROD1E1IN': 108.2722567668642, 'PROD1OUT': 9...
# 1    {'PROD1E1IN': 104.3535050140472, 'PROD1OUT': 9...
# 2    {'PROD1E1IN': 105.9350937121914, 'PROD1OUT': 9...
# 3    {'PROD1E1IN': 106.0854462410004, 'PROD1OUT': 9...
# 4    {'PROD1E1IN': 105.0075133590793, 'PROD1OUT': 9...
# ..                                                 ...
# 525  {'PROD1E1IN': 116.9302158164906, 'PROD1OUT': 1...
# 526  {'PROD1E1IN': 116.2112946019632, 'PROD1OUT': 1...
# 527  {'PROD1E1IN': 116.4229042179647, 'PROD1OUT': 1...
# 528  {'PROD1E1IN': 116.8454717819132, 'PROD1OUT': 1...
# 529  {'PROD1E1IN': 116.0362633732756, 'PROD1OUT': 1...
#
#          Calibration_Base_Type  Calibration_Base_EllapsedTime  \
# 0    CalibrationType.SURROGATE                       0.520668
# 1    CalibrationType.SURROGATE                       0.628635
# 2    CalibrationType.SURROGATE                       0.162018
# 3    CalibrationType.SURROGATE                       0.632233
# 4    CalibrationType.SURROGATE                       0.583200
# ..                         ...                            ...
# 525  CalibrationType.SURROGATE                       0.136410
# 526  CalibrationType.SURROGATE                       0.131737
# 527  CalibrationType.SURROGATE                       0.160286
# 528  CalibrationType.SURROGATE                       0.175372
# 529  CalibrationType.SURROGATE                       0.156025
#
#      Calibration_Base_IterationNum  Calibration_Base_Final_obj  \
# 0                               22                    0.106264
# 1                               27                    0.102114
# 2                                7                    0.089312
# 3                               29                    0.053076
# 4                               26                    0.047875
# ..                             ...                         ...
# 525                              6                    0.000010
# 526                              6                    0.000012
# 527                              7                    0.000001
# 528                              8                    0.000002
# 529                              7                    0.000003
#
#                               Calibration_Base_FinalIO  ...  \
# 0    {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEM...  ...
# 1    {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEM...  ...
# 2    {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEM...  ...
# 3    {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEM...  ...
# 4    {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEM...  ...
# ..                                                 ...  ...
# 525  {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP...  ...
# 526  {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEM...  ...
# 527  {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEM...  ...
# 528  {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEM...  ...
# 529  {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEM...  ...
#
#     OnlineLearning_SelectedReplayids OnlineLearning_SelectedReplayIOs  \
# 0                              [120]                             None
# 1                               [52]                             None
# 2                               [28]                             None
# 3                              [189]                             None
# 4                              [177]                             None
# ..                               ...                              ...
# 525                             [44]                             None
# 526                            [103]                             None
# 527                            [147]                             None
# 528                            [136]                             None
# 529                            [114]                             None
#
#      LocalImprovement  GlobalRetention Used_Surrogate_version  \
# 0            1.123734         1.009631                   base
# 1            1.169148         1.019864              online_v0
# 2            1.235113         1.029779              online_v1
# 3            1.238461         1.033969              online_v2
# 4            1.713886         1.030834              online_v3
# ..                ...              ...                    ...
# 525        450.907820         1.718193            online_v524
# 526          2.264907         1.698626            online_v525
# 527          0.455729         1.655792            online_v526
# 528          1.150019         1.626419            online_v527
# 529               NaN         1.607373            online_v528
#
#      New_Surrogate_version                       Final_Calibration_Result_IOs  \
# 0                online_v0  {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEM...
# 1                online_v1  {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEM...
# 2                online_v2  {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEM...
# 3                online_v3  {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEM...
# 4                online_v4  {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEM...
# ..                     ...                                                ...
# 525            online_v525  {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP...
# 526            online_v526  {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEM...
# 527            online_v527  {'PROD1E1IN': 116.36768062063601, 'PROD1OUT': ...
# 528            online_v528  {'PROD1E1IN': 117.23122165473416, 'PROD1OUT': ...
# 529            online_v529  {'PROD1E1IN': 116.59127450642313, 'PROD1OUT': ...
#
#      Final_Calibration_SimCost Final_Calibration_Accurate  \
# 0                 1.197877e-05                       True
# 1                 1.843956e-02                       True
# 2                 3.678199e-06                       True
# 3                 6.737377e-02                       True
# 4                 3.516983e-02                       True
# ..                         ...                        ...
# 525               2.107498e-07                       True
# 526               2.127758e-02                       True
# 527               5.366977e-07                       True
# 528               5.791999e-06                       True
# 529               7.285932e-03                       True
#
#      Final_Calibration_Type
# 0                    direct
# 1                    direct
# 2                    direct
# 3                    direct
# 4                    direct
# ..                      ...
# 525                  direct
# 526                  direct
# 527              validation
# 528              validation
# 529              validation
#
# [530 rows x 36 columns]

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_1000.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-both',  # always-one, always-both, conditional
                     'logging_level': 'DEBUG',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodelbig/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [DEBUG] 11:13:13 - CalibrationWorkflow: Logger initialized.
# [INFO] 11:13:13 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 11:13:13 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodelbig/sklearnann.joblib
# [INFO] 11:13:13 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 11:13:14 - CalibrationWorkflow:
# ============================================================
# [INFO] 11:13:14 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 11:13:14 - CalibrationWorkflow: ============================================================
#
# [INFO] 11:13:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 11:13:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:14 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.07840999924802e-05, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00030082686928713936, 'E2FOULING': 0.00037100868484275383}
# [INFO] 11:13:14 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.152004 > threshold: 0.1
# [DEBUG] 11:13:14 - CalibrationWorkflow: Direct calibration particles reinited {1: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0020800000000000046, 'E2FOULING': 0.0013400000000000029}, 2: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0016400000000000037, 'E2FOULING': 0.0018400000000000042}, 3: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0020400000000000045, 'E2FOULING': 0.0028200000000000065}, 4: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0007000000000000012, 'E2FOULING': 0.0008300000000000015}, 5: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.0003200000000000002}, 6: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0010900000000000022, 'E2FOULING': 0.0019400000000000044}, 7: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0025500000000000063, 'E2FOULING': 0.0017300000000000039}, 8: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.002620000000000006, 'E2FOULING': 0.0023700000000000058}, 9: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0024400000000000055, 'E2FOULING': 0.00034000000000000024}, 10: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0007000000000000012, 'E2FOULING': 0.0012200000000000025}, 11: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0013500000000000029, 'E2FOULING': 0.0005700000000000008}, 12: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.002910000000000007, 'E2FOULING': 0.0008800000000000017}, 13: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0005000000000000007, 'E2FOULING': 0.0027400000000000063}, 14: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0010800000000000022, 'E2FOULING': 0.002030000000000005}, 15: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0015500000000000034, 'E2FOULING': 0.0005200000000000007}, 16: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0024800000000000056, 'E2FOULING': 0.0005800000000000009}, 17: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0005000000000000007, 'E2FOULING': 0.0007600000000000013}, 18: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0010600000000000021, 'E2FOULING': 0.0016500000000000037}, 19: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7 ...
# [INFO] 11:13:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:14 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 11:13:14 - CalibrationWorkflow: ----------------------------------------
# [DEBUG] 11:13:14 - CalibrationWorkflow: Init PSO base_calib_error_factor is set to 1
# [INFO] 11:13:17 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.04237939392246178, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.0003424000000000002}
# [INFO] 11:13:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.042379 < threshold 0.100000
# [INFO] 11:13:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:17 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:13:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:17 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 11:13:17 - CalibrationWorkflow: Retraining model with 12 samples (replay + outliers)
# [INFO] 11:13:17 - CalibrationWorkflow: Self.model updated to online_v0
# [DEBUG] 11:13:17 - CalibrationWorkflow: Retrained model version: online_v0
# [DEBUG] 11:13:17 - CalibrationWorkflow: Model retrained (iteration 1)
# [DEBUG] 11:13:17 - CalibrationWorkflow: Training time: 0.013s
# [INFO] 11:13:17 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:13:17 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [DEBUG] 11:13:17 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0003858453451426925, 'E2FOULING': 0.0003958998035361572}, y_true_next: {'PROD1E1IN': 104.3535050140472, 'PROD1OUT': 94.1073492322335, 'FEED1E1OUT': 51.16120403126303, 'FEED1OUT': 71.76031470141083}
# [DEBUG] 11:13:17 - CalibrationWorkflow: Run prediction with prev model version: base, result {'PROD1E1IN': 103.51750590738028, 'PROD1OUT': 94.60441419250705, 'FEED1E1OUT': 49.92683958111391, 'FEED1OUT': 70.57684955354817}
# [DEBUG] 11:13:17 - CalibrationWorkflow: Run prediction with current model version: online_v0, result {'PROD1E1IN': 103.54546613188916, 'PROD1OUT': 94.5878570138731, 'FEED1E1OUT': 49.98029095789429, 'FEED1OUT': 70.6445986429951}
# [DEBUG] 11:13:18 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:13:20 - CalibrationWorkflow: Run prediction on original data with online_v0 version, cost 0.04378656833333493
# [INFO] 11:13:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:20 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 11:13:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:20 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.006659282885365154, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003513142584715147}
# [INFO] 11:13:20 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.266926 > threshold: 0.1
# [DEBUG] 11:13:20 - CalibrationWorkflow: Direct calibration particles reinited {1: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0020800000000000046, 'E2FOULING': 0.0013400000000000029}, 2: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0016400000000000037, 'E2FOULING': 0.0018400000000000042}, 3: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0020400000000000045, 'E2FOULING': 0.0028200000000000065}, 4: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0007000000000000012, 'E2FOULING': 0.0008300000000000015}, 5: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.0003200000000000002}, 6: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0010900000000000022, 'E2FOULING': 0.0019400000000000044}, 7: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0025500000000000063, 'E2FOULING': 0.0017300000000000039}, 8: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.002620000000000006, 'E2FOULING': 0.0023700000000000058}, 9: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0024400000000000055, 'E2FOULING': 0.00034000000000000024}, 10: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0007000000000000012, 'E2FOULING': 0.0012200000000000025}, 11: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0013500000000000029, 'E2FOULING': 0.0005700000000000008}, 12: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.002910000000000007, 'E2FOULING': 0.0008800000000000017}, 13: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0005000000000000007, 'E2FOULING': 0.0027400000000000063}, 14: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0010800000000000022, 'E2FOULING': 0.002030000000000005}, 15: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0015500000000000034, 'E2FOULING': 0.0005200000000000007}, 16: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0024800000000000056, 'E2FOULING': 0.0005800000000000009}, 17: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0005000000000000007, 'E2FOULING': 0.0007600000000000013}, 18: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0010600000000000021, 'E2FOULING': 0.0016500000000000037}, 19: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1 ...
# [INFO] 11:13:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:20 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 11:13:20 - CalibrationWorkflow: ----------------------------------------
# [DEBUG] 11:13:20 - CalibrationWorkflow: Init PSO base_calib_error_factor is set to 1
# [INFO] 11:13:22 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.015743602096819187, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.0003424000000000002}
# [INFO] 11:13:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.015744 < threshold 0.100000
# [INFO] 11:13:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:22 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:13:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:22 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 11:13:22 - CalibrationWorkflow: Retraining model with 12 samples (replay + outliers)
# [INFO] 11:13:22 - CalibrationWorkflow: Self.model updated to online_v1
# [DEBUG] 11:13:22 - CalibrationWorkflow: Retrained model version: online_v1
# [DEBUG] 11:13:22 - CalibrationWorkflow: Model retrained (iteration 2)
# [DEBUG] 11:13:22 - CalibrationWorkflow: Training time: 0.004s
# [INFO] 11:13:22 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:13:22 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [DEBUG] 11:13:22 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.0003847697530392205, 'E2FOULING': 0.0003664171550081036}, y_true_next: {'PROD1E1IN': 105.9350937121914, 'PROD1OUT': 95.00289890904224, 'FEED1E1OUT': 50.38786037970237, 'FEED1OUT': 72.07939496571692}
# [DEBUG] 11:13:22 - CalibrationWorkflow: Run prediction with prev model version: online_v0, result {'PROD1E1IN': 105.34064692354447, 'PROD1OUT': 95.61997378754465, 'FEED1E1OUT': 49.252196091372525, 'FEED1OUT': 70.6380812200889}
# [DEBUG] 11:13:22 - CalibrationWorkflow: Run prediction with current model version: online_v1, result {'PROD1E1IN': 105.40198813164422, 'PROD1OUT': 95.57308304240654, 'FEED1E1OUT': 49.34403558980007, 'FEED1OUT': 70.80390177320338}
# [DEBUG] 11:13:24 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:13:25 - CalibrationWorkflow: Run prediction on original data with online_v1 version, cost 0.04374605349208489
# [INFO] 11:13:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 11:13:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:25 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.9598398098781138e-05, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.0003200000000000002}
# [INFO] 11:13:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.034171 < threshold 0.100000
# [INFO] 11:13:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:13:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:25 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:13:25 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:13:25 - CalibrationWorkflow: Self.model updated to online_v2
# [DEBUG] 11:13:25 - CalibrationWorkflow: Retrained model version: online_v2
# [DEBUG] 11:13:25 - CalibrationWorkflow: Model retrained (iteration 3)
# [DEBUG] 11:13:25 - CalibrationWorkflow: Training time: 0.003s
# [INFO] 11:13:25 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:13:25 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:13:25 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0004268043194975153, 'E2FOULING': 0.0003875934499864579}, y_true_next: {'PROD1E1IN': 106.0854462410004, 'PROD1OUT': 95.8292211784443, 'FEED1E1OUT': 50.71513840982942, 'FEED1OUT': 72.21505276321437}
# [DEBUG] 11:13:25 - CalibrationWorkflow: Run prediction with prev model version: online_v1, result {'PROD1E1IN': 105.79836158287901, 'PROD1OUT': 96.24514808905151, 'FEED1E1OUT': 50.02098093599758, 'FEED1OUT': 71.37760715102473}
# [DEBUG] 11:13:25 - CalibrationWorkflow: Run prediction with current model version: online_v2, result {'PROD1E1IN': 105.87750959927962, 'PROD1OUT': 96.20972075280062, 'FEED1E1OUT': 50.122696529293066, 'FEED1OUT': 71.53166358729186}
# [DEBUG] 11:13:27 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:13:28 - CalibrationWorkflow: Run prediction on original data with online_v2 version, cost 0.0437782329299734
# [INFO] 11:13:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 11:13:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:28 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.6772970111039003e-06, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.0003424000000000002}
# [INFO] 11:13:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.051762 < threshold 0.100000
# [INFO] 11:13:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:28 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:13:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:28 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:13:28 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:13:28 - CalibrationWorkflow: Self.model updated to online_v3
# [DEBUG] 11:13:28 - CalibrationWorkflow: Retrained model version: online_v3
# [DEBUG] 11:13:28 - CalibrationWorkflow: Model retrained (iteration 4)
# [DEBUG] 11:13:28 - CalibrationWorkflow: Training time: 0.003s
# [INFO] 11:13:28 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:13:28 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:13:28 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0003682943731335989, 'E2FOULING': 0.0004176367323909044}, y_true_next: {'PROD1E1IN': 105.0075133590793, 'PROD1OUT': 94.30550788506662, 'FEED1E1OUT': 51.24622537398864, 'FEED1OUT': 71.1041429147474}
# [DEBUG] 11:13:28 - CalibrationWorkflow: Run prediction with prev model version: online_v2, result {'PROD1E1IN': 104.28368660469013, 'PROD1OUT': 94.65066953155264, 'FEED1E1OUT': 50.01697631059082, 'FEED1OUT': 70.3199524974005}
# [DEBUG] 11:13:28 - CalibrationWorkflow: Run prediction with current model version: online_v3, result {'PROD1E1IN': 104.35409675947676, 'PROD1OUT': 94.60733210415768, 'FEED1E1OUT': 50.13118663932703, 'FEED1OUT': 70.49170859557346}
# [DEBUG] 11:13:29 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:13:31 - CalibrationWorkflow: Run prediction on original data with online_v3 version, cost 0.04387454751072947
# [INFO] 11:13:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 11:13:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:31 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.006838427220307553, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003537135661212066}
# [INFO] 11:13:31 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.219482 > threshold: 0.1
# [DEBUG] 11:13:31 - CalibrationWorkflow: Direct calibration particles reinited {1: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0020800000000000046, 'E2FOULING': 0.0013400000000000029}, 2: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0016400000000000037, 'E2FOULING': 0.0018400000000000042}, 3: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0020400000000000045, 'E2FOULING': 0.0028200000000000065}, 4: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0007000000000000012, 'E2FOULING': 0.0008300000000000015}, 5: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.0003200000000000002}, 6: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0010900000000000022, 'E2FOULING': 0.0019400000000000044}, 7: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0025500000000000063, 'E2FOULING': 0.0017300000000000039}, 8: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.002620000000000006, 'E2FOULING': 0.0023700000000000058}, 9: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0024400000000000055, 'E2FOULING': 0.00034000000000000024}, 10: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0007000000000000012, 'E2FOULING': 0.0012200000000000025}, 11: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0013500000000000029, 'E2FOULING': 0.0005700000000000008}, 12: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.002910000000000007, 'E2FOULING': 0.0008800000000000017}, 13: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0005000000000000007, 'E2FOULING': 0.0027400000000000063}, 14: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0010800000000000022, 'E2FOULING': 0.002030000000000005}, 15: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0015500000000000034, 'E2FOULING': 0.0005200000000000007}, 16: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0024800000000000056, 'E2FOULING': 0.0005800000000000009}, 17: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0005000000000000007, 'E2FOULING': 0.0007600000000000013}, 18: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0010600000000000021, 'E2FOULING': 0.0016500000000000037}, 19: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1 ...
# [INFO] 11:13:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:31 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 11:13:31 - CalibrationWorkflow: ----------------------------------------
# [DEBUG] 11:13:31 - CalibrationWorkflow: Init PSO base_calib_error_factor is set to 1
# [INFO] 11:13:33 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.01585081552206672, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.0003424000000000002}
# [INFO] 11:13:33 - CalibrationWorkflow: Working point is accurate enough with cost: 0.015851 < threshold 0.100000
# [INFO] 11:13:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:33 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:13:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:33 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 11:13:33 - CalibrationWorkflow: Retraining model with 12 samples (replay + outliers)
# [INFO] 11:13:33 - CalibrationWorkflow: Self.model updated to online_v4
# [DEBUG] 11:13:33 - CalibrationWorkflow: Retrained model version: online_v4
# [DEBUG] 11:13:33 - CalibrationWorkflow: Model retrained (iteration 5)
# [DEBUG] 11:13:33 - CalibrationWorkflow: Training time: 0.004s
# [INFO] 11:13:33 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:13:33 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [DEBUG] 11:13:33 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.0003865641527368978, 'E2FOULING': 0.0003837776388379698}, y_true_next: {'PROD1E1IN': 105.2450237343393, 'PROD1OUT': 94.74462148595524, 'FEED1E1OUT': 51.20939167558146, 'FEED1OUT': 72.29283211661624}
# [DEBUG] 11:13:33 - CalibrationWorkflow: Run prediction with prev model version: online_v3, result {'PROD1E1IN': 104.85349183386955, 'PROD1OUT': 95.19893047145538, 'FEED1E1OUT': 50.313709439051614, 'FEED1OUT': 71.50202507734431}
# [DEBUG] 11:13:33 - CalibrationWorkflow: Run prediction with current model version: online_v4, result {'PROD1E1IN': 104.93815842907044, 'PROD1OUT': 95.14854518669145, 'FEED1E1OUT': 50.44450770494484, 'FEED1OUT': 71.68453895766699}
# [DEBUG] 11:13:35 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:13:36 - CalibrationWorkflow: Run prediction on original data with online_v4 version, cost 0.04417490814346917
# [INFO] 11:13:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 11:13:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:36 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 6.228628674671416e-06, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.0003200000000000002}
# [INFO] 11:13:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.044795 < threshold 0.100000
# [INFO] 11:13:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:36 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:13:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:36 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:13:36 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:13:36 - CalibrationWorkflow: Self.model updated to online_v5
# [DEBUG] 11:13:36 - CalibrationWorkflow: Retrained model version: online_v5
# [DEBUG] 11:13:36 - CalibrationWorkflow: Model retrained (iteration 6)
# [DEBUG] 11:13:36 - CalibrationWorkflow: Training time: 0.003s
# [INFO] 11:13:36 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:13:36 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:13:36 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.0003810459963643718, 'E2FOULING': 0.0003715400271790817}, y_true_next: {'PROD1E1IN': 104.0663321663678, 'PROD1OUT': 93.44377163244644, 'FEED1E1OUT': 50.35972053090467, 'FEED1OUT': 71.30224439835644}
# [DEBUG] 11:13:36 - CalibrationWorkflow: Run prediction with prev model version: online_v4, result {'PROD1E1IN': 103.54262061848371, 'PROD1OUT': 93.98579442668122, 'FEED1E1OUT': 49.64658152629271, 'FEED1OUT': 70.68061642892926}
# [DEBUG] 11:13:36 - CalibrationWorkflow: Run prediction with current model version: online_v5, result {'PROD1E1IN': 103.63555651416657, 'PROD1OUT': 93.94720617624016, 'FEED1E1OUT': 49.775926947723846, 'FEED1OUT': 70.85447697951994}
# [DEBUG] 11:13:37 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:13:39 - CalibrationWorkflow: Run prediction on original data with online_v5 version, cost 0.04448385894312833
# [INFO] 11:13:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 11:13:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:39 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 5.4807747869887694e-06, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.0003200000000000002}
# [INFO] 11:13:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.021557 < threshold 0.100000
# [INFO] 11:13:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:39 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:13:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:39 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:13:39 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:13:39 - CalibrationWorkflow: Self.model updated to online_v6
# [DEBUG] 11:13:39 - CalibrationWorkflow: Retrained model version: online_v6
# [DEBUG] 11:13:39 - CalibrationWorkflow: Model retrained (iteration 7)
# [DEBUG] 11:13:39 - CalibrationWorkflow: Training time: 0.003s
# [INFO] 11:13:39 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:13:39 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:13:39 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0004316306099827564, 'E2FOULING': 0.0003955641958206342}, y_true_next: {'PROD1E1IN': 103.7492818766758, 'PROD1OUT': 93.56305374030796, 'FEED1E1OUT': 48.90867623489834, 'FEED1OUT': 69.3782033072572}
# [DEBUG] 11:13:39 - CalibrationWorkflow: Run prediction with prev model version: online_v5, result {'PROD1E1IN': 103.34198307666821, 'PROD1OUT': 93.93816955095186, 'FEED1E1OUT': 48.950374499150165, 'FEED1OUT': 69.56039224990108}
# [DEBUG] 11:13:39 - CalibrationWorkflow: Run prediction with current model version: online_v6, result {'PROD1E1IN': 103.40134727302207, 'PROD1OUT': 93.89290631618013, 'FEED1E1OUT': 49.02231689707874, 'FEED1OUT': 69.65696142859956}
# [DEBUG] 11:13:40 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:13:42 - CalibrationWorkflow: Run prediction on original data with online_v6 version, cost 0.044512230581350155
# [INFO] 11:13:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 11:13:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:42 - CalibrationWorkflow: Obj Treshold reached with 1 iteration, best cost: 5.265633411061464e-06, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.00042921349705147703, 'E2FOULING': 0.0004921521168915614}
# [INFO] 11:13:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.017697 < threshold 0.100000
# [INFO] 11:13:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:42 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:13:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:42 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:13:42 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:13:42 - CalibrationWorkflow: Self.model updated to online_v7
# [DEBUG] 11:13:42 - CalibrationWorkflow: Retrained model version: online_v7
# [DEBUG] 11:13:42 - CalibrationWorkflow: Model retrained (iteration 8)
# [DEBUG] 11:13:42 - CalibrationWorkflow: Training time: 0.003s
# [INFO] 11:13:42 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:13:42 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:13:42 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.000404769739239879, 'E2FOULING': 0.0003387199532341512}, y_true_next: {'PROD1E1IN': 105.2583717026583, 'PROD1OUT': 94.74291447019567, 'FEED1E1OUT': 50.53997134623916, 'FEED1OUT': 72.42273899587951}
# [DEBUG] 11:13:42 - CalibrationWorkflow: Run prediction with prev model version: online_v6, result {'PROD1E1IN': 105.38058608195801, 'PROD1OUT': 95.25217005520766, 'FEED1E1OUT': 50.32583756970017, 'FEED1OUT': 71.77241190072942}
# [DEBUG] 11:13:42 - CalibrationWorkflow: Run prediction with current model version: online_v7, result {'PROD1E1IN': 105.42991988518963, 'PROD1OUT': 95.21704530706306, 'FEED1E1OUT': 50.352654744274034, 'FEED1OUT': 71.78498995000605}
# [DEBUG] 11:13:43 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:13:44 - CalibrationWorkflow: Run prediction on original data with online_v7 version, cost 0.044323339960797625
# [INFO] 11:13:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 11:13:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:44 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 2.7168581953807594e-06, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.0003424000000000002}
# [INFO] 11:13:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.012115 < threshold 0.100000
# [INFO] 11:13:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:13:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:44 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:13:44 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:13:44 - CalibrationWorkflow: Self.model updated to online_v8
# [DEBUG] 11:13:44 - CalibrationWorkflow: Retrained model version: online_v8
# [DEBUG] 11:13:44 - CalibrationWorkflow: Model retrained (iteration 9)
# [DEBUG] 11:13:44 - CalibrationWorkflow: Training time: 0.003s
# [INFO] 11:13:44 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:13:44 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:13:44 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0004192332463585948, 'E2FOULING': 0.0004147215642408191}, y_true_next: {'PROD1E1IN': 108.984519915952, 'PROD1OUT': 98.1293317824576, 'FEED1E1OUT': 51.61290545610018, 'FEED1OUT': 72.7635135295223}
# [DEBUG] 11:13:44 - CalibrationWorkflow: Run prediction with prev model version: online_v7, result {'PROD1E1IN': 109.17454759093158, 'PROD1OUT': 98.15165580961624, 'FEED1E1OUT': 51.14477905182515, 'FEED1OUT': 72.78250949597383}
# [DEBUG] 11:13:44 - CalibrationWorkflow: Run prediction with current model version: online_v8, result {'PROD1E1IN': 109.19944518149654, 'PROD1OUT': 98.10978335739783, 'FEED1E1OUT': 51.20821989771403, 'FEED1OUT': 72.83119079321118}
# [DEBUG] 11:13:46 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:13:47 - CalibrationWorkflow: Run prediction on original data with online_v8 version, cost 0.044301679128123425
# [INFO] 11:13:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:47 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 11:13:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:47 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.009551742464381797, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.0003424000000000002}
# [INFO] 11:13:47 - CalibrationWorkflow: Working point is accurate enough with cost: 0.057613 < threshold 0.100000
# [INFO] 11:13:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:47 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:13:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:47 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:13:47 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:13:47 - CalibrationWorkflow: Self.model updated to online_v9
# [DEBUG] 11:13:47 - CalibrationWorkflow: Retrained model version: online_v9
# [DEBUG] 11:13:47 - CalibrationWorkflow: Model retrained (iteration 10)
# [DEBUG] 11:13:47 - CalibrationWorkflow: Training time: 0.003s
# [INFO] 11:13:47 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:13:47 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:13:47 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.0004131801397823434, 'E2FOULING': 0.0004004721041568429}, y_true_next: {'PROD1E1IN': 104.224635670864, 'PROD1OUT': 93.77644604558299, 'FEED1E1OUT': 49.2060467536532, 'FEED1OUT': 69.34155975500977}
# [DEBUG] 11:13:47 - CalibrationWorkflow: Run prediction with prev model version: online_v8, result {'PROD1E1IN': 103.88928195344415, 'PROD1OUT': 93.9278584631185, 'FEED1E1OUT': 49.228153524651766, 'FEED1OUT': 69.56971111489489}
# [DEBUG] 11:13:47 - CalibrationWorkflow: Run prediction with current model version: online_v9, result {'PROD1E1IN': 103.88698021318463, 'PROD1OUT': 93.86836650428363, 'FEED1E1OUT': 49.2816168567236, 'FEED1OUT': 69.6368885285598}
# [DEBUG] 11:13:49 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:13:50 - CalibrationWorkflow: Run prediction on original data with online_v9 version, cost 0.04429293778192474
# [INFO] 11:13:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 11:13:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:50 - CalibrationWorkflow: Obj Treshold reached with 1 iteration, best cost: 2.0618322587982623e-06, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.0004231146045306316, 'E2FOULING': 0.00047538016245923635}
# [INFO] 11:13:50 - CalibrationWorkflow: Working point is accurate enough with cost: 0.014009 < threshold 0.100000
# [INFO] 11:13:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:50 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:13:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:50 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:13:50 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:13:50 - CalibrationWorkflow: Self.model updated to online_v10
# [DEBUG] 11:13:50 - CalibrationWorkflow: Retrained model version: online_v10
# [DEBUG] 11:13:50 - CalibrationWorkflow: Model retrained (iteration 11)
# [DEBUG] 11:13:50 - CalibrationWorkflow: Training time: 0.003s
# [INFO] 11:13:50 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:13:50 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:13:50 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0004079347933577989, 'E2FOULING': 0.0004016109176335707}, y_true_next: {'PROD1E1IN': 103.3332712469416, 'PROD1OUT': 93.11618016136129, 'FEED1E1OUT': 49.40346732965634, 'FEED1OUT': 69.33168443926297}
# [DEBUG] 11:13:50 - CalibrationWorkflow: Run prediction with prev model version: online_v9, result {'PROD1E1IN': 102.85342255571061, 'PROD1OUT': 93.23463543697858, 'FEED1E1OUT': 49.41139406901181, 'FEED1OUT': 69.63125327151022}
# [DEBUG] 11:13:50 - CalibrationWorkflow: Run prediction with current model version: online_v10, result {'PROD1E1IN': 102.85184982900277, 'PROD1OUT': 93.19867229503188, 'FEED1E1OUT': 49.422777428309644, 'FEED1OUT': 69.62187850919773}
# [DEBUG] 11:13:52 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:13:53 - CalibrationWorkflow: Run prediction on original data with online_v10 version, cost 0.04410526422925035
# [INFO] 11:13:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 11:13:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:53 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.009627182431923295, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.0003424000000000002}
# [INFO] 11:13:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.024807 < threshold 0.100000
# [INFO] 11:13:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:53 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:13:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:13:53 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:13:53 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:13:53 - CalibrationWorkflow: Self.model updated to online_v11
# [DEBUG] 11:13:53 - CalibrationWorkflow: Retrained model version: online_v11
# [DEBUG] 11:13:53 - CalibrationWorkflow: Model retrained (iteration 12)
# [DEBUG] 11:13:53 - CalibrationWorkflow: Training time: 0.003s
# [INFO] 11:13:53 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:13:53 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:13:53 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0003977322078879234, 'E2FOULING': 0.0003942882968251896}, y_true_next: {'PROD1E1IN': 102.7345388700823, 'PROD1OUT': 92.51748839309408, 'FEED1E1OUT': 49.72324955832892, 'FEED1OUT': 69.55886399358633}
# [DEBUG] 11:13:53 - CalibrationWorkflow: Run prediction with prev model version: online_v10, result {'PROD1E1IN': 102.22346388517964, 'PROD1OUT': 92.69288875807784, 'FEED1E1OUT': 49.65791079099078, 'FEED1OUT': 69.74141073929752}
# ...
# [INFO] 11:38:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:38:52 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 11:38:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:38:52 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 2.2909721741386918e-05, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0005311605919530485, 'E2FOULING': 0.0005141360201549711}
# [INFO] 11:38:52 - CalibrationWorkflow: Working point is accurate enough with cost: 0.022686 < threshold 0.100000
# [INFO] 11:38:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:38:52 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:38:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:38:52 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:38:52 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:38:52 - CalibrationWorkflow: Self.model updated to online_v524
# [DEBUG] 11:38:52 - CalibrationWorkflow: Retrained model version: online_v524
# [DEBUG] 11:38:52 - CalibrationWorkflow: Model retrained (iteration 525)
# [DEBUG] 11:38:52 - CalibrationWorkflow: Training time: 0.004s
# [INFO] 11:38:52 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:38:52 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:38:52 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.0004548607687919593, 'E2FOULING': 0.0004232561799224009}, y_true_next: {'PROD1E1IN': 116.9302158164906, 'PROD1OUT': 103.5070048304623, 'FEED1E1OUT': 55.1784613581126, 'FEED1OUT': 83.47997856692132}
# [DEBUG] 11:38:52 - CalibrationWorkflow: Run prediction with prev model version: online_v523, result {'PROD1E1IN': 116.37891720388714, 'PROD1OUT': 103.74858358854463, 'FEED1E1OUT': 55.160887820391444, 'FEED1OUT': 82.92868712934956}
# [DEBUG] 11:38:52 - CalibrationWorkflow: Run prediction with current model version: online_v524, result {'PROD1E1IN': 116.42745007098623, 'PROD1OUT': 103.79401955382977, 'FEED1E1OUT': 55.111055038625196, 'FEED1OUT': 82.8565008123908}
# [DEBUG] 11:38:53 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:38:55 - CalibrationWorkflow: Run prediction on original data with online_v524 version, cost 0.018938817686531478
# [INFO] 11:38:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:38:55 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 11:38:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:38:55 - CalibrationWorkflow: Obj Treshold reached with 1 iteration, best cost: 2.1608303983628776e-05, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00038046000000000027, 'E2FOULING': 0.0003580800000000002}
# [INFO] 11:38:55 - CalibrationWorkflow: Working point is accurate enough with cost: 0.099329 < threshold 0.100000
# [INFO] 11:38:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:38:55 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:38:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:38:55 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:38:55 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:38:55 - CalibrationWorkflow: Self.model updated to online_v525
# [DEBUG] 11:38:55 - CalibrationWorkflow: Retrained model version: online_v525
# [DEBUG] 11:38:55 - CalibrationWorkflow: Model retrained (iteration 526)
# [DEBUG] 11:38:55 - CalibrationWorkflow: Training time: 0.005s
# [INFO] 11:38:55 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:38:55 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:38:55 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0004822419516333996, 'E2FOULING': 0.000441137560881643}, y_true_next: {'PROD1E1IN': 116.2112946019632, 'PROD1OUT': 103.4262400024965, 'FEED1E1OUT': 55.00286776519147, 'FEED1OUT': 82.91277788580129}
# [DEBUG] 11:38:55 - CalibrationWorkflow: Run prediction with prev model version: online_v524, result {'PROD1E1IN': 115.80222906324217, 'PROD1OUT': 103.5284930921377, 'FEED1E1OUT': 55.06214682546316, 'FEED1OUT': 82.67053554406112}
# [DEBUG] 11:38:55 - CalibrationWorkflow: Run prediction with current model version: online_v525, result {'PROD1E1IN': 115.87420775779299, 'PROD1OUT': 103.51658032636144, 'FEED1E1OUT': 55.06824089009403, 'FEED1OUT': 82.67859210326652}
# [DEBUG] 11:38:56 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:38:57 - CalibrationWorkflow: Run prediction on original data with online_v525 version, cost 0.019002343405218725
# [INFO] 11:38:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:38:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 11:38:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:38:57 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 8.96547291235377e-06, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0004404535067150582, 'E2FOULING': 0.0005055033029201571}
# [INFO] 11:38:58 - CalibrationWorkflow: Working point is accurate enough with cost: 0.019177 < threshold 0.100000
# [INFO] 11:38:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:38:58 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:38:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:38:58 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:38:58 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:38:58 - CalibrationWorkflow: Self.model updated to online_v526
# [DEBUG] 11:38:58 - CalibrationWorkflow: Retrained model version: online_v526
# [DEBUG] 11:38:58 - CalibrationWorkflow: Model retrained (iteration 527)
# [DEBUG] 11:38:58 - CalibrationWorkflow: Training time: 0.004s
# [INFO] 11:38:58 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:38:58 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:38:58 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0004733674673527922, 'E2FOULING': 0.0004382734306785922}, y_true_next: {'PROD1E1IN': 116.4229042179647, 'PROD1OUT': 103.1173986374834, 'FEED1E1OUT': 53.74496166488706, 'FEED1OUT': 81.45195936183433}
# [DEBUG] 11:38:58 - CalibrationWorkflow: Run prediction with prev model version: online_v525, result {'PROD1E1IN': 116.17167799723798, 'PROD1OUT': 103.45368782776845, 'FEED1E1OUT': 54.14181038340634, 'FEED1OUT': 81.3293389807769}
# [DEBUG] 11:38:58 - CalibrationWorkflow: Run prediction with current model version: online_v526, result {'PROD1E1IN': 116.21500855903938, 'PROD1OUT': 103.41731904179991, 'FEED1E1OUT': 54.153391421416956, 'FEED1OUT': 81.34691162579037}
# [DEBUG] 11:38:59 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:39:00 - CalibrationWorkflow: Run prediction on original data with online_v526 version, cost 0.018979317352366833
# [INFO] 11:39:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:39:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 11:39:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:39:00 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.008569686204022623, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00045170394712405813, 'E2FOULING': 0.0005329063545911595}
# [INFO] 11:39:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.013701 < threshold 0.100000
# [INFO] 11:39:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:39:00 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:39:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:39:00 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:39:00 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:39:00 - CalibrationWorkflow: Self.model updated to online_v527
# [DEBUG] 11:39:00 - CalibrationWorkflow: Retrained model version: online_v527
# [DEBUG] 11:39:00 - CalibrationWorkflow: Model retrained (iteration 528)
# [DEBUG] 11:39:00 - CalibrationWorkflow: Training time: 0.004s
# [INFO] 11:39:00 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:39:00 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:39:00 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0004984942750080559, 'E2FOULING': 0.0004635914130454697}, y_true_next: {'PROD1E1IN': 116.8454717819132, 'PROD1OUT': 103.8043984760304, 'FEED1E1OUT': 53.18168285239341, 'FEED1OUT': 80.54540479995939}
# [DEBUG] 11:39:00 - CalibrationWorkflow: Run prediction with prev model version: online_v526, result {'PROD1E1IN': 116.68980876667332, 'PROD1OUT': 103.99979443384008, 'FEED1E1OUT': 53.85439388344041, 'FEED1OUT': 80.89322374582586}
# [DEBUG] 11:39:00 - CalibrationWorkflow: Run prediction with current model version: online_v527, result {'PROD1E1IN': 116.75034321544855, 'PROD1OUT': 103.96159382563208, 'FEED1E1OUT': 53.84678586567481, 'FEED1OUT': 80.86562625382909}
# [DEBUG] 11:39:02 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:39:03 - CalibrationWorkflow: Run prediction on original data with online_v527 version, cost 0.018839500338943303
# [INFO] 11:39:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:39:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 11:39:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:39:03 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 6.837039949632735e-06, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0004959903405413693, 'E2FOULING': 0.000493459447124182}
# [INFO] 11:39:03 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 11:39:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:39:03 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:39:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:39:03 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:39:03 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:39:03 - CalibrationWorkflow: Self.model updated to online_v528
# [DEBUG] 11:39:03 - CalibrationWorkflow: Retrained model version: online_v528
# [DEBUG] 11:39:03 - CalibrationWorkflow: Model retrained (iteration 529)
# [DEBUG] 11:39:03 - CalibrationWorkflow: Training time: 0.005s
# [INFO] 11:39:03 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:39:03 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:39:03 - CalibrationWorkflow: Type of x_next is <class 'dict'> and y_true_next <class 'dict'>, x_next: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0005021358045441324, 'E2FOULING': 0.000435547364149358}, y_true_next: {'PROD1E1IN': 116.0362633732756, 'PROD1OUT': 103.2290198013638, 'FEED1E1OUT': 53.70527292136836, 'FEED1OUT': 81.64632108635038}
# [DEBUG] 11:39:03 - CalibrationWorkflow: Run prediction with prev model version: online_v527, result {'PROD1E1IN': 115.91798434792477, 'PROD1OUT': 103.33223952110366, 'FEED1E1OUT': 54.26299554293487, 'FEED1OUT': 81.58769348948167}
# [DEBUG] 11:39:03 - CalibrationWorkflow: Run prediction with current model version: online_v528, result {'PROD1E1IN': 115.9459155784534, 'PROD1OUT': 103.28284257551732, 'FEED1E1OUT': 54.20658078845582, 'FEED1OUT': 81.60361037035393}
# [DEBUG] 11:39:05 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:39:06 - CalibrationWorkflow: Run prediction on original data with online_v528 version, cost 0.01860591818603821
# [INFO] 11:39:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:39:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 11:39:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:39:06 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 2.339984946454041e-06, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0005088332213252938, 'E2FOULING': 0.00044100056508113676}
# [INFO] 11:39:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 11:39:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:39:06 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 11:39:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 11:39:06 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 11:39:06 - CalibrationWorkflow: Retraining model with 11 samples (replay + outliers)
# [INFO] 11:39:06 - CalibrationWorkflow: Self.model updated to online_v529
# [DEBUG] 11:39:06 - CalibrationWorkflow: Retrained model version: online_v529
# [DEBUG] 11:39:06 - CalibrationWorkflow: Model retrained (iteration 530)
# [DEBUG] 11:39:06 - CalibrationWorkflow: Training time: 0.004s
# [INFO] 11:39:06 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 11:39:06 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [DEBUG] 11:39:08 - CalibrationWorkflow: Run prediction on original data with base model base version, cost 0.04394263264287142
# [DEBUG] 11:39:09 - CalibrationWorkflow: Run prediction on original data with online_v529 version, cost 0.01825197853214367
# [INFO] 11:39:09 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/04_Calibration_Online_FNN-high_always-both.xlsx')
# Out:
# [INFO] 11:39:12 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_always-both.xlsx

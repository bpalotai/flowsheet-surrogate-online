# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_excel('../02_Base_Surrogate_Training/Adaptive_train_data.xlsx', index_col=0)
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/AdaptivedatFNN/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 22:06:06 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 22:06:06 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/AdaptivedatFNN/sklearnann.joblib
# [INFO] 22:06:06 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 22:06:06 - CalibrationWorkflow:
# ============================================================
# [INFO] 22:06:06 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 22:06:06 - CalibrationWorkflow: ============================================================
#
# [INFO] 22:06:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 22:06:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:06 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.01146311158719026, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 22:06:06 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.450269 > threshold: 0.1
# [INFO] 22:06:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:06 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:06:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:15 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.029215761991821368, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0003411908630183983, 'E2FOULING': 0.0005501292362621582}
# [INFO] 22:06:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.029216 < threshold 0.100000
# [INFO] 22:06:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:06:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:15 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 22:06:15 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:06:15 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 22:06:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:06:15 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:06:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 22:06:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:16 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.012217412870316715, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 22:06:16 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.322583 > threshold: 0.1
# [INFO] 22:06:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:16 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:06:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:26 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.07777991066718408, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00031877839730767263, 'E2FOULING': 0.0005895789123945133}
# [INFO] 22:06:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.077780 < threshold 0.100000
# [INFO] 22:06:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:06:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:26 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 22:06:26 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:06:26 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 22:06:26 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:06:26 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:06:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 22:06:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:27 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.016954697918203223, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 22:06:27 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.294546 > threshold: 0.1
# [INFO] 22:06:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:27 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:06:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:35 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.05894836585645672, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00042232374580519446, 'E2FOULING': 0.0004986435266355247}
# [INFO] 22:06:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.058948 < threshold 0.100000
# [INFO] 22:06:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:35 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:06:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:35 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 22:06:35 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:06:35 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 22:06:35 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:06:35 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:06:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 22:06:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:35 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.007156074297190165, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00035415537882613977, 'E2FOULING': 0.00025}
# [INFO] 22:06:36 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.143388 > threshold: 0.1
# [INFO] 22:06:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:36 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:06:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:46 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.0877772268401904, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00032629459940518285, 'E2FOULING': 0.0004364897753262103}
# [INFO] 22:06:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.087777 < threshold 0.100000
# [INFO] 22:06:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:46 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:06:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:46 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 22:06:46 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:06:46 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 22:06:46 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:06:46 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:06:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 22:06:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:46 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 5.743771440762503e-06, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0003443462359964251, 'E2FOULING': 0.00025}
# [INFO] 22:06:46 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.107077 > threshold: 0.1
# [INFO] 22:06:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:46 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:06:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:58 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.08446590665926679, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00027766678534869556, 'E2FOULING': 0.0005237862772489024}
# [INFO] 22:06:58 - CalibrationWorkflow: Working point is accurate enough with cost: 0.084466 < threshold 0.100000
# [INFO] 22:06:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:58 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:06:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:58 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 22:06:58 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:06:58 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 22:06:58 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:06:58 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:06:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 22:06:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:59 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.1482666499317167e-05, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00031974466143751284, 'E2FOULING': 0.00025}
# [INFO] 22:06:59 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.125786 > threshold: 0.1
# [INFO] 22:06:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:06:59 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:06:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:09 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.07246159530923592, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.0003741342770699299, 'E2FOULING': 0.0005914046204509345}
# [INFO] 22:07:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.072462 < threshold 0.100000
# [INFO] 22:07:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:09 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:09 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 22:07:09 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:09 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 22:07:09 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:09 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:07:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 22:07:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:10 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 4.291015743547959e-06, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00035641177970416153, 'E2FOULING': 0.00025}
# [INFO] 22:07:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.063951 < threshold 0.100000
# [INFO] 22:07:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:10 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:10 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:10 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:10 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 22:07:10 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:10 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 22:07:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:11 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 2.4697214404168716e-06, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0005196634867286215, 'E2FOULING': 0.00025}
# [INFO] 22:07:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.084309 < threshold 0.100000
# [INFO] 22:07:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:11 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:11 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:11 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:11 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 22:07:11 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:11 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 22:07:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:11 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 3.0767001733161565e-06, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00046156368473844104, 'E2FOULING': 0.0002556048193603289}
# [INFO] 22:07:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.028622 < threshold 0.100000
# [INFO] 22:07:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:11 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:11 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:11 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:11 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 22:07:11 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:11 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 22:07:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:12 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 6.872598423145872e-06, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0004452660124225796, 'E2FOULING': 0.00027120900394009734}
# [INFO] 22:07:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.071422 < threshold 0.100000
# [INFO] 22:07:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:12 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:12 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:12 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 22:07:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:12 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 22:07:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:12 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.0607794504176889e-05, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.0005289437743563172, 'E2FOULING': 0.0004423852469604036}
# [INFO] 22:07:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.091221 < threshold 0.100000
# [INFO] 22:07:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:12 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:12 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:12 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 22:07:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:12 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 22:07:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:13 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 4.586926271309577e-06, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.00048187213709504256, 'E2FOULING': 0.0005070951121045968}
# [INFO] 22:07:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.072898 < threshold 0.100000
# [INFO] 22:07:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:13 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:13 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:13 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 22:07:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:13 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 22:07:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:14 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 4.225278975624801e-06, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.000437805134123003, 'E2FOULING': 0.0005045244138157746}
# [INFO] 22:07:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.033086 < threshold 0.100000
# [INFO] 22:07:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:14 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:14 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:14 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 22:07:14 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:14 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 22:07:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:14 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 5.4371454854149146e-06, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.000393114065327669, 'E2FOULING': 0.0005127948531812448}
# [INFO] 22:07:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.022856 < threshold 0.100000
# [INFO] 22:07:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:14 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:14 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:14 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 22:07:14 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:14 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 22:07:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:15 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 9.50089525003939e-06, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.000620000000000001, 'E2FOULING': 0.0004700000000000006}
# [INFO] 22:07:15 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.102303 > threshold: 0.1
# [INFO] 22:07:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:15 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:07:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:21 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 4.896945592114914e-06, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0005033760519136045, 'E2FOULING': 0.00033986835888961313}
# [INFO] 22:07:21 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 22:07:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:21 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:21 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 22:07:21 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:21 - CalibrationWorkflow: Self.model updated to online_v14
# [INFO] 22:07:21 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:21 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:07:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 22:07:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:22 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 2.6353445889457334e-06, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0004012075529316297, 'E2FOULING': 0.0004988377571352498}
# [INFO] 22:07:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.030697 < threshold 0.100000
# [INFO] 22:07:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:22 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:22 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:22 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:22 - CalibrationWorkflow: Self.model updated to online_v15
# [INFO] 22:07:22 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:22 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 22:07:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:23 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 3.677346418435351e-06, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0003962382373037253, 'E2FOULING': 0.0004972409683745376}
# [INFO] 22:07:23 - CalibrationWorkflow: Working point is accurate enough with cost: 0.021706 < threshold 0.100000
# [INFO] 22:07:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:23 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:23 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:23 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:23 - CalibrationWorkflow: Self.model updated to online_v16
# [INFO] 22:07:23 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:23 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:23 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 22:07:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:23 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.006384602996658101, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.00043345947256724074, 'E2FOULING': 0.0005869604744146657}
# [INFO] 22:07:23 - CalibrationWorkflow: Working point is accurate enough with cost: 0.068255 < threshold 0.100000
# [INFO] 22:07:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:23 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:23 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:23 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:23 - CalibrationWorkflow: Self.model updated to online_v17
# [INFO] 22:07:23 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:23 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 22:07:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:24 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 7.465985907124754e-06, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.00035326707257902275, 'E2FOULING': 0.0006256998912409208}
# [INFO] 22:07:24 - CalibrationWorkflow: Working point is accurate enough with cost: 0.038909 < threshold 0.100000
# [INFO] 22:07:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:24 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:24 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:24 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:24 - CalibrationWorkflow: Self.model updated to online_v18
# [INFO] 22:07:24 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:24 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 22:07:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:25 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.0445121215516522e-05, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.0004029133123845905, 'E2FOULING': 0.0004925595843164759}
# [INFO] 22:07:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.028408 < threshold 0.100000
# [INFO] 22:07:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:25 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:25 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:25 - CalibrationWorkflow: Self.model updated to online_v19
# [INFO] 22:07:25 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:25 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 22:07:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:25 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 3.97905439914087e-06, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.00036965542593268353, 'E2FOULING': 0.000507335020654125}
# [INFO] 22:07:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.006677 < threshold 0.100000
# [INFO] 22:07:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:25 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:25 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:25 - CalibrationWorkflow: Self.model updated to online_v20
# [INFO] 22:07:25 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:25 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 22:07:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:26 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 3.944514992519949e-06, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.00043706447298321507, 'E2FOULING': 0.00043457612859434193}
# [INFO] 22:07:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.011558 < threshold 0.100000
# [INFO] 22:07:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:26 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:26 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:26 - CalibrationWorkflow: Self.model updated to online_v21
# [INFO] 22:07:26 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:26 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 22:07:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:26 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 2.2045288540547193e-06, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.0003763214379261576, 'E2FOULING': 0.00042123305474828124}
# [INFO] 22:07:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 22:07:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:26 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:26 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:26 - CalibrationWorkflow: Self.model updated to online_v22
# [INFO] 22:07:26 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:26 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 22:07:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:27 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 7.415091371791231e-06, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.0004678726692172949, 'E2FOULING': 0.0003046820093487422}
# [INFO] 22:07:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.029781 < threshold 0.100000
# [INFO] 22:07:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:27 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:27 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:27 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:27 - CalibrationWorkflow: Self.model updated to online_v23
# [INFO] 22:07:27 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:27 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 22:07:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:28 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 6.660913363480752e-06, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0003810230277826556, 'E2FOULING': 0.00046844236213098737}
# [INFO] 22:07:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 22:07:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:28 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:28 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:28 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:28 - CalibrationWorkflow: Self.model updated to online_v24
# [INFO] 22:07:28 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:28 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 22:07:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:28 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.008948069446963273, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.0003138829533827996, 'E2FOULING': 0.0002583527267278452}
# [INFO] 22:07:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.088035 < threshold 0.100000
# [INFO] 22:07:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:28 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:28 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:28 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:28 - CalibrationWorkflow: Self.model updated to online_v25
# [INFO] 22:07:28 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:28 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 22:07:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:29 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.3646146783569726e-05, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.0004844840383733568, 'E2FOULING': 0.0003152485010119798}
# [INFO] 22:07:29 - CalibrationWorkflow: Working point is accurate enough with cost: 0.027117 < threshold 0.100000
# [INFO] 22:07:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:29 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:29 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:29 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:29 - CalibrationWorkflow: Self.model updated to online_v26
# [INFO] 22:07:29 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:29 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 22:07:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:30 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.935469653417621e-06, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.0003511693610162873, 'E2FOULING': 0.00025}
# [INFO] 22:07:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.068159 < threshold 0.100000
# [INFO] 22:07:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:30 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:30 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:30 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:30 - CalibrationWorkflow: Self.model updated to online_v27
# [INFO] 22:07:30 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:30 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:30 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 22:07:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:30 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 4.970338034622334e-06, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.00038970162842403314, 'E2FOULING': 0.00030303798723374726}
# [INFO] 22:07:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.027699 < threshold 0.100000
# [INFO] 22:07:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:30 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:30 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:30 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:30 - CalibrationWorkflow: Self.model updated to online_v28
# [INFO] 22:07:30 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:30 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 29 of 529.
# [INFO] 22:07:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:31 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.7858547669741069e-06, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.00037502054339795055, 'E2FOULING': 0.0004069866583761649}
# [INFO] 22:07:31 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 22:07:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:31 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:07:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:31 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:07:31 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:07:31 - CalibrationWorkflow: Self.model updated to online_v29
# [INFO] 22:07:31 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:07:31 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:07:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 30 of 529.
# [INFO] 22:07:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:07:31 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.16559660874884907, values: {'FEED1MASSFLOW': 18170.33282487203, 'FEED1TEMP': 24.88142490999688, 'PROD1MASSFLOW': 45110.96621847873, 'PROD1TEMP': 115.0679318499356, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 22:07:31 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# ...
# [INFO] 22:14:02 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 2.4412358958834138e-06, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.0005432218126961111, 'E2FOULING': 0.0004985943920274193}
# [INFO] 22:14:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 22:14:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:14:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:02 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:14:02 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:14:02 - CalibrationWorkflow: Self.model updated to online_v519
# [INFO] 22:14:02 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:14:02 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:14:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 22:14:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:03 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 6.196553110690622e-06, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.0004508548232318607, 'E2FOULING': 0.00037995465053680926}
# [INFO] 22:14:03 - CalibrationWorkflow: Working point is accurate enough with cost: 0.039108 < threshold 0.100000
# [INFO] 22:14:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:03 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:14:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:03 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:14:03 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:14:03 - CalibrationWorkflow: Self.model updated to online_v520
# [INFO] 22:14:03 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:14:03 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:14:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 22:14:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:04 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.006681751958089243, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0004879078727017839, 'E2FOULING': 0.0002920133408352377}
# [INFO] 22:14:04 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.108421 > threshold: 0.1
# [INFO] 22:14:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:04 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:14:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:11 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.011837601280146378, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0005278882111946115, 'E2FOULING': 0.00036425580916361194}
# [INFO] 22:14:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.011838 < threshold 0.100000
# [INFO] 22:14:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:11 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:14:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:11 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 22:14:11 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:14:11 - CalibrationWorkflow: Self.model updated to online_v521
# [INFO] 22:14:11 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:14:11 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:14:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 22:14:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:11 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.3186281311730266e-06, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005561882734028984, 'E2FOULING': 0.0004693013727854815}
# [INFO] 22:14:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 22:14:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:11 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:14:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:11 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:14:11 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:14:11 - CalibrationWorkflow: Self.model updated to online_v522
# [INFO] 22:14:11 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:14:11 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:14:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 22:14:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:12 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.2696945159428186e-05, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0005316034653682702, 'E2FOULING': 0.00036999759462612986}
# [INFO] 22:14:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.017726 < threshold 0.100000
# [INFO] 22:14:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:14:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:12 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:14:12 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:14:12 - CalibrationWorkflow: Self.model updated to online_v523
# [INFO] 22:14:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:14:12 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:14:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 22:14:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:12 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 4.4143231692333736e-06, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0005491303893795217, 'E2FOULING': 0.0004621592059030516}
# [INFO] 22:14:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.006609 < threshold 0.100000
# [INFO] 22:14:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:14:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:13 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:14:13 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:14:13 - CalibrationWorkflow: Self.model updated to online_v524
# [INFO] 22:14:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:14:13 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:14:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 22:14:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:13 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 6.534068043188522e-06, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00040416242829060926, 'E2FOULING': 0.000317833162593889}
# [INFO] 22:14:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.081245 < threshold 0.100000
# [INFO] 22:14:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:14:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:13 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:14:13 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:14:13 - CalibrationWorkflow: Self.model updated to online_v525
# [INFO] 22:14:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:14:13 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:14:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 22:14:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:14 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 7.286746877918662e-06, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0004354314800388438, 'E2FOULING': 0.00038191190065515026}
# [INFO] 22:14:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.034743 < threshold 0.100000
# [INFO] 22:14:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:14:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:14 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:14:14 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:14:14 - CalibrationWorkflow: Self.model updated to online_v526
# [INFO] 22:14:14 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:14:14 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:14:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 22:14:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:14 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 5.22267217915659e-06, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0004770677547875509, 'E2FOULING': 0.0004047941429175151}
# [INFO] 22:14:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 22:14:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:14:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:15 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:14:15 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:14:15 - CalibrationWorkflow: Self.model updated to online_v527
# [INFO] 22:14:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:14:15 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:14:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 22:14:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:15 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 6.683962208629026e-06, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0005091388921219301, 'E2FOULING': 0.000525869301640069}
# [INFO] 22:14:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.011043 < threshold 0.100000
# [INFO] 22:14:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:14:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:15 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:14:15 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:14:15 - CalibrationWorkflow: Self.model updated to online_v528
# [INFO] 22:14:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:14:15 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:14:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 22:14:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:16 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 7.836440506475005e-06, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0005289052225653637, 'E2FOULING': 0.00037886673832612924}
# [INFO] 22:14:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000013 < threshold 0.100000
# [INFO] 22:14:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 22:14:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:14:16 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 22:14:16 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:14:16 - CalibrationWorkflow: Self.model updated to online_v529
# [INFO] 22:14:16 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:14:16 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 22:14:16 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/03_Calibration_Online_FNN-BNN-low_always-one.xlsx')
# Out:
# [INFO] 22:14:16 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_FNN-BNN_always-one.xlsx

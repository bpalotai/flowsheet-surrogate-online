# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_200.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-both',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodel/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 08:27:07 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 08:27:07 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodel/sklearnann.joblib
# [INFO] 08:27:07 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 08:27:07 - CalibrationWorkflow:
# ============================================================
# [INFO] 08:27:07 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 08:27:07 - CalibrationWorkflow: ============================================================
#
# [INFO] 08:27:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:07 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 08:27:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:08 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.10623807907973465, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002689634532047034}
# [INFO] 08:27:08 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.450493 > threshold: 0.1
# [INFO] 08:27:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:08 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:27:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:16 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.030864101503769465, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0004492203105314358, 'E2FOULING': 0.00046864134752700994}
# [INFO] 08:27:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.030864 < threshold 0.100000
# [INFO] 08:27:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:27:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:16 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 08:27:16 - CalibrationWorkflow: Retraining model with 4 samples (replay + outliers)
# [INFO] 08:27:16 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 08:27:16 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:27:16 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 08:27:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 08:27:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:17 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.11025491117415605, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00025009608187398215, 'E2FOULING': 0.0002884957115407789}
# [INFO] 08:27:17 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.303114 > threshold: 0.1
# [INFO] 08:27:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:17 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:27:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:24 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.018585827609490065, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00044003527634176373, 'E2FOULING': 0.0004015299799746336}
# [INFO] 08:27:24 - CalibrationWorkflow: Working point is accurate enough with cost: 0.018586 < threshold 0.100000
# [INFO] 08:27:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:24 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:27:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:24 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 08:27:24 - CalibrationWorkflow: Retraining model with 4 samples (replay + outliers)
# [INFO] 08:27:24 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 08:27:24 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:27:24 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 08:27:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 08:27:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:25 - CalibrationWorkflow: Treshold reached with 8 iteration, best cost: 0.0891592260465276, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 08:27:25 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.320785 > threshold: 0.1
# [INFO] 08:27:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:25 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:27:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:32 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.0656197480087035, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.0003963598272653118, 'E2FOULING': 0.0005212602583201406}
# [INFO] 08:27:32 - CalibrationWorkflow: Working point is accurate enough with cost: 0.065620 < threshold 0.100000
# [INFO] 08:27:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:32 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:27:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:32 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 08:27:32 - CalibrationWorkflow: Retraining model with 4 samples (replay + outliers)
# [INFO] 08:27:32 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 08:27:32 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:27:32 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 08:27:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:33 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 08:27:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:33 - CalibrationWorkflow: Treshold reached with 20 iteration, best cost: 0.05912932958384293, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003365669092719574}
# [INFO] 08:27:33 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.409678 > threshold: 0.1
# [INFO] 08:27:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:33 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:27:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:45 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.09376539457954444, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.000418403585332557, 'E2FOULING': 0.0006075616661756777}
# [INFO] 08:27:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.093765 < threshold 0.100000
# [INFO] 08:27:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:45 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:27:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:45 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 08:27:45 - CalibrationWorkflow: Retraining model with 4 samples (replay + outliers)
# [INFO] 08:27:45 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 08:27:45 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:27:45 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 08:27:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 08:27:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:46 - CalibrationWorkflow: Treshold reached with 23 iteration, best cost: 0.06127536681247217, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.00035008906091749115}
# [INFO] 08:27:46 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.203176 > threshold: 0.1
# [INFO] 08:27:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:46 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:27:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:55 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 2.9033146471891523e-06, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0003592530731631392, 'E2FOULING': 0.0004499217042346173}
# [INFO] 08:27:55 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 08:27:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:55 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:27:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:55 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 08:27:55 - CalibrationWorkflow: Retraining model with 4 samples (replay + outliers)
# [INFO] 08:27:55 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 08:27:55 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:27:55 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 08:27:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:56 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 08:27:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:57 - CalibrationWorkflow: Treshold reached with 32 iteration, best cost: 0.0500486545821277, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003347064329117077}
# [INFO] 08:27:57 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.261356 > threshold: 0.1
# [INFO] 08:27:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:27:57 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:27:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:01 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.06219976350992501, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00040074666486188376, 'E2FOULING': 0.0005385453175765772}
# [INFO] 08:28:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.062200 < threshold 0.100000
# [INFO] 08:28:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:01 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 08:28:01 - CalibrationWorkflow: Retraining model with 4 samples (replay + outliers)
# [INFO] 08:28:01 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 08:28:01 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:01 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 08:28:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 08:28:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:03 - CalibrationWorkflow: Treshold reached with 31 iteration, best cost: 0.028836129357467117, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00028405701844004045, 'E2FOULING': 0.00033131182965635164}
# [INFO] 08:28:03 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.112523 > threshold: 0.1
# [INFO] 08:28:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:03 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:28:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:09 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.03657571084137229, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.0004376815481160042, 'E2FOULING': 0.0004136028915944523}
# [INFO] 08:28:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.036576 < threshold 0.100000
# [INFO] 08:28:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:09 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:09 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 08:28:09 - CalibrationWorkflow: Retraining model with 4 samples (replay + outliers)
# [INFO] 08:28:09 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 08:28:09 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:09 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 08:28:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 08:28:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:10 - CalibrationWorkflow: Treshold reached with 26 iteration, best cost: 0.020076452150217795, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0005056515456048771, 'E2FOULING': 0.00037497882725536424}
# [INFO] 08:28:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.027378 < threshold 0.100000
# [INFO] 08:28:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:10 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:10 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:10 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:10 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 08:28:10 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:10 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 08:28:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:11 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.00853026901250053, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.0004342894160943848, 'E2FOULING': 0.00025}
# [INFO] 08:28:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.021142 < threshold 0.100000
# [INFO] 08:28:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:11 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:11 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:11 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:11 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 08:28:11 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:11 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 08:28:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:12 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 6.8778728104223265e-06, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00038926820543445494, 'E2FOULING': 0.0004494765526033424}
# [INFO] 08:28:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 08:28:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:12 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:12 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:12 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 08:28:12 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:12 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 08:28:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:13 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.707428637621523e-05, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.0004819191304342639, 'E2FOULING': 0.00045123695888725013}
# [INFO] 08:28:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.042417 < threshold 0.100000
# [INFO] 08:28:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:13 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:13 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:13 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 08:28:13 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:13 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 08:28:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:13 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 1.1546186273854359e-05, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0005412273351416572, 'E2FOULING': 0.0005317065273210738}
# [INFO] 08:28:14 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.186718 > threshold: 0.1
# [INFO] 08:28:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:14 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:28:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:22 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.014649816382797866, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0003791539512353939, 'E2FOULING': 0.00034239098995958716}
# [INFO] 08:28:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.014650 < threshold 0.100000
# [INFO] 08:28:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:22 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:22 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 08:28:22 - CalibrationWorkflow: Retraining model with 4 samples (replay + outliers)
# [INFO] 08:28:22 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 08:28:22 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:22 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 08:28:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:23 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 08:28:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:23 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 1.0966797671328143e-05, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.000494193156299268, 'E2FOULING': 0.0004973379062612754}
# [INFO] 08:28:23 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.107060 > threshold: 0.1
# [INFO] 08:28:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:23 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:28:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:30 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.09662075667640158, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.00036646232422891175, 'E2FOULING': 0.0006386068683835747}
# [INFO] 08:28:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.096621 < threshold 0.100000
# [INFO] 08:28:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:30 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:30 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 08:28:30 - CalibrationWorkflow: Retraining model with 4 samples (replay + outliers)
# [INFO] 08:28:30 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 08:28:30 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:30 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 08:28:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 08:28:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:31 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.007129937312984375, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00042624711686864696, 'E2FOULING': 0.0004065736880990095}
# [INFO] 08:28:31 - CalibrationWorkflow: Working point is accurate enough with cost: 0.012549 < threshold 0.100000
# [INFO] 08:28:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:31 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:31 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:31 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:31 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 08:28:31 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:31 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 08:28:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:32 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.8266115015238694e-05, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0006422330405976811, 'E2FOULING': 0.0003991189339926144}
# [INFO] 08:28:32 - CalibrationWorkflow: Working point is accurate enough with cost: 0.094187 < threshold 0.100000
# [INFO] 08:28:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:32 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:32 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:32 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:32 - CalibrationWorkflow: Self.model updated to online_v14
# [INFO] 08:28:32 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:32 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:32 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 08:28:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:33 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 5.431607675378446e-06, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0004445760293303268, 'E2FOULING': 0.00044073408123255733}
# [INFO] 08:28:33 - CalibrationWorkflow: Working point is accurate enough with cost: 0.039086 < threshold 0.100000
# [INFO] 08:28:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:33 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:33 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:33 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:33 - CalibrationWorkflow: Self.model updated to online_v15
# [INFO] 08:28:33 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:33 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:33 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 08:28:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:33 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 9.410483214017364e-06, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.00043199437585431045, 'E2FOULING': 0.0004903625673974344}
# [INFO] 08:28:33 - CalibrationWorkflow: Working point is accurate enough with cost: 0.037148 < threshold 0.100000
# [INFO] 08:28:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:33 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:33 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:33 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:33 - CalibrationWorkflow: Self.model updated to online_v16
# [INFO] 08:28:33 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:33 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:34 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 08:28:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:34 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 8.886073288993377e-06, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.0004467667780245897, 'E2FOULING': 0.0005205590709889019}
# [INFO] 08:28:34 - CalibrationWorkflow: Working point is accurate enough with cost: 0.063511 < threshold 0.100000
# [INFO] 08:28:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:34 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:34 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:34 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:34 - CalibrationWorkflow: Self.model updated to online_v17
# [INFO] 08:28:34 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:34 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 08:28:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:35 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.1446986418091472e-05, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.00044148271587652867, 'E2FOULING': 0.0004320826624837845}
# [INFO] 08:28:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.031547 < threshold 0.100000
# [INFO] 08:28:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:35 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:35 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:35 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:35 - CalibrationWorkflow: Self.model updated to online_v18
# [INFO] 08:28:35 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:35 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 08:28:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:36 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.581200303801256e-05, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005373192528457223}
# [INFO] 08:28:36 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.152905 > threshold: 0.1
# [INFO] 08:28:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:36 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 08:28:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:40 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.024247215175708832, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00039194078504075855, 'E2FOULING': 0.0004933500150922643}
# [INFO] 08:28:40 - CalibrationWorkflow: Working point is accurate enough with cost: 0.024247 < threshold 0.100000
# [INFO] 08:28:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:40 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:40 - CalibrationWorkflow: Selected point for online learning: ['validation', 'direct_calibration']
# [INFO] 08:28:40 - CalibrationWorkflow: Retraining model with 4 samples (replay + outliers)
# [INFO] 08:28:40 - CalibrationWorkflow: Self.model updated to online_v19
# [INFO] 08:28:40 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:40 - CalibrationWorkflow: New data points (['validation', 'direct_calibration']) added for online learning.
# [INFO] 08:28:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:41 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 08:28:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:41 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 7.20741240711958e-06, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0003925784950512377, 'E2FOULING': 0.00044428933622622243}
# [INFO] 08:28:41 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 08:28:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:41 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:41 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:41 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:41 - CalibrationWorkflow: Self.model updated to online_v20
# [INFO] 08:28:41 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:41 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 08:28:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:42 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.007402976530093937, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0004312529351457857, 'E2FOULING': 0.000327249618433538}
# [INFO] 08:28:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 08:28:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:42 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:42 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:42 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:42 - CalibrationWorkflow: Self.model updated to online_v21
# [INFO] 08:28:42 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:42 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 08:28:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:43 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.7625885912761754e-06, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.0003930209289394296, 'E2FOULING': 0.00043246382656780477}
# [INFO] 08:28:43 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 08:28:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:43 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:43 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:43 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:43 - CalibrationWorkflow: Self.model updated to online_v22
# [INFO] 08:28:43 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:43 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 08:28:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:43 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.0427216090348496e-05, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.0004387594460534468, 'E2FOULING': 0.0003765994981185019}
# [INFO] 08:28:43 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 08:28:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:43 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:43 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:43 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:43 - CalibrationWorkflow: Self.model updated to online_v23
# [INFO] 08:28:43 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:43 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 08:28:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:44 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.009167451464591012, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0004303358856964637, 'E2FOULING': 0.0003097900387638371}
# [INFO] 08:28:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.040201 < threshold 0.100000
# [INFO] 08:28:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:44 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:44 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:44 - CalibrationWorkflow: Self.model updated to online_v24
# [INFO] 08:28:44 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:44 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 08:28:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:45 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 9.559341497460194e-06, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.0004388712446828483, 'E2FOULING': 0.0003366945229483482}
# [INFO] 08:28:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.029367 < threshold 0.100000
# [INFO] 08:28:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:45 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:45 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:45 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:45 - CalibrationWorkflow: Self.model updated to online_v25
# [INFO] 08:28:45 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:45 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 08:28:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:46 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.030911638427613e-05, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.0003326851174514455, 'E2FOULING': 0.00044096882087217104}
# [INFO] 08:28:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.043033 < threshold 0.100000
# [INFO] 08:28:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:46 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:46 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:46 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:46 - CalibrationWorkflow: Self.model updated to online_v26
# [INFO] 08:28:46 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:46 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 08:28:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:46 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 5.156072230559957e-06, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.0003009185747711643, 'E2FOULING': 0.00034963767024721247}
# [INFO] 08:28:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.062443 < threshold 0.100000
# [INFO] 08:28:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:46 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:28:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:46 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:28:46 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:28:46 - CalibrationWorkflow: Self.model updated to online_v27
# [INFO] 08:28:46 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:28:46 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:28:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:47 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 08:28:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:28:47 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 1.552919258772913e-05, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.0003561487302363391, 'E2FOULING': 0.00038253037006877826}
# ...
# [INFO] 08:38:17 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:38:17 - CalibrationWorkflow: Self.model updated to online_v518
# [INFO] 08:38:17 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:38:17 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:38:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:18 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 519 of 529.
# [INFO] 08:38:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:18 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 6.565964216290927e-06, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.0005564524432914735, 'E2FOULING': 0.0005481698529525206}
# [INFO] 08:38:18 - CalibrationWorkflow: Working point is accurate enough with cost: 0.010641 < threshold 0.100000
# [INFO] 08:38:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:18 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:38:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:18 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:38:18 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:38:18 - CalibrationWorkflow: Self.model updated to online_v519
# [INFO] 08:38:18 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:38:18 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:38:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:18 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 08:38:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:19 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.6771582455366523e-05, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.0004451195439309808, 'E2FOULING': 0.0005350431831006908}
# [INFO] 08:38:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.024021 < threshold 0.100000
# [INFO] 08:38:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:19 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:38:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:19 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:38:19 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:38:19 - CalibrationWorkflow: Self.model updated to online_v520
# [INFO] 08:38:19 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:38:19 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:38:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 08:38:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:19 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.2748900917050174e-05, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.00048723160008811367, 'E2FOULING': 0.00039980081475438924}
# [INFO] 08:38:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.009903 < threshold 0.100000
# [INFO] 08:38:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:19 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:38:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:19 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:38:19 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:38:19 - CalibrationWorkflow: Self.model updated to online_v521
# [INFO] 08:38:19 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:38:19 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:38:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:20 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 08:38:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:20 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 0.007375596439259635, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005354707158697736, 'E2FOULING': 0.000575856704225628}
# [INFO] 08:38:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.031626 < threshold 0.100000
# [INFO] 08:38:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:20 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:38:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:20 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:38:20 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:38:20 - CalibrationWorkflow: Self.model updated to online_v522
# [INFO] 08:38:20 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:38:20 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:38:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 08:38:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:21 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 1.4382087068852195e-05, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0004852413973143562, 'E2FOULING': 0.00037800207198354326}
# [INFO] 08:38:21 - CalibrationWorkflow: Working point is accurate enough with cost: 0.032024 < threshold 0.100000
# [INFO] 08:38:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:21 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:38:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:21 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:38:21 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:38:21 - CalibrationWorkflow: Self.model updated to online_v523
# [INFO] 08:38:21 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:38:21 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:38:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 08:38:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:22 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 1.7355840742466042e-05, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0005231598037214645, 'E2FOULING': 0.00041872680252406}
# [INFO] 08:38:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 08:38:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:22 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:38:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:22 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:38:22 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:38:22 - CalibrationWorkflow: Self.model updated to online_v524
# [INFO] 08:38:22 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:38:22 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:38:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:23 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 08:38:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:23 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.007290489201014103, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.0003916906855476046, 'E2FOULING': 0.00048371489658768273}
# [INFO] 08:38:23 - CalibrationWorkflow: Working point is accurate enough with cost: 0.048552 < threshold 0.100000
# [INFO] 08:38:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:23 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:38:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:23 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:38:23 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:38:23 - CalibrationWorkflow: Self.model updated to online_v525
# [INFO] 08:38:23 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:38:23 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:38:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 08:38:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:24 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 8.920581025207699e-06, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0004010739346804194, 'E2FOULING': 0.0005016918705214061}
# [INFO] 08:38:24 - CalibrationWorkflow: Working point is accurate enough with cost: 0.068507 < threshold 0.100000
# [INFO] 08:38:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:24 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:38:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:24 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:38:24 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:38:24 - CalibrationWorkflow: Self.model updated to online_v526
# [INFO] 08:38:24 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:38:24 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:38:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 08:38:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:25 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 5.556898299403267e-06, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00045070624052431487, 'E2FOULING': 0.0004737636586737774}
# [INFO] 08:38:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 08:38:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:38:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:25 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:38:25 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:38:25 - CalibrationWorkflow: Self.model updated to online_v527
# [INFO] 08:38:25 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:38:25 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:38:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 08:38:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:26 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 1.7349833007566692e-05, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.000457358685015931, 'E2FOULING': 0.000442832008906214}
# [INFO] 08:38:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.019624 < threshold 0.100000
# [INFO] 08:38:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:38:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:26 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:38:26 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:38:26 - CalibrationWorkflow: Self.model updated to online_v528
# [INFO] 08:38:26 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:38:26 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:38:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 08:38:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:26 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 0.009320823114727112, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.00043384301454840854, 'E2FOULING': 0.00037679953268801185}
# [INFO] 08:38:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.063678 < threshold 0.100000
# [INFO] 08:38:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:27 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-both.
# [INFO] 08:38:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 08:38:27 - CalibrationWorkflow: Selected point for online learning: ['validation']
# [INFO] 08:38:27 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 08:38:27 - CalibrationWorkflow: Self.model updated to online_v529
# [INFO] 08:38:27 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 08:38:27 - CalibrationWorkflow: New data points (['validation']) added for online learning.
# [INFO] 08:38:27 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/04_Calibration_Online_FNN-low_always-both.xlsx')
# Out:
# [INFO] 08:38:27 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_always-both.xlsx

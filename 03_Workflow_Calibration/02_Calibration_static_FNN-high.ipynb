# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_200.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'surrogate', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodelbig/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 09:15:50 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 09:15:50 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodelbig/sklearnann.joblib
# [INFO] 09:15:50 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 09:15:50 - CalibrationWorkflow:
# ============================================================
# [INFO] 09:15:50 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 09:15:50 - CalibrationWorkflow: ============================================================
#
# [INFO] 09:15:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:15:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 09:15:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:15:50 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 6.577791281866553e-06, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0002620376813347924, 'E2FOULING': 0.0005814930296709426}
# [INFO] 09:15:50 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.221616 > threshold: 0.1
# [INFO] 09:15:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:15:50 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:15:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:15:57 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.05332483600778465, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00033547036906715454, 'E2FOULING': 0.00040196171920577533}
# [INFO] 09:15:57 - CalibrationWorkflow: Working point is accurate enough with cost: 0.053325 < threshold 0.100000
# [INFO] 09:15:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:15:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 09:15:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:15:57 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 4.193439945741374e-06, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00026251569302620056, 'E2FOULING': 0.00042490353570657005}
# [INFO] 09:15:57 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.177451 > threshold: 0.1
# [INFO] 09:15:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:15:57 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:15:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:04 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.08640318437733814, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00032978527456902184, 'E2FOULING': 0.0005952009104428044}
# [INFO] 09:16:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.086403 < threshold 0.100000
# [INFO] 09:16:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 09:16:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:04 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 5.6348003071297165e-06, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00035055643894648265}
# [INFO] 09:16:04 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.248125 > threshold: 0.1
# [INFO] 09:16:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:04 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:16:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:12 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.05068343228180457, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.0003299001114220221, 'E2FOULING': 0.00032018927510292}
# [INFO] 09:16:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.050683 < threshold 0.100000
# [INFO] 09:16:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 09:16:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:12 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 2.4166986642275354e-06, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00033044739952795346, 'E2FOULING': 0.0003717342322922038}
# [INFO] 09:16:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.095765 < threshold 0.100000
# [INFO] 09:16:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 09:16:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:12 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 4.6175126524940015e-06, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.00047334838223293027}
# [INFO] 09:16:13 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.161187 > threshold: 0.1
# [INFO] 09:16:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:13 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:16:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:15 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.08306165144680244, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0003103000000000001, 'E2FOULING': 0.0006206000000000009}
# [INFO] 09:16:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.083062 < threshold 0.100000
# [INFO] 09:16:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 09:16:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:15 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 4.3822739610903685e-06, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003845580270326354}
# [INFO] 09:16:15 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.243818 > threshold: 0.1
# [INFO] 09:16:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:15 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:16:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:22 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.0354945991288121, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00034302929221322363, 'E2FOULING': 0.0003353903935589703}
# [INFO] 09:16:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.035495 < threshold 0.100000
# [INFO] 09:16:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 09:16:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:22 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 7.482772857954461e-06, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003952008818689094}
# [INFO] 09:16:23 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.187597 > threshold: 0.1
# [INFO] 09:16:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:23 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:16:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:31 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.047600710693192466, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.0003277008783707903, 'E2FOULING': 0.0003100602121724006}
# [INFO] 09:16:31 - CalibrationWorkflow: Working point is accurate enough with cost: 0.047601 < threshold 0.100000
# [INFO] 09:16:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 09:16:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:31 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 1.2310052528374698e-05, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0003185735721216606, 'E2FOULING': 0.0004768666806165457}
# [INFO] 09:16:31 - CalibrationWorkflow: Working point is accurate enough with cost: 0.096449 < threshold 0.100000
# [INFO] 09:16:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 09:16:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:31 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 9.503852983203572e-06, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00025, 'E2FOULING': 0.000312753676857521}
# [INFO] 09:16:31 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.297416 > threshold: 0.1
# [INFO] 09:16:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:31 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:16:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:38 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.042157613414187285, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00033480502391346943, 'E2FOULING': 0.0003540092343468411}
# [INFO] 09:16:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.042158 < threshold 0.100000
# [INFO] 09:16:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 09:16:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:38 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.3215763303715022e-06, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0003099565565956293, 'E2FOULING': 0.00041262292998178084}
# [INFO] 09:16:38 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.131039 > threshold: 0.1
# [INFO] 09:16:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:38 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:16:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:44 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.07617303258539797, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00033653823885047406, 'E2FOULING': 0.00040667790484028146}
# [INFO] 09:16:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.076173 < threshold 0.100000
# [INFO] 09:16:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 09:16:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:44 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 1.087065584463372e-05, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00031243386487447757, 'E2FOULING': 0.0005280158583947455}
# [INFO] 09:16:44 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.102171 > threshold: 0.1
# [INFO] 09:16:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:44 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:16:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:51 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.030504930303502684, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.0003489176315670363, 'E2FOULING': 0.000427754083483813}
# [INFO] 09:16:51 - CalibrationWorkflow: Working point is accurate enough with cost: 0.030505 < threshold 0.100000
# [INFO] 09:16:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 09:16:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:51 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.6834480533973752e-05, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.00030564561508151356, 'E2FOULING': 0.0005716481551720682}
# [INFO] 09:16:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.110928 > threshold: 0.1
# [INFO] 09:16:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:51 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:16:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:58 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.03402625793041098, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0003585928246211953, 'E2FOULING': 0.0003301683324373539}
# [INFO] 09:16:58 - CalibrationWorkflow: Working point is accurate enough with cost: 0.034026 < threshold 0.100000
# [INFO] 09:16:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:58 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 09:16:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:58 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.0208784430470825e-05, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0002857167637449349, 'E2FOULING': 0.0005094222044398811}
# [INFO] 09:16:58 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.117276 > threshold: 0.1
# [INFO] 09:16:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:16:58 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:16:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:04 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.05912553674041135, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0003232610225298764, 'E2FOULING': 0.0005130295580304641}
# [INFO] 09:17:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.059126 < threshold 0.100000
# [INFO] 09:17:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 09:17:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:04 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 4.26004000978153e-06, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00025, 'E2FOULING': 0.000443897154248329}
# [INFO] 09:17:04 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.180529 > threshold: 0.1
# [INFO] 09:17:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:04 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:17:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:10 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.08504784362086032, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00032867334172101046, 'E2FOULING': 0.0006082965902336493}
# [INFO] 09:17:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.085048 < threshold 0.100000
# [INFO] 09:17:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 09:17:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:10 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 1.3424725554769918e-05, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0004165370488694371, 'E2FOULING': 0.0003854044646720668}
# [INFO] 09:17:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.045636 < threshold 0.100000
# [INFO] 09:17:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 09:17:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:11 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 6.298948908290032e-06, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.00029477225036359314, 'E2FOULING': 0.0003349631322186949}
# [INFO] 09:17:11 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.109605 > threshold: 0.1
# [INFO] 09:17:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:11 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:17:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:19 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.06141315257360938, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0003209334601375994, 'E2FOULING': 0.0004895988597411134}
# [INFO] 09:17:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.061413 < threshold 0.100000
# [INFO] 09:17:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 09:17:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:19 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 5.240667780976984e-06, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.00025, 'E2FOULING': 0.00041610441324095994}
# [INFO] 09:17:19 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.203168 > threshold: 0.1
# [INFO] 09:17:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:19 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:17:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:26 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.01728554058969947, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0003449817335990067, 'E2FOULING': 0.0004289824941860189}
# [INFO] 09:17:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.017286 < threshold 0.100000
# [INFO] 09:17:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 09:17:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:26 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 6.781546785430714e-06, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.00028021802760775033, 'E2FOULING': 0.0005118156375243373}
# [INFO] 09:17:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.089065 < threshold 0.100000
# [INFO] 09:17:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 09:17:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:26 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 5.915076759466178e-06, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.00025, 'E2FOULING': 0.000556750823926816}
# [INFO] 09:17:26 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.159334 > threshold: 0.1
# [INFO] 09:17:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:26 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:17:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:29 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.07620209852379337, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.0003103000000000001, 'E2FOULING': 0.0006206000000000009}
# [INFO] 09:17:29 - CalibrationWorkflow: Working point is accurate enough with cost: 0.076202 < threshold 0.100000
# [INFO] 09:17:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 09:17:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:29 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 8.305010991248831e-06, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00025, 'E2FOULING': 0.00048263593940229996}
# [INFO] 09:17:29 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.145433 > threshold: 0.1
# [INFO] 09:17:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:29 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:17:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:36 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.026346231421641338, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.0003189473828768965, 'E2FOULING': 0.0004769862900731986}
# [INFO] 09:17:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.026346 < threshold 0.100000
# [INFO] 09:17:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 09:17:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:37 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 1.3944521946181489e-05, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0002774945776392283, 'E2FOULING': 0.000569664882566844}
# [INFO] 09:17:37 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.131698 > threshold: 0.1
# [INFO] 09:17:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:37 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:17:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:39 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.09746319589082392, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0003103000000000001, 'E2FOULING': 0.0006206000000000009}
# [INFO] 09:17:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.097463 < threshold 0.100000
# [INFO] 09:17:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 09:17:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:39 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 2.2487617089751036e-05, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0002828359334866614, 'E2FOULING': 0.0004326704917003269}
# [INFO] 09:17:39 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.124148 > threshold: 0.1
# [INFO] 09:17:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:39 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:17:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:43 - CalibrationWorkflow: Treshold reached with 1 iteration, best cost: 0.13957186961542795, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0003103000000000001, 'E2FOULING': 0.0006206000000000009}
# [INFO] 09:17:43 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.139572 > threshold: 0.1
# [INFO] 09:17:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 09:17:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:43 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.007943761775247617, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003986546149659135}
# [INFO] 09:17:44 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.220366 > threshold: 0.1
# [INFO] 09:17:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:44 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:17:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:50 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.02520082463221481, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.00033389735400556547, 'E2FOULING': 0.00041178416394594715}
# [INFO] 09:17:50 - CalibrationWorkflow: Working point is accurate enough with cost: 0.025201 < threshold 0.100000
# [INFO] 09:17:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 09:17:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:50 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 5.816447932207978e-06, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.000319535047769426, 'E2FOULING': 0.0004673731305061086}
# [INFO] 09:17:51 - CalibrationWorkflow: Working point is accurate enough with cost: 0.078529 < threshold 0.100000
# [INFO] 09:17:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 09:17:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:51 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.007241766787103176, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.00028162053611554085, 'E2FOULING': 0.0005972175940019704}
# [INFO] 09:17:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.106670 > threshold: 0.1
# [INFO] 09:17:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:51 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:17:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:53 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.07895440979243928, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0003103000000000001, 'E2FOULING': 0.0006206000000000009}
# [INFO] 09:17:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.078954 < threshold 0.100000
# [INFO] 09:17:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 09:17:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:53 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.3840964006886873e-05, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.00025, 'E2FOULING': 0.00047829064266803373}
# [INFO] 09:17:54 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.123590 > threshold: 0.1
# [INFO] 09:17:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:54 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:17:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:56 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.08226772816482086, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.0002900000000000001, 'E2FOULING': 0.0005800000000000009}
# [INFO] 09:17:56 - CalibrationWorkflow: Working point is accurate enough with cost: 0.082268 < threshold 0.100000
# [INFO] 09:17:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:56 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 09:17:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:57 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 1.0994064485148248e-05, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.0003034838050304799, 'E2FOULING': 0.00043485980324698293}
# [INFO] 09:17:57 - CalibrationWorkflow: Working point is accurate enough with cost: 0.091516 < threshold 0.100000
# [INFO] 09:17:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 09:17:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:57 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 2.1943736935592813e-05, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005467127506890682}
# [INFO] 09:17:57 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.178967 > threshold: 0.1
# [INFO] 09:17:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:17:57 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:17:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:04 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.03108123666083641, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.00032200432915554893, 'E2FOULING': 0.00045475109796735}
# [INFO] 09:18:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.031081 < threshold 0.100000
# [INFO] 09:18:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 09:18:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:05 - CalibrationWorkflow: Treshold reached with 34 iteration, best cost: 0.022282047311983376, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.00028907603135767317, 'E2FOULING': 0.0004768399239405978}
# [INFO] 09:18:05 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.120936 > threshold: 0.1
# [INFO] 09:18:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:05 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:18:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:10 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.06561036510639882, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.00032039140525124733, 'E2FOULING': 0.0005018068708168712}
# [INFO] 09:18:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.065610 < threshold 0.100000
# [INFO] 09:18:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 29 of 529.
# [INFO] 09:18:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:11 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.008724150612017815, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005061411558732494}
# [INFO] 09:18:11 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.111320 > threshold: 0.1
# [INFO] 09:18:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:11 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:18:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:13 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.07093209447924645, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.0002900000000000001, 'E2FOULING': 0.0005800000000000009}
# [INFO] 09:18:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.070932 < threshold 0.100000
# [INFO] 09:18:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 30 of 529.
# [INFO] 09:18:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:14 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.22667558428909704, values: {'FEED1MASSFLOW': 18170.33282487203, 'FEED1TEMP': 24.88142490999688, 'PROD1MASSFLOW': 45110.96621847873, 'PROD1TEMP': 115.0679318499356, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 09:18:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 31 of 529.
# [INFO] 09:18:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:14 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.2990056319482439, values: {'FEED1MASSFLOW': 18607.84387976851, 'FEED1TEMP': 25.14488217461214, 'PROD1MASSFLOW': 43738.61199857389, 'PROD1TEMP': 115.3747174316839, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 09:18:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 32 of 529.
# [INFO] 09:18:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:14 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.3081502852925585, values: {'FEED1MASSFLOW': 19115.08117402765, 'FEED1TEMP': 24.77391698651811, 'PROD1MASSFLOW': 42751.55908633373, 'PROD1TEMP': 115.3524481338415, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 09:18:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 33 of 529.
# [INFO] 09:18:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:14 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.26666282651339174, values: {'FEED1MASSFLOW': 19418.03437168451, 'FEED1TEMP': 25.0300579250388, 'PROD1MASSFLOW': 43087.88928120025, 'PROD1TEMP': 114.4650169900805, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 09:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 34 of 529.
# [INFO] 09:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:15 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.20287802767159258, values: {'FEED1MASSFLOW': 19996.37302723919, 'FEED1TEMP': 25.05396733167793, 'PROD1MASSFLOW': 39075.45922402187, 'PROD1TEMP': 115.4384103153362, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 09:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 35 of 529.
# [INFO] 09:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:15 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.17534851124008066, values: {'FEED1MASSFLOW': 20114.96473047106, 'FEED1TEMP': 24.8676559665023, 'PROD1MASSFLOW': 40171.91798417241, 'PROD1TEMP': 115.7924017721878, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 09:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 36 of 529.
# [INFO] 09:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:15 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.14410098183515202, values: {'FEED1MASSFLOW': 20464.74060999631, 'FEED1TEMP': 25.14479618506942, 'PROD1MASSFLOW': 39328.05034260821, 'PROD1TEMP': 115.7990352506138, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 09:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 37 of 529.
# [INFO] 09:18:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:16 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.15255758067042582, values: {'FEED1MASSFLOW': 20969.69452156387, 'FEED1TEMP': 25.25139017769914, 'PROD1MASSFLOW': 39239.44675475179, 'PROD1TEMP': 115.2266590735738, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 09:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 38 of 529.
# [INFO] 09:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:16 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.15933819745379546, values: {'FEED1MASSFLOW': 21516.56747134487, 'FEED1TEMP': 25.01599682709554, 'PROD1MASSFLOW': 37569.24954175691, 'PROD1TEMP': 115.7682074791824, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 09:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 39 of 529.
# [INFO] 09:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:16 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.19088943440976458, values: {'FEED1MASSFLOW': 21885.72678255862, 'FEED1TEMP': 24.92770160919124, 'PROD1MASSFLOW': 36155.43092699922, 'PROD1TEMP': 115.2474249227753, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 09:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 40 of 529.
# [INFO] 09:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:16 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.20022766010500848, values: {'FEED1MASSFLOW': 22629.3343245605, 'FEED1TEMP': 24.93546075225073, 'PROD1MASSFLOW': 35951.0272805308, 'PROD1TEMP': 114.5619751637425, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 09:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 41 of 529.
# [INFO] 09:18:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:17 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.1499810956563586, values: {'FEED1MASSFLOW': 23052.81408141617, 'FEED1TEMP': 24.96979552398567, 'PROD1MASSFLOW': 35366.6433778873, 'PROD1TEMP': 114.8085323228307, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 09:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 42 of 529.
# [INFO] 09:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:17 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.15546334871937445, values: {'FEED1MASSFLOW': 23873.98895120752, 'FEED1TEMP': 24.64705546402934, 'PROD1MASSFLOW': 33606.38987270086, 'PROD1TEMP': 115.3910956750255, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 09:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 43 of 529.
# [INFO] 09:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:17 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.09711683593847803, values: {'FEED1MASSFLOW': 24085.05631312843, 'FEED1TEMP': 25.02029345511958, 'PROD1MASSFLOW': 32971.19764637543, 'PROD1TEMP': 114.4096466605709, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 09:18:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 09:18:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:18:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 44 of 529.
# [INFO] 09:18:17 - CalibrationWorkflow: ----------------------------------------
# ...
# [INFO] 09:35:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 09:35:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 519 of 529.
# [INFO] 09:35:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:18 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.008245427540686403, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.00033445700000000014, 'E2FOULING': 0.0006689140000000009}
# [INFO] 09:35:18 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.434890 > threshold: 0.1
# [INFO] 09:35:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:18 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:35:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:22 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.0849599134121545, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.0005726814251799776, 'E2FOULING': 0.0006453274232495082}
# [INFO] 09:35:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.084960 < threshold 0.100000
# [INFO] 09:35:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 09:35:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:23 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 0.009346669906639815, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.0002516352795829265, 'E2FOULING': 0.0006203094910220937}
# [INFO] 09:35:23 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.835703 > threshold: 0.1
# [INFO] 09:35:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:23 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:35:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:29 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.0360137484830268, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.00043849466138045864, 'E2FOULING': 0.0005485310091894371}
# [INFO] 09:35:29 - CalibrationWorkflow: Working point is accurate enough with cost: 0.036014 < threshold 0.100000
# [INFO] 09:35:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 09:35:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:30 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.026910314404088524, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.00025247842691362803, 'E2FOULING': 0.0005296877754805984}
# [INFO] 09:35:30 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 1.048476 > threshold: 0.1
# [INFO] 09:35:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:30 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:35:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:42 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 0.034983563041929046, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0004638959739212058, 'E2FOULING': 0.00047124172225095805}
# [INFO] 09:35:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.034984 < threshold 0.100000
# [INFO] 09:35:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 09:35:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:42 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.0070803954747202195, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0003103000000000001, 'E2FOULING': 0.0006206000000000009}
# [INFO] 09:35:43 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.501271 > threshold: 0.1
# [INFO] 09:35:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:43 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:35:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:50 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.014782994609197438, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0004794884042453482, 'E2FOULING': 0.0005215837504132151}
# [INFO] 09:35:50 - CalibrationWorkflow: Working point is accurate enough with cost: 0.014783 < threshold 0.100000
# [INFO] 09:35:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 09:35:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:51 - CalibrationWorkflow: Treshold reached with 11 iteration, best cost: 0.020936563453615376, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.00026301565352819306, 'E2FOULING': 0.0005613389960620626}
# [INFO] 09:35:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.989787 > threshold: 0.1
# [INFO] 09:35:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:35:51 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:35:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:02 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.08721121241176773, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0004481937514912641, 'E2FOULING': 0.0005793321009026749}
# [INFO] 09:36:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.087211 < threshold 0.100000
# [INFO] 09:36:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 09:36:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:02 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 0.008683108926132393, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0003317162600961274, 'E2FOULING': 0.0005375818488068589}
# [INFO] 09:36:02 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.402263 > threshold: 0.1
# [INFO] 09:36:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:02 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:36:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:11 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.03563610109553415, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0004951634844394869, 'E2FOULING': 0.0003490759806977372}
# [INFO] 09:36:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.035636 < threshold 0.100000
# [INFO] 09:36:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 09:36:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:11 - CalibrationWorkflow: Treshold reached with 22 iteration, best cost: 0.04162334286120191, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004804748680812907}
# [INFO] 09:36:11 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.616322 > threshold: 0.1
# [INFO] 09:36:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:11 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:36:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:23 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.03131004238527723, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.0004001007778974826, 'E2FOULING': 0.00042809837155443026}
# [INFO] 09:36:23 - CalibrationWorkflow: Working point is accurate enough with cost: 0.031310 < threshold 0.100000
# [INFO] 09:36:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:23 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 09:36:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:23 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.031658129363515454, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0002502362929587189, 'E2FOULING': 0.0005159483656729695}
# [INFO] 09:36:23 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.771318 > threshold: 0.1
# [INFO] 09:36:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:23 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:36:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:40 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 0.05344325901951232, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0004131158400452752, 'E2FOULING': 0.0005283290217445984}
# [INFO] 09:36:40 - CalibrationWorkflow: Working point is accurate enough with cost: 0.053443 < threshold 0.100000
# [INFO] 09:36:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:40 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 09:36:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:40 - CalibrationWorkflow: Obj Treshold reached with 16 iteration, best cost: 0.009932227232047258, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005420625984096693}
# [INFO] 09:36:40 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.689309 > threshold: 0.1
# [INFO] 09:36:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:40 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:36:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:55 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 0.06481503312326228, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0003963270616828277, 'E2FOULING': 0.0005151735626090195}
# [INFO] 09:36:55 - CalibrationWorkflow: Working point is accurate enough with cost: 0.064815 < threshold 0.100000
# [INFO] 09:36:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:55 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 09:36:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:55 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 2.2143085258934666e-05, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0002532430903991724, 'E2FOULING': 0.0006357189440922533}
# [INFO] 09:36:55 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.812091 > threshold: 0.1
# [INFO] 09:36:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:36:55 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:36:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:37:08 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.09440134709958463, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0004167792094888483, 'E2FOULING': 0.0006091618032829255}
# [INFO] 09:37:08 - CalibrationWorkflow: Working point is accurate enough with cost: 0.094401 < threshold 0.100000
# [INFO] 09:37:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:37:08 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 09:37:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:37:09 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.012164292537305155, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.00025, 'E2FOULING': 0.000563930504415222}
# [INFO] 09:37:09 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.816086 > threshold: 0.1
# [INFO] 09:37:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:37:09 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 09:37:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 09:37:22 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 0.0667260285209679, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0004147450305809699, 'E2FOULING': 0.000472978920000598}
# [INFO] 09:37:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.066726 < threshold 0.100000
# [INFO] 09:37:22 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/Surrogate_base/02_Calibration_static_FNN-high.xlsx')
# Out:
# [INFO] 09:37:50 - CalibrationWorkflow: Calibration results saved to ./Results/Surrogate_base/Calibration_result_base_suorrogate_with_direct.xlsx

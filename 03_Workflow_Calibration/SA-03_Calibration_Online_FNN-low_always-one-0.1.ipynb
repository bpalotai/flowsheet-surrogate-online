# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_200.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodel/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.1, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 15:27:51 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 15:27:51 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodel/sklearnann.joblib
# [INFO] 15:27:51 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.1, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 15:27:51 - CalibrationWorkflow:
# ============================================================
# [INFO] 15:27:51 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 15:27:51 - CalibrationWorkflow: ============================================================
#
# [INFO] 15:27:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:27:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 15:27:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:27:52 - CalibrationWorkflow: Treshold reached with 25 iteration, best cost: 0.10621969997522461, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.00026909115591037066}
# [INFO] 15:27:52 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.450274 > threshold: 0.1
# [INFO] 15:27:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:27:52 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:27:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:12 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.040552841367149754, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0003805959872668056, 'E2FOULING': 0.0006069289301180403}
# [INFO] 15:28:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.040553 < threshold 0.100000
# [INFO] 15:28:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:28:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:12 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:28:12 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:28:12 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 15:28:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:28:12 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:28:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 15:28:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:14 - CalibrationWorkflow: Treshold reached with 22 iteration, best cost: 0.11495298518014174, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00025, 'E2FOULING': 0.00027067392051540145}
# [INFO] 15:28:14 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.324854 > threshold: 0.1
# [INFO] 15:28:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:14 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:28:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:28 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.019916869322751232, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00044064953978633265, 'E2FOULING': 0.0003653922717821284}
# [INFO] 15:28:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.019917 < threshold 0.100000
# [INFO] 15:28:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:28 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:28:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:28 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:28:28 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:28:28 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 15:28:28 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:28:28 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:28:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 15:28:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:30 - CalibrationWorkflow: Treshold reached with 6 iteration, best cost: 0.10789923786196795, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 15:28:30 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.324152 > threshold: 0.1
# [INFO] 15:28:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:30 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:28:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:41 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.029632395809316744, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00034004526490581774, 'E2FOULING': 0.0004687299831033851}
# [INFO] 15:28:41 - CalibrationWorkflow: Working point is accurate enough with cost: 0.029632 < threshold 0.100000
# [INFO] 15:28:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:41 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:28:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:41 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:28:41 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:28:41 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 15:28:41 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:28:41 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:28:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 15:28:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:43 - CalibrationWorkflow: Treshold reached with 16 iteration, best cost: 0.08642012020277791, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002781959991579947}
# [INFO] 15:28:43 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.475762 > threshold: 0.1
# [INFO] 15:28:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:43 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:28:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:52 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.016414428353154976, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00046244967179380014, 'E2FOULING': 0.0004489579543118218}
# [INFO] 15:28:52 - CalibrationWorkflow: Working point is accurate enough with cost: 0.016414 < threshold 0.100000
# [INFO] 15:28:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:52 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:28:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:52 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:28:52 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:28:52 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 15:28:52 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:28:52 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:28:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 15:28:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:54 - CalibrationWorkflow: Treshold reached with 26 iteration, best cost: 0.08677642008787638, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002888669897749067}
# [INFO] 15:28:54 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.258451 > threshold: 0.1
# [INFO] 15:28:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:28:54 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:28:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:09 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.256281648512464e-05, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00033135850479173166, 'E2FOULING': 0.0004378861762324368}
# [INFO] 15:29:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000013 < threshold 0.100000
# [INFO] 15:29:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:09 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:29:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:09 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:29:09 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:29:09 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 15:29:09 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:29:09 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:29:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 15:29:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:11 - CalibrationWorkflow: Treshold reached with 26 iteration, best cost: 0.0872780503119649, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00026358156355458183, 'E2FOULING': 0.00025}
# [INFO] 15:29:11 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.299034 > threshold: 0.1
# [INFO] 15:29:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:11 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:29:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:22 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.024345170161484478, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.0003454664967116743, 'E2FOULING': 0.0004844530213713044}
# [INFO] 15:29:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.024345 < threshold 0.100000
# [INFO] 15:29:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:22 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:29:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:22 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:29:22 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:29:22 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 15:29:22 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:29:22 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:29:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:23 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 15:29:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:23 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.08038551450129736, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 15:29:24 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.284640 > threshold: 0.1
# [INFO] 15:29:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:24 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:29:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:33 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.037893692037150935, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.0003512976769832098, 'E2FOULING': 0.0005033441036889363}
# [INFO] 15:29:33 - CalibrationWorkflow: Working point is accurate enough with cost: 0.037894 < threshold 0.100000
# [INFO] 15:29:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:33 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:29:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:33 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:29:33 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:29:33 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 15:29:33 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:29:33 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:29:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:34 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 15:29:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:36 - CalibrationWorkflow: Treshold reached with 42 iteration, best cost: 0.06564391320742119, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0005210760594482913, 'E2FOULING': 0.0002568539466456026}
# [INFO] 15:29:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.089764 < threshold 0.100000
# [INFO] 15:29:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:36 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:29:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:36 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:29:36 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:29:36 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 15:29:36 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:29:36 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:29:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 15:29:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:37 - CalibrationWorkflow: Treshold reached with 8 iteration, best cost: 0.06225011244957738, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 15:29:37 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.342851 > threshold: 0.1
# [INFO] 15:29:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:37 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:29:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:48 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.012900278566036514, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00043012844647605665, 'E2FOULING': 0.00025715820648505676}
# [INFO] 15:29:48 - CalibrationWorkflow: Working point is accurate enough with cost: 0.012900 < threshold 0.100000
# [INFO] 15:29:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:48 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:29:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:48 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:29:48 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:29:48 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 15:29:48 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:29:48 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:29:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:49 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 15:29:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:50 - CalibrationWorkflow: Treshold reached with 34 iteration, best cost: 0.036637586873086936, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00025227017618540223, 'E2FOULING': 0.00032376522626883847}
# [INFO] 15:29:51 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.409733 > threshold: 0.1
# [INFO] 15:29:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:29:51 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:29:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:02 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 7.2074197843102915e-06, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00044079376086955766, 'E2FOULING': 0.00037262938450178845}
# [INFO] 15:30:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000007 < threshold 0.100000
# [INFO] 15:30:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:30:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:02 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:30:02 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:30:02 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 15:30:02 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:30:02 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:30:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 15:30:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:04 - CalibrationWorkflow: Treshold reached with 33 iteration, best cost: 0.052468861596786584, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.0003091043765898292, 'E2FOULING': 0.0003503659718139914}
# [INFO] 15:30:05 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.121571 > threshold: 0.1
# [INFO] 15:30:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:05 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:30:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:18 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.017485835872000765, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00044837646695006347, 'E2FOULING': 0.000470606963211404}
# [INFO] 15:30:18 - CalibrationWorkflow: Working point is accurate enough with cost: 0.017486 < threshold 0.100000
# [INFO] 15:30:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:18 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:30:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:18 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:30:18 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:30:18 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 15:30:18 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:30:18 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:30:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 15:30:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:19 - CalibrationWorkflow: Treshold reached with 10 iteration, best cost: 0.04284313581188933, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0005185496113159989, 'E2FOULING': 0.00025}
# [INFO] 15:30:19 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.120626 > threshold: 0.1
# [INFO] 15:30:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:19 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:30:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:29 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.06937518314271324, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0003665002720424466, 'E2FOULING': 0.0006070744967354597}
# [INFO] 15:30:29 - CalibrationWorkflow: Working point is accurate enough with cost: 0.069375 < threshold 0.100000
# [INFO] 15:30:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:29 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:30:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:29 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:30:29 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:30:29 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 15:30:29 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:30:29 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:30:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:30 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 15:30:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:30 - CalibrationWorkflow: Treshold reached with 16 iteration, best cost: 0.03656177945612756, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0005008685676807306, 'E2FOULING': 0.00025}
# [INFO] 15:30:31 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.104453 > threshold: 0.1
# [INFO] 15:30:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:31 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:30:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:38 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.04038079784018499, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0003554658337784854, 'E2FOULING': 0.0005316375082923162}
# [INFO] 15:30:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.040381 < threshold 0.100000
# [INFO] 15:30:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:30:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:38 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:30:38 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:30:38 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 15:30:38 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:30:38 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:30:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 15:30:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:40 - CalibrationWorkflow: Treshold reached with 31 iteration, best cost: 0.0366959912374944, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00025, 'E2FOULING': 0.0003339547156354142}
# [INFO] 15:30:40 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.234059 > threshold: 0.1
# [INFO] 15:30:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:40 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:30:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:50 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.022538946774947607, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.0004438368595941781, 'E2FOULING': 0.0003845966268336133}
# [INFO] 15:30:50 - CalibrationWorkflow: Working point is accurate enough with cost: 0.022539 < threshold 0.100000
# [INFO] 15:30:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:50 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:30:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:50 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:30:50 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:30:50 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 15:30:50 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:30:50 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:30:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 15:30:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:52 - CalibrationWorkflow: Treshold reached with 12 iteration, best cost: 0.017685743673104607, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0006748265574851942, 'E2FOULING': 0.00025}
# [INFO] 15:30:52 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.146573 > threshold: 0.1
# [INFO] 15:30:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:30:52 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:30:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:06 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.2357369632517027e-05, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0004553612616159287, 'E2FOULING': 0.00039639076677841235}
# [INFO] 15:31:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 15:31:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:06 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:31:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:06 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:31:06 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:31:06 - CalibrationWorkflow: Self.model updated to online_v14
# [INFO] 15:31:06 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:31:06 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:31:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 15:31:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:07 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.02618757183631607, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.00036063673481748746, 'E2FOULING': 0.00025}
# [INFO] 15:31:07 - CalibrationWorkflow: Working point is accurate enough with cost: 0.071405 < threshold 0.100000
# [INFO] 15:31:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:07 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:31:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:07 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:31:07 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:31:07 - CalibrationWorkflow: Self.model updated to online_v15
# [INFO] 15:31:07 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:31:07 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:31:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:08 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 15:31:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:09 - CalibrationWorkflow: Treshold reached with 14 iteration, best cost: 0.021535558993097375, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0003922611946389783, 'E2FOULING': 0.00025}
# [INFO] 15:31:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.067000 < threshold 0.100000
# [INFO] 15:31:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:09 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:31:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:09 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:31:09 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:31:09 - CalibrationWorkflow: Self.model updated to online_v16
# [INFO] 15:31:09 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:31:09 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:31:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 15:31:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:11 - CalibrationWorkflow: Treshold reached with 27 iteration, best cost: 0.019127214142584066, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.00033938701799619055, 'E2FOULING': 0.0003759085729594368}
# [INFO] 15:31:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.013680 < threshold 0.100000
# [INFO] 15:31:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:11 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:31:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:11 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:31:11 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:31:11 - CalibrationWorkflow: Self.model updated to online_v17
# [INFO] 15:31:11 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:31:11 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:31:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 15:31:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:12 - CalibrationWorkflow: Treshold reached with 12 iteration, best cost: 0.015419934886848417, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.00040373650650801703, 'E2FOULING': 0.00033557242533836806}
# [INFO] 15:31:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.008322 < threshold 0.100000
# [INFO] 15:31:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:31:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:12 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:31:12 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:31:12 - CalibrationWorkflow: Self.model updated to online_v18
# [INFO] 15:31:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:31:12 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:31:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 15:31:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:14 - CalibrationWorkflow: Treshold reached with 26 iteration, best cost: 0.01207115550203987, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.0002962699612552761, 'E2FOULING': 0.00030340943455459026}
# [INFO] 15:31:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.085504 < threshold 0.100000
# [INFO] 15:31:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:31:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:14 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:31:14 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:31:14 - CalibrationWorkflow: Self.model updated to online_v19
# [INFO] 15:31:14 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:31:14 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:31:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 15:31:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:16 - CalibrationWorkflow: Treshold reached with 21 iteration, best cost: 0.012384746546687767, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.000507542342783839, 'E2FOULING': 0.00025}
# [INFO] 15:31:16 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.126468 > threshold: 0.1
# [INFO] 15:31:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:16 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:31:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:30 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 4.94303474402545e-06, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0004190172241791565, 'E2FOULING': 0.0003952708556264161}
# [INFO] 15:31:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 15:31:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:30 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:31:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:30 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:31:30 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:31:30 - CalibrationWorkflow: Self.model updated to online_v20
# [INFO] 15:31:30 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:31:30 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:31:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 15:31:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:31 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.008093927185790504, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.000530144448725824, 'E2FOULING': 0.00025}
# [INFO] 15:31:31 - CalibrationWorkflow: Working point is accurate enough with cost: 0.086926 < threshold 0.100000
# [INFO] 15:31:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:31 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:31:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:31 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:31:31 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:31:31 - CalibrationWorkflow: Self.model updated to online_v21
# [INFO] 15:31:31 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:31:31 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:31:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:32 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 15:31:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:32 - CalibrationWorkflow: Treshold reached with 11 iteration, best cost: 0.018187952662693952, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.00042254065664450933, 'E2FOULING': 0.00028280134055586975}
# [INFO] 15:31:32 - CalibrationWorkflow: Working point is accurate enough with cost: 0.027135 < threshold 0.100000
# [INFO] 15:31:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:32 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:31:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:32 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:31:32 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:31:32 - CalibrationWorkflow: Self.model updated to online_v22
# [INFO] 15:31:32 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:31:32 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:31:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:33 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 15:31:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:33 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.007389330927786642, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.0003372212807839315, 'E2FOULING': 0.00035317079209051913}
# [INFO] 15:31:33 - CalibrationWorkflow: Working point is accurate enough with cost: 0.065007 < threshold 0.100000
# [INFO] 15:31:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:33 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:31:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:33 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:31:33 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:31:33 - CalibrationWorkflow: Self.model updated to online_v23
# [INFO] 15:31:33 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:31:33 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:31:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:34 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 15:31:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:35 - CalibrationWorkflow: Treshold reached with 21 iteration, best cost: 0.012947566621437926, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0003891238467103789, 'E2FOULING': 0.0003196551068384133}
# [INFO] 15:31:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.015840 < threshold 0.100000
# [INFO] 15:31:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:35 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:31:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:35 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:31:35 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:31:35 - CalibrationWorkflow: Self.model updated to online_v24
# [INFO] 15:31:35 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:31:35 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:31:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 15:31:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:36 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.009286522963631352, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.0004550487230359159, 'E2FOULING': 0.00025}
# [INFO] 15:31:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.089264 < threshold 0.100000
# [INFO] 15:31:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:36 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:31:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:36 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:31:36 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:31:36 - CalibrationWorkflow: Self.model updated to online_v25
# [INFO] 15:31:36 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:31:36 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:31:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:31:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 15:31:37 - CalibrationWorkflow: ----------------------------------------
# ...
# [INFO] 15:53:52 - CalibrationWorkflow: Self.model updated to online_v520
# [INFO] 15:53:52 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:53:52 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:53:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:53:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 15:53:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:53:53 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 0.008602643750041276, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0004454001189603214, 'E2FOULING': 0.00033016041759928986}
# [INFO] 15:53:53 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.124648 > threshold: 0.1
# [INFO] 15:53:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:53:53 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:53:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:02 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.06955649868434412, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.000473084672850034, 'E2FOULING': 0.0005634347448236684}
# [INFO] 15:54:03 - CalibrationWorkflow: Working point is accurate enough with cost: 0.069556 < threshold 0.100000
# [INFO] 15:54:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:03 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:54:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:03 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:54:03 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:54:03 - CalibrationWorkflow: Self.model updated to online_v521
# [INFO] 15:54:03 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:54:03 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:54:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 15:54:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:04 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 8.028455345073428e-06, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.00043560116072487653, 'E2FOULING': 0.0004211952017219927}
# [INFO] 15:54:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.074615 < threshold 0.100000
# [INFO] 15:54:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:04 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:54:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:04 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:54:04 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:54:04 - CalibrationWorkflow: Self.model updated to online_v522
# [INFO] 15:54:04 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:54:04 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:54:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 15:54:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:05 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.00806958714767725, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.00045100958488449055, 'E2FOULING': 0.0004208737670076416}
# [INFO] 15:54:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.070945 < threshold 0.100000
# [INFO] 15:54:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:05 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:54:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:05 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:54:05 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:54:05 - CalibrationWorkflow: Self.model updated to online_v523
# [INFO] 15:54:05 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:54:05 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:54:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 15:54:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:06 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 5.669035177082375e-06, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.00045401464787270154, 'E2FOULING': 0.0004285836899793367}
# [INFO] 15:54:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.041965 < threshold 0.100000
# [INFO] 15:54:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:06 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:54:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:06 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:54:06 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:54:06 - CalibrationWorkflow: Self.model updated to online_v524
# [INFO] 15:54:06 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:54:06 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:54:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:07 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 15:54:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:07 - CalibrationWorkflow: Obj Treshold reached with 15 iteration, best cost: 0.00969113490464588, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004308453806873776}
# [INFO] 15:54:08 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.620358 > threshold: 0.1
# [INFO] 15:54:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:08 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:54:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:27 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.04644468871267732, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00044319734763026907, 'E2FOULING': 0.0005723957988223569}
# [INFO] 15:54:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.046445 < threshold 0.100000
# [INFO] 15:54:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:27 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:54:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:27 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:54:27 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:54:27 - CalibrationWorkflow: Self.model updated to online_v525
# [INFO] 15:54:27 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:54:27 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:54:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 15:54:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:29 - CalibrationWorkflow: Treshold reached with 30 iteration, best cost: 0.011686779083609974, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0003362691208601225, 'E2FOULING': 0.0004345439514227809}
# [INFO] 15:54:29 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.262982 > threshold: 0.1
# [INFO] 15:54:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:29 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:54:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:43 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.018258122121450875, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.00044088557806795116, 'E2FOULING': 0.0003929145508451265}
# [INFO] 15:54:43 - CalibrationWorkflow: Working point is accurate enough with cost: 0.018258 < threshold 0.100000
# [INFO] 15:54:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:43 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:54:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:43 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:54:43 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:54:43 - CalibrationWorkflow: Self.model updated to online_v526
# [INFO] 15:54:43 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:54:43 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:54:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 15:54:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:44 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 7.383036891819272e-06, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00035669193801847183, 'E2FOULING': 0.00041782287088233477}
# [INFO] 15:54:45 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.161560 > threshold: 0.1
# [INFO] 15:54:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:45 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 15:54:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:57 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.06415468961670255, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00043825131602345563, 'E2FOULING': 0.0003285012506601559}
# [INFO] 15:54:57 - CalibrationWorkflow: Working point is accurate enough with cost: 0.064155 < threshold 0.100000
# [INFO] 15:54:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:57 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:54:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:57 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 15:54:57 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:54:57 - CalibrationWorkflow: Self.model updated to online_v527
# [INFO] 15:54:57 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:54:57 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 15:54:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:58 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 15:54:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:59 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 8.477572396717795e-06, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0004213477173296246, 'E2FOULING': 0.00039424181487960784}
# [INFO] 15:54:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.094032 < threshold 0.100000
# [INFO] 15:54:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:59 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:54:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:54:59 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:54:59 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:54:59 - CalibrationWorkflow: Self.model updated to online_v528
# [INFO] 15:54:59 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:54:59 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:55:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:55:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 15:55:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:55:00 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.1522432831389778e-05, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0004310873465222549, 'E2FOULING': 0.00042382275252653666}
# [INFO] 15:55:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.049251 < threshold 0.100000
# [INFO] 15:55:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:55:00 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 15:55:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 15:55:00 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 15:55:00 - CalibrationWorkflow: Retraining model with 21 samples (replay + outliers)
# [INFO] 15:55:00 - CalibrationWorkflow: Self.model updated to online_v529
# [INFO] 15:55:00 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 15:55:00 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 15:55:01 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/Calibration_result_online_always-one-replay-0.1.xlsx')
# Out:
# [INFO] 15:55:01 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_always-one-replay-0.1.xlsx

# %%
res = workflow.get_results()

# %%
resdf = pd.DataFrame(res)

# %%
resdf.columns
# Out:
# Index(['SampleID', 'Total_workflow_EllapsedTime', 'Calibration_type',
#        'OriginalFactors', 'Target', 'Calibration_Base_Type',
#        'Calibration_Base_EllapsedTime', 'Calibration_Base_IterationNum',
#        'Calibration_Base_Final_obj', 'Calibration_Base_FinalIO',
#        'Calibration_Base_SurrogatePred', 'Validation_Base_SimulationRes',
#        'Validation_Base_SimCost', 'Validation_Base_Accurate',
#        'Validation_Base_Decision', 'Calibration_Direct_EllapsedTime',
#        'Calibration_Direct_IterationNum', 'Calibration_Direct_Final_obj',
#        'Calibration_Direct_FinalIO', 'Calibration_Direct_SimCost',
#        'Calibration_Direct_Accuracy', 'Calibration_Direct_Decision',
#        'OnlineLearning_New_Data', 'OnlineLearning_New_SelectionType',
#        'OnlineLearning_New_DataType', 'OnlineLearning_EllapsedTime',
#        'OnlineLearning_SelectedReplayids', 'OnlineLearning_SelectedReplayIOs',
#        'LocalImprovement', 'GlobalRetention', 'Used_Surrogate_version',
#        'New_Surrogate_version', 'Final_Calibration_Result_IOs',
#        'Final_Calibration_SimCost', 'Final_Calibration_Accurate',
#        'Final_Calibration_Type'],
#       dtype='object')

# %%
resdf['Validation_Base_Accurate'].value_counts()
# Out:
# Validation_Base_Accurate
# True     437
# False     93
# Name: count, dtype: int64

# %%
resdf['Final_Calibration_Accurate'].value_counts()
# Out:
# Final_Calibration_Accurate
# True    530
# Name: count, dtype: int64

# %%
workflow_settings['sim_validation_treshold']
# Out:
# 0.1

# %%
import seaborn as sns

#sns.kdeplot(resdf['Calibration_Base_Final_obj'], label='Surrogate obj',  fill=True, linewidth=2, clip=(0, None))
sns.kdeplot(resdf['Validation_Base_SimCost'], label='Validation obj',  fill=True, linewidth=2, clip=(0, None))
sns.kdeplot(resdf['Final_Calibration_SimCost'], label='Final Calib obj',  fill=True, linewidth=2, clip=(0, None))
plt.axvline(x=workflow_settings['sim_validation_treshold'], color='red', linestyle='--', label='Threshold')
plt.legend()

# %%
resdf['Calibration_Direct_EllapsedTime'].plot()
# Out:
# <Axes: >

# %%
resdf['LocalImprovement'].mean()
# Out:
# 10.276167556627689

# %%
resdf['GlobalRetention'].plot()
# Out:
# <Axes: >

# %%
resdf
# Out:
#      SampleID  Total_workflow_EllapsedTime Calibration_type  \
# 0           0                    22.294732           online
# 1           1                    15.951129           online
# 2           2                    12.787016           online
# 3           3                    10.972824           online
# 4           4                    17.099149           online
# ..        ...                          ...              ...
# 525       525                    20.623854           online
# 526       526                    16.743213           online
# 527       527                    13.931800           online
# 528       528                     1.335045           online
# 529       529                     1.223481           online
#
#                                        OriginalFactors  \
# 0    {'E1FOULING': 0.0003966064602180043, 'E2FOULIN...
# 1    {'E1FOULING': 0.0003858453451426925, 'E2FOULIN...
# 2    {'E1FOULING': 0.0003847697530392205, 'E2FOULIN...
# 3    {'E1FOULING': 0.0004268043194975153, 'E2FOULIN...
# 4    {'E1FOULING': 0.0003682943731335989, 'E2FOULIN...
# ..                                                 ...
# 525  {'E1FOULING': 0.0004548607687919593, 'E2FOULIN...
# 526  {'E1FOULING': 0.0004822419516333996, 'E2FOULIN...
# 527  {'E1FOULING': 0.0004733674673527922, 'E2FOULIN...
# 528  {'E1FOULING': 0.0004984942750080559, 'E2FOULIN...
# 529  {'E1FOULING': 0.0005021358045441324, 'E2FOULIN...
#
#                                                 Target  \
# 0    {'PROD1E1IN': 108.2722567668642, 'PROD1OUT': 9...
# 1    {'PROD1E1IN': 104.3535050140472, 'PROD1OUT': 9...
# 2    {'PROD1E1IN': 105.9350937121914, 'PROD1OUT': 9...
# 3    {'PROD1E1IN': 106.0854462410004, 'PROD1OUT': 9...
# 4    {'PROD1E1IN': 105.0075133590793, 'PROD1OUT': 9...
# ..                                                 ...
# 525  {'PROD1E1IN': 116.9302158164906, 'PROD1OUT': 1...
# 526  {'PROD1E1IN': 116.2112946019632, 'PROD1OUT': 1...
# 527  {'PROD1E1IN': 116.4229042179647, 'PROD1OUT': 1...
# 528  {'PROD1E1IN': 116.8454717819132, 'PROD1OUT': 1...
# 529  {'PROD1E1IN': 116.0362633732756, 'PROD1OUT': 1...
#
#          Calibration_Base_Type  Calibration_Base_EllapsedTime  \
# 0    CalibrationType.SURROGATE                       1.043054
# 1    CalibrationType.SURROGATE                       0.852482
# 2    CalibrationType.SURROGATE                       0.284928
# 3    CalibrationType.SURROGATE                       0.609345
# 4    CalibrationType.SURROGATE                       0.932007
# ..                         ...                            ...
# 525  CalibrationType.SURROGATE                       0.568938
# 526  CalibrationType.SURROGATE                       1.079483
# 527  CalibrationType.SURROGATE                       0.208952
# 528  CalibrationType.SURROGATE                       0.331253
# 529  CalibrationType.SURROGATE                       0.179887
#
#      Calibration_Base_IterationNum  Calibration_Base_Final_obj  \
# 0                               27                    0.106220
# 1                               24                    0.114953
# 2                                8                    0.107899
# 3                               18                    0.086420
# 4                               28                    0.086776
# ..                             ...                         ...
# 525                             17                    0.009691
# 526                             32                    0.011687
# 527                              6                    0.000007
# 528                              9                    0.000008
# 529                              5                    0.000012
#
#                               Calibration_Base_FinalIO  ...  \
# 0    {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEM...  ...
# 1    {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEM...  ...
# 2    {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEM...  ...
# 3    {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEM...  ...
# 4    {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEM...  ...
# ..                                                 ...  ...
# 525  {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP...  ...
# 526  {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEM...  ...
# 527  {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEM...  ...
# 528  {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEM...  ...
# 529  {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEM...  ...
#
#                       OnlineLearning_SelectedReplayids  \
# 0    [162, 7, 132, 93, 146, 61, 98, 22, 191, 133, 1...
# 1    [174, 98, 3, 29, 57, 199, 195, 14, 25, 108, 87...
# 2    [71, 26, 144, 50, 58, 5, 191, 157, 162, 88, 45...
# 3    [113, 39, 104, 86, 125, 17, 169, 53, 29, 134, ...
# 4    [162, 16, 156, 33, 138, 188, 178, 26, 147, 169...
# ..                                                 ...
# 525  [191, 148, 166, 154, 54, 195, 115, 164, 28, 18...
# 526  [19, 142, 64, 31, 55, 152, 27, 116, 137, 45, 7...
# 527  [13, 94, 125, 113, 29, 138, 36, 165, 25, 96, 1...
# 528  [195, 79, 133, 31, 86, 107, 158, 52, 147, 193,...
# 529  [94, 107, 53, 23, 160, 83, 106, 126, 16, 30, 1...
#
#     OnlineLearning_SelectedReplayIOs  LocalImprovement  GlobalRetention  \
# 0                               None          1.065318         1.006782
# 1                               None          1.037557         1.015153
# 2                               None          1.051151         1.023796
# 3                               None          1.063718         1.032090
# 4                               None          1.115483         1.040113
# ..                               ...               ...              ...
# 525                             None          1.008736         4.588391
# 526                             None          1.038259         4.609744
# 527                             None          1.111639         4.580155
# 528                             None          1.093864         4.561288
# 529                             None               NaN         4.549341
#
#     Used_Surrogate_version  New_Surrogate_version  \
# 0                     base              online_v0
# 1                online_v0              online_v1
# 2                online_v1              online_v2
# 3                online_v2              online_v3
# 4                online_v3              online_v4
# ..                     ...                    ...
# 525            online_v524            online_v525
# 526            online_v525            online_v526
# 527            online_v526            online_v527
# 528            online_v527            online_v528
# 529            online_v528            online_v529
#
#                           Final_Calibration_Result_IOs  \
# 0    {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEM...
# 1    {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEM...
# 2    {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEM...
# 3    {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEM...
# 4    {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEM...
# ..                                                 ...
# 525  {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP...
# 526  {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEM...
# 527  {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEM...
# 528  {'PROD1E1IN': 116.51404302398385, 'PROD1OUT': ...
# 529  {'PROD1E1IN': 116.1931685440739, 'PROD1OUT': 1...
#
#      Final_Calibration_SimCost Final_Calibration_Accurate  \
# 0                     0.040553                       True
# 1                     0.019917                       True
# 2                     0.029632                       True
# 3                     0.016414                       True
# 4                     0.000013                       True
# ..                         ...                        ...
# 525                   0.046445                       True
# 526                   0.018258                       True
# 527                   0.064155                       True
# 528                   0.094032                       True
# 529                   0.049251                       True
#
#      Final_Calibration_Type
# 0                    direct
# 1                    direct
# 2                    direct
# 3                    direct
# 4                    direct
# ..                      ...
# 525                  direct
# 526                  direct
# 527                  direct
# 528              validation
# 529              validation
#
# [530 rows x 36 columns]

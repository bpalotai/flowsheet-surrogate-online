# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_excel('../02_Base_Surrogate_Training/Adaptive_train_data.xlsx', index_col=0)
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'conditional',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/AdaptivedatFNN/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 22:29:15 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 22:29:15 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/AdaptivedatFNN/sklearnann.joblib
# [INFO] 22:29:15 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 22:29:15 - CalibrationWorkflow:
# ============================================================
# [INFO] 22:29:15 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 22:29:15 - CalibrationWorkflow: ============================================================
#
# [INFO] 22:29:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 22:29:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:16 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.01146311158719026, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 22:29:16 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.450269 > threshold: 0.1
# [INFO] 22:29:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:16 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:29:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:26 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.07991686944280996, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.000327256778816251, 'E2FOULING': 0.0006229015267919895}
# [INFO] 22:29:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.079917 < threshold 0.100000
# [INFO] 22:29:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:29:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:26 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:29:26 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 22:29:26 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:29:26 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:29:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 22:29:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:27 - CalibrationWorkflow: Treshold reached with 14 iteration, best cost: 0.011579216209801284, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 22:29:27 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.322821 > threshold: 0.1
# [INFO] 22:29:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:27 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:29:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:49 - CalibrationWorkflow: Obj Treshold reached with 12 iteration, best cost: 0.08355780129415993, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0003043055026005261, 'E2FOULING': 0.0005679941597556862}
# [INFO] 22:29:49 - CalibrationWorkflow: Working point is accurate enough with cost: 0.083558 < threshold 0.100000
# [INFO] 22:29:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:49 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:29:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:49 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:29:49 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 22:29:49 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:29:49 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:29:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 22:29:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:50 - CalibrationWorkflow: Treshold reached with 10 iteration, best cost: 0.015155934900764544, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 22:29:50 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.300045 > threshold: 0.1
# [INFO] 22:29:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:29:50 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:29:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:09 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 0.08612399096361478, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.0002956937735947423, 'E2FOULING': 0.00046649285630018017}
# [INFO] 22:30:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.086124 < threshold 0.100000
# [INFO] 22:30:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:09 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:30:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:09 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:30:09 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 22:30:09 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:30:09 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:30:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 22:30:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:10 - CalibrationWorkflow: Treshold reached with 11 iteration, best cost: 0.03818167886675509, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 22:30:10 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.467650 > threshold: 0.1
# [INFO] 22:30:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:10 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:30:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:25 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 0.08540839414274767, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00033052048270994607, 'E2FOULING': 0.00037750637522067593}
# [INFO] 22:30:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.085408 < threshold 0.100000
# [INFO] 22:30:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:30:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:25 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:30:25 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 22:30:25 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:30:25 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:30:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 22:30:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:26 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 1.724684120205005e-05, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.0002893421876023789}
# [INFO] 22:30:26 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.234618 > threshold: 0.1
# [INFO] 22:30:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:26 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:30:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:56 - CalibrationWorkflow: Obj Treshold reached with 19 iteration, best cost: 0.0943784117815806, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00029525587481641437, 'E2FOULING': 0.0006395924752204211}
# [INFO] 22:30:56 - CalibrationWorkflow: Working point is accurate enough with cost: 0.094378 < threshold 0.100000
# [INFO] 22:30:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:56 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:30:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:56 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:30:56 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 22:30:56 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:30:56 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:30:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 22:30:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:57 - CalibrationWorkflow: Treshold reached with 30 iteration, best cost: 0.027105447330580217, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00025, 'E2FOULING': 0.00026508532887524434}
# [INFO] 22:30:58 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.305711 > threshold: 0.1
# [INFO] 22:30:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:30:58 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:30:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:15 - CalibrationWorkflow: Obj Treshold reached with 12 iteration, best cost: 0.09296231007639273, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.000286172221806816, 'E2FOULING': 0.00046498970606899886}
# [INFO] 22:31:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.092962 < threshold 0.100000
# [INFO] 22:31:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:31:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:15 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:31:15 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 22:31:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:31:15 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:31:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 22:31:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:16 - CalibrationWorkflow: Treshold reached with 21 iteration, best cost: 0.03310942597241555, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00025, 'E2FOULING': 0.00029363179466594777}
# [INFO] 22:31:16 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.215691 > threshold: 0.1
# [INFO] 22:31:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:16 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:31:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:32 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 0.09330472365842117, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.0002755987508822735, 'E2FOULING': 0.00040123519483808203}
# [INFO] 22:31:32 - CalibrationWorkflow: Working point is accurate enough with cost: 0.093305 < threshold 0.100000
# [INFO] 22:31:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:32 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:31:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:32 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:31:32 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 22:31:32 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:31:32 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:31:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:33 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 22:31:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:33 - CalibrationWorkflow: Treshold reached with 40 iteration, best cost: 0.12168330773570826, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.00025, 'E2FOULING': 0.00045932478966466796}
# [INFO] 22:31:33 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.280741 > threshold: 0.1
# [INFO] 22:31:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:33 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:31:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:44 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.07210353484217231, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.00034347183572199636, 'E2FOULING': 0.0005361155182794525}
# [INFO] 22:31:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.072104 < threshold 0.100000
# [INFO] 22:31:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:31:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:44 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:31:44 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 22:31:44 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:31:44 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:31:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 22:31:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:45 - CalibrationWorkflow: Obj Treshold reached with 12 iteration, best cost: 1.56814345854912e-05, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00041104890788015724, 'E2FOULING': 0.00029792780701463727}
# [INFO] 22:31:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 22:31:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:45 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:31:45 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:31:45 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:31:45 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:31:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 22:31:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:46 - CalibrationWorkflow: Obj Treshold reached with 18 iteration, best cost: 0.006655043870278636, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0003742058301560421, 'E2FOULING': 0.00044740435845686894}
# [INFO] 22:31:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.015138 < threshold 0.100000
# [INFO] 22:31:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:46 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:31:46 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:31:46 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:31:46 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:31:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 22:31:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:47 - CalibrationWorkflow: Treshold reached with 18 iteration, best cost: 0.0937545588625625, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004788309410400974}
# [INFO] 22:31:47 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.236011 > threshold: 0.1
# [INFO] 22:31:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:47 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:31:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:59 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 0.09594359612990051, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00037985698512548697, 'E2FOULING': 0.0006512181313012585}
# [INFO] 22:31:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.095944 < threshold 0.100000
# [INFO] 22:31:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:59 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:31:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:59 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:31:59 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 22:31:59 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:31:59 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:31:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:31:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 22:31:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:00 - CalibrationWorkflow: Treshold reached with 53 iteration, best cost: 0.030858706650742015, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0004041114370828707, 'E2FOULING': 0.0005550525735826042}
# [INFO] 22:32:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.036532 < threshold 0.100000
# [INFO] 22:32:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:32:01 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:32:01 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:32:01 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:32:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 22:32:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:02 - CalibrationWorkflow: Treshold reached with 48 iteration, best cost: 0.01959484995200223, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0003988856623553536, 'E2FOULING': 0.0004424828913176574}
# [INFO] 22:32:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 22:32:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:32:02 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:32:02 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:32:02 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:32:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 22:32:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:04 - CalibrationWorkflow: Treshold reached with 51 iteration, best cost: 0.02847034554206009, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00033387789985612636, 'E2FOULING': 0.0005317374903800358}
# [INFO] 22:32:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.038306 < threshold 0.100000
# [INFO] 22:32:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:04 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:32:04 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:32:04 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:32:04 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:32:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 22:32:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:04 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.0068342124499310335, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0006370438465789269, 'E2FOULING': 0.0003243836061396976}
# [INFO] 22:32:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.065809 < threshold 0.100000
# [INFO] 22:32:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:04 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:32:04 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:32:04 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:32:04 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:32:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 22:32:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:06 - CalibrationWorkflow: Treshold reached with 52 iteration, best cost: 0.02017587100324937, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0003773959493146271, 'E2FOULING': 0.00035132234685791554}
# [INFO] 22:32:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 22:32:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:06 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:32:06 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:32:06 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:32:06 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:32:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 22:32:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:07 - CalibrationWorkflow: Treshold reached with 33 iteration, best cost: 0.06045793075525893, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.00025, 'E2FOULING': 0.00044700175217142273}
# [INFO] 22:32:07 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.166145 > threshold: 0.1
# [INFO] 22:32:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:07 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:32:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:24 - CalibrationWorkflow: Obj Treshold reached with 12 iteration, best cost: 0.09249806518000123, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.0002856516054271136, 'E2FOULING': 0.00043061068926385633}
# [INFO] 22:32:24 - CalibrationWorkflow: Working point is accurate enough with cost: 0.092498 < threshold 0.100000
# [INFO] 22:32:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:24 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:32:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:24 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:32:24 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 22:32:24 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:32:24 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:32:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 22:32:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:25 - CalibrationWorkflow: Treshold reached with 31 iteration, best cost: 0.0983790231811974, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005381922337197196}
# [INFO] 22:32:25 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.143586 > threshold: 0.1
# [INFO] 22:32:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:32:25 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:32:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:15 - CalibrationWorkflow: Treshold reached with 38 iteration, best cost: 0.10074137568721775, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.0002663682738917031, 'E2FOULING': 0.000495600143357524}
# [INFO] 22:33:15 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.100741 > threshold: 0.1
# [INFO] 22:33:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:15 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:33:15 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 22:33:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:33:15 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:33:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 22:33:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:16 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 0.006871773246267893, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.0003933260807238485, 'E2FOULING': 0.0004613264304285108}
# [INFO] 22:33:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 22:33:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:16 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:33:16 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:33:16 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:33:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 22:33:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:17 - CalibrationWorkflow: Treshold reached with 27 iteration, best cost: 0.054624409113118146, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00025, 'E2FOULING': 0.0004890006973353686}
# [INFO] 22:33:17 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.124370 > threshold: 0.1
# [INFO] 22:33:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:17 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:33:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:36 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 0.07805187858457918, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00028260806347876337, 'E2FOULING': 0.0005222449801471297}
# [INFO] 22:33:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.078052 < threshold 0.100000
# [INFO] 22:33:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:36 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:36 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:33:36 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 22:33:36 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:33:36 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:33:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 22:33:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:38 - CalibrationWorkflow: Treshold reached with 51 iteration, best cost: 0.027119538479942275, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0004016306108242431, 'E2FOULING': 0.0004756845144917385}
# [INFO] 22:33:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.008570 < threshold 0.100000
# [INFO] 22:33:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:38 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:33:38 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:33:38 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:33:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 22:33:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:38 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 6.977237302497493e-06, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0005331162310893259, 'E2FOULING': 0.0003910009866687033}
# [INFO] 22:33:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.070109 < threshold 0.100000
# [INFO] 22:33:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:39 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:39 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:33:39 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:33:39 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:33:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 22:33:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:39 - CalibrationWorkflow: Obj Treshold reached with 12 iteration, best cost: 1.3111391948527467e-05, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.0004539334840232985, 'E2FOULING': 0.0004104317535811413}
# [INFO] 22:33:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.020068 < threshold 0.100000
# [INFO] 22:33:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:39 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:39 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:33:39 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:33:39 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:33:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:40 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 22:33:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:41 - CalibrationWorkflow: Treshold reached with 53 iteration, best cost: 0.0650779431708011, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.0003582411812210668, 'E2FOULING': 0.0005899931537885864}
# [INFO] 22:33:41 - CalibrationWorkflow: Working point is accurate enough with cost: 0.063360 < threshold 0.100000
# [INFO] 22:33:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:41 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:41 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:33:41 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:33:41 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:33:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:41 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 22:33:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:42 - CalibrationWorkflow: Treshold reached with 41 iteration, best cost: 0.0644355021717391, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0003057380899428048, 'E2FOULING': 0.0005246411640300846}
# [INFO] 22:33:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.043299 < threshold 0.100000
# [INFO] 22:33:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:42 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:42 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:33:42 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:33:42 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:33:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 22:33:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:43 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 9.45122534470876e-06, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.000442549262259283, 'E2FOULING': 0.00048275040294144675}
# [INFO] 22:33:43 - CalibrationWorkflow: Working point is accurate enough with cost: 0.052389 < threshold 0.100000
# [INFO] 22:33:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:43 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:43 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:33:43 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:33:43 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:33:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 22:33:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:44 - CalibrationWorkflow: Obj Treshold reached with 19 iteration, best cost: 1.666515193540172e-05, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.00047868918260240083, 'E2FOULING': 0.00040573502851772323}
# [INFO] 22:33:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.024918 < threshold 0.100000
# [INFO] 22:33:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:44 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:33:44 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:33:44 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:33:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 22:33:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:45 - CalibrationWorkflow: Treshold reached with 37 iteration, best cost: 0.08705852626571309, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.00027554582756843715, 'E2FOULING': 0.0005009486427735209}
# [INFO] 22:33:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.093983 < threshold 0.100000
# [INFO] 22:33:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:45 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:45 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:33:45 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:33:45 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:33:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 22:33:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:46 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 8.811202985024484e-06, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.000527285243955467, 'E2FOULING': 0.00042683657446867737}
# [INFO] 22:33:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.063305 < threshold 0.100000
# [INFO] 22:33:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:46 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:46 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:33:46 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:33:46 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:33:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 29 of 529.
# [INFO] 22:33:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:47 - CalibrationWorkflow: Treshold reached with 28 iteration, best cost: 0.11648606930401306, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.00025, 'E2FOULING': 0.0005199956911939765}
# [INFO] 22:33:47 - CalibrationWorkflow: Working point is accurate enough with cost: 0.098017 < threshold 0.100000
# [INFO] 22:33:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:47 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:47 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:33:47 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:33:47 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:33:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:47 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 30 of 529.
# [INFO] 22:33:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:48 - CalibrationWorkflow: Treshold reached with 12 iteration, best cost: 0.02018961159133118, values: {'FEED1MASSFLOW': 18170.33282487203, 'FEED1TEMP': 24.88142490999688, 'PROD1MASSFLOW': 45110.96621847873, 'PROD1TEMP': 115.0679318499356, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 22:33:48 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 22:33:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:48 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:33:48 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:33:48 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:33:48 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:33:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 31 of 529.
# [INFO] 22:33:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:33:48 - CalibrationWorkflow: Treshold reached with 8 iteration, best cost: 0.037082023344097055, values: {'FEED1MASSFLOW': 18607.84387976851, 'FEED1TEMP': 25.14488217461214, 'PROD1MASSFLOW': 43738.61199857389, 'PROD1TEMP': 115.3747174316839, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# ...
# [INFO] 22:58:02 - CalibrationWorkflow: Treshold reached with 57 iteration, best cost: 0.12142241824763243, values: {'FEED1MASSFLOW': 13389.10627836312, 'FEED1TEMP': 20.00940520749543, 'PROD1MASSFLOW': 35184.59183121471, 'PROD1TEMP': 128.043630919933, 'E1FOULING': 0.0003047923301545016, 'E2FOULING': 0.00042655502007862427}
# [INFO] 22:58:02 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.551341 > threshold: 0.1
# [INFO] 22:58:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:02 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:58:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:15 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.04479885278947144, values: {'FEED1MASSFLOW': 13389.10627836312, 'FEED1TEMP': 20.00940520749543, 'PROD1MASSFLOW': 35184.59183121471, 'PROD1TEMP': 128.043630919933, 'E1FOULING': 0.0004462981640696754, 'E2FOULING': 0.0005298494001213316}
# [INFO] 22:58:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.044799 < threshold 0.100000
# [INFO] 22:58:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:58:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:15 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:58:15 - CalibrationWorkflow: Self.model updated to online_v75
# [INFO] 22:58:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:58:15 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:58:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 519 of 529.
# [INFO] 22:58:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:16 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.009273598520638129, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.0006334386975866301, 'E2FOULING': 0.0005047898464346566}
# [INFO] 22:58:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.076311 < threshold 0.100000
# [INFO] 22:58:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:58:16 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:58:16 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:58:16 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:58:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 22:58:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:16 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 0.00954963160571402, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.0005117604723266178, 'E2FOULING': 0.0002955588108808783}
# [INFO] 22:58:16 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.117069 > threshold: 0.1
# [INFO] 22:58:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:16 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 22:58:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:25 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.09153361340338423, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.00045797970787708975, 'E2FOULING': 0.0006727995385337111}
# [INFO] 22:58:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.091534 < threshold 0.100000
# [INFO] 22:58:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:58:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:25 - CalibrationWorkflow: Retraining model with 2 samples (replay + outliers)
# [INFO] 22:58:25 - CalibrationWorkflow: Self.model updated to online_v76
# [INFO] 22:58:25 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 22:58:25 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 22:58:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 22:58:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:26 - CalibrationWorkflow: Obj Treshold reached with 14 iteration, best cost: 0.007152829989050725, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0005299057743230688, 'E2FOULING': 0.00032413213345986846}
# [INFO] 22:58:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.039864 < threshold 0.100000
# [INFO] 22:58:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:58:26 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:58:26 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:58:26 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:58:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 22:58:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:26 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 4.749988142270961e-06, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0006354578559780586, 'E2FOULING': 0.00039768896654843655}
# [INFO] 22:58:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.088587 < threshold 0.100000
# [INFO] 22:58:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:58:26 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:58:26 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:58:26 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:58:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 22:58:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:27 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 2.053479687253537e-05, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0005255734447200812, 'E2FOULING': 0.0004176143185906559}
# [INFO] 22:58:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 22:58:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:27 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:58:27 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:58:27 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:58:27 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:58:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 22:58:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:28 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 1.3327082025183722e-05, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.000570305581688762, 'E2FOULING': 0.0004035247291998802}
# [INFO] 22:58:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.014138 < threshold 0.100000
# [INFO] 22:58:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:28 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:58:28 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:58:28 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:58:28 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:58:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 22:58:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:28 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 8.409917021952059e-06, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.0004542444671950854, 'E2FOULING': 0.00032491523395913294}
# [INFO] 22:58:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.028612 < threshold 0.100000
# [INFO] 22:58:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:28 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:58:28 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:58:28 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:58:28 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:58:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 22:58:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:29 - CalibrationWorkflow: Obj Treshold reached with 15 iteration, best cost: 1.5981241964591845e-05, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.00043238235472204143, 'E2FOULING': 0.0004105408395634391}
# [INFO] 22:58:29 - CalibrationWorkflow: Working point is accurate enough with cost: 0.026969 < threshold 0.100000
# [INFO] 22:58:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:29 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:58:29 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:58:29 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:58:29 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:58:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 22:58:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:30 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 8.854706676066812e-06, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.00048034072923030635, 'E2FOULING': 0.0003774940334732201}
# [INFO] 22:58:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.007987 < threshold 0.100000
# [INFO] 22:58:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:30 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:58:30 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:58:30 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:58:30 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:58:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:30 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 22:58:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:30 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.00713472776198143, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.000555667964521166, 'E2FOULING': 0.00048327783777703877}
# [INFO] 22:58:30 - CalibrationWorkflow: Working point is accurate enough with cost: 0.025926 < threshold 0.100000
# [INFO] 22:58:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:30 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:58:30 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:58:30 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:58:30 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:58:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:31 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 22:58:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:31 - CalibrationWorkflow: Obj Treshold reached with 11 iteration, best cost: 1.1165537523473608e-05, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0005187709374577343, 'E2FOULING': 0.0003773551916831444}
# [INFO] 22:58:31 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 22:58:31 - CalibrationWorkflow: ----------------------------------------
# [INFO] 22:58:31 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: conditional.
# [INFO] 22:58:31 - CalibrationWorkflow: ----------------------------------------
# [WARNING] 22:58:31 - CalibrationWorkflow: No simulation working point found. Skipping online learning step.
# [WARNING] 22:58:31 - CalibrationWorkflow: No simulation data available for online learning. Skipping online learning step.
# [INFO] 22:58:31 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/05_Calibration_Online_FNN-BNN-low_conditional.xlsx')
# Out:
# [INFO] 22:58:32 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_FNN-BNN_conditional.xlsx

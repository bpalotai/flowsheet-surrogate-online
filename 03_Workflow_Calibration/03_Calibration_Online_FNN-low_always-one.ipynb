# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_200.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodel/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 23:26:12 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 23:26:12 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodel/sklearnann.joblib
# [INFO] 23:26:12 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0.01, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 23:26:12 - CalibrationWorkflow:
# ============================================================
# [INFO] 23:26:12 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 23:26:12 - CalibrationWorkflow: ============================================================
#
# [INFO] 23:26:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 23:26:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:12 - CalibrationWorkflow: Treshold reached with 7 iteration, best cost: 0.11372939572771253, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025005382704078284}
# [INFO] 23:26:12 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.493285 > threshold: 0.1
# [INFO] 23:26:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:12 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:26:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:20 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 2.560798851463728e-06, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0003854859732729944, 'E2FOULING': 0.0004161963953196157}
# [INFO] 23:26:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 23:26:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:20 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:20 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:26:20 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:26:20 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 23:26:20 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:26:20 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:26:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 23:26:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:21 - CalibrationWorkflow: Treshold reached with 25 iteration, best cost: 0.0971576696195434, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00029881908425954457, 'E2FOULING': 0.0002543893517129248}
# [INFO] 23:26:21 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.184923 > threshold: 0.1
# [INFO] 23:26:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:21 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:26:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:33 - CalibrationWorkflow: Treshold reached with 45 iteration, best cost: 0.7696838090228476, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00026308808174680775, 'E2FOULING': 0.0015546689274097668}
# [INFO] 23:27:33 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.769684 > threshold: 0.1
# [INFO] 23:27:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:33 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:33 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:27:33 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:27:33 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 23:27:33 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:27:33 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:27:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:33 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 23:27:33 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:33 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.08662090154443323, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 23:27:34 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.324413 > threshold: 0.1
# [INFO] 23:27:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:34 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:27:34 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:42 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.09284460456879626, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.0004610710743856069, 'E2FOULING': 0.00046211968100768155}
# [INFO] 23:27:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.092845 < threshold 0.100000
# [INFO] 23:27:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:42 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:42 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:27:42 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:27:42 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 23:27:42 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:27:42 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:27:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 23:27:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:43 - CalibrationWorkflow: Treshold reached with 16 iteration, best cost: 0.052663451657453016, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.000301069687122438, 'E2FOULING': 0.00026841422555472255}
# [INFO] 23:27:43 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.269035 > threshold: 0.1
# [INFO] 23:27:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:43 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:27:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:53 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.009855006453315801, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0004549898375657362, 'E2FOULING': 0.0004340797722728919}
# [INFO] 23:27:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.009855 < threshold 0.100000
# [INFO] 23:27:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:53 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:53 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:27:53 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:27:53 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 23:27:53 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:27:53 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:27:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 23:27:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:54 - CalibrationWorkflow: Treshold reached with 24 iteration, best cost: 0.05100601381980084, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025, 'E2FOULING': 0.00028612887778018905}
# [INFO] 23:27:54 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.261611 > threshold: 0.1
# [INFO] 23:27:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:54 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:27:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:01 - CalibrationWorkflow: Treshold reached with 42 iteration, best cost: 0.9094802910023144, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.00025075136953733916, 'E2FOULING': 0.0019903860325593092}
# [INFO] 23:29:01 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.909480 > threshold: 0.1
# [INFO] 23:29:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:29:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:01 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:29:01 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:29:01 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 23:29:01 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:29:01 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:29:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 23:29:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:02 - CalibrationWorkflow: Treshold reached with 21 iteration, best cost: 0.0486228499214649, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00026073331697745006, 'E2FOULING': 0.00025327568713793186}
# [INFO] 23:29:02 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.299399 > threshold: 0.1
# [INFO] 23:29:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:02 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:29:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:10 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.0632518780574588, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.0004560898513976487, 'E2FOULING': 0.00045633683873331875}
# [INFO] 23:29:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.063252 < threshold 0.100000
# [INFO] 23:29:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:10 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:29:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:10 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:29:10 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:29:10 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 23:29:10 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:29:10 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:29:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 23:29:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:11 - CalibrationWorkflow: Treshold reached with 13 iteration, best cost: 0.028758007213798207, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025123555866235774}
# [INFO] 23:29:11 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.283036 > threshold: 0.1
# [INFO] 23:29:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:11 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:29:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:21 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 8.95695577340864e-06, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.0003513928293440285, 'E2FOULING': 0.00034904522613594285}
# [INFO] 23:29:21 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 23:29:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:21 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:29:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:21 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:29:21 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:29:21 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 23:29:21 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:29:21 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:29:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 23:29:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:22 - CalibrationWorkflow: Treshold reached with 39 iteration, best cost: 0.018685648634965493, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0005413410862586383, 'E2FOULING': 0.00025421717090617956}
# [INFO] 23:29:22 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.108795 > threshold: 0.1
# [INFO] 23:29:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:22 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:29:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:35 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.6133800293278843e-06, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0004177913602592433, 'E2FOULING': 0.00041734089039229373}
# [INFO] 23:29:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 23:29:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:35 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:29:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:35 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:29:35 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:29:35 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 23:29:35 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:29:35 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:29:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 23:29:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:36 - CalibrationWorkflow: Treshold reached with 23 iteration, best cost: 0.01061409919185916, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.0002857438423441131, 'E2FOULING': 0.00025}
# [INFO] 23:29:36 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.213023 > threshold: 0.1
# [INFO] 23:29:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:36 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:29:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:45 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 7.879462179157198e-06, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.0003801734075513096, 'E2FOULING': 0.00037862192250932565}
# [INFO] 23:29:45 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 23:29:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:45 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:29:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:45 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:29:45 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:29:45 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 23:29:45 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:29:45 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:29:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 23:29:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:46 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.006957302096465079, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.00037079166620411627, 'E2FOULING': 0.0003696488577078738}
# [INFO] 23:29:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.029210 < threshold 0.100000
# [INFO] 23:29:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:46 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:29:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:46 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:29:46 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:29:46 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 23:29:46 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:29:46 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:29:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:47 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 23:29:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:47 - CalibrationWorkflow: Obj Treshold reached with 13 iteration, best cost: 0.00992973972889691, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00043113836704823037, 'E2FOULING': 0.0004110997284129693}
# [INFO] 23:29:47 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 23:29:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:47 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:29:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:47 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:29:47 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:29:47 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 23:29:47 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:29:47 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:29:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 23:29:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:48 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.616808595309408e-05, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0005564492933268596, 'E2FOULING': 0.0002703421234558929}
# [INFO] 23:29:48 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.143037 > threshold: 0.1
# [INFO] 23:29:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:29:48 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:29:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:00 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.032385482853012806, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.00040032596339707, 'E2FOULING': 0.0005406253284319091}
# [INFO] 23:30:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.032385 < threshold 0.100000
# [INFO] 23:30:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:00 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:30:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:00 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:30:00 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:30:00 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 23:30:00 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:30:00 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:30:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 23:30:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:01 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.4753948940344417e-05, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0004634243627730282, 'E2FOULING': 0.00046423518498832567}
# [INFO] 23:30:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.045409 < threshold 0.100000
# [INFO] 23:30:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:30:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:01 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:30:01 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:30:01 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 23:30:01 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:30:01 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:30:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 23:30:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:02 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.007719999005464826, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00039474756072769917, 'E2FOULING': 0.0003937930559905633}
# [INFO] 23:30:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 23:30:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:30:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:02 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:30:02 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:30:02 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 23:30:02 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:30:02 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:30:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 23:30:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:03 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 4.1870450255301665e-06, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0006402556882361426, 'E2FOULING': 0.0004261503976034512}
# [INFO] 23:30:03 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.111259 > threshold: 0.1
# [INFO] 23:30:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:03 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:30:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:16 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 4.777922141202325e-06, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0005279954870477715, 'E2FOULING': 0.00038911057388857183}
# [INFO] 23:30:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 23:30:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:30:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:16 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:30:16 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:30:16 - CalibrationWorkflow: Self.model updated to online_v14
# [INFO] 23:30:16 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:30:16 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:30:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 23:30:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:17 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.0093728268943502e-05, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.0003649042896614788, 'E2FOULING': 0.0003630945838954064}
# [INFO] 23:30:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 23:30:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:17 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:30:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:17 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:30:17 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:30:17 - CalibrationWorkflow: Self.model updated to online_v15
# [INFO] 23:30:17 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:30:17 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:30:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 23:30:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:18 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 1.2515934763645677e-05, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.00035069811460704053, 'E2FOULING': 0.0004367673004866151}
# [INFO] 23:30:18 - CalibrationWorkflow: Working point is accurate enough with cost: 0.011516 < threshold 0.100000
# [INFO] 23:30:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:18 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:30:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:18 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:30:18 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:30:18 - CalibrationWorkflow: Self.model updated to online_v16
# [INFO] 23:30:18 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:30:18 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:30:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:18 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 23:30:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:19 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 0.008162659236032549, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.00045715023574582626, 'E2FOULING': 0.00045753300206195823}
# [INFO] 23:30:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.047094 < threshold 0.100000
# [INFO] 23:30:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:19 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:30:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:19 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:30:19 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:30:19 - CalibrationWorkflow: Self.model updated to online_v17
# [INFO] 23:30:19 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:30:19 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:30:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:19 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 23:30:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:19 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 0.00868877173369393, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.00045166967752077996, 'E2FOULING': 0.00045243736706994636}
# [INFO] 23:30:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.045965 < threshold 0.100000
# [INFO] 23:30:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:20 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:30:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:20 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:30:20 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:30:20 - CalibrationWorkflow: Self.model updated to online_v18
# [INFO] 23:30:20 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:30:20 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:30:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:20 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 23:30:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:20 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.007976120553970489, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00025, 'E2FOULING': 0.00045956725744357484}
# [INFO] 23:30:20 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.133237 > threshold: 0.1
# [INFO] 23:30:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:30:20 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:30:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:35 - CalibrationWorkflow: Treshold reached with 51 iteration, best cost: 0.3027883744411647, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00028935865181701137, 'E2FOULING': 0.0008976830162465583}
# [INFO] 23:31:35 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.302788 > threshold: 0.1
# [INFO] 23:31:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:35 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:31:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:35 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:31:35 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:31:35 - CalibrationWorkflow: Self.model updated to online_v19
# [INFO] 23:31:35 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:31:35 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:31:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:36 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 23:31:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:36 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.1516629845001732e-05, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.00040678323967359274, 'E2FOULING': 0.0004058433091400622}
# [INFO] 23:31:36 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 23:31:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:36 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:31:36 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:36 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:31:36 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:31:36 - CalibrationWorkflow: Self.model updated to online_v20
# [INFO] 23:31:36 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:31:36 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:31:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 23:31:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:37 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 1.2900674042825195e-05, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0005034910245745327, 'E2FOULING': 0.00041305241538935525}
# [INFO] 23:31:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.050554 < threshold 0.100000
# [INFO] 23:31:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:37 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:31:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:37 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:31:37 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:31:37 - CalibrationWorkflow: Self.model updated to online_v21
# [INFO] 23:31:37 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:31:37 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:31:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 23:31:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:38 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.007436751967575772, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.00046647092114799444, 'E2FOULING': 0.0004671108914312852}
# [INFO] 23:31:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.046151 < threshold 0.100000
# [INFO] 23:31:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:31:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:38 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:31:38 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:31:38 - CalibrationWorkflow: Self.model updated to online_v22
# [INFO] 23:31:38 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:31:38 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:31:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 23:31:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:39 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 2.954248623149145e-06, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.0004531430899978682, 'E2FOULING': 0.00045393738135008455}
# [INFO] 23:31:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.010998 < threshold 0.100000
# [INFO] 23:31:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:39 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:31:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:39 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:31:39 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:31:39 - CalibrationWorkflow: Self.model updated to online_v23
# [INFO] 23:31:39 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:31:39 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:31:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:39 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 23:31:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:39 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 2.6257754841222513e-06, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0003906343464688897, 'E2FOULING': 0.000389772105627485}
# [INFO] 23:31:39 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 23:31:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:39 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:31:39 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:39 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:31:39 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:31:39 - CalibrationWorkflow: Self.model updated to online_v24
# [INFO] 23:31:39 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:31:39 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:31:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:40 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 23:31:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:40 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 5.263470395155565e-06, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.0004714914737277711, 'E2FOULING': 0.0003269898840872709}
# [INFO] 23:31:40 - CalibrationWorkflow: Working point is accurate enough with cost: 0.060123 < threshold 0.100000
# [INFO] 23:31:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:40 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:31:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:40 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:31:40 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:31:40 - CalibrationWorkflow: Self.model updated to online_v25
# [INFO] 23:31:40 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:31:40 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:31:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:41 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 23:31:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:41 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 8.21445778559599e-06, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.000474394879450906, 'E2FOULING': 0.00047533871708948703}
# [INFO] 23:31:41 - CalibrationWorkflow: Working point is accurate enough with cost: 0.044203 < threshold 0.100000
# [INFO] 23:31:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:41 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:31:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:41 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:31:41 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:31:41 - CalibrationWorkflow: Self.model updated to online_v26
# [INFO] 23:31:41 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:31:41 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:31:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:42 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 23:31:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:42 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 2.5812445202573694e-06, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.0003725227628096465, 'E2FOULING': 0.0003706570109896228}
# [INFO] 23:31:42 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 23:31:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:42 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:31:42 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:31:42 - CalibrationWorkflow: Selected point for online learning: validation
# ...
# [INFO] 23:41:59 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.6026507194498463e-06, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.0005425570455884652, 'E2FOULING': 0.0005335166586052478}
# [INFO] 23:41:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 23:41:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:41:59 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:41:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:41:59 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:41:59 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:41:59 - CalibrationWorkflow: Self.model updated to online_v519
# [INFO] 23:41:59 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:41:59 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:41:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:41:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 23:41:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:41:59 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 4.035808022846703e-06, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.0004943667600008279, 'E2FOULING': 0.0004762266014909099}
# [INFO] 23:41:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 23:41:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:41:59 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:41:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:41:59 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:41:59 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:41:59 - CalibrationWorkflow: Self.model updated to online_v520
# [INFO] 23:41:59 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:41:59 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:42:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 23:42:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:00 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.1464089127774065e-06, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.0005213439804507883, 'E2FOULING': 0.00032344741465587716}
# [INFO] 23:42:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.046974 < threshold 0.100000
# [INFO] 23:42:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:00 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:42:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:00 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:42:00 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:42:00 - CalibrationWorkflow: Self.model updated to online_v521
# [INFO] 23:42:00 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:42:00 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:42:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 23:42:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:01 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 5.265477730626325e-06, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005345480784642936, 'E2FOULING': 0.0005142636273244036}
# [INFO] 23:42:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.007726 < threshold 0.100000
# [INFO] 23:42:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:42:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:01 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:42:01 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:42:01 - CalibrationWorkflow: Self.model updated to online_v522
# [INFO] 23:42:01 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:42:01 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:42:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 23:42:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:02 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.0945988896023106e-05, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.00043909361141386967, 'E2FOULING': 0.0004397691682586474}
# [INFO] 23:42:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.087569 < threshold 0.100000
# [INFO] 23:42:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:42:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:02 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:42:02 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:42:02 - CalibrationWorkflow: Self.model updated to online_v523
# [INFO] 23:42:02 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:42:02 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:42:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 23:42:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:03 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.6379070918130594e-05, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0004975202564210196, 'E2FOULING': 0.0004992211117921759}
# [INFO] 23:42:03 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000017 < threshold 0.100000
# [INFO] 23:42:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:03 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:42:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:03 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:42:03 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:42:03 - CalibrationWorkflow: Self.model updated to online_v524
# [INFO] 23:42:03 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:42:03 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:42:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 23:42:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:03 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.9725663197298692e-05, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.0004308226692534694, 'E2FOULING': 0.00025}
# [INFO] 23:42:03 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.165049 > threshold: 0.1
# [INFO] 23:42:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:03 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:42:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:14 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 4.362048327776514e-06, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00043418162151963904, 'E2FOULING': 0.00043452761299495653}
# [INFO] 23:42:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 23:42:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:42:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:14 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:42:14 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:42:14 - CalibrationWorkflow: Self.model updated to online_v525
# [INFO] 23:42:14 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:42:14 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:42:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 23:42:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:15 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 7.4769283898900045e-06, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0004257841545232097, 'E2FOULING': 0.0004042401939027907}
# [INFO] 23:42:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.045505 < threshold 0.100000
# [INFO] 23:42:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:42:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:15 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:42:15 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:42:15 - CalibrationWorkflow: Self.model updated to online_v526
# [INFO] 23:42:15 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:42:15 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:42:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 23:42:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:16 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 4.292704762670713e-06, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0004885334365182415, 'E2FOULING': 0.0003704967337954685}
# [INFO] 23:42:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.008876 < threshold 0.100000
# [INFO] 23:42:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:42:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:16 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:42:16 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:42:16 - CalibrationWorkflow: Self.model updated to online_v527
# [INFO] 23:42:16 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:42:16 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:42:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 23:42:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:17 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 3.965697011112166e-06, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0004740114212473806, 'E2FOULING': 0.00047460655361297857}
# [INFO] 23:42:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 23:42:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:17 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:42:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:17 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:42:17 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:42:17 - CalibrationWorkflow: Self.model updated to online_v528
# [INFO] 23:42:17 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:42:17 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:42:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 23:42:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:18 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 7.734332597117745e-06, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.00049487798124135, 'E2FOULING': 0.000496530156970232}
# [INFO] 23:42:18 - CalibrationWorkflow: Working point is accurate enough with cost: 0.007010 < threshold 0.100000
# [INFO] 23:42:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:18 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:42:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:42:18 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:42:18 - CalibrationWorkflow: Retraining model with 3 samples (replay + outliers)
# [INFO] 23:42:18 - CalibrationWorkflow: Self.model updated to online_v529
# [INFO] 23:42:18 - CalibrationWorkflow: Batch of 1 points collected. Retraining model.
# [INFO] 23:42:18 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:42:18 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/03_Calibration_Online_FNN-low_always-one.xlsx')
# Out:
# [INFO] 23:42:53 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_always-one.xlsx

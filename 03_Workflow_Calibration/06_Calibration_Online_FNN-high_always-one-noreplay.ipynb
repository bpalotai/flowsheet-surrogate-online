# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_csv('../01_DataCollecting/Sim_result/Surrogate_dataset_LHS_1000.csv', index_col=0, encoding='ISO-8859-1')
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/Sklearnmodelbig/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 10:29:40 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 10:29:40 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/Sklearnmodelbig/sklearnann.joblib
# [INFO] 10:29:40 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 10:29:41 - CalibrationWorkflow:
# ============================================================
# [INFO] 10:29:41 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 10:29:41 - CalibrationWorkflow: ============================================================
#
# [INFO] 10:29:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:41 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 10:29:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:41 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.3974508427088034e-05, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00034032148684093425, 'E2FOULING': 0.00047368146616876043}
# [INFO] 10:29:41 - CalibrationWorkflow: Working point is accurate enough with cost: 0.029071 < threshold 0.100000
# [INFO] 10:29:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:41 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:29:41 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:41 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:29:41 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:29:41 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 10:29:41 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:29:41 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:29:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:44 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 10:29:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:44 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.4092074147347231e-05, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.00038000000000000035}
# [INFO] 10:29:44 - CalibrationWorkflow: Working point is accurate enough with cost: 0.024792 < threshold 0.100000
# [INFO] 10:29:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:44 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:29:44 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:44 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:29:44 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:29:44 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 10:29:44 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:29:44 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:29:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:47 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 10:29:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:47 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 9.062531601856597e-06, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.00038000000000000035}
# [INFO] 10:29:47 - CalibrationWorkflow: Working point is accurate enough with cost: 0.016537 < threshold 0.100000
# [INFO] 10:29:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:47 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:29:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:47 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:29:47 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:29:47 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 10:29:47 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:29:47 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:29:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 10:29:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:50 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 1.4144584072720585e-05, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0003921220000000003, 'E2FOULING': 0.00043825400000000033}
# [INFO] 10:29:50 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000014 < threshold 0.100000
# [INFO] 10:29:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:50 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:29:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:50 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:29:50 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:29:50 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 10:29:50 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:29:50 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:29:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:52 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 10:29:52 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:53 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 4.748051880002638e-06, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.00040660000000000034}
# [INFO] 10:29:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 10:29:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:53 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:29:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:53 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:29:53 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:29:53 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 10:29:53 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:29:53 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:29:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:55 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 10:29:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:55 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 1.0868007425418004e-05, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.00042441600279262675, 'E2FOULING': 0.00044815930337757074}
# [INFO] 10:29:55 - CalibrationWorkflow: Working point is accurate enough with cost: 0.024024 < threshold 0.100000
# [INFO] 10:29:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:55 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:29:55 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:55 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:29:55 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:29:55 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 10:29:55 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:29:55 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:29:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:58 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 10:29:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:58 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.3150541059038077e-05, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.00041065204336397415, 'E2FOULING': 0.00041775881896007506}
# [INFO] 10:29:58 - CalibrationWorkflow: Working point is accurate enough with cost: 0.012831 < threshold 0.100000
# [INFO] 10:29:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:58 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:29:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:29:58 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:29:58 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:29:58 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 10:29:58 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:29:58 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 10:30:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:01 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 1.1436060188565424e-05, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.0005109922083039017, 'E2FOULING': 0.00041505163584277936}
# [INFO] 10:30:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.044316 < threshold 0.100000
# [INFO] 10:30:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:01 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:01 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:01 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 10:30:01 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:01 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 10:30:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:04 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 1.2266041101167353e-05, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.0004250938321895893, 'E2FOULING': 0.00025}
# [INFO] 10:30:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.020326 < threshold 0.100000
# [INFO] 10:30:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:04 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:04 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:04 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:04 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 10:30:04 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:04 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:07 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 10:30:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:07 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 1.8863598081193422e-05, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0003921220000000003, 'E2FOULING': 0.00043825400000000033}
# [INFO] 10:30:07 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000007 < threshold 0.100000
# [INFO] 10:30:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:07 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:07 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:07 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:07 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 10:30:07 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:07 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 10:30:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:10 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 1.0831581285115044e-05, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.0003921220000000003, 'E2FOULING': 0.00043825400000000033}
# [INFO] 10:30:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000005 < threshold 0.100000
# [INFO] 10:30:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:10 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:10 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:10 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:10 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 10:30:10 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:10 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 10:30:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:13 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.1960887869606054e-05, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.00040660000000000034}
# [INFO] 10:30:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.012970 < threshold 0.100000
# [INFO] 10:30:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:13 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:13 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:13 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 10:30:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:13 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 10:30:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:15 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 3.507823756081231e-06, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.00040660000000000034}
# [INFO] 10:30:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 10:30:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:15 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:15 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:15 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 10:30:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:15 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:18 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 10:30:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:18 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 5.70785503484896e-06, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.00038000000000000035}
# [INFO] 10:30:18 - CalibrationWorkflow: Working point is accurate enough with cost: 0.009107 < threshold 0.100000
# [INFO] 10:30:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:18 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:18 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:18 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:18 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:18 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 10:30:18 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:18 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 10:30:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:21 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 6.103093033151484e-06, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0004885932497852666, 'E2FOULING': 0.000377286387834956}
# [INFO] 10:30:21 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 10:30:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:21 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:21 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:21 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:21 - CalibrationWorkflow: Self.model updated to online_v14
# [INFO] 10:30:21 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:21 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 10:30:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:24 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 5.612568160500766e-06, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.00038000000000000035}
# [INFO] 10:30:24 - CalibrationWorkflow: Working point is accurate enough with cost: 0.019832 < threshold 0.100000
# [INFO] 10:30:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:24 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:24 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:24 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:24 - CalibrationWorkflow: Self.model updated to online_v15
# [INFO] 10:30:24 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:24 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 10:30:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:26 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 3.0419692077095447e-06, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.00038000000000000035}
# [INFO] 10:30:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.014770 < threshold 0.100000
# [INFO] 10:30:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:27 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:27 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:27 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:27 - CalibrationWorkflow: Self.model updated to online_v16
# [INFO] 10:30:27 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:27 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 10:30:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:29 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 3.7135931062392975e-06, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.00040660000000000034}
# [INFO] 10:30:29 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 10:30:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:29 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:29 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:29 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:29 - CalibrationWorkflow: Self.model updated to online_v17
# [INFO] 10:30:29 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:29 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:32 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 10:30:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:32 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 3.733951522319735e-06, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.00040660000000000034}
# [INFO] 10:30:32 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 10:30:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:32 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:32 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:32 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:32 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:32 - CalibrationWorkflow: Self.model updated to online_v18
# [INFO] 10:30:32 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:32 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:35 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 10:30:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:35 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 2.4006668022535735e-06, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.00038000000000000035}
# [INFO] 10:30:35 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 10:30:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:35 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:35 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:35 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:35 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:35 - CalibrationWorkflow: Self.model updated to online_v19
# [INFO] 10:30:35 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:35 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:37 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 10:30:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:37 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 0.009525010983000758, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.00040660000000000034}
# [INFO] 10:30:37 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000007 < threshold 0.100000
# [INFO] 10:30:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:37 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:37 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:37 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:37 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:37 - CalibrationWorkflow: Self.model updated to online_v20
# [INFO] 10:30:37 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:37 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:40 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 10:30:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:40 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 1.30538508822146e-05, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.00042627963054115813, 'E2FOULING': 0.0003731085698824065}
# [INFO] 10:30:40 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 10:30:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:40 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:40 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:40 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:40 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:40 - CalibrationWorkflow: Self.model updated to online_v21
# [INFO] 10:30:40 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:40 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:43 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 10:30:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:43 - CalibrationWorkflow: Obj Treshold reached with 1 iteration, best cost: 1.749714762987086e-05, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.00038046000000000027, 'E2FOULING': 0.00042522000000000035}
# [INFO] 10:30:43 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 10:30:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:43 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:43 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:43 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:43 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:43 - CalibrationWorkflow: Self.model updated to online_v22
# [INFO] 10:30:43 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:43 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 10:30:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:46 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.5942148034016246e-05, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.00043415042604135287, 'E2FOULING': 0.00037333404273899297}
# [INFO] 10:30:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 10:30:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:46 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:46 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:46 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:46 - CalibrationWorkflow: Self.model updated to online_v23
# [INFO] 10:30:46 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:46 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:48 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 10:30:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:48 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 1.1585180904737484e-05, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.00040660000000000034}
# [INFO] 10:30:48 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 10:30:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:48 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:48 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:48 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:48 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:48 - CalibrationWorkflow: Self.model updated to online_v24
# [INFO] 10:30:48 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:48 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:51 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 10:30:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:51 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 3.448707001404679e-06, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.00040660000000000034}
# [INFO] 10:30:51 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 10:30:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:51 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:51 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:51 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:51 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:51 - CalibrationWorkflow: Self.model updated to online_v25
# [INFO] 10:30:51 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:51 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:54 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 10:30:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:54 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 1.2368069539428975e-05, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.0003921220000000003, 'E2FOULING': 0.00043825400000000033}
# [INFO] 10:30:54 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000007 < threshold 0.100000
# [INFO] 10:30:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:54 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:54 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:54 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:54 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:54 - CalibrationWorkflow: Self.model updated to online_v26
# [INFO] 10:30:54 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:54 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:56 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 10:30:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:56 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 3.861990915764853e-06, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.0003638000000000003, 'E2FOULING': 0.00040660000000000034}
# [INFO] 10:30:57 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000004 < threshold 0.100000
# [INFO] 10:30:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:57 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:57 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:57 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:57 - CalibrationWorkflow: Self.model updated to online_v27
# [INFO] 10:30:57 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:57 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:30:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 10:30:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:59 - CalibrationWorkflow: Obj Treshold reached with 1 iteration, best cost: 1.2858389933401861e-05, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.00038046000000000027, 'E2FOULING': 0.00042522000000000035}
# [INFO] 10:30:59 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 10:30:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:59 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:30:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:30:59 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:30:59 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:30:59 - CalibrationWorkflow: Self.model updated to online_v28
# [INFO] 10:30:59 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:30:59 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:31:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 29 of 529.
# [INFO] 10:31:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:02 - CalibrationWorkflow: Obj Treshold reached with 0 iteration, best cost: 3.1299295277129412e-06, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.00034000000000000024, 'E2FOULING': 0.00038000000000000035}
# [INFO] 10:31:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 10:31:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:31:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:02 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:31:02 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:31:02 - CalibrationWorkflow: Self.model updated to online_v29
# [INFO] 10:31:02 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:31:02 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:31:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 30 of 529.
# [INFO] 10:31:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:05 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.12253191255106, values: {'FEED1MASSFLOW': 18170.33282487203, 'FEED1TEMP': 24.88142490999688, 'PROD1MASSFLOW': 45110.96621847873, 'PROD1TEMP': 115.0679318499356, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 10:31:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 10:31:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:05 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:31:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:05 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:31:05 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:31:05 - CalibrationWorkflow: Self.model updated to online_v30
# [INFO] 10:31:05 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:31:05 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:31:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:07 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 31 of 529.
# [INFO] 10:31:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:08 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.1537179451035144, values: {'FEED1MASSFLOW': 18607.84387976851, 'FEED1TEMP': 25.14488217461214, 'PROD1MASSFLOW': 43738.61199857389, 'PROD1TEMP': 115.3747174316839, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 10:31:08 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 10:31:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:08 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:31:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:08 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:31:08 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:31:08 - CalibrationWorkflow: Self.model updated to online_v31
# [INFO] 10:31:08 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:31:08 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:31:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:10 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 32 of 529.
# [INFO] 10:31:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:10 - CalibrationWorkflow: Treshold reached with 4 iteration, best cost: 0.11602043780663399, values: {'FEED1MASSFLOW': 19115.08117402765, 'FEED1TEMP': 24.77391698651811, 'PROD1MASSFLOW': 42751.55908633373, 'PROD1TEMP': 115.3524481338415, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 10:31:10 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 10:31:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:10 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:31:10 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:10 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:31:10 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:31:10 - CalibrationWorkflow: Self.model updated to online_v32
# [INFO] 10:31:10 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:31:10 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:31:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 33 of 529.
# [INFO] 10:31:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:13 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.04414077460582845, values: {'FEED1MASSFLOW': 19418.03437168451, 'FEED1TEMP': 25.0300579250388, 'PROD1MASSFLOW': 43087.88928120025, 'PROD1TEMP': 114.4650169900805, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 10:31:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 10:31:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:31:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:13 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:31:13 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:31:13 - CalibrationWorkflow: Self.model updated to online_v33
# [INFO] 10:31:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:31:13 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:31:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:31:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 34 of 529.
# ...
# [INFO] 10:56:43 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:56:43 - CalibrationWorkflow: Self.model updated to online_v519
# [INFO] 10:56:43 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:56:43 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:56:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:45 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 10:56:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:45 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 1.681852032578071e-05, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.0003921220000000003, 'E2FOULING': 0.00043825400000000033}
# [INFO] 10:56:45 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.129738 > threshold: 0.1
# [INFO] 10:56:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:45 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 10:56:45 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:50 - CalibrationWorkflow: Obj Treshold reached with 2 iteration, best cost: 0.0727817923192746, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.00041106720458111327, 'E2FOULING': 0.00046557881429968255}
# [INFO] 10:56:50 - CalibrationWorkflow: Working point is accurate enough with cost: 0.072782 < threshold 0.100000
# [INFO] 10:56:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:50 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:56:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:50 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 10:56:50 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:56:50 - CalibrationWorkflow: Self.model updated to online_v520
# [INFO] 10:56:50 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:56:50 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 10:56:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:53 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 10:56:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:53 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.0750194664038224e-05, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.00044780635199765176, 'E2FOULING': 0.00046538954919990823}
# [INFO] 10:56:53 - CalibrationWorkflow: Working point is accurate enough with cost: 0.051873 < threshold 0.100000
# [INFO] 10:56:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:53 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:56:53 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:53 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:56:53 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:56:53 - CalibrationWorkflow: Self.model updated to online_v521
# [INFO] 10:56:53 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:56:53 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:56:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:56 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 10:56:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:56 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 4.754547080109917e-06, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.000531745323711062, 'E2FOULING': 0.0004305423440357936}
# [INFO] 10:56:56 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000006 < threshold 0.100000
# [INFO] 10:56:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:56 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:56:56 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:56 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:56:56 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:56:56 - CalibrationWorkflow: Self.model updated to online_v522
# [INFO] 10:56:56 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:56:56 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:56:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:59 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 10:56:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:59 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.009442314358394809, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0004517033336924677, 'E2FOULING': 0.00036330749989002347}
# [INFO] 10:56:59 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.123052 > threshold: 0.1
# [INFO] 10:56:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:56:59 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 10:56:59 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:06 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.04580795493224022, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.0004612464966554006, 'E2FOULING': 0.000484506794053332}
# [INFO] 10:57:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.045808 < threshold 0.100000
# [INFO] 10:57:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:06 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:57:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:06 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 10:57:06 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:57:06 - CalibrationWorkflow: Self.model updated to online_v523
# [INFO] 10:57:06 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:57:06 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 10:57:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 10:57:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:09 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 1.5127839454739444e-05, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0005136657552676085, 'E2FOULING': 0.00040900837721658017}
# [INFO] 10:57:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 10:57:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:09 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:57:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:09 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:57:09 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:57:09 - CalibrationWorkflow: Self.model updated to online_v524
# [INFO] 10:57:09 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:57:09 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:57:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:12 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 10:57:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:12 - CalibrationWorkflow: Obj Treshold reached with 1 iteration, best cost: 1.5151573165097321e-05, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00038046000000000027, 'E2FOULING': 0.00042522000000000035}
# [INFO] 10:57:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.063687 < threshold 0.100000
# [INFO] 10:57:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:57:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:12 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:57:12 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:57:12 - CalibrationWorkflow: Self.model updated to online_v525
# [INFO] 10:57:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:57:12 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:57:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 10:57:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:14 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.4800271213413636e-05, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.00045367681007069387, 'E2FOULING': 0.00043368472747025845}
# [INFO] 10:57:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 10:57:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:57:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:15 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:57:15 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:57:15 - CalibrationWorkflow: Self.model updated to online_v526
# [INFO] 10:57:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:57:15 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:57:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:17 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 10:57:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:17 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 6.1296890276807045e-06, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0005135686060589512, 'E2FOULING': 0.00041565031403598547}
# [INFO] 10:57:17 - CalibrationWorkflow: Working point is accurate enough with cost: 0.013004 < threshold 0.100000
# [INFO] 10:57:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:17 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:57:17 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:17 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:57:17 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:57:17 - CalibrationWorkflow: Self.model updated to online_v527
# [INFO] 10:57:17 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:57:17 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:57:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:20 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 10:57:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:20 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.165104103182729e-05, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0005527229270004214, 'E2FOULING': 0.0005328152870907045}
# [INFO] 10:57:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.050513 < threshold 0.100000
# [INFO] 10:57:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:20 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:57:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:20 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:57:20 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:57:20 - CalibrationWorkflow: Self.model updated to online_v528
# [INFO] 10:57:20 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:57:20 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:57:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:23 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 10:57:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:23 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.9779202921057834e-05, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0005060867859231347, 'E2FOULING': 0.0004124113292131195}
# [INFO] 10:57:23 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000002 < threshold 0.100000
# [INFO] 10:57:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:23 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 10:57:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 10:57:23 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 10:57:23 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 10:57:23 - CalibrationWorkflow: Self.model updated to online_v529
# [INFO] 10:57:23 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 10:57:23 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 10:57:26 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/06_Calibration_Online_FNN-high_always-one-noreplay.xlsx')
# Out:
# [INFO] 10:58:08 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_always-one-noreplay.xlsx

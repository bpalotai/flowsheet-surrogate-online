# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

import os
relative_path = "../__Fitting_Drivers/"
absolute_path = os.path.abspath(relative_path)

import sys
import time
import json
from tqdm import tqdm

sys.path.append(absolute_path)

# %%
process_data = pd.read_excel('../01_DataCollecting/Sim_result/Heat_exchanger_process_data_result_V5-short.xlsx', index_col=0)
process_data.reset_index(drop=True, inplace=True)

training_data = pd.read_excel('../02_Base_Surrogate_Training/Adaptive_train_data.xlsx', index_col=0)
training_data.reset_index(drop=True, inplace=True)

#direct_calibration = pd.read_excel('../03_Calibration_offline/Results/Direct_sim/Direct_Calibration_result_offline.xlsx', index_col=0)

# %%
from CalibrationWorkflow_driver import CalibrationWorkflow

# %%
y_fitt = {'PROD1E1IN': {'Weight': 1, 'SDEV':1},
  'PROD1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1E1OUT': {'Weight': 1, 'SDEV':1},
  'FEED1OUT': {'Weight': 1, 'SDEV':1}}

absminfouling = 0.00025
absmaxfouling = 0.002936
# minimum hard limit az optimizernek , 'E1FOULING': (0.00025, 0.002936)
fitparamlimit = {'E1FOULING': {'min':absminfouling, 'max':absmaxfouling}, 'E2FOULING': {'min':absminfouling, 'max':absmaxfouling}}

# %%
# Simulation Cols mapping
cols_mapping = {'InputParams': {'FEED1MASSFLOW': 'C3', 'FEED1TEMP': 'C4','PROD1MASSFLOW': 'C5','PROD1TEMP': 'C6',
                          'E1FOULING': 'C11', 'E2FOULING': 'C15'},
               'OutputParams': {'PROD1E1IN': 'C3', 'PROD1OUT': 'C4', 'FEED1E1OUT': 'C7', 'FEED1OUT': 'C8'},
               'Outputuoms': {'PROD1E1IN': 'C', 'PROD1OUT': 'C', 'FEED1E1OUT': 'C', 'FEED1OUT': 'C'}
               }

        # always-one: If direct calibration data exists and is accurate, use that; else use validation data if accurate.
        # always-both: Use both validation and direct calibration data if available and accurate.
        # conditional: Only use direct calibration data if it exists and is accurate.
workflow_settings = {'calibration_type': 'online', # direct, surrogate, online
                     'run_direct_for_not_accurate': True,
                     'stop_workingpoint' : None, # None 
                     'workflow_random_seed': None, # None
                     'debug_workflow': False,
                     'sim_validation_treshold' : 0.1, # None
                     'base_calibration_error_factor': 0.1,
                     'point_selection_type': 'always-one',  # always-one, always-both, conditional
                     'logging_level': 'INFO',  # DEBUG, INFO, WARNING, ERROR, CRITICAL
                     }
calibration_settings = {'y_fitt': y_fitt,
                        'fitparamlimit': fitparamlimit,
                        'particle_num': 20,
                        'optim_iterations': 100,
                        'c1' : 0.1,
                        'c2' : 0.4,
                        'w': 0.7,
                        'stopping_treshold' : 0.0001,
                        'stopping_obj' : 0.1,
                        'optim_debug' : False,
                        }

simulation_model_setting = { 'hy_filename' : '../00_Modell_database/Simulation/SampleModel_V2.hsc',
                            'cols_mapping' : cols_mapping, 
                            'resultindict' : True, 
                            }

surrogate_model_settings = {'load_path' : '../00_Modell_database/AdaptivedatFNN/sklearnann.joblib'}

online_learning_settings = {'batch_size': 1, 'replay_ratio': 0, 'retrain_scaler': False}

# %%
# Initialize the calibration workflow with the provided settings and models
workflow = CalibrationWorkflow(process_data, workflow_settings = workflow_settings, calibration_settings=calibration_settings)
workflow.set_simulation_model(simulation_model_setting = simulation_model_setting)
workflow.set_surrogate_model(surrogate_model_settings = surrogate_model_settings)
workflow.init_models()
workflow.init_online_learning(training_data, **online_learning_settings)
# Out:
# [INFO] 23:25:29 - CalibrationWorkflow: Simulation model is initialized, and model loaded from: SampleModel_V2.hsc
# [INFO] 23:25:29 - CalibrationWorkflow: Surrogate model is initialized from: ../00_Modell_database/AdaptivedatFNN/sklearnann.joblib
# [INFO] 23:25:29 - CalibrationWorkflow: Online learning initialized with surrogate model and settings : {'batch_size': 1, 'replay_ratio': 0, 'retrain_scaler': False}

# %%
workflow.run_calibration()
# Out:
# [INFO] 23:25:30 - CalibrationWorkflow:
# ============================================================
# [INFO] 23:25:30 - CalibrationWorkflow: STARTING CALIBRATION WORKFLOW.
# [INFO] 23:25:30 - CalibrationWorkflow: ============================================================
#
# [INFO] 23:25:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:30 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 0 of 529.
# [INFO] 23:25:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:30 - CalibrationWorkflow: Treshold reached with 5 iteration, best cost: 0.01146311158719026, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 23:25:30 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.450269 > threshold: 0.1
# [INFO] 23:25:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:30 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:25:30 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:46 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 0.04132947523048566, values: {'FEED1MASSFLOW': 18035.53430133957, 'FEED1TEMP': 25.25656349837262, 'PROD1MASSFLOW': 45159.7172098537, 'PROD1TEMP': 116.5605783388438, 'E1FOULING': 0.0003537430082171358, 'E2FOULING': 0.0005792345834381607}
# [INFO] 23:25:46 - CalibrationWorkflow: Working point is accurate enough with cost: 0.041329 < threshold 0.100000
# [INFO] 23:25:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:46 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:25:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:46 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:25:46 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:25:46 - CalibrationWorkflow: Self.model updated to online_v0
# [INFO] 23:25:46 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:25:46 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:25:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:46 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 1 of 529.
# [INFO] 23:25:46 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:47 - CalibrationWorkflow: Treshold reached with 11 iteration, best cost: 0.010537424562902967, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.0002500950014680545, 'E2FOULING': 0.00025}
# [INFO] 23:25:47 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.321476 > threshold: 0.1
# [INFO] 23:25:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:47 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:25:47 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:57 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 0.07510658010688076, values: {'FEED1MASSFLOW': 17885.82338340906, 'FEED1TEMP': 25.10209144360454, 'PROD1MASSFLOW': 45784.42355995381, 'PROD1TEMP': 112.4047556463791, 'E1FOULING': 0.000391525268295547, 'E2FOULING': 0.0005980711817562426}
# [INFO] 23:25:57 - CalibrationWorkflow: Working point is accurate enough with cost: 0.075107 < threshold 0.100000
# [INFO] 23:25:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:57 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:25:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:57 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:25:57 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:25:57 - CalibrationWorkflow: Self.model updated to online_v1
# [INFO] 23:25:57 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:25:57 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:25:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:57 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 2 of 529.
# [INFO] 23:25:57 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:58 - CalibrationWorkflow: Treshold reached with 12 iteration, best cost: 0.012210077163746063, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.00025, 'E2FOULING': 0.00025}
# [INFO] 23:25:58 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.298592 > threshold: 0.1
# [INFO] 23:25:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:25:58 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:25:58 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:11 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.08606200504985201, values: {'FEED1MASSFLOW': 18346.78716534058, 'FEED1TEMP': 24.39474639961635, 'PROD1MASSFLOW': 43968.7644161378, 'PROD1TEMP': 114.9850130448022, 'E1FOULING': 0.0003549714320335702, 'E2FOULING': 0.0005749374794448091}
# [INFO] 23:26:11 - CalibrationWorkflow: Working point is accurate enough with cost: 0.086062 < threshold 0.100000
# [INFO] 23:26:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:11 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:11 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:26:11 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:11 - CalibrationWorkflow: Self.model updated to online_v2
# [INFO] 23:26:11 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:11 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:26:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:11 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 3 of 529.
# [INFO] 23:26:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:11 - CalibrationWorkflow: Obj Treshold reached with 14 iteration, best cost: 1.7749898559941774e-05, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.00033759494849339356, 'E2FOULING': 0.00025}
# [INFO] 23:26:11 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.168371 > threshold: 0.1
# [INFO] 23:26:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:11 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:26:11 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:19 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 8.511685684953932e-06, values: {'FEED1MASSFLOW': 18031.97789720889, 'FEED1TEMP': 25.37707320881815, 'PROD1MASSFLOW': 44989.79188359602, 'PROD1TEMP': 114.7011892797068, 'E1FOULING': 0.0003997094866101071, 'E2FOULING': 0.00036901820576824054}
# [INFO] 23:26:19 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 23:26:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:19 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:19 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:19 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:26:19 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:19 - CalibrationWorkflow: Self.model updated to online_v3
# [INFO] 23:26:19 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:19 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:26:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:20 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 4 of 529.
# [INFO] 23:26:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:20 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 8.660520030198846e-06, values: {'FEED1MASSFLOW': 18402.51470121294, 'FEED1TEMP': 25.30051362002577, 'PROD1MASSFLOW': 44746.73347561211, 'PROD1TEMP': 113.1770821822774, 'E1FOULING': 0.0002943595652746584, 'E2FOULING': 0.00035651695268401466}
# [INFO] 23:26:20 - CalibrationWorkflow: Working point is accurate enough with cost: 0.072964 < threshold 0.100000
# [INFO] 23:26:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:20 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:20 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:20 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:20 - CalibrationWorkflow: Self.model updated to online_v4
# [INFO] 23:26:20 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:20 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:20 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 5 of 529.
# [INFO] 23:26:20 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:21 - CalibrationWorkflow: Obj Treshold reached with 14 iteration, best cost: 1.364423812270691e-05, values: {'FEED1MASSFLOW': 17997.59317952945, 'FEED1TEMP': 25.09644354590142, 'PROD1MASSFLOW': 45134.36548487598, 'PROD1TEMP': 113.652920791493, 'E1FOULING': 0.0003203966936970348, 'E2FOULING': 0.0002852497290224504}
# [INFO] 23:26:21 - CalibrationWorkflow: Working point is accurate enough with cost: 0.089944 < threshold 0.100000
# [INFO] 23:26:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:21 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:21 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:21 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:21 - CalibrationWorkflow: Self.model updated to online_v5
# [INFO] 23:26:21 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:21 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:21 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 6 of 529.
# [INFO] 23:26:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:21 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.1537117551397288e-05, values: {'FEED1MASSFLOW': 18084.65614134908, 'FEED1TEMP': 24.80421915636417, 'PROD1MASSFLOW': 43467.83433646649, 'PROD1TEMP': 112.7850379729959, 'E1FOULING': 0.000362318670590994, 'E2FOULING': 0.0004237765382278973}
# [INFO] 23:26:21 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000007 < threshold 0.100000
# [INFO] 23:26:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:21 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:21 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:21 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:21 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:21 - CalibrationWorkflow: Self.model updated to online_v6
# [INFO] 23:26:21 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:21 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 7 of 529.
# [INFO] 23:26:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:22 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 9.311554436370515e-06, values: {'FEED1MASSFLOW': 18477.7006531532, 'FEED1TEMP': 25.12975535877417, 'PROD1MASSFLOW': 43395.45933686732, 'PROD1TEMP': 112.475242789803, 'E1FOULING': 0.00046129884550549083, 'E2FOULING': 0.00044918910662573224}
# [INFO] 23:26:22 - CalibrationWorkflow: Working point is accurate enough with cost: 0.010935 < threshold 0.100000
# [INFO] 23:26:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:22 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:22 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:22 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:22 - CalibrationWorkflow: Self.model updated to online_v7
# [INFO] 23:26:22 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:22 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:22 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 8 of 529.
# [INFO] 23:26:22 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:23 - CalibrationWorkflow: Treshold reached with 46 iteration, best cost: 0.01585791004401774, values: {'FEED1MASSFLOW': 18520.4937017785, 'FEED1TEMP': 25.86541371420142, 'PROD1MASSFLOW': 44076.70141489332, 'PROD1TEMP': 114.4533322335381, 'E1FOULING': 0.00038407017178003006, 'E2FOULING': 0.0004526718436330195}
# [INFO] 23:26:23 - CalibrationWorkflow: Working point is accurate enough with cost: 0.021861 < threshold 0.100000
# [INFO] 23:26:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:23 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:23 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:23 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:23 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:23 - CalibrationWorkflow: Self.model updated to online_v8
# [INFO] 23:26:23 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:23 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:24 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 9 of 529.
# [INFO] 23:26:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:24 - CalibrationWorkflow: Obj Treshold reached with 14 iteration, best cost: 8.43832733422151e-06, values: {'FEED1MASSFLOW': 18660.3907132854, 'FEED1TEMP': 26.07873635582999, 'PROD1MASSFLOW': 44200.01152429615, 'PROD1TEMP': 117.9005876329935, 'E1FOULING': 0.0003859918404581203, 'E2FOULING': 0.0005232244259694784}
# [INFO] 23:26:24 - CalibrationWorkflow: Working point is accurate enough with cost: 0.020807 < threshold 0.100000
# [INFO] 23:26:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:24 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:24 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:24 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:24 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:24 - CalibrationWorkflow: Self.model updated to online_v9
# [INFO] 23:26:24 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:24 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 10 of 529.
# [INFO] 23:26:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:25 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.2535009088039252e-05, values: {'FEED1MASSFLOW': 18876.91740213866, 'FEED1TEMP': 25.32153833506365, 'PROD1MASSFLOW': 43435.74620706195, 'PROD1TEMP': 112.9838429049392, 'E1FOULING': 0.00043553612300447015, 'E2FOULING': 0.0006010725168805661}
# [INFO] 23:26:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.086017 < threshold 0.100000
# [INFO] 23:26:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:25 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:25 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:25 - CalibrationWorkflow: Self.model updated to online_v10
# [INFO] 23:26:25 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:25 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:25 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 11 of 529.
# [INFO] 23:26:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:25 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.1191173498629504e-05, values: {'FEED1MASSFLOW': 18643.14411539117, 'FEED1TEMP': 25.3554302638567, 'PROD1MASSFLOW': 44143.5770076145, 'PROD1TEMP': 111.7603373062146, 'E1FOULING': 0.0004459740352778258, 'E2FOULING': 0.0005185748427353535}
# [INFO] 23:26:25 - CalibrationWorkflow: Working point is accurate enough with cost: 0.034602 < threshold 0.100000
# [INFO] 23:26:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:25 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:25 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:25 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:25 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:25 - CalibrationWorkflow: Self.model updated to online_v11
# [INFO] 23:26:25 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:25 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 12 of 529.
# [INFO] 23:26:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:26 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 7.600265558620387e-06, values: {'FEED1MASSFLOW': 18446.06149612611, 'FEED1TEMP': 25.62626459235253, 'PROD1MASSFLOW': 43697.93498948791, 'PROD1TEMP': 111.1194481981285, 'E1FOULING': 0.00044776437507207595, 'E2FOULING': 0.0005348085398420103}
# [INFO] 23:26:26 - CalibrationWorkflow: Working point is accurate enough with cost: 0.059508 < threshold 0.100000
# [INFO] 23:26:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:26 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:26 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:26 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:26 - CalibrationWorkflow: Self.model updated to online_v12
# [INFO] 23:26:26 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:26 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:26 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 13 of 529.
# [INFO] 23:26:26 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:27 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 3.337589778474612e-06, values: {'FEED1MASSFLOW': 18668.05296991525, 'FEED1TEMP': 25.61921279497917, 'PROD1MASSFLOW': 44385.96507603588, 'PROD1TEMP': 113.279785633648, 'E1FOULING': 0.0004303954910942461, 'E2FOULING': 0.0005426361853269072}
# [INFO] 23:26:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.064787 < threshold 0.100000
# [INFO] 23:26:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:27 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:27 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:27 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:27 - CalibrationWorkflow: Self.model updated to online_v13
# [INFO] 23:26:27 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:27 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:27 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 14 of 529.
# [INFO] 23:26:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:27 - CalibrationWorkflow: Obj Treshold reached with 12 iteration, best cost: 1.1343007665778956e-05, values: {'FEED1MASSFLOW': 18352.78321601855, 'FEED1TEMP': 25.55705958189525, 'PROD1MASSFLOW': 44385.20797493326, 'PROD1TEMP': 112.3261641092777, 'E1FOULING': 0.0005983092909543252, 'E2FOULING': 0.0004526605612640119}
# [INFO] 23:26:27 - CalibrationWorkflow: Working point is accurate enough with cost: 0.069514 < threshold 0.100000
# [INFO] 23:26:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:27 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:27 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:27 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:27 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:27 - CalibrationWorkflow: Self.model updated to online_v14
# [INFO] 23:26:27 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:27 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 15 of 529.
# [INFO] 23:26:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:28 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 1.3596519552441225e-05, values: {'FEED1MASSFLOW': 17825.13415797469, 'FEED1TEMP': 25.40114138598801, 'PROD1MASSFLOW': 43081.58696077522, 'PROD1TEMP': 112.5128205432028, 'E1FOULING': 0.00035325559551944454, 'E2FOULING': 0.0004416193104576302}
# [INFO] 23:26:28 - CalibrationWorkflow: Working point is accurate enough with cost: 0.013363 < threshold 0.100000
# [INFO] 23:26:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:28 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:28 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:28 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:28 - CalibrationWorkflow: Self.model updated to online_v15
# [INFO] 23:26:28 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:28 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:28 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 16 of 529.
# [INFO] 23:26:28 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:28 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.006805008465500883, values: {'FEED1MASSFLOW': 18323.7838842099, 'FEED1TEMP': 25.65096336878833, 'PROD1MASSFLOW': 43175.32284352887, 'PROD1TEMP': 113.6133450881955, 'E1FOULING': 0.000317541625278212, 'E2FOULING': 0.00041783836868181833}
# [INFO] 23:26:29 - CalibrationWorkflow: Working point is accurate enough with cost: 0.034608 < threshold 0.100000
# [INFO] 23:26:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:29 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:29 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:26:29 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:29 - CalibrationWorkflow: Self.model updated to online_v16
# [INFO] 23:26:29 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:29 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:26:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:29 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 17 of 529.
# [INFO] 23:26:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:29 - CalibrationWorkflow: Treshold reached with 14 iteration, best cost: 0.03266986634609315, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.0002594871634314594, 'E2FOULING': 0.0005478269680788784}
# [INFO] 23:26:29 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.132796 > threshold: 0.1
# [INFO] 23:26:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:29 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:26:29 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:38 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 0.08327924371826809, values: {'FEED1MASSFLOW': 18448.8180474298, 'FEED1TEMP': 25.95915441923967, 'PROD1MASSFLOW': 42914.58187645639, 'PROD1TEMP': 110.1333518383596, 'E1FOULING': 0.0003818474505133979, 'E2FOULING': 0.0006715429104224365}
# [INFO] 23:26:38 - CalibrationWorkflow: Working point is accurate enough with cost: 0.083279 < threshold 0.100000
# [INFO] 23:26:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:38 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:38 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:26:38 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:38 - CalibrationWorkflow: Self.model updated to online_v17
# [INFO] 23:26:38 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:38 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:26:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:38 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 18 of 529.
# [INFO] 23:26:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:38 - CalibrationWorkflow: Treshold reached with 2 iteration, best cost: 0.4407731843508193, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.0005507231628961578, 'E2FOULING': 0.0010463740095027006}
# [INFO] 23:26:38 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.692578 > threshold: 0.1
# [INFO] 23:26:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:38 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:26:38 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:49 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.03435704124339619, values: {'FEED1MASSFLOW': 18643.62100452733, 'FEED1TEMP': 26.36254471307676, 'PROD1MASSFLOW': 43218.13320937832, 'PROD1TEMP': 111.6540844028967, 'E1FOULING': 0.00034912113829449514, 'E2FOULING': 0.0005869912424862019}
# [INFO] 23:26:49 - CalibrationWorkflow: Working point is accurate enough with cost: 0.034357 < threshold 0.100000
# [INFO] 23:26:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:49 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:26:49 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:49 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:26:49 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:26:49 - CalibrationWorkflow: Self.model updated to online_v18
# [INFO] 23:26:49 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:26:49 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:26:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:50 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 19 of 529.
# [INFO] 23:26:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:50 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.3446128105346351e-05, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.00027080213117930705, 'E2FOULING': 0.00033186667894658986}
# [INFO] 23:26:50 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.113663 > threshold: 0.1
# [INFO] 23:26:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:26:50 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:26:50 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:00 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.057120289990990586, values: {'FEED1MASSFLOW': 18744.7944771309, 'FEED1TEMP': 26.35817937206048, 'PROD1MASSFLOW': 42607.96578096438, 'PROD1TEMP': 112.847140926355, 'E1FOULING': 0.0003769812606669284, 'E2FOULING': 0.0005594591395528354}
# [INFO] 23:27:00 - CalibrationWorkflow: Working point is accurate enough with cost: 0.057120 < threshold 0.100000
# [INFO] 23:27:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:00 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:00 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:27:00 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:27:00 - CalibrationWorkflow: Self.model updated to online_v19
# [INFO] 23:27:00 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:27:00 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:27:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:00 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 20 of 529.
# [INFO] 23:27:00 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:01 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 7.145694320075438e-06, values: {'FEED1MASSFLOW': 19093.09301159911, 'FEED1TEMP': 25.70392235640197, 'PROD1MASSFLOW': 43358.5103467333, 'PROD1TEMP': 110.4620252731733, 'E1FOULING': 0.0003706914593876179, 'E2FOULING': 0.00043364782016352396}
# [INFO] 23:27:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 23:27:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:01 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:27:01 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:27:01 - CalibrationWorkflow: Self.model updated to online_v20
# [INFO] 23:27:01 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:27:01 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:27:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:01 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 21 of 529.
# [INFO] 23:27:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:01 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 1.1108183695722112e-05, values: {'FEED1MASSFLOW': 19376.26054987276, 'FEED1TEMP': 25.79169028302191, 'PROD1MASSFLOW': 42439.9668315721, 'PROD1TEMP': 108.9364290967066, 'E1FOULING': 0.0004170602960884656, 'E2FOULING': 0.0003658387180692697}
# [INFO] 23:27:01 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000000 < threshold 0.100000
# [INFO] 23:27:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:01 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:01 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:01 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:27:01 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:27:01 - CalibrationWorkflow: Self.model updated to online_v21
# [INFO] 23:27:01 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:27:01 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 22 of 529.
# [INFO] 23:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:02 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 5.716689234041775e-06, values: {'FEED1MASSFLOW': 19984.60202471443, 'FEED1TEMP': 26.19424569430545, 'PROD1MASSFLOW': 42809.9985829119, 'PROD1TEMP': 111.4971787385278, 'E1FOULING': 0.0003681461654915848, 'E2FOULING': 0.0002723901695466446}
# [INFO] 23:27:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.058661 < threshold 0.100000
# [INFO] 23:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:02 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:27:02 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:27:02 - CalibrationWorkflow: Self.model updated to online_v22
# [INFO] 23:27:02 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:27:02 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 23 of 529.
# [INFO] 23:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:02 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 0.00704938420946978, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.0003581222412386214, 'E2FOULING': 0.00025}
# [INFO] 23:27:02 - CalibrationWorkflow: Working point is NOT accurate enough with cost: 0.117547 > threshold: 0.1
# [INFO] 23:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:02 - CalibrationWorkflow: [DIRECT-CALIBRATION] Running direct calibration as working point is not accurate enough.
# [INFO] 23:27:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:12 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 0.012693902994898287, values: {'FEED1MASSFLOW': 18501.68187251517, 'FEED1TEMP': 25.92673010020582, 'PROD1MASSFLOW': 42474.81369223073, 'PROD1TEMP': 112.4588072683434, 'E1FOULING': 0.0004151172119217883, 'E2FOULING': 0.0005094722394362246}
# [INFO] 23:27:12 - CalibrationWorkflow: Working point is accurate enough with cost: 0.012694 < threshold 0.100000
# [INFO] 23:27:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:12 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:12 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:12 - CalibrationWorkflow: Selected point for online learning: direct_calibration
# [INFO] 23:27:12 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:27:12 - CalibrationWorkflow: Self.model updated to online_v23
# [INFO] 23:27:12 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:27:12 - CalibrationWorkflow: New data point (direct_calibration) added for online learning.
# [INFO] 23:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 24 of 529.
# [INFO] 23:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:13 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 8.920696018251849e-06, values: {'FEED1MASSFLOW': 19030.92044076275, 'FEED1TEMP': 25.56435287862604, 'PROD1MASSFLOW': 43629.59739779926, 'PROD1TEMP': 110.3347767491657, 'E1FOULING': 0.0003586700074369429, 'E2FOULING': 0.0003834706741261155}
# [INFO] 23:27:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000007 < threshold 0.100000
# [INFO] 23:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:13 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:27:13 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:27:13 - CalibrationWorkflow: Self.model updated to online_v24
# [INFO] 23:27:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:27:13 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:13 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 25 of 529.
# [INFO] 23:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:13 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 7.118666249981454e-06, values: {'FEED1MASSFLOW': 19058.28497897546, 'FEED1TEMP': 25.73663828801682, 'PROD1MASSFLOW': 42271.77494918703, 'PROD1TEMP': 109.0630417181647, 'E1FOULING': 0.0003987339295235407, 'E2FOULING': 0.0003356985561337361}
# [INFO] 23:27:13 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000012 < threshold 0.100000
# [INFO] 23:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:13 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:13 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:13 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:27:13 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:27:13 - CalibrationWorkflow: Self.model updated to online_v25
# [INFO] 23:27:13 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:27:13 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 26 of 529.
# [INFO] 23:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:14 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 2.69425694533296e-06, values: {'FEED1MASSFLOW': 19187.12580348476, 'FEED1TEMP': 25.83138351642461, 'PROD1MASSFLOW': 41933.45878194667, 'PROD1TEMP': 110.8411747166131, 'E1FOULING': 0.00039149280256507127, 'E2FOULING': 0.0002893625033181628}
# [INFO] 23:27:14 - CalibrationWorkflow: Working point is accurate enough with cost: 0.026052 < threshold 0.100000
# [INFO] 23:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:14 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:14 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:27:14 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:27:14 - CalibrationWorkflow: Self.model updated to online_v26
# [INFO] 23:27:14 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:27:14 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:14 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 27 of 529.
# [INFO] 23:27:14 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:15 - CalibrationWorkflow: Obj Treshold reached with 6 iteration, best cost: 2.699662657016158e-06, values: {'FEED1MASSFLOW': 19289.04705748388, 'FEED1TEMP': 25.64690489901984, 'PROD1MASSFLOW': 42441.01211194655, 'PROD1TEMP': 110.7269340538833, 'E1FOULING': 0.0003319536752963505, 'E2FOULING': 0.00025}
# [INFO] 23:27:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.080728 < threshold 0.100000
# [INFO] 23:27:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:15 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:27:15 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:27:15 - CalibrationWorkflow: Self.model updated to online_v27
# [INFO] 23:27:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:27:15 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:27:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:15 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 28 of 529.
# [INFO] 23:27:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:15 - CalibrationWorkflow: Obj Treshold reached with 3 iteration, best cost: 4.292446530461072e-06, values: {'FEED1MASSFLOW': 18891.3848624232, 'FEED1TEMP': 24.96283642907302, 'PROD1MASSFLOW': 42503.71988242067, 'PROD1TEMP': 108.431715841819, 'E1FOULING': 0.0003884473234872397, 'E2FOULING': 0.00036884247854730246}
# [INFO] 23:27:15 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000010 < threshold 0.100000
# [INFO] 23:27:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:15 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:15 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:15 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:27:15 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:27:15 - CalibrationWorkflow: Self.model updated to online_v28
# [INFO] 23:27:15 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:27:15 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:27:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:16 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 29 of 529.
# [INFO] 23:27:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:16 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 7.064823725827571e-06, values: {'FEED1MASSFLOW': 19179.27177336458, 'FEED1TEMP': 25.81663579622885, 'PROD1MASSFLOW': 42499.26412259203, 'PROD1TEMP': 108.1809334461259, 'E1FOULING': 0.00039694438628127437, 'E2FOULING': 0.0004569873193528574}
# [INFO] 23:27:16 - CalibrationWorkflow: Working point is accurate enough with cost: 0.010243 < threshold 0.100000
# [INFO] 23:27:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:16 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:27:16 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:27:16 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:27:16 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:27:16 - CalibrationWorkflow: Self.model updated to online_v29
# [INFO] 23:27:16 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# ...
# [INFO] 23:35:01 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:35:01 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:35:01 - CalibrationWorkflow: Self.model updated to online_v518
# [INFO] 23:35:01 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:35:01 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:35:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 519 of 529.
# [INFO] 23:35:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:02 - CalibrationWorkflow: Obj Treshold reached with 7 iteration, best cost: 3.973751289143896e-06, values: {'FEED1MASSFLOW': 13460.09377708731, 'FEED1TEMP': 19.95931033374501, 'PROD1MASSFLOW': 34971.30267683078, 'PROD1TEMP': 127.1980712324164, 'E1FOULING': 0.0005247019346970318, 'E2FOULING': 0.0005589613448376185}
# [INFO] 23:35:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000008 < threshold 0.100000
# [INFO] 23:35:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:35:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:02 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:35:02 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:35:02 - CalibrationWorkflow: Self.model updated to online_v519
# [INFO] 23:35:02 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:35:02 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:35:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:02 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 520 of 529.
# [INFO] 23:35:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:02 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.2549237782950828e-05, values: {'FEED1MASSFLOW': 13357.31646310376, 'FEED1TEMP': 20.08680420753544, 'PROD1MASSFLOW': 34161.71213644301, 'PROD1TEMP': 128.528287133596, 'E1FOULING': 0.0004370401040466567, 'E2FOULING': 0.0005692197041172871}
# [INFO] 23:35:02 - CalibrationWorkflow: Working point is accurate enough with cost: 0.032050 < threshold 0.100000
# [INFO] 23:35:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:02 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:35:02 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:02 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:35:02 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:35:02 - CalibrationWorkflow: Self.model updated to online_v520
# [INFO] 23:35:02 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:35:02 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:35:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:03 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 521 of 529.
# [INFO] 23:35:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:03 - CalibrationWorkflow: Obj Treshold reached with 10 iteration, best cost: 0.009348392041578946, values: {'FEED1MASSFLOW': 13225.12340268073, 'FEED1TEMP': 20.25756341527094, 'PROD1MASSFLOW': 33850.6749054734, 'PROD1TEMP': 130.5456040212975, 'E1FOULING': 0.00046737239954614364, 'E2FOULING': 0.0005042739026485151}
# [INFO] 23:35:03 - CalibrationWorkflow: Working point is accurate enough with cost: 0.030839 < threshold 0.100000
# [INFO] 23:35:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:03 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:35:03 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:03 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:35:03 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:35:03 - CalibrationWorkflow: Self.model updated to online_v521
# [INFO] 23:35:03 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:35:03 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:35:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 522 of 529.
# [INFO] 23:35:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:04 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 0.007033264063984516, values: {'FEED1MASSFLOW': 13474.94756791568, 'FEED1TEMP': 20.0405339372923, 'PROD1MASSFLOW': 34108.58984126122, 'PROD1TEMP': 126.5129551337264, 'E1FOULING': 0.0005048200776330767, 'E2FOULING': 0.0004688007440293931}
# [INFO] 23:35:04 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000001 < threshold 0.100000
# [INFO] 23:35:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:04 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:35:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:04 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:35:04 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:35:04 - CalibrationWorkflow: Self.model updated to online_v522
# [INFO] 23:35:04 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:35:04 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:35:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:04 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 523 of 529.
# [INFO] 23:35:04 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:05 - CalibrationWorkflow: Obj Treshold reached with 20 iteration, best cost: 1.1988574520542632e-05, values: {'FEED1MASSFLOW': 13019.57825983349, 'FEED1TEMP': 20.36871276302036, 'PROD1MASSFLOW': 33925.59257997732, 'PROD1TEMP': 129.9444298021472, 'E1FOULING': 0.00047340313725574654, 'E2FOULING': 0.0004302627253500432}
# [INFO] 23:35:05 - CalibrationWorkflow: Working point is accurate enough with cost: 0.032295 < threshold 0.100000
# [INFO] 23:35:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:05 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:35:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:05 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:35:05 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:35:05 - CalibrationWorkflow: Self.model updated to online_v523
# [INFO] 23:35:05 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:35:05 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:35:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:05 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 524 of 529.
# [INFO] 23:35:05 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:06 - CalibrationWorkflow: Obj Treshold reached with 9 iteration, best cost: 0.0076631922896534185, values: {'FEED1MASSFLOW': 13234.59913779514, 'FEED1TEMP': 19.9302929315644, 'PROD1MASSFLOW': 33155.28919497795, 'PROD1TEMP': 127.2959656523102, 'E1FOULING': 0.0005097880684449583, 'E2FOULING': 0.0003742711245856448}
# [INFO] 23:35:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.011442 < threshold 0.100000
# [INFO] 23:35:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:06 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:35:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:06 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:35:06 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:35:06 - CalibrationWorkflow: Self.model updated to online_v524
# [INFO] 23:35:06 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:35:06 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:35:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:06 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 525 of 529.
# [INFO] 23:35:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:06 - CalibrationWorkflow: Obj Treshold reached with 5 iteration, best cost: 5.749678844658587e-06, values: {'FEED1MASSFLOW': 12954.7585825279, 'FEED1TEMP': 20.37686487581168, 'PROD1MASSFLOW': 33873.8385065002, 'PROD1TEMP': 127.6779865427403, 'E1FOULING': 0.00039283370286427675, 'E2FOULING': 0.0004458831901649207}
# [INFO] 23:35:06 - CalibrationWorkflow: Working point is accurate enough with cost: 0.035603 < threshold 0.100000
# [INFO] 23:35:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:06 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:35:06 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:06 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:35:06 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:35:06 - CalibrationWorkflow: Self.model updated to online_v525
# [INFO] 23:35:06 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:35:06 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:35:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:07 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 526 of 529.
# [INFO] 23:35:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:07 - CalibrationWorkflow: Obj Treshold reached with 4 iteration, best cost: 5.00700826528584e-06, values: {'FEED1MASSFLOW': 12771.85892666417, 'FEED1TEMP': 20.67833582921827, 'PROD1MASSFLOW': 34390.01928937094, 'PROD1TEMP': 126.5095434339036, 'E1FOULING': 0.0004329066093249462, 'E2FOULING': 0.0004858643691902364}
# [INFO] 23:35:07 - CalibrationWorkflow: Working point is accurate enough with cost: 0.022172 < threshold 0.100000
# [INFO] 23:35:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:07 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:35:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:07 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:35:07 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:35:07 - CalibrationWorkflow: Self.model updated to online_v526
# [INFO] 23:35:07 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:35:07 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:35:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:07 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 527 of 529.
# [INFO] 23:35:07 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:08 - CalibrationWorkflow: Obj Treshold reached with 13 iteration, best cost: 1.4168251024319458e-05, values: {'FEED1MASSFLOW': 13325.12954876125, 'FEED1TEMP': 20.28309263880478, 'PROD1MASSFLOW': 33554.65230857147, 'PROD1TEMP': 127.354641807343, 'E1FOULING': 0.0004504128555972457, 'E2FOULING': 0.0004857589490671025}
# [INFO] 23:35:08 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000009 < threshold 0.100000
# [INFO] 23:35:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:08 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:35:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:08 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:35:08 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:35:08 - CalibrationWorkflow: Self.model updated to online_v527
# [INFO] 23:35:08 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:35:08 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:35:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:08 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 528 of 529.
# [INFO] 23:35:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:08 - CalibrationWorkflow: Obj Treshold reached with 8 iteration, best cost: 1.1318552415823684e-05, values: {'FEED1MASSFLOW': 13512.72411503304, 'FEED1TEMP': 20.31195573184907, 'PROD1MASSFLOW': 34288.72184630365, 'PROD1TEMP': 127.5592676817017, 'E1FOULING': 0.0005137538276738585, 'E2FOULING': 0.0005167948260337331}
# [INFO] 23:35:08 - CalibrationWorkflow: Working point is accurate enough with cost: 0.009298 < threshold 0.100000
# [INFO] 23:35:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:08 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:35:08 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:08 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:35:08 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:35:08 - CalibrationWorkflow: Self.model updated to online_v528
# [INFO] 23:35:08 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:35:08 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:35:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:09 - CalibrationWorkflow: [PRIMARY-CALIBRATION] Processing sample 529 of 529.
# [INFO] 23:35:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:09 - CalibrationWorkflow: Obj Treshold reached with 12 iteration, best cost: 7.3683928617650815e-06, values: {'FEED1MASSFLOW': 13105.83814868971, 'FEED1TEMP': 20.72957378271357, 'PROD1MASSFLOW': 33714.31065376479, 'PROD1TEMP': 126.8299559108337, 'E1FOULING': 0.0005245780102810487, 'E2FOULING': 0.0004297275063399823}
# [INFO] 23:35:09 - CalibrationWorkflow: Working point is accurate enough with cost: 0.000003 < threshold 0.100000
# [INFO] 23:35:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:09 - CalibrationWorkflow: [ONLINELEARNING] Running online learning with sample selection type: always-one.
# [INFO] 23:35:09 - CalibrationWorkflow: ----------------------------------------
# [INFO] 23:35:09 - CalibrationWorkflow: Selected point for online learning: validation
# [INFO] 23:35:09 - CalibrationWorkflow: Retraining model with 1 samples (replay + outliers)
# [INFO] 23:35:09 - CalibrationWorkflow: Self.model updated to online_v529
# [INFO] 23:35:09 - CalibrationWorkflow: Batch of 0 points collected. Retraining model.
# [INFO] 23:35:09 - CalibrationWorkflow: New data point (validation) added for online learning.
# [INFO] 23:35:09 - CalibrationWorkflow: Calibration workflow completed.

# %%
workflow.save_results_df('./Results/OnlineLearning/06_Calibration_Online_FNN-BNN-low_always-one-noreplay.xlsx')
# Out:
# [INFO] 23:35:10 - CalibrationWorkflow: Calibration results saved to ./Results/OnlineLearning/Calibration_result_online_FNN-BNN_always-one-noreplay.xlsx
